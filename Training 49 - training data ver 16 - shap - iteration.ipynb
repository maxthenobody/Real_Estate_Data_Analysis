# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import math
from tqdm import tqdm
import requests
from urllib.parse import urlparse
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
import datetime
from sklearn.preprocessing import quantile_transform
pd.options.mode.chained_assignment = None  # default='warn'
import gc
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
font_path = './NanumFontSetup_TTF_BARUNGOTHIC/NanumBarunGothic.ttf'
import matplotlib.font_manager as fm
fontprop = fm.FontProperties(fname=font_path, size=18)
import seaborn as sns
import shap

# %%
# %%time
# Read Data
basedir = './Training/training_data_ver_16/'
training_data_df = pd.read_csv(basedir + 'training_data_ver_16.csv').drop(columns=['주택가격지수']).dropna()
#training_data_df = training_data_df[(training_data_df['가격면적'] >= 200) & (training_data_df['가격면적'] <= 1500)]
training_data_df.columns = [col.replace(' ','_').replace('·','_') for col in training_data_df.columns]
# Out:
# Wall time: 1min 26s

# %%
training_data_df = training_data_df[(training_data_df['가격면적'] >= 200) & (training_data_df['가격면적'] <= 3000)]

# %%
training_data_df['호수대비부속건축물면적'] = training_data_df['부속건축물면적'] / training_data_df['총호수']

# %%
training_data_df = training_data_df[(training_data_df['호수대비부속건축물면적'] < 100)]

# %%
training_data_df = training_data_df.reset_index(drop=True)

# %%
cols_to_log = ['총건축면적', '총연면적', '총용적률연면적', '토지면적', '부속건축물면적']
for col in cols_to_log:
    training_data_df[col] = training_data_df[col].apply(np.log1p)

# %%
cat_cols_df = pd.read_csv(basedir + 'cat_cols.csv')

# %%
cat_cols_list = [col.replace(' ','_').replace('·','_') for col in cat_cols_df['colname'].tolist()]
len(cat_cols_list)
# Out:
# 296

# %%
cat_cols = [col for col in training_data_df.columns if col in cat_cols_list]
len(cat_cols)
# Out:
# 296

# %%
cat_cols[:10]
# Out:
# ['건물나이',
#  'trade_type',
#  '표준지여부',
#  '지목명',
#  '용도지역명1',
#  '용도지역명2',
#  '토지이동상황',
#  '지형높이',
#  '지형형상',
#  '도로접면']

# %%
training_data_df['토지면적over총연면적times공시지가'] = training_data_df['토지면적'] / training_data_df['총연면적'] * training_data_df['공시지가(만원)']

# %%
shap_summary_df = pd.read_csv(basedir + 'shap_top_36.csv', index_col=[0]).sort_values(['shap_summary_mean'], ascending=False)
print(shap_summary_df.shape)
shap_summary_df.head()
# Out:
# (36, 6)
#                        model_0_shap_summary  model_1_shap_summary  \
# trade_type                        93.883975             96.789440
# 토지면적over총연면적times공시지가             71.798361             75.450018
# year_linear                       66.046958             67.115133
# 건축년도                              50.745131             50.318326
# 전용면적                              37.663049             40.305701
#
#                        model_2_shap_summary  model_3_shap_summary  \
# trade_type                        95.676615             91.307413
# 토지면적over총연면적times공시지가             74.559728             75.656161
# year_linear                       64.616693             62.829061
# 건축년도                              49.530523             51.125563
# 전용면적                              35.925046             37.538836
#
#                        model_4_shap_summary  shap_summary_mean
# trade_type                        95.812986          94.694086
# 토지면적over총연면적times공시지가             74.839162          74.460686
# year_linear                       66.577451          65.437059
# 건축년도                              49.264659          50.196840
# 전용면적                              37.998428          37.886212

# %%
shap_summary_df.tail(50)
# Out:
#                        model_0_shap_summary  model_1_shap_summary  \
# trade_type                        93.883975             96.789440
# 토지면적over총연면적times공시지가             71.798361             75.450018
# year_linear                       66.046958             67.115133
# 건축년도                              50.745131             50.318326
# 전용면적                              37.663049             40.305701
# ynorm                             32.979992             34.373101
# xy                                23.269583             22.479291
# x_2nd                             20.439473             20.525790
# 층mean                             13.221159             12.170351
# 주건축물수                             12.342852             11.590904
# 토지이동상황                             7.815714              9.547900
# 호수대비연면적                            7.667011              9.381337
# 옥내자주식대수                            6.852987              7.843172
# 총건축면적                              7.963527              6.873535
# xnorm                              6.803672              7.311966
# 아파트지구                              7.137952              7.346927
# 호수대비부속건축물면적                        6.739590              6.549272
# 층                                  5.511222              5.853379
# y_2nd                              5.263857              5.696230
# 총호수                                4.989469              5.864352
# 호수대비주차수                            4.648375              4.845299
# 용도지역명1                             3.785091              3.990092
# 층norm                              3.445154              3.347993
# 지구단위계획구역                           3.054804              3.400910
# 부속건축물수                             2.754032              2.659774
# 도로접면                               2.783017              2.847473
# 지형높이                               3.113858              2.565431
# 가축사육제한구역                           2.536646              2.873232
# 옥외자주식대수                            2.747110              2.201661
# 지붕_평지붕_fraction                    2.427655              2.052549
# 층min                               2.365700              2.263140
# 건물나이                               2.270007              2.246607
# 부속건축물면적                            2.274706              2.359438
# month_sin                          2.023663              1.972840
# (한강)폐기물매립시설_설치제한지역                 2.027975              2.202183
# 지형형상                               1.415590              1.590090
#
#                        model_2_shap_summary  model_3_shap_summary  \
# trade_type                        95.676615             91.307413
# 토지면적over총연면적times공시지가             74.559728             75.656161
# year_linear                       64.616693             62.829061
# 건축년도                              49.530523             51.125563
# 전용면적                              35.925046             37.538836
# ynorm                             33.867562             34.391293
# xy                                20.672874             22.702364
# x_2nd                             17.587809             19.614992
# 층mean                             11.587628             13.440068
# 주건축물수                             12.635774             10.983418
# 토지이동상황                             8.360660              8.322591
# 호수대비연면적                            7.698921              8.781902
# 옥내자주식대수                            8.308562              8.213430
# 총건축면적                              7.432328              9.012067
# xnorm                              8.457653              8.170461
# 아파트지구                              8.088494              7.472243
# 호수대비부속건축물면적                        7.349318              5.958950
# 층                                  5.680242              5.743304
# y_2nd                              5.008680              5.611510
# 총호수                                5.007968              5.029198
# 호수대비주차수                            5.227942              4.602111
# 용도지역명1                             4.223215              3.570580
# 층norm                              3.751441              3.359511
# 지구단위계획구역                           2.816960              2.971492
# 부속건축물수                             3.933791              2.947894
# 도로접면                               2.767660              2.650845
# 지형높이                               2.560675              2.356150
# 가축사육제한구역                           2.350622              2.456631
# 옥외자주식대수                            3.012646              2.367191
# 지붕_평지붕_fraction                    2.439802              2.814827
# 층min                               2.403568              2.464968
# 건물나이                               2.117551              1.964327
# 부속건축물면적                            2.412263              1.867810
# month_sin                          2.077300              1.973926
# (한강)폐기물매립시설_설치제한지역                 1.929704              1.924578
# 지형형상                               1.553766              1.634229
#
#                        model_4_shap_summary  shap_summary_mean
# trade_type                        95.812986          94.694086
# 토지면적over총연면적times공시지가             74.839162          74.460686
# year_linear                       66.577451          65.437059
# 건축년도                              49.264659          50.196840
# 전용면적                              37.998428          37.886212
# ynorm                             32.689793          33.660348
# xy                                24.383246          22.701472
# x_2nd                             19.215703          19.476753
# 층mean                             13.378779          12.759597
# 주건축물수                             11.691039          11.848797
# 토지이동상황                             8.899731           8.589319
# 호수대비연면적                            8.494274           8.404689
# 옥내자주식대수                            8.128981           7.869426
# 총건축면적                              7.622812           7.780854
# xnorm                              7.534501           7.655651
# 아파트지구                              7.286672           7.466458
# 호수대비부속건축물면적                        6.839031           6.687232
# 층                                  5.643009           5.686231
# y_2nd                              5.025404           5.321136
# 총호수                                5.361863           5.250570
# 호수대비주차수                            4.832412           4.831228
# 용도지역명1                             4.192283           3.952252
# 층norm                              3.105679           3.401956
# 지구단위계획구역                           3.274841           3.103801
# 부속건축물수                             2.956563           3.050411
# 도로접면                               2.944002           2.798599
# 지형높이                               2.735251           2.666273
# 가축사육제한구역                           2.788056           2.601038
# 옥외자주식대수                            2.489591           2.563640
# 지붕_평지붕_fraction                    2.719419           2.490850
# 층min                               2.243410           2.348157
# 건물나이                               2.464594           2.212617
# 부속건축물면적                            1.944714           2.171786
# month_sin                          2.063541           2.022254
# (한강)폐기물매립시설_설치제한지역                 1.791128           1.975113
# 지형형상                               1.503744           1.539484

# %%
target_cols = ['금액(만원)', '가격면적', 'target_log_transformed', 'targetarea_log_transformed', '지번주소']

# %%
from sklearn.model_selection import KFold, GroupKFold
import lightgbm as lgb
from sklearn.metrics import mean_squared_error

# %%
shap_summary1_df = shap_summary_df.copy()

# %%
for i in range(20):
    gc.collect()
    shortened_df = shap_summary1_df.iloc[:35-i,:]
    training_data_df = training_data_df[shortened_df.index.tolist()+target_cols]
    
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    
    cat_cols = [col for col in cat_cols if col in training_data_df.columns.tolist()]
    
    print(shortened_df.shape)

    oof = np.zeros(training_data_df.shape[0])

    for train_idx, val_idx in kf.split(training_data_df):
        train_data = training_data_df.loc[train_idx]
        val_data = training_data_df.loc[val_idx]

        x_train = train_data.drop(columns=target_cols)
        y_train = train_data['가격면적']

        x_val = val_data.drop(columns=target_cols)
        y_val = val_data['가격면적']

        params = {
            'objective': 'huber',
            'learning_rate': 10,
            'seed': 42,
            'max_depth': 12,
            'num_leaves': 37,
            'lambda_l2': 0,
            'metric': 'huber',
            'num_threads': 6,
        }

        train_dataset = lgb.Dataset(x_train, label=y_train, categorical_feature=cat_cols)
        val_dataset = lgb.Dataset(x_val, label=y_val, categorical_feature=cat_cols)

        num_rounds = 10000

        bst = lgb.train(params, train_dataset, num_rounds, valid_sets=[val_dataset], early_stopping_rounds=500, verbose_eval=1000)

        preds = bst.predict(x_val, num_iteration=bst.best_iteration)
        oof[val_idx] = preds
        
    print(np.sqrt(mean_squared_error(training_data_df['가격면적'], oof)))
# Out:
# (35, 6)
# Using categorical_feature in Dataset.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.130848 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4882
# [LightGBM] [Info] Number of data points in the train set: 2926580, number of used features: 35
# Overriding the parameters from Reference Dataset.
# categorical_column in param dict is overridden.
# [LightGBM] [Info] Start training from score 524.640869
# Training until validation scores don't improve for 500 rounds
# [1000]	valid_0's huber: 41