# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
pd.options.mode.chained_assignment = None  # default='warn'
plt.rcParams['font.family'] = 'Malgun Gothic'
import datetime
import time
tqdm.tqdm.pandas()

# %%
new_df = pd.read_excel('./공공주택찾기/경기도/LH_거래사례_20180101_20220222.xlsx')
new_df = new_df.drop(columns=[
    '일괄계약', '도로명', '시군구', '본번', '부번', '건물연식'
])
print(new_df.shape)
new_df.head()
# Out:
# (7407, 10)
#                    지번주소 건물(단지)명  전용면적(㎡)  거래금액(만원)  층  건축년도       계약날짜  \
# 0  경기도 고양덕양구 성사동 705-18  예그리나4차    42.95     29362  3  2021 2021-11-11
# 1  경기도 고양덕양구 성사동 705-18  예그리나4차    42.95     29362  4  2021 2021-11-11
# 2  경기도 고양덕양구 성사동 705-18  예그리나4차    42.95     28721  2  2021 2021-11-11
# 3  경기도 고양덕양구 성사동 705-18  예그리나4차    48.53     31421  3  2021 2021-11-11
# 4  경기도 고양덕양구 성사동 705-18  예그리나4차    48.53     30715  2  2021 2021-11-11
#
#      단가(만원/㎡)  부동산유형 소유자
# 0  683.632130  연립다세대  LH
# 1  683.632130  연립다세대  LH
# 2  668.707800  연립다세대  LH
# 3  647.455182  연립다세대  LH
# 4  632.907480  연립다세대  LH

# %%
concat_df = new_df.copy().sort_values(['지번주소', '건축년도', '부동산유형', '계약날짜', '전용면적(㎡)', '층']).reset_index(drop=True)
print(concat_df.shape)
concat_df.head()
# Out:
# (7407, 10)
#                    지번주소 건물(단지)명  전용면적(㎡)  거래금액(만원)  층  건축년도       계약날짜  \
# 0  경기도 고양덕양구 성사동 705-18  예그리나4차    42.95     28721  2  2021 2021-11-11
# 1  경기도 고양덕양구 성사동 705-18  예그리나4차    42.95     29362  3  2021 2021-11-11
# 2  경기도 고양덕양구 성사동 705-18  예그리나4차    42.95     29362  4  2021 2021-11-11
# 3  경기도 고양덕양구 성사동 705-18  예그리나4차    48.53     30715  2  2021 2021-11-11
# 4  경기도 고양덕양구 성사동 705-18  예그리나4차    48.53     31421  3  2021 2021-11-11
#
#      단가(만원/㎡)  부동산유형 소유자
# 0  668.707800  연립다세대  LH
# 1  683.632130  연립다세대  LH
# 2  683.632130  연립다세대  LH
# 3  632.907480  연립다세대  LH
# 4  647.455182  연립다세대  LH

# %%
concat_df['계약날짜'] = pd.to_datetime(concat_df['계약날짜'])

# %%
from_2019_df = concat_df.copy()

# %%
from_2019_df['전용면적(㎡)_최소'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '전용면적(㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('min')['전용면적(㎡)']
from_2019_df['전용면적(㎡)_평균'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '전용면적(㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('mean')['전용면적(㎡)']
from_2019_df['전용면적(㎡)_최대'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '전용면적(㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('max')['전용면적(㎡)']
from_2019_df['전용면적(㎡)_합'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '전용면적(㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('sum')['전용면적(㎡)']

# %%
from_2019_df['거래금액(만원)_최소'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '거래금액(만원)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('min')['거래금액(만원)']
from_2019_df['거래금액(만원)_평균'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '거래금액(만원)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('mean')['거래금액(만원)']
from_2019_df['거래금액(만원)_최대'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '거래금액(만원)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('max')['거래금액(만원)']
from_2019_df['거래금액(만원)_합'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '거래금액(만원)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('sum')['거래금액(만원)']

# %%
from_2019_df['층_최대'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '층']].groupby(['지번주소', '건축년도', '부동산유형']).transform('max')['층']

# %%
from_2019_df['단가(만원/㎡)_최소'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '단가(만원/㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('min')['단가(만원/㎡)']
from_2019_df['단가(만원/㎡)_평균'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '단가(만원/㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('mean')['단가(만원/㎡)']
from_2019_df['단가(만원/㎡)_최대'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '단가(만원/㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('max')['단가(만원/㎡)']

# %%
from_2019_df.head()
# Out:
#                    지번주소 건물(단지)명  전용면적(㎡)  거래금액(만원)  층  건축년도       계약날짜  \
# 0  경기도 고양덕양구 성사동 705-18  예그리나4차    42.95     28721  2  2021 2021-11-11
# 1  경기도 고양덕양구 성사동 705-18  예그리나4차    42.95     29362  3  2021 2021-11-11
# 2  경기도 고양덕양구 성사동 705-18  예그리나4차    42.95     29362  4  2021 2021-11-11
# 3  경기도 고양덕양구 성사동 705-18  예그리나4차    48.53     30715  2  2021 2021-11-11
# 4  경기도 고양덕양구 성사동 705-18  예그리나4차    48.53     31421  3  2021 2021-11-11
#
#      단가(만원/㎡)  부동산유형 소유자  전용면적(㎡)_최소  전용면적(㎡)_평균  전용면적(㎡)_최대  전용면적(㎡)_합  \
# 0  668.707800  연립다세대  LH       42.95   52.483333       70.56    1102.15
# 1  683.632130  연립다세대  LH       42.95   52.483333       70.56    1102.15
# 2  683.632130  연립다세대  LH       42.95   52.483333       70.56    1102.15
# 3  632.907480  연립다세대  LH       42.95   52.483333       70.56    1102.15
# 4  647.455182  연립다세대  LH       42.95   52.483333       70.56    1102.15
#
#    거래금액(만원)_최소   거래금액(만원)_평균  거래금액(만원)_최대  거래금액(만원)_합  층_최대  단가(만원/㎡)_최소  \
# 0        28721  32724.190476        37384      687208     5   503.486395
# 1        28721  32724.190476        37384      687208     5   503.486395
# 2        28721  32724.190476        37384      687208     5   503.486395
# 3        28721  32724.190476        37384      687208     5   503.486395
# 4        28721  32724.190476        37384      687208     5   503.486395
#
#    단가(만원/㎡)_평균  단가(만원/㎡)_최대
# 0   628.232657    683.63213
# 1   628.232657    683.63213
# 2   628.232657    683.63213
# 3   628.232657    683.63213
# 4   628.232657    683.63213

# %%
summary_df = from_2019_df.drop(columns=['전용면적(㎡)', '거래금액(만원)', '층', '단가(만원/㎡)']).drop_duplicates()
summary_df['구'] = summary_df['지번주소'].apply(lambda x: x.split(' ')[1])
summary_df['동'] = summary_df['지번주소'].apply(lambda x: x.split(' ')[2])
summary_df = summary_df.sort_values(['구', '동', '계약날짜', '지번주소', '부동산유형']).reset_index(drop=True)
summary_df = summary_df.drop(columns=['구', '동'])
print(summary_df.shape)
summary_df.head()
# Out:
# (433, 18)
#                     지번주소     건물(단지)명  건축년도       계약날짜  부동산유형 소유자  전용면적(㎡)_최소  \
# 0   경기도 고양덕양구 성사동 705-18      예그리나4차  2021 2021-11-11  연립다세대  LH       42.95
# 1  경기도 고양일산동구 식사동 1582-3    (1582-3)  2021 2022-02-08   오피스텔  LH       19.04
# 2     경기도 광명시 소하동 1092-1       소하홈타운  2019 2020-05-27  연립다세대  LH       40.19
# 3     경기도 광명시 소하동 1092-1       소하홈타운  2019 2020-05-27   오피스텔  LH       79.79
# 4  경기도 광주시 곤지암읍 삼리 114-1  소그노팰리스(B동)  2018 2018-07-30  연립다세대  LH       45.09
#
#    전용면적(㎡)_평균  전용면적(㎡)_최대  전용면적(㎡)_합  거래금액(만원)_최소   거래금액(만원)_평균  거래금액(만원)_최대  \
# 0   52.483333       70.56    1102.15        28721  32724.190476        37384
# 1   21.763733       25.55    1632.28        12681  14606.133333        17102
# 2   57.638333       67.02    1383.32        21195  27902.750000        30967
# 3   79.790000       79.79      79.79        28882  28882.000000        28882
# 4   52.291818       57.57     575.21        17150  21172.727273        25600
#
#    거래금액(만원)_합  층_최대  단가(만원/㎡)_최소  단가(만원/㎡)_평균  단가(만원/㎡)_최대
# 0      687208     5   503.486395   628.232657   683.632130
# 1     1095460     8   659.290096   671.265631   676.053215
# 2      669666     5   422.470904   486.248590   527.369993
# 3       28882     1   361.975185   361.975185   361.975185
# 4      232900     4   379.939210   404.996057   451.738133

# %%
concat_df['지번주소'].nunique()
# Out:
# 350

# %%
# %%time
summary_df.to_excel('./공공주택찾기/경기도/LH_거래사례_요약_동별계약날짜순정렬_20180101_20220222.xlsx', index=False)
# Out:
# Wall time: 166 ms
