# %%
import pandas as pd
import os
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
pd.options.mode.chained_assignment = None  # default='warn'
plt.rcParams['font.family'] = 'Malgun Gothic'
font = {'size': 16}
matplotlib.rc('font', **font)

# %%
basedir = './국토교통부_실거래가_공개시스템/땅값분석/'
yunrip_df = pd.read_csv(basedir + 'yunrip_30.csv')
commerce_df = pd.read_csv(basedir + 'commerce_30.csv')
land_df = pd.read_csv(basedir + 'land.csv')

# %%
common_cols = ['시군구', '번지', '용도지역', '도로조건', '계약날짜', '대지면적(㎡)', '거래금액(만원)', '단가(㎡)', '단가(평)', '거래유형', '건물연식']
common_df = pd.concat([yunrip_df[common_cols], commerce_df[common_cols], land_df[[col for col in land_df.columns if col not in ['지목', '지분구분', '해제사유발생일']]]])
common_df['계약날짜'] = pd.to_datetime(common_df['계약날짜'], format='%Y-%m-%d')
print(common_df.shape)
common_df.head()
# Out:
# (168755, 11)
#              시군구      번지       용도지역  도로조건       계약날짜  대지면적(㎡)  거래금액(만원)  \
# 0  서울특별시 강남구 개포동  171-13  제2종일반주거지역  8m미만 2019-10-23     56.1   60000.0
# 1  서울특별시 강남구 개포동  1239-7  제2종일반주거지역  8m미만 2018-06-14     45.0   52000.0
# 2  서울특별시 강남구 개포동  1239-7  제2종일반주거지역  8m미만 2019-03-05     45.0   50000.0
# 3  서울특별시 강남구 개포동  1239-7  제2종일반주거지역  8m미만 2020-06-01     45.0   58000.0
# 4  서울특별시 강남구 개포동  1239-7  제2종일반주거지역  8m미만 2020-06-13     45.0   57000.0
#
#          단가(㎡)        단가(평)    거래유형  건물연식
# 0  1069.518717  3535.598930  연립/다세대  31.0
# 1  1155.555556  3820.018222  연립/다세대  30.0
# 2  1111.111111  3673.094444  연립/다세대  31.0
# 3  1288.888889  4260.789556  연립/다세대  32.0
# 4  1266.666667  4187.327667  연립/다세대  32.0

# %%
dandok_filenames = [f for f in os.listdir('./국토교통부_실거래가_공개시스템/단독다가구매매/') if (f.endswith('.csv'))&('(매매)' in f)]
dandok_filenames
# Out:
# ['단독다가구(매매)_실거래가_20130101_20131231.csv',
#  '단독다가구(매매)_실거래가_20140101_20141231.csv',
#  '단독다가구(매매)_실거래가_20150101_20151231.csv',
#  '단독다가구(매매)_실거래가_20160101_20161231.csv',
#  '단독다가구(매매)_실거래가_20170101_20171231.csv',
#  '단독다가구(매매)_실거래가_20180101_20181231.csv',
#  '단독다가구(매매)_실거래가_20190101_20191231.csv',
#  '단독다가구(매매)_실거래가_20200101_20201231.csv',
#  '단독다가구(매매)_실거래가_20210101_20210405.csv']

# %%
dfs_list = []
for f in dandok_filenames:
    df = pd.read_csv('./국토교통부_실거래가_공개시스템/단독다가구매매/' + f, encoding='euc-kr', header=15)
    if '해제사유발생일' in df.columns:
        df = df.drop(columns=['해제사유발생일'])
    dfs_list.append(df)

# %%
dandok_df = pd.concat(dfs_list).reset_index(drop=True)
print(dandok_df.shape)
dandok_df.head()
# Out:
# (109211, 11)
#              시군구   번지 주택유형  도로조건  연면적(㎡)  대지면적(㎡)    계약년월  계약일 거래금액(만원)  \
# 0  서울특별시 강남구 논현동   8*  다가구  8m미만  329.78    165.4  201305   24  177,500
# 1  서울특별시 강남구 논현동  1**  다가구  8m미만  335.90    171.4  201312   18  173,500
# 2  서울특별시 강남구 논현동   7*  다가구  8m미만  435.32    177.2  201304   23  138,000
# 3  서울특별시 강남구 논현동  1**  다가구  8m미만  347.10    181.9  201308   28  169,000
# 4  서울특별시 강남구 논현동  2**  다가구  8m미만  401.33    193.8  201305   21  179,000
#
#      건축년도      도로명
# 0  1993.0  논현로138길
# 1  1990.0   학동로12길
# 2  1992.0  논현로146길
# 3  1991.0  선릉로135길
# 4  1997.0  논현로124길

# %%
dandok_df['구'] = dandok_df['시군구'].apply(lambda x: x.split(' ')[1])
dandok_df['동'] = dandok_df['시군구'].apply(lambda x: x.split(' ')[2])
dandok_df['거래금액(만원)'] = dandok_df['거래금액(만원)'].apply(lambda x: int(x.replace(',','')))
dandok_df['대지면적(㎡)'] = dandok_df['대지면적(㎡)'].apply(float)
dandok_df['단가(평)'] = dandok_df['거래금액(만원)'] / dandok_df['대지면적(㎡)'] * 3.305785

# %%
def day_modifier(x):
    # x is a number
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x)
        if len(x) == 1:
            return '0' + x
        else:
            return x

# %%
dandok_df['계약날짜'] = dandok_df['계약년월'].apply(lambda x: str(x)[:4]) + '-' +\
dandok_df['계약년월'].apply(lambda x: str(x)[-2:]) + '-' + dandok_df['계약일'].apply(day_modifier)

# %%
dandok_df['계약날짜'] = pd.to_datetime(dandok_df['계약날짜'])

# %%
dandok_df.drop(columns=['계약년월', '계약일'], inplace=True)

# %%
target = '광진구 군자동'
target_purpose = '3종일반'
계약일자시점 = 2018

# %%
target_df = common_df[(common_df['시군구'].str.contains(target))&(common_df['용도지역'].str.contains(target_purpose))&(common_df['계약날짜'].dt.year >= 계약일자시점)].sort_values(['단가(평)'], ascending=False)
print(target_df.shape)
target_df.head()
# Out:
# (24, 11)
#                  시군구     번지       용도지역   도로조건       계약날짜  대지면적(㎡)  거래금액(만원)  \
# 9500   서울특별시 광진구 군자동    3**    제3종일반주거  25m이상 2020-11-27   348.00  350000.0
# 7843   서울특별시 광진구 군자동    1**    제3종일반주거  25m이상 2019-04-19   321.00  300000.0
# 6399   서울특별시 광진구 군자동     9*    제3종일반주거  25m이상 2018-01-12   455.50  399000.0
# 28823  서울특별시 광진구 군자동  343-0  제3종일반주거지역   8m미만 2019-03-07    34.52   29500.0
# 28824  서울특별시 광진구 군자동  343-0  제3종일반주거지역   8m미만 2019-11-20    34.52   29500.0
#
#              단가(㎡)        단가(평)    거래유형  건물연식
# 9500   1005.747126  3324.783764   상업/업무  37.0
# 7843    934.579439  3089.518692   상업/업무  37.0
# 6399    875.960483  2895.737025   상업/업무  38.0
# 28823   854.577057  2825.048016  연립/다세대  33.0
# 28824   854.577057  2825.048016  연립/다세대  33.0

# %%
dandok_target_df = dandok_df[(dandok_df['시군구'].str.contains(target))&(dandok_df['계약날짜'].dt.year >= 계약일자시점)]
print(dandok_target_df.shape)
dandok_target_df.head()
# Out:
# (162, 13)
#                  시군구   번지 주택유형  도로조건  연면적(㎡)  대지면적(㎡)  거래금액(만원)    건축년도  \
# 73491  서울특별시 광진구 군자동  3**  다가구  8m미만  109.20     64.0     80000  1994.0
# 73492  서울특별시 광진구 군자동  3**  다가구  8m미만  118.42     76.0     34500  1990.0
# 73493  서울특별시 광진구 군자동  4**  다가구  8m미만  149.31     89.3     66250  1996.0
# 73494  서울특별시 광진구 군자동  3**  다가구  8m미만  184.30     90.0     62500  1989.0
# 73495  서울특별시 광진구 군자동  3**  다가구  8m미만  137.52    106.0     63300  1988.0
#
#            도로명    구    동        단가(평)       계약날짜
# 73491  광나루로19길  광진구  군자동  4132.231250 2018-10-18
# 73492   군자로11길  광진구  군자동  1500.652401 2018-07-21
# 73493   능동로31길  광진구  군자동  2452.500070 2018-10-18
# 73494  광나루로15길  광진구  군자동  2295.684028 2018-08-31
# 73495  광나루로15길  광진구  군자동  1974.115005 2018-03-03

# %%
dandok_target_df['단가(평)'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
dandok_target_df['단가(평)'].quantile(0.95)
# Out:
# 3889.487747490308

# %%
target_df['단가(평)'].quantile(0.90)
# Out:
# 2874.5303223658184

# %%
#target_df = target_df[target_df['단가(평)'] <= target_df['단가(평)'].quantile(0.9)]
target_df.shape
# Out:
# (24, 11)

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('{}~최신 {} {} 토지, 연립/다세대, 상업/업무용 30년이상 건물 실거래 {}건과 (파랑) 및 단독주택 실거래 {}건의 (주홍) 단가 산포도와 회귀선'.format(계약일자시점, target, target_purpose, target_df.shape[0], dandok_target_df.shape[0]))
plt.grid(True)
ax.xaxis.update_units(target_df['계약날짜'])
sns.regplot(x=ax.xaxis.convert_units(target_df['계약날짜']), y=target_df['단가(평)'])
ax.xaxis.update_units(dandok_target_df['계약날짜'])
sns.regplot(x=ax.xaxis.convert_units(dandok_target_df['계약날짜']), y=dandok_target_df['단가(평)'])
plt.savefig(basedir + '{}{}/산포도.png'.format(target, target_purpose))

# %%
font = {'size': 10}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(10,6))
plt.title('{}~최신 {} {} 토지, 연립/다세대 및 상업/업무용 30년이상 건물 실거래 {}건의 단가 분포도'.format(계약일자시점, target, target_purpose, target_df.shape[0]))
sns.histplot(target_df['단가(평)'])
plt.savefig(basedir + '{}{}/분포도.png'.format(target, target_purpose))
plt.show()
plt.clf()

description = target_df['단가(평)'].describe()
print('거래량:', description['count'])
print('평균:', description['mean'])
print('표준편차:', description['std'])
print('최소:', description['min'])
print('25분위:', description['25%'])
print('중간값:', description['50%'])
print('75분위:', description['75%'])
print('최대:', description['max'])
# Out:
# 거래량: 16.0
# 평균: 1944.1729855746821
# 표준편차: 1122.3557609414306
# 최소: 110.19283333333335
# 25분위: 1406.1505600474743
# 중간값: 1856.2245138888889
# 75분위: 2389.1751004111684
# 최대: 4813.368269230769

# %%
for year in sorted(target_df['계약날짜'].dt.year.unique()):
    year_df = target_df[target_df['계약날짜'].dt.year == year]
    
    f, ax = plt.subplots(figsize=(10,6))
    plt.title('{}년 {} {}주거지역 토지 및 연립/다세대, 상업/업무용 30년이상 건물 실거래 {}건의 단가 분포도'.format(year, target, target_purpose, year_df.shape[0]))
    plt.ylabel('거래량')
    sns.histplot(year_df['단가(평)'])
    plt.savefig(basedir + '{}{}/{}분포도.png'.format(target, target_purpose, year))
    plt.show()
    plt.clf()
    
    description = year_df['단가(평)'].describe()
    print('거래량:', description['count'])
    print('평균:', description['mean'])
    print('표준편차:', description['std'])
    print('최소:', description['min'])
    print('25분위:', description['25%'])
    print('중간값:', description['50%'])
    print('75분위:', description['75%'])
    print('최대:', description['max'])
# Out:
# 거래량: 110.0
# 평균: 1661.9807652524714
# 표준편차: 1437.7390771347605
# 최소: 120.21036363636364
# 25분위: 935.7083746335334
# 중간값: 1361.205588235294
# 75분위: 1933.425044705971
# 최대: 9971.479943324935
# 거래량: 138.0
# 평균: 1937.3374333480049
# 표준편차: 1296.410694472433
# 최소: 102.85578718108276
# 25분위: 1029.8956007233098
# 중간값: 1753.5470573727935
# 75분위: 2721.4752275936385
# 최대: 6484.424423076924
# 거래량: 166.0
# 평균: 2354.423689558845
# 표준편차: 1380.2681105701088
# 최소: 105.81077109602327
# 25분위: 1603.7766107593052
# 중간값: 2121.2409889959135
# 75분위: 2941.3004033353195
# 최대: 10578.512
# 거래량: 32.0
# 평균: 2126.647814618734
# 표준편차: 1010.8098701762747
# 최소: 740.9518103448277
# 25분위: 1565.4839368564317
# 중간값: 1993.4963417351796
# 75분위: 2309.785106124472
# 최대: 6161.371431689219

# %%
target_df = target_df.sort_values(['단가(평)'], ascending=False).reset_index(drop=True)

# %%
target_df.head(20)
# Out:
#               시군구     번지       용도지역   도로조건       계약날짜  대지면적(㎡)  거래금액(만원)  \
# 0   서울특별시 동작구 상도동    1**  제2종일반주거지역   8m미만 2020-12-10     4.50   14400.0
# 1   서울특별시 동작구 상도동    산6*  제2종일반주거지역  12m미만 2018-11-16     3.97   11975.0
# 2   서울특별시 동작구 상도동    산6*  제2종일반주거지역   8m미만 2018-11-16     1.59    4485.0
# 3   서울특별시 동작구 상도동    1**  제2종일반주거지역   8m미만 2020-07-07    15.00   36000.0
# 4   서울특별시 동작구 상도동  221-1  제2종일반주거지역  25m미만 2020-04-17    22.91   46000.0
# 5   서울특별시 동작구 상도동    1**    제2종일반주거   8m미만 2020-08-10    76.00  149435.0
# 6   서울특별시 동작구 상도동    산6*  제2종일반주거지역  12m미만 2019-06-08     2.86    5610.0
# 7   서울특별시 동작구 상도동  221-1  제2종일반주거지역  25m미만 2021-01-06    22.91   42700.0
# 8   서울특별시 동작구 상도동    산6*  제2종일반주거지역  12m미만 2019-06-08    56.69  104550.0
# 9   서울특별시 동작구 상도동    2**  제2종일반주거지역   8m미만 2018-11-29     2.03    3710.0
# 10  서울특별시 동작구 상도동    산6*  제2종일반주거지역   8m미만 2019-06-08     3.46    5950.0
# 11  서울특별시 동작구 상도동    산6*  제2종일반주거지역   8m미만 2019-06-08    22.74   38930.0
# 12  서울특별시 동작구 상도동     2*  제2종일반주거지역   8m미만 2019-06-10     3.00    5000.0
# 13  서울특별시 동작구 상도동    1**  제2종일반주거지역   8m미만 2020-08-13    30.00   50000.0
# 14  서울특별시 동작구 상도동    2**  제2종일반주거지역   8m미만 2019-05-30     4.06    6728.0
# 15  서울특별시 동작구 상도동    산6*  제2종일반주거지역   8m미만 2019-06-08     4.85    7820.0
# 16  서울특별시 동작구 상도동    산6*  제2종일반주거지역   8m미만 2019-06-08     1.81    2890.0
# 17  서울특별시 동작구 상도동    1**  제2종일반주거지역   8m미만 2020-08-13     3.25    5000.0
# 18  서울특별시 동작구 상도동    2**  제2종일반주거지역   8m미만 2018-11-29     2.03    3018.0
# 19  서울특별시 동작구 상도동    산6*  제2종일반주거지역  12m미만 2018-11-29     2.00    2756.0
#
#           단가(㎡)         단가(평)    거래유형  건물연식
# 0   3200.000000  10578.512000      토지   NaN
# 1   3016.372796   9971.479943      토지   NaN
# 2   2820.754717   9324.808632      토지   NaN
# 3   2400.000000   7933.884000      토지   NaN
# 4   2007.856831   6637.542994  연립/다세대  36.0
# 5   1966.250000   6499.999756   상업/업무  54.0
# 6   1961.538462   6484.424423      토지   NaN
# 7   1863.814928   6161.371432  연립/다세대  37.0
# 8   1844.240607   6096.662934      토지   NaN
# 9   1827.586207   6041.607069      토지   NaN
# 10  1719.653179   5684.803685      토지   NaN
# 11  1711.961302   5659.375992      토지   NaN
# 12  1666.666667   5509.641667      토지   NaN
# 13  1666.666667   5509.641667      토지   NaN
# 14  1657.142857   5478.158000      토지   NaN
# 15  1612.371134   5330.152309      토지   NaN
# 16  1596.685083   5278.297597      토지   NaN
# 17  1538.461538   5085.823077      토지   NaN
# 18  1486.699507   4914.708931      토지   NaN
# 19  1378.000000   4555.371730      토지   NaN

# %%
target_df.tail(20)
# Out:
#                시군구   번지       용도지역 도로조건       계약날짜  대지면적(㎡)  거래금액(만원)  \
# 426  서울특별시 동작구 상도동  2**  제2종일반주거지역    - 2018-12-11    99.00    4500.0
# 427  서울특별시 동작구 상도동  2**  제2종일반주거지역    - 2018-09-10    99.04    4500.0
# 428  서울특별시 동작구 상도동  2**  제2종일반주거지역    - 2019-12-01    94.25    4000.0
# 429  서울특별시 동작구 상도동  2**  제2종일반주거지역    - 2019-12-01    43.00    1800.0
# 430  서울특별시 동작구 상도동  2**  제2종일반주거지역    - 2020-03-04    99.20    3850.0
# 431  서울특별시 동작구 상도동  2**  제2종일반주거지역    - 2019-05-10    33.06    1260.0
# 432  서울특별시 동작구 상도동  2**  제2종일반주거지역    - 2019-04-25    32.99    1200.0
# 433  서울특별시 동작구 상도동  3**  제2종일반주거지역    - 2018-02-08     2.75     100.0
# 434  서울특별시 동작구 상도동  2**  제2종일반주거지역    - 2020-09-10    99.04    3600.0
# 435  서울특별시 동작구 상도동  2**  제2종일반주거지역    - 2019-05-10    99.80    3624.0
# 436  서울특별시 동작구 상도동  2**  제2종일반주거지역    - 2019-05-10    65.28    2364.0
# 437  서울특별시 동작구 상도동  2**  제2종일반주거지역    - 2020-09-09   248.35    8700.0
# 438  서울특별시 동작구 상도동  2**  제2종일반주거지역    - 2020-01-03    40.05    1400.0
# 439  서울특별시 동작구 상도동  2**  제2종일반주거지역    - 2019-04-25    66.05    2300.0
# 440  서울특별시 동작구 상도동  2**  제2종일반주거지역    - 2020-09-18    99.66    3400.0
# 441  서울특별시 동작구 상도동  2**  제2종일반주거지역    - 2020-01-03   198.08    6600.0
# 442  서울특별시 동작구 상도동  2**  제2종일반주거지역    - 2019-04-02    99.04    3300.0
# 443  서울특별시 동작구 상도동  2**  제2종일반주거지역    - 2019-04-08    99.04    3300.0
# 444  서울특별시 동작구 상도동  2**  제2종일반주거지역    - 2020-01-03    51.55    1650.0
# 445  서울특별시 동작구 상도동  2**  제2종일반주거지역    - 2019-03-29    96.42    3000.0
#
#          단가(㎡)       단가(평) 거래유형  건물연식
# 426  45.454545  150.262955   토지   NaN
# 427  45.436187  150.202267   토지   NaN
# 428  42.440318  140.298568   토지   NaN
# 429  41.860465  138.381698   토지   NaN
# 430  38.810484  128.299115   토지   NaN
# 431  38.112523  125.991806   토지   NaN
# 432  36.374659  120.246802   토지   NaN
# 433  36.363636  120.210364   토지   NaN
# 434  36.348950  120.161813   토지   NaN
# 435  36.312625  120.041732   토지   NaN
# 436  36.213235  119.713170   토지   NaN
# 437  35.031206  115.805635   토지   NaN
# 438  34.956305  115.558027   토지   NaN
# 439  34.822104  115.114391   토지   NaN
# 440  34.115994  112.780142   토지   NaN
# 441  33.319871  110.148329   토지   NaN
# 442  33.319871  110.148329   토지   NaN
# 443  33.319871  110.148329   토지   NaN
# 444  32.007759  105.810771   토지   NaN
# 445  31.113877  102.855787   토지   NaN

# %%
target_df.to_excel('./국토교통부_실거래가_공개시스템/땅값분석/{}{}/{}_{}_땅값분석.xlsx'.format(target, target_purpose, target, target_purpose), index=False)
