# %%
# 업데이트 내용
# 건물연식과 계약날짜 검색범위 조정할 필요 없이 가장 자주 쓰이는 건물연식, 계약날짜 조합 파일들 전부 생성

# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
pd.options.mode.chained_assignment = None  # default='warn'
plt.rcParams['font.family'] = 'Malgun Gothic'
import datetime

# %%
target_gu = '강남구' # 구 명
target_dong = '논현' # 동 명: 동 명에서 마지막 글자 '동' 뺄 것
#target_purpose = '준주거' # 종 명: 건드릴 필요 없음
target_building_age = 3 # 건물연식: 건드릴 필요 없음
target_period = 36 # 계약날짜 검색범위: 건드릴 필요 없음

# %%
date_today = pd.to_datetime(datetime.datetime.now().strftime('%Y-%m-%d'), format='%Y-%m-%d')

# %%
date_today_record = str(date_today).split(' ')[0].replace('-', '')
date_today_record
# Out:
# '20210820'

# %%
def day_modifier(x):
    # x is a number
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x)
        if len(x) == 1:
            return '0' + x
        else:
            return x

# %%
def landnum_modifier(x):
    # x is a string
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x).replace('외', '').replace(' ','')
        splitted = x.split('-')
        if len(splitted) == 1:
            return x + '-0'
        else:
            return x

# %%
def data_prep(bdtype, tradetype):
    # bdtype is a string: one of 아파트, 연립다세대 or 오피스텔
    # tradetype is a string: one of 매매 or 전월세
    
    basedir = './국토교통부_실거래가_공개시스템/{}/{}/'.format(bdtype, tradetype)
    filenames = [f for f in os.listdir(basedir) if (f.endswith('.csv'))&('(' in f)]
    
    dfs_list = []
    for i, f in tqdm(enumerate(filenames)):
        df = pd.read_csv(basedir + f, encoding='euc-kr', header=15)
        if '해제사유발생일' in df.columns.tolist():
            df = df[df['해제사유발생일'].isna()]
            df = df.drop(columns=['해제사유발생일'])

        dfs_list.append(df)
    
    concat_df = pd.concat(dfs_list).reset_index(drop=True)
        
    concat_df['번지'] = concat_df['번지'].apply(landnum_modifier)
    
    concat_df['계약년월'] = concat_df['계약년월'].apply(str)
    concat_df['계약일'] = concat_df['계약일'].apply(str)
    
    concat_df['계약날짜기준_건물연식'] = concat_df['계약년월'].apply(lambda x: int(x[:4])) - concat_df['건축년도']
    
    concat_df['계약일'] = concat_df['계약일'].apply(day_modifier)
    
    concat_df['계약날짜'] = concat_df['계약년월'].apply(lambda x: x[:4]) + '-' + concat_df['계약년월'].apply(lambda x: x[-2:])\
    + '-' + concat_df['계약일']
    
    concat_df['계약날짜'] = pd.to_datetime(concat_df['계약날짜'], format='%Y-%m-%d')
    
    concat_df['거래금액(만원)'] = concat_df['거래금액(만원)'].apply(lambda x: int(x.replace(',','')))
    concat_df['단가(만원/㎡)'] = concat_df['거래금액(만원)'] / concat_df['전용면적(㎡)']
    
    concat_df['지번주소'] = concat_df['시군구'] + ' ' + concat_df['번지']
        
    cols_to_drop = ['시군구', '번지', '본번', '부번', '지번주소', '계약년월', '계약일', '도로명']
        
    concat_df = concat_df[['지번주소', '도로명'] + [col for col in concat_df.columns if col not in cols_to_drop]]
    
    date_today = pd.to_datetime(datetime.datetime.now().strftime('%Y-%m-%d'), format='%Y-%m-%d')
    concat_df['건물연식'] = date_today.year - concat_df['건축년도']
    
    concat_df = concat_df.dropna(subset=['지번주소'])
    
    if '건물명' in concat_df.columns:
        concat_df.rename(columns={'건물명':'건물(단지)명'}, inplace=True)
    elif '단지명' in concat_df.columns:
        concat_df.rename(columns={'단지명':'건물(단지)명'}, inplace=True)
    
    concat_df = concat_df[concat_df['층'] >= 0].reset_index(drop=True)
    
    return concat_df

# %%
apart_df = data_prep('아파트', '매매')
apart_df['부동산유형'] = '아파트'
print(apart_df.shape)
apart_df.head()
# Out:
# 16it [00:02,  7.84it/s]
# (1207813, 12)
#                   지번주소      도로명         건물(단지)명  전용면적(㎡)  거래금액(만원)  층  건축년도  \
# 0  서울특별시 강남구 개포동 655-2  언주로 103  개포2차현대아파트(220)    77.75     59500  7  1988
# 1  서울특별시 강남구 개포동 655-2  언주로 103  개포2차현대아파트(220)    77.75     60000  6  1988
# 2  서울특별시 강남구 개포동 655-2  언주로 103  개포2차현대아파트(220)    77.75     67000  9  1988
# 3  서울특별시 강남구 개포동 655-2  언주로 103  개포2차현대아파트(220)    77.75     60000  4  1988
# 4  서울특별시 강남구 개포동 655-2  언주로 103  개포2차현대아파트(220)    77.75     72250  5  1988
#
#    계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식 부동산유형
# 0           18 2006-03-10  765.273312    33   아파트
# 1           18 2006-03-29  771.704180    33   아파트
# 2           18 2006-04-29  861.736334    33   아파트
# 3           18 2006-06-01  771.704180    33   아파트
# 4           18 2006-10-20  929.260450    33   아파트

# %%
yunrip_df = data_prep('연립다세대', '매매')
yunrip_df['부동산유형'] = '연립다세대'
print(yunrip_df.shape)
yunrip_df.head()
# Out:
# 16it [00:01,  9.98it/s]
# (648562, 13)
#                    지번주소         도로명   건물(단지)명  전용면적(㎡)  대지권면적(㎡)  거래금액(만원)  층  \
# 0  서울특별시 강남구 개포동 171-13   선릉로14길 11  (171-13)    68.08     56.10     56500  2
# 1  서울특별시 강남구 개포동 1239-7   개포로15길 25   강남빌라 가동    52.59     45.00     40500  2
# 2  서울특별시 강남구 개포동 1239-7   개포로15길 25   강남빌라 가동    52.59     45.00     42000  1
# 3  서울특별시 강남구 개포동 1239-6   개포로15길 27   강남빌라 나동    52.75     44.68     22000  2
# 4  서울특별시 강남구 개포동 1175-2  논현로6길 36-8      강남파크    49.43     23.70     17000  4
#
#      건축년도  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형
# 0  1988.0         18.0 2006-12-20  829.905993  33.0  연립다세대
# 1  1988.0         18.0 2006-12-09  770.108386  33.0  연립다세대
# 2  1988.0         18.0 2006-12-19  798.630918  33.0  연립다세대
# 3  1988.0         18.0 2006-11-02  417.061611  33.0  연립다세대
# 4  1993.0         13.0 2006-07-19  343.920696  28.0  연립다세대

# %%
officetel_df = data_prep('오피스텔', '매매')
officetel_df['부동산유형'] = '오피스텔'
print(officetel_df.shape)
officetel_df.head()
# Out:
# 16it [00:00, 40.91it/s]
# (184505, 12)
#                  지번주소      도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)   층    건축년도  \
# 0  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44      6400   8  1997.0
# 1  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44      7100   7  1997.0
# 2  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44      7300  11  1997.0
# 3  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    31.91      7500  10  1997.0
# 4  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44      7400  15  1997.0
#
#    계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식 부동산유형
# 0          9.0 2006-01-10  197.287300  24.0  오피스텔
# 1          9.0 2006-01-10  218.865598  24.0  오피스텔
# 2          9.0 2006-01-11  225.030826  24.0  오피스텔
# 3          9.0 2006-01-18  235.036039  24.0  오피스텔
# 4          9.0 2006-01-19  228.113440  24.0  오피스텔

# %%
yunrip_df = yunrip_df.drop(columns=['대지권면적(㎡)'])
house_df = pd.concat([apart_df, yunrip_df, officetel_df]).sort_values(['지번주소', '건축년도', '전용면적(㎡)', '계약날짜']).reset_index(drop=True)
print(house_df.shape)
house_df.head()
# Out:
# (2040880, 12)
#                     지번주소       도로명      건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 0   서울특별시 강남구 개포동 1164-0   논현로2길 6         골드캐슬    58.05     57500  2  2017.0
# 1   서울특별시 강남구 개포동 1164-0   논현로2길 6         골드캐슬    58.05     57000  1  2017.0
# 2   서울특별시 강남구 개포동 1164-0   논현로2길 6         골드캐슬    58.05     63000  2  2017.0
# 3  서울특별시 강남구 개포동 1164-12  논현로2길 34  새롬(1164-12)    71.72     64500  7  2000.0
# 4  서울특별시 강남구 개포동 1164-12  논현로2길 34  새롬(1164-12)    73.50     29800  4  2000.0
#
#    계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형
# 0          1.0 2018-01-20   990.525409   4.0  연립다세대
# 1          1.0 2018-06-01   981.912145   4.0  연립다세대
# 2          2.0 2019-01-19  1085.271318   4.0  연립다세대
# 3         17.0 2017-09-23   899.330731  21.0    아파트
# 4          6.0 2006-10-18   405.442177  21.0    아파트

# %%
'''land_specs_df = pd.read_csv('./prepped_data/land_specs_ver_4.csv')
print(land_specs_df.shape)
land_specs_df.head()'''
# Out:
# "land_specs_df = pd.read_csv('./prepped_data/land_specs_ver_4.csv')\nprint(land_specs_df.shape)\nland_specs_df.head()"

# %%
'''last_df = land_specs_df.drop_duplicates(subset=['지번주소'], keep='last').drop(columns=['년', '공시지가']).reset_index(drop=True)
print(last_df.shape)
last_df.head()'''
# Out:
# "last_df = land_specs_df.drop_duplicates(subset=['지번주소'], keep='last').drop(columns=['년', '공시지가']).reset_index(drop=True)\nprint(last_df.shape)\nlast_df.head()"

# %%
'''house_merge_df = house_df.merge(last_df, on=['지번주소']).reset_index(drop=True)
print(house_merge_df.shape)'''
# Out:
# "house_merge_df = house_df.merge(last_df, on=['지번주소']).reset_index(drop=True)\nprint(house_merge_df.shape)"

# %%
house_df['구'] = house_df['지번주소'].apply(lambda x: x.split(' ')[1])
house_df['동'] = house_df['지번주소'].apply(lambda x: x.split(' ')[2])
#house_merge_df['구'] = house_merge_df['지번주소'].apply(lambda x: x.split(' ')[1])
#house_merge_df['동'] = house_merge_df['지번주소'].apply(lambda x: x.split(' ')[2])

# %%
house_df['일괄계약'] = 'N'

# %%
#house_df = house_df.merge(last_df, on=['지번주소']).reset_index(drop=True)

# %%
'''print(house_df.shape)
house_df.head()'''
# Out:
# 'print(house_df.shape)\nhouse_df.head()'

# %%
def identify_bulk_contract(df):
    df = df.copy()
    
    for addr in tqdm(df['지번주소'].unique()):
        addr_df = df[df['지번주소'] == addr]
        
        for btyear in addr_df['건축년도'].unique():
            btyear_df = addr_df[addr_df['건축년도'] == btyear]
        
            for contract_date in btyear_df['계약날짜'].unique():
                contract_date_df = btyear_df[btyear_df['계약날짜'] == contract_date]

                if contract_date_df.shape[0] >= 5:
                    df.loc[contract_date_df.index, '일괄계약'] = 'Y'
    
    return df

# %%
target_1_12_df = house_df[
    (house_df['지번주소'].str.contains(target_gu + ' ' + target_dong))
    #&(house_df['동'] == target_dong)
    &(house_df['계약날짜'] >= (date_today - pd.DateOffset(months=12)))
    &(house_df['건물연식'] <= 1)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_1_12_df.shape)
target_1_12_df.head()
# Out:
# (35, 15)
#                        지번주소            도로명          건물(단지)명  전용면적(㎡)  \
# 19120  서울특별시 강남구 논현동 158-15  강남대로122길 61-1  NONHYEON VARAUM    19.28
# 19121  서울특별시 강남구 논현동 158-15  강남대로122길 61-1  NONHYEON VARAUM    19.28
# 19122  서울특별시 강남구 논현동 158-15  강남대로122길 61-1  NONHYEON VARAUM    19.55
# 19123  서울특별시 강남구 논현동 158-15  강남대로122길 61-1  NONHYEON VARAUM    19.55
# 19124  서울특별시 강남구 논현동 158-15  강남대로122길 61-1  NONHYEON VARAUM    19.55
#
#        거래금액(만원)  층    건축년도  계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형  \
# 19120     44500  4  2020.0          1.0 2021-05-13  2308.091286   1.0  연립다세대
# 19121     44100  3  2020.0          1.0 2021-06-29  2287.344398   1.0  연립다세대
# 19122     43900  2  2020.0          1.0 2021-05-21  2245.524297   1.0  연립다세대
# 19123     44500  4  2020.0          1.0 2021-06-04  2276.214834   1.0  연립다세대
# 19124     44200  3  2020.0          1.0 2021-06-22  2260.869565   1.0  연립다세대
#
#          구    동 일괄계약
# 19120  강남구  논현동    N
# 19121  강남구  논현동    N
# 19122  강남구  논현동    N
# 19123  강남구  논현동    N
# 19124  강남구  논현동    N

# %%
target_2_24_df = house_df[
    (house_df['지번주소'].str.contains(target_gu + ' ' + target_dong))
    #&(house_df['동'] == target_dong)
    &(house_df['계약날짜'] >= (date_today - pd.DateOffset(months=24)))
    &(house_df['건물연식'] <= 2)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_2_24_df.shape)
target_2_24_df.head()
# Out:
# (59, 15)
#                        지번주소            도로명          건물(단지)명  전용면적(㎡)  \
# 18696  서울특별시 강남구 논현동 149-11    학동로18길 32-8             모두가S    22.58
# 19095  서울특별시 강남구 논현동 156-22      학동로26길 64         MODUGA L    19.85
# 19096  서울특별시 강남구 논현동 156-22      학동로26길 64         MODUGA L    23.52
# 19120  서울특별시 강남구 논현동 158-15  강남대로122길 61-1  NONHYEON VARAUM    19.28
# 19121  서울특별시 강남구 논현동 158-15  강남대로122길 61-1  NONHYEON VARAUM    19.28
#
#        거래금액(만원)  층    건축년도  계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형  \
# 18696     25500  6  2019.0          1.0 2020-01-04  1129.317981   2.0  연립다세대
# 19095     31800  5  2019.0          1.0 2020-06-29  1602.015113   2.0  연립다세대
# 19096     33500  2  2019.0          1.0 2020-05-01  1424.319728   2.0  연립다세대
# 19120     44500  4  2020.0          1.0 2021-05-13  2308.091286   1.0  연립다세대
# 19121     44100  3  2020.0          1.0 2021-06-29  2287.344398   1.0  연립다세대
#
#          구    동 일괄계약
# 18696  강남구  논현동    N
# 19095  강남구  논현동    N
# 19096  강남구  논현동    N
# 19120  강남구  논현동    N
# 19121  강남구  논현동    N

# %%
target_3_36_df = house_df[
    (house_df['지번주소'].str.contains(target_gu + ' ' + target_dong))
    #&(house_df['동'] == target_dong)
    &(house_df['계약날짜'] >= (date_today - pd.DateOffset(months=36)))
    &(house_df['건물연식'] <= 3)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_3_36_df.shape)
target_3_36_df.head()
# Out:
# (85, 15)
#                        지번주소          도로명   건물(단지)명  전용면적(㎡)  거래금액(만원)  층  \
# 17971  서울특별시 강남구 논현동 107-50  학동로41길 32-7  (107-50)    23.82     29000  4
# 17972  서울특별시 강남구 논현동 107-50  학동로41길 32-7  (107-50)    26.62     32000  3
# 18090   서울특별시 강남구 논현동 118-8   학동로53길 3-8    더원 센트럴    37.56     38200  4
# 18696  서울특별시 강남구 논현동 149-11  학동로18길 32-8      모두가S    22.58     25500  6
# 19035   서울특별시 강남구 논현동 154-2    학동로26길 39     154-2    28.07     35000  3
#
#          건축년도  계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형    구    동 일괄계약
# 17971  2018.0          0.0 2018-10-18  1217.464316   3.0  연립다세대  강남구  논현동    N
# 17972  2018.0          3.0 2021-08-05  1202.103681   3.0  연립다세대  강남구  논현동    N
# 18090  2018.0          3.0 2021-01-15  1017.039404   3.0   오피스텔  강남구  논현동    N
# 18696  2019.0          1.0 2020-01-04  1129.317981   2.0  연립다세대  강남구  논현동    N
# 19035  2018.0          2.0 2020-07-25  1246.882793   3.0  연립다세대  강남구  논현동    N

# %%
target_5_60_df = house_df[
    (house_df['지번주소'].str.contains(target_gu + ' ' + target_dong))
    #&(house_df['동'] == target_dong)
    &(house_df['계약날짜'] >= (date_today - pd.DateOffset(months=60)))
    &(house_df['건물연식'] <= 5)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_5_60_df.shape)
target_5_60_df.head()
# Out:
# (249, 15)
#                       지번주소            도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층  \
# 17411  서울특별시 강남구 논현동 104-5  도산대로54길 48-11   동광팰리스    21.82     32800  5
# 17412  서울특별시 강남구 논현동 104-5  도산대로54길 48-11   동광팰리스    21.82     36800  5
# 17413  서울특별시 강남구 논현동 104-5  도산대로54길 48-11   동광팰리스    23.15     34800  3
# 17414  서울특별시 강남구 논현동 104-5  도산대로54길 48-11   동광팰리스    23.15     36500  5
# 17415  서울특별시 강남구 논현동 104-5  도산대로54길 48-11   동광팰리스    23.59     33500  5
#
#          건축년도  계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형    구    동 일괄계약
# 17411  2016.0          2.0 2018-09-03  1503.208066   5.0  연립다세대  강남구  논현동    N
# 17412  2016.0          4.0 2020-10-22  1686.526123   5.0  연립다세대  강남구  논현동    N
# 17413  2016.0          2.0 2018-03-16  1503.239741   5.0  연립다세대  강남구  논현동    N
# 17414  2016.0          5.0 2021-01-25  1576.673866   5.0  연립다세대  강남구  논현동    N
# 17415  2016.0          1.0 2017-12-28  1420.093260   5.0  연립다세대  강남구  논현동    N

# %%
target_1_12_df = identify_bulk_contract(target_1_12_df)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 363.56it/s]

# %%
target_2_24_df = identify_bulk_contract(target_2_24_df)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 519.86it/s]

# %%
target_3_36_df = identify_bulk_contract(target_3_36_df)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 21/21 [00:00<00:00, 583.19it/s]

# %%
target_5_60_df = identify_bulk_contract(target_5_60_df)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 524.27it/s]

# %%
sales_idx_basedir = './한국부동산원/실거래가격지수/'
filenames = [f for f in os.listdir(sales_idx_basedir) if '연립다세대' in f]

sales_idx_df = pd.read_excel(sales_idx_basedir + filenames[0], header=[10, 11])

sales_idx_cols_list = []
for i in range(sales_idx_df.shape[1]):
    if i == 0:
        sales_idx_cols_list.append(sales_idx_df.columns[i][0])
    else:
        sales_idx_cols_list.append(sales_idx_df.columns[i][0] + '_' + sales_idx_df.columns[i][1])

sales_idx_df.columns = sales_idx_cols_list

# %%
def get_sales_idx(x):
    # x is a pandas timestamp
    
    df = sales_idx_df.copy()
    
    if pd.isna(x) == True:
        return x
    else:
        year = str(x.year)
        month = str(x.month)
        if len(month) == 1:
            month = '0'+month
        
        idx = df[year+'년 '+month+'월_지수'].iloc[0]
        
        return idx

# %%
def get_index_applied_prices(df):
    df = df.copy()
    
    last_idx = sales_idx_df.iloc[0,-2]
    
    last_date = sales_idx_df.columns[-1].split('_')[0]
    
    last_date = last_date.split(' ')[0].replace('년','') + '-' + last_date.split(' ')[1].replace('월','') + '-01'
    
    target_upper_limit_df = df[df['계약날짜'] < pd.to_datetime(last_date)]
    target_upper_limit_df['계약날짜_실거래지수'] = target_upper_limit_df['계약날짜'].apply(get_sales_idx)
    target_upper_limit_df['지수적용단가'] = target_upper_limit_df['단가(만원/㎡)'] / target_upper_limit_df['계약날짜_실거래지수'] * last_idx
    df['지수적용단가'] = df['단가(만원/㎡)']
    df.loc[target_upper_limit_df.index, '지수적용단가'] = target_upper_limit_df['지수적용단가']
    df['지수적용날짜'] = df['계약날짜']
    df.loc[target_upper_limit_df.index, '지수적용날짜'] = pd.to_datetime(last_date[:-2] + '01')
    
    return df

# %%
target_1_12_df = get_index_applied_prices(target_1_12_df)
print(target_1_12_df.shape)
target_1_12_df.head()
# Out:
# (35, 17)
#                        지번주소            도로명          건물(단지)명  전용면적(㎡)  \
# 19120  서울특별시 강남구 논현동 158-15  강남대로122길 61-1  NONHYEON VARAUM    19.28
# 19121  서울특별시 강남구 논현동 158-15  강남대로122길 61-1  NONHYEON VARAUM    19.28
# 19122  서울특별시 강남구 논현동 158-15  강남대로122길 61-1  NONHYEON VARAUM    19.55
# 19123  서울특별시 강남구 논현동 158-15  강남대로122길 61-1  NONHYEON VARAUM    19.55
# 19124  서울특별시 강남구 논현동 158-15  강남대로122길 61-1  NONHYEON VARAUM    19.55
#
#        거래금액(만원)  층    건축년도  계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형  \
# 19120     44500  4  2020.0          1.0 2021-05-13  2308.091286   1.0  연립다세대
# 19121     44100  3  2020.0          1.0 2021-06-29  2287.344398   1.0  연립다세대
# 19122     43900  2  2020.0          1.0 2021-05-21  2245.524297   1.0  연립다세대
# 19123     44500  4  2020.0          1.0 2021-06-04  2276.214834   1.0  연립다세대
# 19124     44200  3  2020.0          1.0 2021-06-22  2260.869565   1.0  연립다세대
#
#          구    동 일괄계약       지수적용단가     지수적용날짜
# 19120  강남구  논현동    N  2308.091286 2021-05-13
# 19121  강남구  논현동    N  2287.344398 2021-06-29
# 19122  강남구  논현동    N  2245.524297 2021-05-21
# 19123  강남구  논현동    N  2276.214834 2021-06-04
# 19124  강남구  논현동    N  2260.869565 2021-06-22

# %%
target_2_24_df = get_index_applied_prices(target_2_24_df)
print(target_2_24_df.shape)
target_2_24_df.head()
# Out:
# (59, 17)
#                        지번주소            도로명          건물(단지)명  전용면적(㎡)  \
# 18696  서울특별시 강남구 논현동 149-11    학동로18길 32-8             모두가S    22.58
# 19095  서울특별시 강남구 논현동 156-22      학동로26길 64         MODUGA L    19.85
# 19096  서울특별시 강남구 논현동 156-22      학동로26길 64         MODUGA L    23.52
# 19120  서울특별시 강남구 논현동 158-15  강남대로122길 61-1  NONHYEON VARAUM    19.28
# 19121  서울특별시 강남구 논현동 158-15  강남대로122길 61-1  NONHYEON VARAUM    19.28
#
#        거래금액(만원)  층    건축년도  계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형  \
# 18696     25500  6  2019.0          1.0 2020-01-04  1129.317981   2.0  연립다세대
# 19095     31800  5  2019.0          1.0 2020-06-29  1602.015113   2.0  연립다세대
# 19096     33500  2  2019.0          1.0 2020-05-01  1424.319728   2.0  연립다세대
# 19120     44500  4  2020.0          1.0 2021-05-13  2308.091286   1.0  연립다세대
# 19121     44100  3  2020.0          1.0 2021-06-29  2287.344398   1.0  연립다세대
#
#          구    동 일괄계약       지수적용단가     지수적용날짜
# 18696  강남구  논현동    N  1324.539611 2021-05-01
# 19095  강남구  논현동    N  1794.096371 2021-05-01
# 19096  강남구  논현동    N  1637.066670 2021-05-01
# 19120  강남구  논현동    N  2308.091286 2021-05-13
# 19121  강남구  논현동    N  2287.344398 2021-06-29

# %%
target_3_36_df = get_index_applied_prices(target_3_36_df)
print(target_3_36_df.shape)
target_3_36_df.head()
# Out:
# (85, 17)
#                        지번주소          도로명   건물(단지)명  전용면적(㎡)  거래금액(만원)  층  \
# 17971  서울특별시 강남구 논현동 107-50  학동로41길 32-7  (107-50)    23.82     29000  4
# 17972  서울특별시 강남구 논현동 107-50  학동로41길 32-7  (107-50)    26.62     32000  3
# 18090   서울특별시 강남구 논현동 118-8   학동로53길 3-8    더원 센트럴    37.56     38200  4
# 18696  서울특별시 강남구 논현동 149-11  학동로18길 32-8      모두가S    22.58     25500  6
# 19035   서울특별시 강남구 논현동 154-2    학동로26길 39     154-2    28.07     35000  3
#
#          건축년도  계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형    구    동  \
# 17971  2018.0          0.0 2018-10-18  1217.464316   3.0  연립다세대  강남구  논현동
# 17972  2018.0          3.0 2021-08-05  1202.103681   3.0  연립다세대  강남구  논현동
# 18090  2018.0          3.0 2021-01-15  1017.039404   3.0   오피스텔  강남구  논현동
# 18696  2019.0          1.0 2020-01-04  1129.317981   2.0  연립다세대  강남구  논현동
# 19035  2018.0          2.0 2020-07-25  1246.882793   3.0  연립다세대  강남구  논현동
#
#       일괄계약       지수적용단가     지수적용날짜
# 17971    N  1481.960289 2021-05-01
# 17972    N  1202.103681 2021-08-05
# 18090    N  1060.032616 2021-05-01
# 18696    N  1324.539611 2021-05-01
# 19035    N  1379.142385 2021-05-01

# %%
target_5_60_df = get_index_applied_prices(target_5_60_df)
print(target_5_60_df.shape)
target_5_60_df.head()
# Out:
# (249, 17)
#                       지번주소            도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층  \
# 17411  서울특별시 강남구 논현동 104-5  도산대로54길 48-11   동광팰리스    21.82     32800  5
# 17412  서울특별시 강남구 논현동 104-5  도산대로54길 48-11   동광팰리스    21.82     36800  5
# 17413  서울특별시 강남구 논현동 104-5  도산대로54길 48-11   동광팰리스    23.15     34800  3
# 17414  서울특별시 강남구 논현동 104-5  도산대로54길 48-11   동광팰리스    23.15     36500  5
# 17415  서울특별시 강남구 논현동 104-5  도산대로54길 48-11   동광팰리스    23.59     33500  5
#
#          건축년도  계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형    구    동  \
# 17411  2016.0          2.0 2018-09-03  1503.208066   5.0  연립다세대  강남구  논현동
# 17412  2016.0          4.0 2020-10-22  1686.526123   5.0  연립다세대  강남구  논현동
# 17413  2016.0          2.0 2018-03-16  1503.239741   5.0  연립다세대  강남구  논현동
# 17414  2016.0          5.0 2021-01-25  1576.673866   5.0  연립다세대  강남구  논현동
# 17415  2016.0          1.0 2017-12-28  1420.093260   5.0  연립다세대  강남구  논현동
#
#       일괄계약       지수적용단가     지수적용날짜
# 17411    N  1819.339676 2021-05-01
# 17412    N  1831.274913 2021-05-01
# 17413    N  1902.313590 2021-05-01
# 17414    N  1643.324455 2021-05-01
# 17415    N  1833.282507 2021-05-01

# %%
target_1_12_df = target_1_12_df.sort_values(['지번주소', '건축년도', '부동산유형', '계약날짜', '전용면적(㎡)']).reset_index(drop=True)
target_1_12_df1 = target_1_12_df[['지번주소', '건물(단지)명', '건물연식', '층', '전용면적(㎡)', '계약날짜', '거래금액(만원)', '단가(만원/㎡)', '지수적용날짜', '지수적용단가', '부동산유형', '일괄계약']]
target_1_12_df1.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/실거래가_건물연식1년_최근12개월.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
target_2_24_df = target_2_24_df.sort_values(['지번주소', '건축년도', '부동산유형', '계약날짜', '전용면적(㎡)']).reset_index(drop=True)
target_2_24_df1 = target_2_24_df[['지번주소', '건물(단지)명', '건물연식', '층', '전용면적(㎡)', '계약날짜', '거래금액(만원)', '단가(만원/㎡)', '지수적용날짜', '지수적용단가', '부동산유형', '일괄계약']]
target_2_24_df1.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/실거래가_건물연식2년_최근24개월.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
target_3_36_df = target_3_36_df.sort_values(['지번주소', '건축년도', '부동산유형', '계약날짜', '전용면적(㎡)']).reset_index(drop=True)
target_3_36_df1 = target_3_36_df[['지번주소', '건물(단지)명', '건물연식', '층', '전용면적(㎡)', '계약날짜', '거래금액(만원)', '단가(만원/㎡)', '지수적용날짜', '지수적용단가', '부동산유형', '일괄계약']]
target_3_36_df1.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/실거래가_건물연식3년_최근36개월.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
target_5_60_df = target_5_60_df.sort_values(['지번주소', '건축년도', '부동산유형', '계약날짜', '전용면적(㎡)']).reset_index(drop=True)
target_5_60_df1 = target_5_60_df[['지번주소', '건물(단지)명', '건물연식', '층', '전용면적(㎡)', '계약날짜', '거래금액(만원)', '단가(만원/㎡)', '지수적용날짜', '지수적용단가', '부동산유형', '일괄계약']]
target_5_60_df1.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/실거래가_건물연식5년_최근60개월.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
target_df = target_3_36_df.copy()

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('최근 {}개월 {} {} 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 {}건의 전용면적 단가'.format(target_period, target_gu, target_dong, target_building_age, target_df.shape[0]))
plt.grid(True)
ax.xaxis.update_units(target_df['계약날짜'])
sns.regplot(x=ax.xaxis.convert_units(target_df['계약날짜']), y=target_df['단가(만원/㎡)'])
plt.savefig('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/산포도.png'.format(target_gu, target_dong, date_today_record))

# %%
target_last_df = target_df.drop_duplicates(subset=['지번주소', '건축년도'], keep='last').reset_index(drop=True)

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('최근 {}개월 {} {} 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 {}건의 전용면적 단가'.format(target_period, target_gu, target_dong, target_building_age, target_last_df.shape[0]))
plt.grid(True)
ax.xaxis.update_units(target_last_df['계약날짜'])
sns.regplot(x=ax.xaxis.convert_units(target_last_df['계약날짜']), y=target_last_df['단가(만원/㎡)'])
plt.savefig('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/마지막_산포도.png'.format(target_gu, target_dong, date_today_record))

# %%
target_last_df.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/마지막_실거래가.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
target_df2 = house_df[
    (house_df['지번주소'].str.contains(target_gu + ' ' + target_dong))
    #&(house_df['동'] == target_dong)
    #&(house_merge_df['계약날짜'] >= (date_today - pd.DateOffset(months=target_period)))
    &(house_df['계약날짜기준_건물연식'] <= target_building_age)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_df2.shape)
target_df2.head()
# Out:
# (1236, 15)
#                        지번주소         도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 17361  서울특별시 강남구 논현동 104-21  선릉로137길 22   노블레스빌    47.08     37000  5  2012.0
# 17364  서울특별시 강남구 논현동 104-21  선릉로137길 22   노블레스빌    59.43     47500  4  2012.0
# 17367  서울특별시 강남구 논현동 104-23  선릉로137길 20    케이씨빌   113.77     42000  1  2004.0
# 17368  서울특별시 강남구 논현동 104-23  선릉로137길 20    케이씨빌   113.77     50000  2  2004.0
# 17369  서울특별시 강남구 논현동 104-23  선릉로137길 20    케이씨빌   113.77     45000  4  2004.0
#
#        계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형    구    동 일괄계약
# 17361          2.0 2014-12-26  785.896347   9.0  연립다세대  강남구  논현동    N
# 17364          1.0 2013-02-25  799.259633   9.0  연립다세대  강남구  논현동    N
# 17367          3.0 2007-01-08  369.165861  17.0    아파트  강남구  논현동    N
# 17368          3.0 2007-02-02  439.483168  17.0    아파트  강남구  논현동    N
# 17369          3.0 2007-03-03  395.534851  17.0    아파트  강남구  논현동    N

# %%
target_df2 = get_index_applied_prices(target_df2)

# %%
font = {'size': 12}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(12,6))
plt.title('{} {} 계약날짜기준 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 {}건의 전용면적 단가'.format(target_gu, target_dong, target_building_age, target_df2.shape[0]))
plt.grid(True)
sns.histplot(target_df2['단가(만원/㎡)'], kde=True)
# Out:
# <AxesSubplot:title={'center':'강남구 논현 계약날짜기준 건물연식 3년이하 연립다세대 및 오피스텔 매매 실거래 1236건의 전용면적 단가'}, xlabel='단가(만원/㎡)', ylabel='Count'>

# %%
target_df3 = target_df2[['지번주소', '건물(단지)명', '건축년도', '층', '전용면적(㎡)', '계약날짜', '단가(만원/㎡)', '지수적용날짜', '지수적용단가', '부동산유형']]
target_df3 = target_df3.sort_values(['지번주소', '건축년도', '계약날짜']).reset_index(drop=True)
target_df3.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/전체_실거래가.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
target_df3_30 = target_df3[
    (target_df3['전용면적(㎡)'] >= 28)
    &(target_df3['전용면적(㎡)'] <= 32)
]

# %%
target_df3_30.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/전체_실거래가_30.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
concat_df = pd.concat([target_df2])

# %%
concat_df = concat_df.sort_values(['지번주소', '건축년도', '전용면적(㎡)', '계약날짜']).reset_index(drop=True)
concat_df = concat_df.drop_duplicates(['지번주소', '건축년도', '전용면적(㎡)'], keep='last').reset_index(drop=True)

# %%
concat_df['단가평균'] = concat_df[['지번주소', '건축년도', '단가(만원/㎡)']].groupby(['지번주소', '건축년도']).transform('mean')['단가(만원/㎡)']
concat_df['지수적용단가평균'] = concat_df[['지번주소', '건축년도', '지수적용단가']].groupby(['지번주소', '건축년도']).transform('mean')['지수적용단가']

# %%
concat_df = concat_df.sort_values(['지번주소', '건축년도', '지수적용날짜']).reset_index(drop=True)
print(concat_df.shape)
concat_df.head()
# Out:
# (503, 19)
#                    지번주소            도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 0  서울특별시 강남구 논현동 104-21     선릉로137길 22   노블레스빌    47.08     37000  5  2012.0
# 1  서울특별시 강남구 논현동 104-21     선릉로137길 22   노블레스빌    59.43     47500  4  2012.0
# 2  서울특별시 강남구 논현동 104-23     선릉로137길 20    케이씨빌   113.77     45000  4  2004.0
# 3   서울특별시 강남구 논현동 104-5  도산대로54길 48-11   동광팰리스    21.82     32800  5  2016.0
# 4   서울특별시 강남구 논현동 104-5  도산대로54길 48-11   동광팰리스    23.15     34800  3  2016.0
#
#    계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형    구    동 일괄계약  \
# 0          2.0 2014-12-26   785.896347   9.0  연립다세대  강남구  논현동    N
# 1          1.0 2013-02-25   799.259633   9.0  연립다세대  강남구  논현동    N
# 2          3.0 2007-03-03   395.534851  17.0    아파트  강남구  논현동    N
# 3          2.0 2018-09-03  1503.208066   5.0  연립다세대  강남구  논현동    N
# 4          2.0 2018-03-16  1503.239741   5.0  연립다세대  강남구  논현동    N
#
#         지수적용단가     지수적용날짜         단가평균     지수적용단가평균
# 0  1182.214982 2021-05-01   792.577990  1196.169087
# 1  1210.123192 2021-05-01   792.577990  1196.169087
# 2   739.548139 2021-05-01   395.534851   739.548139
# 3  1819.339676 2021-05-01  1364.292432  1652.591323
# 4  1902.313590 2021-05-01  1364.292432  1652.591323

# %%
concat_last_df = concat_df.drop_duplicates(subset=['지번주소', '건축년도'], keep='last')
print(concat_last_df.shape)
concat_last_df.head()
# Out:
# (159, 19)
#                     지번주소            도로명   건물(단지)명  전용면적(㎡)  거래금액(만원)  층  \
# 1   서울특별시 강남구 논현동 104-21     선릉로137길 22     노블레스빌    59.43     47500  4
# 2   서울특별시 강남구 논현동 104-23     선릉로137길 20      케이씨빌   113.77     45000  4
# 11   서울특별시 강남구 논현동 104-5  도산대로54길 48-11     동광팰리스    31.08     34500  6
# 13   서울특별시 강남구 논현동 105-4     도산대로46길 21     한진로즈힐    84.94     54000  1
# 15  서울특별시 강남구 논현동 107-50    학동로41길 32-7  (107-50)    26.62     32000  3
#
#       건축년도  계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형    구    동 일괄계약  \
# 1   2012.0          1.0 2013-02-25   799.259633   9.0  연립다세대  강남구  논현동    N
# 2   2004.0          3.0 2007-03-03   395.534851  17.0    아파트  강남구  논현동    N
# 11  2016.0          3.0 2019-04-24  1110.038610   5.0  연립다세대  강남구  논현동    N
# 13  2004.0          3.0 2007-08-17   635.742877  17.0    아파트  강남구  논현동    N
# 15  2018.0          3.0 2021-08-05  1202.103681   3.0  연립다세대  강남구  논현동    N
#
#          지수적용단가     지수적용날짜         단가평균     지수적용단가평균
# 1   1210.123192 2021-05-01   792.577990  1196.169087
# 2    739.548139 2021-05-01   395.534851   739.548139
# 11  1352.872036 2021-05-01  1364.292432  1652.591323
# 13  1071.597605 2021-05-01   618.402610  1110.118908
# 15  1202.103681 2021-08-05  1209.783999  1342.031985

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('{} {} 계약날짜기준 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 지번별 {}곳의 전용면적 실거래가격지수 적용후 단가평균'.format(target_gu, target_dong, target_building_age, concat_last_df.shape[0]))
plt.grid(True)
sns.histplot(concat_last_df['지수적용단가'], kde=True)
plt.savefig('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/지번별_분포도.png'.format(target_gu, target_dong, date_today_record))

# %%
concat_last_df = concat_last_df.sort_values(['지번주소']).reset_index(drop=True)

# %%
concat_last_df = concat_last_df[['지번주소', '건물(단지)명', '건축년도', '전용면적(㎡)', '층', '계약날짜', '단가(만원/㎡)', '지수적용날짜', '지수적용단가', '부동산유형']]
concat_last_df.rename(columns={'계약날짜':'마지막_계약날짜'}, inplace=True)
concat_last_df.head()
# Out:
#                    지번주소   건물(단지)명    건축년도  전용면적(㎡)  층   마지막_계약날짜     단가(만원/㎡)  \
# 0  서울특별시 강남구 논현동 104-21     노블레스빌  2012.0    59.43  4 2013-02-25   799.259633
# 1  서울특별시 강남구 논현동 104-23      케이씨빌  2004.0   113.77  4 2007-03-03   395.534851
# 2   서울특별시 강남구 논현동 104-5     동광팰리스  2016.0    31.08  6 2019-04-24  1110.038610
# 3   서울특별시 강남구 논현동 105-4     한진로즈힐  2004.0    84.94  1 2007-08-17   635.742877
# 4  서울특별시 강남구 논현동 107-50  (107-50)  2018.0    26.62  3 2021-08-05  1202.103681
#
#       지수적용날짜       지수적용단가  부동산유형
# 0 2021-05-01  1210.123192  연립다세대
# 1 2021-05-01   739.548139    아파트
# 2 2021-05-01  1352.872036  연립다세대
# 3 2021-05-01  1071.597605    아파트
# 4 2021-08-05  1202.103681  연립다세대

# %%
concat_last_df.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/전체_마지막_실거래가.xlsx'.format(target_gu, target_dong, date_today_record), index=False)
