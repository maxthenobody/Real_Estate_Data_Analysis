# %%
import pandas as pd
import numpy as np
import math
import os
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
pd.options.mode.chained_assignment = None  # default='warn'
plt.rcParams['font.family'] = 'Malgun Gothic'
import datetime

# %%
date_today = pd.to_datetime(datetime.datetime.now().strftime('%Y-%m-%d'), format='%Y-%m-%d')

# %%
def day_modifier(x):
    # x is a number
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x)
        if len(x) == 1:
            return '0' + x
        else:
            return x

# %%
def landnum_modifier(x):
    # x is a string
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x).replace('외', '').replace(' ','')
        splitted = x.split('-')
        if len(splitted) == 1:
            return x + '-0'
        else:
            return x

# %%
def data_prep(bdtype, tradetype):
    # bdtype is a string: one of 아파트, 연립다세대 or 오피스텔
    # tradetype is a string: one of 매매 or 전월세
    
    basedir = './국토교통부_실거래가_공개시스템/{}/{}/'.format(bdtype, tradetype)
    filenames = [f for f in os.listdir(basedir) if (f.endswith('.csv'))&('(' in f)]
    
    dfs_list = []
    for i, f in tqdm(enumerate(filenames)):
        df = pd.read_csv(basedir + f, encoding='euc-kr', header=15)
        if '해제사유발생일' in df.columns.tolist():
            df = df[df['해제사유발생일'].isna()]
            df = df.drop(columns=['해제사유발생일'])

        dfs_list.append(df)
    
    concat_df = pd.concat(dfs_list).reset_index(drop=True)
        
    concat_df['번지'] = concat_df['번지'].apply(landnum_modifier)
    
    concat_df['계약년월'] = concat_df['계약년월'].apply(str)
    concat_df['계약일'] = concat_df['계약일'].apply(str)
    
    concat_df['계약날짜기준_건물연식'] = concat_df['계약년월'].apply(lambda x: int(x[:4])) - concat_df['건축년도']
    
    concat_df['계약일'] = concat_df['계약일'].apply(day_modifier)
    
    concat_df['계약날짜'] = concat_df['계약년월'].apply(lambda x: x[:4]) + '-' + concat_df['계약년월'].apply(lambda x: x[-2:])\
    + '-' + concat_df['계약일']
    
    concat_df['계약날짜'] = pd.to_datetime(concat_df['계약날짜'], format='%Y-%m-%d')
    
    concat_df['거래금액(만원)'] = concat_df['거래금액(만원)'].apply(lambda x: int(x.replace(',','')))
    concat_df['단가(만원/㎡)'] = concat_df['거래금액(만원)'] / concat_df['전용면적(㎡)']
    
    concat_df['지번주소'] = concat_df['시군구'] + ' ' + concat_df['번지']
        
    cols_to_drop = ['시군구', '번지', '본번', '부번', '지번주소', '계약년월', '계약일', '도로명']
        
    concat_df = concat_df[['지번주소', '도로명'] + [col for col in concat_df.columns if col not in cols_to_drop]]
    
    date_today = pd.to_datetime(datetime.datetime.now().strftime('%Y-%m-%d'), format='%Y-%m-%d')
    concat_df['건물연식'] = date_today.year - concat_df['건축년도']
    
    concat_df = concat_df.dropna(subset=['지번주소'])
    
    if '건물명' in concat_df.columns:
        concat_df.rename(columns={'건물명':'건물(단지)명'}, inplace=True)
    elif '단지명' in concat_df.columns:
        concat_df.rename(columns={'단지명':'건물(단지)명'}, inplace=True)
    
    concat_df = concat_df[concat_df['층'] >= 0].reset_index(drop=True)
    
    return concat_df

# %%
target_house = '연립다세대'
house_df = data_prep(target_house, '매매')
print(house_df.shape)
house_df.head()
# Out:
# 16it [00:01, 10.84it/s]
# (631520, 12)
#                    지번주소         도로명   건물(단지)명  전용면적(㎡)  대지권면적(㎡)  거래금액(만원)  층  \
# 0  서울특별시 강남구 개포동 171-13   선릉로14길 11  (171-13)    68.08     56.10     56500  2
# 1  서울특별시 강남구 개포동 1239-7   개포로15길 25   강남빌라 가동    52.59     45.00     40500  2
# 2  서울특별시 강남구 개포동 1239-7   개포로15길 25   강남빌라 가동    52.59     45.00     42000  1
# 3  서울특별시 강남구 개포동 1239-6   개포로15길 27   강남빌라 나동    52.75     44.68     22000  2
# 4  서울특별시 강남구 개포동 1175-2  논현로6길 36-8      강남파크    49.43     23.70     17000  4
#
#      건축년도  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식
# 0  1988.0         18.0 2006-12-20  829.905993  33.0
# 1  1988.0         18.0 2006-12-09  770.108386  33.0
# 2  1988.0         18.0 2006-12-19  798.630918  33.0
# 3  1988.0         18.0 2006-11-02  417.061611  33.0
# 4  1993.0         13.0 2006-07-19  343.920696  28.0

# %%
land_specs_df = pd.read_csv('./prepped_data/land_specs_ver_4.csv')
print(land_specs_df.shape)
land_specs_df.head()
# Out:
# (8706295, 11)
#                   지번주소     년 지목명   토지면적  용도지역명1  용도지역명2 토지이동상황 지형높이 지형형상 도로접면  \
# 0  서울특별시 강남구 개포동 100-0  2013   전  876.0  자연녹지지역  지정되지않음      전  완경사  부정형   맹지
# 1  서울특별시 강남구 개포동 100-0  2014   전  876.0  자연녹지지역  지정되지않음      전  완경사  부정형   맹지
# 2  서울특별시 강남구 개포동 100-0  2015   전  876.0  자연녹지지역  지정되지않음      전  완경사  부정형   맹지
# 3  서울특별시 강남구 개포동 100-0  2016   전  876.0  자연녹지지역  지정되지않음      전  완경사  부정형   맹지
# 4  서울특별시 강남구 개포동 100-0  2017   전  876.0  자연녹지지역  지정되지않음      전  완경사  부정형   맹지
#
#        공시지가
# 0  325000.0
# 1  330000.0
# 2  335000.0
# 3  345000.0
# 4  355000.0

# %%
last_df = land_specs_df.drop_duplicates(subset=['지번주소'], keep='last').drop(columns=['년', '공시지가']).reset_index(drop=True)
print(last_df.shape)
last_df.head()
# Out:
# (981464, 9)
#                   지번주소 지목명    토지면적  용도지역명1  용도지역명2 토지이동상황 지형높이 지형형상 도로접면
# 0  서울특별시 강남구 개포동 100-0   전   876.0  자연녹지지역  지정되지않음      전  완경사  부정형   맹지
# 1  서울특별시 강남구 개포동 101-0   전   641.0  자연녹지지역  지정되지않음      전   평지  부정형   맹지
# 2  서울특별시 강남구 개포동 102-0   전   509.0  자연녹지지역  지정되지않음      전   평지  부정형   맹지
# 3  서울특별시 강남구 개포동 103-0   전    48.7  자연녹지지역  개발제한구역      전   평지  부정형   맹지
# 4  서울특별시 강남구 개포동 104-1   전  2995.0  개발제한구역  자연녹지지역      전  완경사  부정형   맹지

# %%
house_merge_df = house_df.merge(last_df, on=['지번주소']).reset_index(drop=True)

# %%
house_df['구'] = house_df['지번주소'].apply(lambda x: x.split(' ')[1])
house_df['동'] = house_df['지번주소'].apply(lambda x: x.split(' ')[2])
house_merge_df['구'] = house_merge_df['지번주소'].apply(lambda x: x.split(' ')[1])
house_merge_df['동'] = house_merge_df['지번주소'].apply(lambda x: x.split(' ')[2])

# %%
target_gu = '동대문구'
target_dong = '장안동'
target_purpose = '3종일반'
target_building_age = 5
target_period = 18 # in months

# %%
target_df = house_merge_df[
    (house_merge_df['구'] == target_gu)
    &(house_merge_df['동'] == target_dong)
    &(house_merge_df['계약날짜'] >= (date_today - pd.DateOffset(months=target_period)))
    &(house_merge_df['건물연식'] <= target_building_age)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_df.shape)
target_df.head()
# Out:
# (302, 22)
#                         지번주소           도로명   건물(단지)명  전용면적(㎡)  대지권면적(㎡)  \
# 124593  서울특별시 동대문구 장안동 324-4   장한로30길 23-2   조일티아모3차    56.85     35.35
# 124594  서울특별시 동대문구 장안동 324-4   장한로30길 23-2   조일티아모3차    56.90     35.38
# 124595  서울특별시 동대문구 장안동 324-4   장한로30길 23-2   조일티아모3차    56.85     35.35
# 124702  서울특별시 동대문구 장안동 315-6   답십리로69가길 21  삼원해피니스2차    57.49     38.46
# 124803  서울특별시 동대문구 장안동 393-3  답십리로66길 75-6     거성팰리스    41.67     28.04
#
#         거래금액(만원)  층    건축년도  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식 지목명  \
# 124593     32000  4  2016.0          4.0 2020-07-22  562.884785   5.0   대
# 124594     32000  3  2016.0          4.0 2020-09-05  562.390158   5.0   대
# 124595     39500  3  2016.0          5.0 2021-03-24  694.810906   5.0   대
# 124702     34000  2  2016.0          4.0 2020-09-22  591.407201   5.0   대
# 124803     38000  5  2016.0          5.0 2021-02-25  911.927046   5.0   대
#
#          토지면적     용도지역명1  용도지역명2 토지이동상황 지형높이  지형형상     도로접면     구    동
# 124593  707.3  제2종일반주거지역  지정되지않음    다세대   평지  세로장방  세로각지(가)  동대문구  장안동
# 124594  707.3  제2종일반주거지역  지정되지않음    다세대   평지  세로장방  세로각지(가)  동대문구  장안동
# 124595  707.3  제2종일반주거지역  지정되지않음    다세대   평지  세로장방  세로각지(가)  동대문구  장안동
# 124702  707.6  제2종일반주거지역  지정되지않음    다세대   평지  사다리형  세로각지(가)  동대문구  장안동
# 124803  551.0  제2종일반주거지역  지정되지않음    다세대   평지  세로장방  세로한면(가)  동대문구  장안동

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('최근 {}개월 {} {} 건물연식 {}년이하 {} 매매 실거래 {}건의 전용면적 단가'.format(target_period, target_gu, target_dong, target_building_age, target_house, target_df.shape[0]))
plt.grid(True)
ax.xaxis.update_units(target_df['계약날짜'])
sns.regplot(x=ax.xaxis.convert_units(target_df['계약날짜']), y=target_df['단가(만원/㎡)'])
plt.savefig('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_{}/전체_산포도.png'.format(target_gu, target_dong, target_house))

# %%
concat_df = pd.concat([target_df])

# %%
concat_df.head()
# Out:
#                         지번주소           도로명   건물(단지)명  전용면적(㎡)  대지권면적(㎡)  \
# 124593  서울특별시 동대문구 장안동 324-4   장한로30길 23-2   조일티아모3차    56.85     35.35
# 124594  서울특별시 동대문구 장안동 324-4   장한로30길 23-2   조일티아모3차    56.90     35.38
# 124595  서울특별시 동대문구 장안동 324-4   장한로30길 23-2   조일티아모3차    56.85     35.35
# 124702  서울특별시 동대문구 장안동 315-6   답십리로69가길 21  삼원해피니스2차    57.49     38.46
# 124803  서울특별시 동대문구 장안동 393-3  답십리로66길 75-6     거성팰리스    41.67     28.04
#
#         거래금액(만원)  층    건축년도  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식 지목명  \
# 124593     32000  4  2016.0          4.0 2020-07-22  562.884785   5.0   대
# 124594     32000  3  2016.0          4.0 2020-09-05  562.390158   5.0   대
# 124595     39500  3  2016.0          5.0 2021-03-24  694.810906   5.0   대
# 124702     34000  2  2016.0          4.0 2020-09-22  591.407201   5.0   대
# 124803     38000  5  2016.0          5.0 2021-02-25  911.927046   5.0   대
#
#          토지면적     용도지역명1  용도지역명2 토지이동상황 지형높이  지형형상     도로접면     구    동
# 124593  707.3  제2종일반주거지역  지정되지않음    다세대   평지  세로장방  세로각지(가)  동대문구  장안동
# 124594  707.3  제2종일반주거지역  지정되지않음    다세대   평지  세로장방  세로각지(가)  동대문구  장안동
# 124595  707.3  제2종일반주거지역  지정되지않음    다세대   평지  세로장방  세로각지(가)  동대문구  장안동
# 124702  707.6  제2종일반주거지역  지정되지않음    다세대   평지  사다리형  세로각지(가)  동대문구  장안동
# 124803  551.0  제2종일반주거지역  지정되지않음    다세대   평지  세로장방  세로한면(가)  동대문구  장안동

# %%
concat_df['단가평균'] = concat_df[['지번주소', '건축년도', '단가(만원/㎡)']].groupby(['지번주소', '건축년도']).transform('mean')['단가(만원/㎡)']

# %%
concat_df = concat_df.sort_values(['지번주소', '건축년도', '계약날짜']).reset_index(drop=True)
print(concat_df.shape)
concat_df.head()
# Out:
# (302, 23)
#                     지번주소         도로명  건물(단지)명  전용면적(㎡)  대지권면적(㎡)  거래금액(만원)  층  \
# 0  서울특별시 동대문구 장안동 123-21  답십리로63길 64  삼화에코빌9차    37.84     26.66     27500  2
# 1  서울특별시 동대문구 장안동 123-21  답십리로63길 64  삼화에코빌9차    28.57     20.13     20650  4
# 2  서울특별시 동대문구 장안동 123-21  답십리로63길 64  삼화에코빌9차    47.80     33.67     31850  5
# 3  서울특별시 동대문구 장안동 123-21  답십리로63길 64  삼화에코빌9차    39.34     27.70     27150  5
# 4  서울특별시 동대문구 장안동 123-21  답십리로63길 64  삼화에코빌9차    29.70     20.92     22200  2
#
#      건축년도  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식 지목명   토지면적     용도지역명1  \
# 0  2019.0          0.0 2019-12-02  726.744186   2.0   대  397.0  제2종일반주거지역
# 1  2019.0          0.0 2019-12-02  722.786139   2.0   대  397.0  제2종일반주거지역
# 2  2019.0          0.0 2019-12-02  666.317992   2.0   대  397.0  제2종일반주거지역
# 3  2019.0          0.0 2019-12-02  690.137265   2.0   대  397.0  제2종일반주거지역
# 4  2019.0          0.0 2019-12-02  747.474747   2.0   대  397.0  제2종일반주거지역
#
#    용도지역명2 토지이동상황 지형높이  지형형상  도로접면     구    동        단가평균
# 0  지정되지않음   주상기타   평지  사다리형  소로한면  동대문구  장안동  722.807314
# 1  지정되지않음   주상기타   평지  사다리형  소로한면  동대문구  장안동  722.807314
# 2  지정되지않음   주상기타   평지  사다리형  소로한면  동대문구  장안동  722.807314
# 3  지정되지않음   주상기타   평지  사다리형  소로한면  동대문구  장안동  722.807314
# 4  지정되지않음   주상기타   평지  사다리형  소로한면  동대문구  장안동  722.807314

# %%
concat_last_df = concat_df.drop_duplicates(subset=['지번주소', '건축년도'], keep='last')
print(concat_last_df.shape)
concat_last_df
# Out:
# (54, 23)
#                       지번주소             도로명        건물(단지)명  전용면적(㎡)  대지권면적(㎡)  \
# 10   서울특별시 동대문구 장안동 123-21      답십리로63길 64        삼화에코빌9차   37.840     26.66
# 11   서울특별시 동대문구 장안동 132-17       한천로32길 16    이가채(132-17)   41.720     28.92
# 13    서울특별시 동대문구 장안동 135-7          제기로 20           더푸른빌   57.310     30.39
# 29   서울특별시 동대문구 장안동 152-30        한천로24길 9  리움펠리체(152-30)   43.300     26.59
# 32    서울특별시 동대문구 장안동 184-9    답십리로66길 90-3         cj베네치아   40.490     26.63
# 36   서울특별시 동대문구 장안동 218-22      장한로5길 69-6           올림푸스   39.150     23.38
# 51   서울특별시 동대문구 장안동 284-11      한천로46길 112          동성네스트   15.560      9.23
# 52    서울특별시 동대문구 장안동 289-5     장한로31길 34-6           휴렉스빌   21.490     20.13
# 54   서울특별시 동대문구 장안동 293-14    답십리로65길 22-8         성강 청안채   25.150     15.58
# 59    서울특별시 동대문구 장안동 298-5      장한로27가길 63           청솔타운   53.960     31.58
# 61    서울특별시 동대문구 장안동 307-2       장한로27길 11       더 하이드 파크   46.760     11.86
# 62    서울특별시 동대문구 장안동 315-6     답십리로69가길 21       삼원해피니스2차   57.490     38.46
# 64    서울특별시 동대문구 장안동 316-6      사가정로 274-9           J-타워   29.890     16.50
# 66    서울특별시 동대문구 장안동 318-3    장한로36길 23-12           브라운힐   55.430     32.88
# 70    서울특별시 동대문구 장안동 318-4       장한로36길 25       삼원해피니스1차   60.810     40.46
# 75   서울특별시 동대문구 장안동 320-15     장한로34길 23-5   스마트빌(320-15)   50.305     28.93
# 79   서울특별시 동대문구 장안동 320-16       장한로34길 19           까사벨로   56.905     32.75
# 88   서울특별시 동대문구 장안동 321-10       장한로32길 19         삼성리치캐슬   50.620     30.75
# 91    서울특별시 동대문구 장안동 324-4     장한로30길 23-2        조일티아모3차   56.850     35.35
# 94    서울특별시 동대문구 장안동 326-2     장한로32길 23-6           콘체르토   46.560     30.30
# 95    서울특별시 동대문구 장안동 327-8       장한로34길 29           현대캐슬   43.530     28.27
# 139   서울특별시 동대문구 장안동 333-4       장한로26길 85        (333-4)   56.360     27.58
# 155   서울특별시 동대문구 장안동 339-2      장한로26다길 65         하우징365   29.150     20.68
# 157  서울특별시 동대문구 장안동 346-18      장한로26나길 66          토브쉐르빌   45.290     21.60
# 159  서울특별시 동대문구 장안동 349-12     장한로18길 54-3          모던하우스   33.160     19.53
# 165   서울특별시 동대문구 장안동 349-8     답십리로72길 128        에메랄드 2차   48.192     28.99
# 168   서울특별시 동대문구 장안동 358-1       장한로14길 58           스마트빌   46.340     27.75
# 176   서울특별시 동대문구 장안동 358-7       장한로14길 76          자이리버빌   72.970     42.03
# 177   서울특별시 동대문구 장안동 365-9          장한로 98           케이타워   30.128      5.21
# 179   서울특별시 동대문구 장안동 381-6      답십리로68길 91        진한 탑클래스   57.620     29.14
# 187   서울특별시 동대문구 장안동 381-7      답십리로68길 83         THE하우스   29.920     22.53
# 189   서울특별시 동대문구 장안동 381-8       한천로24길 64         DS올림푸스   41.510     20.16
# 190   서울특별시 동대문구 장안동 385-6     한천로26길 47-8          더존팰리스   42.380     23.42
# 193  서울특별시 동대문구 장안동 389-12       장한로25길 47          롯데하이츠   53.960     32.60
# 194  서울특별시 동대문구 장안동 390-12     한천로24길 47-5      에이원빌리지3단지   55.520     31.93
# 198  서울특별시 동대문구 장안동 391-23     한천로24길 47-4  레이크시티(391-23)   37.180     24.29
# 201   서울특별시 동대문구 장안동 392-5       한천로24길 46          화성로얄빌   29.630     23.15
# 203   서울특별시 동대문구 장안동 392-6       한천로24길 50          골든캐슬2   34.440     24.52
# 207   서울특별시 동대문구 장안동 392-8      답십리로68길 86       명진베스트진1차   55.180     34.21
# 208   서울특별시 동대문구 장안동 393-3    답십리로66길 75-6          거성팰리스   41.670     28.04
# 243   서울특별시 동대문구 장안동 397-2     답십리로68길 132   엘림하우스(397-2)   55.450     32.86
# 255  서울특별시 동대문구 장안동 399-17  천호대로77다길 11-11   주현주택(399-17)   29.940     22.87
# 256   서울특별시 동대문구 장안동 401-3     천호대로77다길 12    주현주택(401-3)   29.270     17.00
# 258   서울특별시 동대문구 장안동 409-1        한천로6길 26          홀가하우스   30.040     16.80
# 263   서울특별시 동대문구 장안동 409-7        한천로6길 34           더헤리움   38.750     28.01
# 266   서울특별시 동대문구 장안동 417-2        장한로3길 17  샤론인텔리안(417-2)   38.680     12.93
# 269   서울특별시 동대문구 장안동 419-8     천호대로77가길 26            가은빌   41.320     27.62
# 271   서울특별시 동대문구 장안동 423-5        장한로3길 16          예스홈3차   50.600     35.97
# 274   서울특별시 동대문구 장안동 426-3        장한로9길 25        엘림하우스2차   53.740     33.04
# 279   서울특별시 동대문구 장안동 444-1       장한로10길 48          금성아트빌   42.660     28.10
# 287   서울특별시 동대문구 장안동 445-8      천호대로87길 50          운영하우스   27.510     16.21
# 288  서울특별시 동대문구 장안동 453-11      천호대로91길 20          아성뜨란채   38.000     22.29
# 296   서울특별시 동대문구 장안동 466-4        장한로2길 80        성우스타팰리스   27.250      7.83
# 301   서울특별시 동대문구 장안동 585-0      사가정로23길 64   성우스타팰리스(585)   34.530     22.00
#
#      거래금액(만원)   층    건축년도  계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식 지목명  \
# 10      27500   3  2019.0          0.0 2019-12-02   726.744186   2.0   대
# 11      30000   2  2016.0          5.0 2021-02-15   719.079578   5.0   대
# 13      27500   3  2019.0          0.0 2019-12-02   479.846449   2.0   대
# 29      28650   4  2019.0          0.0 2019-12-23   661.662818   2.0   대
# 32      31000   3  2016.0          4.0 2020-08-26   765.621141   5.0   대
# 36      27350   3  2016.0          4.0 2020-08-14   698.595147   5.0   대
# 51      20000   6  2020.0          0.0 2020-10-25  1285.347044   1.0   대
# 52      20000   6  2016.0          4.0 2020-08-29   930.665426   5.0   대
# 54      24500   3  2016.0          5.0 2021-04-14   974.155070   5.0   대
# 59      37600   6  2016.0          5.0 2021-04-01   696.812454   5.0   대
# 61      37000   7  2018.0          3.0 2021-04-17   791.274594   3.0   대
# 62      34000   2  2016.0          4.0 2020-09-22   591.407201   5.0   대
# 64      21000   6  2018.0          2.0 2020-01-14   702.576112   3.0   대
# 66      33000   2  2017.0          4.0 2021-03-09   595.345481   4.0   대
# 70      34000   5  2016.0          5.0 2021-04-15   559.118566   5.0   대
# 75      35000   4  2017.0          4.0 2021-04-11   695.755889   4.0   대
# 79      35900   4  2017.0          4.0 2021-01-23   630.876021   4.0   대
# 88      32000   2  2016.0          5.0 2021-04-12   632.161201   5.0   대
# 91      39500   3  2016.0          5.0 2021-03-24   694.810906   5.0   대
# 94      35000   3  2016.0          5.0 2021-04-27   751.718213   5.0   대
# 95      27000   5  2016.0          4.0 2020-09-18   620.261888   5.0   대
# 139     37450   5  2019.0          0.0 2019-12-23   664.478353   2.0   대
# 155     23800   4  2020.0          0.0 2020-01-16   816.466552   1.0   대
# 157     21950   4  2016.0          4.0 2020-03-05   484.654449   5.0   대
# 159     26300   4  2016.0          4.0 2020-09-04   793.124246   5.0   대
# 165     35000   6  2018.0          3.0 2021-01-30   726.261620   3.0   대
# 168     32500   4  2016.0          5.0 2021-01-27   701.337937   5.0   대
# 176     53100   5  2020.0          0.0 2020-09-03   727.696314   1.0   대
# 177     45000  19  2020.0          1.0 2021-04-01  1493.627191   1.0   대
# 179     29900   5  2016.0          4.0 2020-05-14   518.917043   5.0   대
# 187     24900   4  2016.0          5.0 2021-04-13   832.219251   5.0   대
# 189     35000   3  2016.0          5.0 2021-04-19   843.170320   5.0   대
# 190     29000   6  2016.0          4.0 2020-06-22   684.285040   5.0   대
# 193     43000   2  2020.0          1.0 2021-02-25   796.886583   1.0   대
# 194     37000   5  2017.0          4.0 2021-02-15   666.426513   4.0   대
# 198     27000   5  2016.0          5.0 2021-03-18   726.196880   5.0   대
# 201     23400   3  2017.0          4.0 2021-01-27   789.740128   4.0   대
# 203     33000   6  2019.0          1.0 2020-05-17   958.188153   2.0   대
# 207     32000   3  2016.0          4.0 2020-08-25   579.920261   5.0   대
# 208     38000   5  2016.0          5.0 2021-02-25   911.927046   5.0   대
# 243     37450   3  2020.0          0.0 2020-09-01   675.383228   1.0   대
# 255     33500   4  2018.0          1.0 2019-11-30  1118.904476   3.0   대
# 256     25000   5  2017.0          3.0 2020-07-24   854.116843   4.0   대
# 258     29000   5  2019.0          2.0 2021-04-27   965.379494   2.0   대
# 263     34000   3  2016.0          5.0 2021-03-19   877.419355   5.0   대
# 266     31000   6  2016.0          5.0 2021-04-07   801.447777   5.0   대
# 269     28800   2  2016.0          4.0 2020-12-21   696.999032   5.0   대
# 271     32000   4  2016.0          5.0 2021-01-08   632.411067   5.0   대
# 274     37000   6  2018.0          3.0 2021-02-10   688.500186   3.0   대
# 279     31000   6  2016.0          5.0 2021-02-16   726.676043   5.0   대
# 287     34000   3  2019.0          2.0 2021-03-02  1235.914213   2.0   대
# 288     29700   3  2017.0          2.0 2019-12-25   781.578947   4.0   대
# 296     27500   7  2019.0          2.0 2021-04-14  1009.174312   2.0   대
# 301     44900   6  2018.0          2.0 2020-12-02  1300.318564   3.0   대
#
#        토지면적     용도지역명1     용도지역명2 토지이동상황 지형높이  지형형상     도로접면     구    동  \
# 10    397.0  제2종일반주거지역     지정되지않음   주상기타   평지  사다리형     소로한면  동대문구  장안동
# 11    136.0  제2종일반주거지역     지정되지않음    다세대   평지  세로장방  세로한면(가)  동대문구  장안동
# 13    122.0  제2종일반주거지역     지정되지않음     단독   평지  가로장방  세로한면(가)  동대문구  장안동
# 29    321.0  제2종일반주거지역     지정되지않음    다세대   평지  세로장방     소로각지  동대문구  장안동
# 32    413.0  제2종일반주거지역     지정되지않음    다세대   평지  세로장방  세로한면(가)  동대문구  장안동
# 36    235.0  제2종일반주거지역     지정되지않음    다세대   평지  사다리형  세로한면(가)  동대문구  장안동
# 51    152.9  제2종일반주거지역     지정되지않음    다세대   평지  세로장방     소로각지  동대문구  장안동
# 52    236.8  제2종일반주거지역     지정되지않음    다세대   평지  가로장방  세로한면(가)  동대문구  장안동
# 54    162.9  제2종일반주거지역     지정되지않음   주상기타   평지  세로장방     소로각지  동대문구  장안동
# 59    963.6  제2종일반주거지역     지정되지않음     연립   평지  가로장방     소로각지  동대문구  장안동
# 61    424.3      준주거지역     지정되지않음   상업기타   평지  사다리형     소로한면  동대문구  장안동
# 62    707.6  제2종일반주거지역     지정되지않음    다세대   평지  사다리형  세로각지(가)  동대문구  장안동
# 64    641.0  제2종일반주거지역     지정되지않음    다세대   평지  세로장방     소로각지  동대문구  장안동
# 66    440.4  제2종일반주거지역     지정되지않음    다세대   평지  가로장방  세로한면(가)  동대문구  장안동
# 70    741.4  제2종일반주거지역     지정되지않음    다세대   평지  가로장방  세로각지(가)  동대문구  장안동
# 75    860.2  제2종일반주거지역     지정되지않음    다세대   평지  가로장방  세로각지(가)  동대문구  장안동
# 79    524.0  제2종일반주거지역     지정되지않음    다세대   평지  가로장방  세로각지(가)  동대문구  장안동
# 88   1701.1  제2종일반주거지역     지정되지않음    다세대   평지  세로장방     소로각지  동대문구  장안동
# 91    707.3  제2종일반주거지역     지정되지않음    다세대   평지  세로장방  세로각지(가)  동대문구  장안동
# 94    357.5  제2종일반주거지역     지정되지않음    다세대   평지  가로장방  세로한면(가)  동대문구  장안동
# 95    357.1  제2종일반주거지역     지정되지않음    주상용   평지  세로장방  세로한면(가)  동대문구  장안동
# 139  1251.4  제3종일반주거지역     지정되지않음   상업기타   평지  세로장방     중로각지  동대문구  장안동
# 155   165.3  제2종일반주거지역     지정되지않음    다세대   평지  가로장방  세로한면(가)  동대문구  장안동
# 157   135.4  제3종일반주거지역     지정되지않음    다세대   평지  가로장방  세로한면(가)  동대문구  장안동
# 159   213.0  제2종일반주거지역     지정되지않음    다세대   평지  가로장방  세로한면(가)  동대문구  장안동
# 165   993.3  제2종일반주거지역     지정되지않음    다세대   평지  세로장방     소로각지  동대문구  장안동
# 168   833.8  제2종일반주거지역     지정되지않음   주상기타   평지   정방형     소로각지  동대문구  장안동
# 176   374.6  제2종일반주거지역     지정되지않음   주상기타   평지  세로장방     소로한면  동대문구  장안동
# 177   819.8     일반상업지역     지정되지않음   상업기타   평지   정방형    광대로한면  동대문구  장안동
# 179   822.3  제3종일반주거지역     지정되지않음     연립   평지  세로장방  세로한면(가)  동대문구  장안동
# 187   659.8  제3종일반주거지역     지정되지않음    다세대   평지  세로장방  세로한면(가)  동대문구  장안동
# 189  1009.6  제3종일반주거지역     지정되지않음    다세대   평지   정방형  세로각지(가)  동대문구  장안동
# 190   765.8  제2종일반주거지역     지정되지않음     연립   평지   정방형  세로한면(가)  동대문구  장안동
# 193   246.3  제2종일반주거지역     지정되지않음    주상용   평지  세로장방     소로한면  동대문구  장안동
# 194   805.3  제2종일반주거지역     지정되지않음    다세대   평지  가로장방  세로각지(가)  동대문구  장안동
# 198   324.0  제2종일반주거지역     지정되지않음     연립   평지  세로장방  세로한면(가)  동대문구  장안동
# 201   467.2  제2종일반주거지역     지정되지않음   주상기타   평지  사다리형  세로한면(가)  동대문구  장안동
# 203   726.7  제2종일반주거지역     지정되지않음    다세대   평지  세로장방  세로한면(가)  동대문구  장안동
# 207   961.3  제2종일반주거지역     지정되지않음     연립   평지  가로장방  세로각지(가)  동대문구  장안동
# 208   551.0  제2종일반주거지역     지정되지않음    다세대   평지  세로장방  세로한면(가)  동대문구  장안동
# 243   518.2  제2종일반주거지역     지정되지않음    다세대   평지  가로장방  세로한면(가)  동대문구  장안동
# 255   268.2  제2종일반주거지역     지정되지않음    다세대   평지  세로장방  세로각지(가)  동대문구  장안동
# 256   410.7  제2종일반주거지역     지정되지않음    다세대   평지   정방형  세로한면(가)  동대문구  장안동
# 258   719.9  제2종일반주거지역     지정되지않음   상업기타   평지  가로장방     소로각지  동대문구  장안동
# 263  1181.9  제2종일반주거지역     지정되지않음    다세대   평지   부정형     소로각지  동대문구  장안동
# 266   220.7      준주거지역     지정되지않음    주상용   평지  사다리형  세로한면(가)  동대문구  장안동
# 269   172.6  제2종일반주거지역     지정되지않음    다세대   평지  사다리형  세로한면(가)  동대문구  장안동
# 271   251.5  제3종일반주거지역     지정되지않음   주상기타   평지  세로장방  세로한면(가)  동대문구  장안동
# 274  1116.3  제2종일반주거지역     지정되지않음    다세대   평지   정방형     소로한면  동대문구  장안동
# 279  1336.8  제2종일반주거지역     지정되지않음     연립   평지   부정형     소로각지  동대문구  장안동
# 287   399.1  제2종일반주거지역     지정되지않음   주상기타   평지  가로장방  세로각지(가)  동대문구  장안동
# 288   231.6  제2종일반주거지역     지정되지않음   주상기타   평지  세로장방  세로한면(가)  동대문구  장안동
# 296   648.1      준주거지역     지정되지않음   상업기타   평지   정방형     소로한면  동대문구  장안동
# 301  2649.8  제2종일반주거지역  제3종일반주거지역    다세대   평지  가로장방     소로각지  동대문구  장안동
#
#             단가평균
# 10    722.807314
# 11    719.079578
# 13    517.361717
# 29    659.286196
# 32    703.001967
# 36    735.546270
# 51    826.704315
# 52    930.665426
# 54    783.002871
# 59    644.043467
# 61    750.445887
# 62    591.407201
# 64    702.576112
# 66    562.877832
# 70    647.390614
# 75    672.474991
# 79    675.676607
# 88    672.768778
# 91    606.695283
# 94    697.308133
# 95    620.261888
# 139   668.205171
# 155   809.272838
# 157   483.633511
# 159   801.391668
# 165   671.403144
# 168   675.000008
# 176   717.503769
# 177  1493.627191
# 179   513.710517
# 187   750.190502
# 189   764.605646
# 190   684.285040
# 193   801.953347
# 194   666.426513
# 198   679.803758
# 201   742.792416
# 203   982.803565
# 207   526.388598
# 208   911.927046
# 243   681.634764
# 255   843.116961
# 256   854.116843
# 258  1238.215232
# 263   845.031683
# 266   773.813866
# 269   725.560302
# 271   730.790948
# 274   687.182079
# 279   696.514409
# 287  1024.142210
# 288   781.578947
# 296  1245.671259
# 301   964.357820

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('최근 {}개월 {} {} 건물연식 {}년이하 {} 매매 실거래 지번별 {}곳의 마지막 거래 전용면적 단가'.format(target_period, target_gu, target_dong, target_building_age, target_house, concat_last_df.shape[0]))
plt.grid(True)
ax.xaxis.update_units(concat_last_df['계약날짜'])
sns.regplot(x=ax.xaxis.convert_units(concat_last_df['계약날짜']), y=concat_last_df['단가(만원/㎡)'])
plt.savefig('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_{}/지번별_산포도.png'.format(target_gu, target_dong, target_house))

# %%
font = {'size': 12}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(12,6))
plt.grid(True)
plt.ylabel('수')
plt.title('최근 {}개월 {} {} 건물연식 {}년이하 {} 매매 실거래 지번별 {}곳의 마지막 거래 전용면적 단가'.format(target_period, target_gu, target_dong, target_building_age, target_house, concat_last_df.shape[0]))
sns.histplot(concat_last_df['단가(만원/㎡)'], kde=True)
plt.savefig('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_{}/지번별_분포도.png'.format(target_gu, target_dong, target_house))
plt.show()
plt.clf()

# %%
concat_last_df = concat_last_df.sort_values(['지번주소']).reset_index(drop=True)

# %%
concat_last_df = concat_last_df[['지번주소', '건물(단지)명', '건물연식', '계약날짜', '단가(만원/㎡)', '용도지역명1']]
concat_last_df
# Out:
#                      지번주소        건물(단지)명  건물연식       계약날짜     단가(만원/㎡)  \
# 0   서울특별시 동대문구 장안동 123-21        삼화에코빌9차   2.0 2019-12-02   726.744186
# 1   서울특별시 동대문구 장안동 132-17    이가채(132-17)   5.0 2021-02-15   719.079578
# 2    서울특별시 동대문구 장안동 135-7           더푸른빌   2.0 2019-12-02   479.846449
# 3   서울특별시 동대문구 장안동 152-30  리움펠리체(152-30)   2.0 2019-12-23   661.662818
# 4    서울특별시 동대문구 장안동 184-9         cj베네치아   5.0 2020-08-26   765.621141
# 5   서울특별시 동대문구 장안동 218-22           올림푸스   5.0 2020-08-14   698.595147
# 6   서울특별시 동대문구 장안동 284-11          동성네스트   1.0 2020-10-25  1285.347044
# 7    서울특별시 동대문구 장안동 289-5           휴렉스빌   5.0 2020-08-29   930.665426
# 8   서울특별시 동대문구 장안동 293-14         성강 청안채   5.0 2021-04-14   974.155070
# 9    서울특별시 동대문구 장안동 298-5           청솔타운   5.0 2021-04-01   696.812454
# 10   서울특별시 동대문구 장안동 307-2       더 하이드 파크   3.0 2021-04-17   791.274594
# 11   서울특별시 동대문구 장안동 315-6       삼원해피니스2차   5.0 2020-09-22   591.407201
# 12   서울특별시 동대문구 장안동 316-6           J-타워   3.0 2020-01-14   702.576112
# 13   서울특별시 동대문구 장안동 318-3           브라운힐   4.0 2021-03-09   595.345481
# 14   서울특별시 동대문구 장안동 318-4       삼원해피니스1차   5.0 2021-04-15   559.118566
# 15  서울특별시 동대문구 장안동 320-15   스마트빌(320-15)   4.0 2021-04-11   695.755889
# 16  서울특별시 동대문구 장안동 320-16           까사벨로   4.0 2021-01-23   630.876021
# 17  서울특별시 동대문구 장안동 321-10         삼성리치캐슬   5.0 2021-04-12   632.161201
# 18   서울특별시 동대문구 장안동 324-4        조일티아모3차   5.0 2021-03-24   694.810906
# 19   서울특별시 동대문구 장안동 326-2           콘체르토   5.0 2021-04-27   751.718213
# 20   서울특별시 동대문구 장안동 327-8           현대캐슬   5.0 2020-09-18   620.261888
# 21   서울특별시 동대문구 장안동 333-4        (333-4)   2.0 2019-12-23   664.478353
# 22   서울특별시 동대문구 장안동 339-2         하우징365   1.0 2020-01-16   816.466552
# 23  서울특별시 동대문구 장안동 346-18          토브쉐르빌   5.0 2020-03-05   484.654449
# 24  서울특별시 동대문구 장안동 349-12          모던하우스   5.0 2020-09-04   793.124246
# 25   서울특별시 동대문구 장안동 349-8        에메랄드 2차   3.0 2021-01-30   726.261620
# 26   서울특별시 동대문구 장안동 358-1           스마트빌   5.0 2021-01-27   701.337937
# 27   서울특별시 동대문구 장안동 358-7          자이리버빌   1.0 2020-09-03   727.696314
# 28   서울특별시 동대문구 장안동 365-9           케이타워   1.0 2021-04-01  1493.627191
# 29   서울특별시 동대문구 장안동 381-6        진한 탑클래스   5.0 2020-05-14   518.917043
# 30   서울특별시 동대문구 장안동 381-7         THE하우스   5.0 2021-04-13   832.219251
# 31   서울특별시 동대문구 장안동 381-8         DS올림푸스   5.0 2021-04-19   843.170320
# 32   서울특별시 동대문구 장안동 385-6          더존팰리스   5.0 2020-06-22   684.285040
# 33  서울특별시 동대문구 장안동 389-12          롯데하이츠   1.0 2021-02-25   796.886583
# 34  서울특별시 동대문구 장안동 390-12      에이원빌리지3단지   4.0 2021-02-15   666.426513
# 35  서울특별시 동대문구 장안동 391-23  레이크시티(391-23)   5.0 2021-03-18   726.196880
# 36   서울특별시 동대문구 장안동 392-5          화성로얄빌   4.0 2021-01-27   789.740128
# 37   서울특별시 동대문구 장안동 392-6          골든캐슬2   2.0 2020-05-17   958.188153
# 38   서울특별시 동대문구 장안동 392-8       명진베스트진1차   5.0 2020-08-25   579.920261
# 39   서울특별시 동대문구 장안동 393-3          거성팰리스   5.0 2021-02-25   911.927046
# 40   서울특별시 동대문구 장안동 397-2   엘림하우스(397-2)   1.0 2020-09-01   675.383228
# 41  서울특별시 동대문구 장안동 399-17   주현주택(399-17)   3.0 2019-11-30  1118.904476
# 42   서울특별시 동대문구 장안동 401-3    주현주택(401-3)   4.0 2020-07-24   854.116843
# 43   서울특별시 동대문구 장안동 409-1          홀가하우스   2.0 2021-04-27   965.379494
# 44   서울특별시 동대문구 장안동 409-7           더헤리움   5.0 2021-03-19   877.419355
# 45   서울특별시 동대문구 장안동 417-2  샤론인텔리안(417-2)   5.0 2021-04-07   801.447777
# 46   서울특별시 동대문구 장안동 419-8            가은빌   5.0 2020-12-21   696.999032
# 47   서울특별시 동대문구 장안동 423-5          예스홈3차   5.0 2021-01-08   632.411067
# 48   서울특별시 동대문구 장안동 426-3        엘림하우스2차   3.0 2021-02-10   688.500186
# 49   서울특별시 동대문구 장안동 444-1          금성아트빌   5.0 2021-02-16   726.676043
# 50   서울특별시 동대문구 장안동 445-8          운영하우스   2.0 2021-03-02  1235.914213
# 51  서울특별시 동대문구 장안동 453-11          아성뜨란채   4.0 2019-12-25   781.578947
# 52   서울특별시 동대문구 장안동 466-4        성우스타팰리스   2.0 2021-04-14  1009.174312
# 53   서울특별시 동대문구 장안동 585-0   성우스타팰리스(585)   3.0 2020-12-02  1300.318564
#
#        용도지역명1
# 0   제2종일반주거지역
# 1   제2종일반주거지역
# 2   제2종일반주거지역
# 3   제2종일반주거지역
# 4   제2종일반주거지역
# 5   제2종일반주거지역
# 6   제2종일반주거지역
# 7   제2종일반주거지역
# 8   제2종일반주거지역
# 9   제2종일반주거지역
# 10      준주거지역
# 11  제2종일반주거지역
# 12  제2종일반주거지역
# 13  제2종일반주거지역
# 14  제2종일반주거지역
# 15  제2종일반주거지역
# 16  제2종일반주거지역
# 17  제2종일반주거지역
# 18  제2종일반주거지역
# 19  제2종일반주거지역
# 20  제2종일반주거지역
# 21  제3종일반주거지역
# 22  제2종일반주거지역
# 23  제3종일반주거지역
# 24  제2종일반주거지역
# 25  제2종일반주거지역
# 26  제2종일반주거지역
# 27  제2종일반주거지역
# 28     일반상업지역
# 29  제3종일반주거지역
# 30  제3종일반주거지역
# 31  제3종일반주거지역
# 32  제2종일반주거지역
# 33  제2종일반주거지역
# 34  제2종일반주거지역
# 35  제2종일반주거지역
# 36  제2종일반주거지역
# 37  제2종일반주거지역
# 38  제2종일반주거지역
# 39  제2종일반주거지역
# 40  제2종일반주거지역
# 41  제2종일반주거지역
# 42  제2종일반주거지역
# 43  제2종일반주거지역
# 44  제2종일반주거지역
# 45      준주거지역
# 46  제2종일반주거지역
# 47  제3종일반주거지역
# 48  제2종일반주거지역
# 49  제2종일반주거지역
# 50  제2종일반주거지역
# 51  제2종일반주거지역
# 52      준주거지역
# 53  제2종일반주거지역

# %%
concat_last_df.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_{}/실거래가.xlsx'.format(target_gu, target_dong, target_house), index=False)

# %%
# %%time
land_plans_df = pd.read_csv('./토지이용계획정보/original_land_plans_mapped.csv')
land_plans_df = land_plans_df.sort_values(['지번주소', '년']).drop_duplicates(subset=['지번주소'], keep='last').drop(columns=['년']).reset_index(drop=True)
print(land_plans_df.shape)
land_plans_df.head()

# %%
from time import sleep
import requests
from urllib.parse import urlparse

# 지번주소로 도로명주소와 좌표를 다운로드함. 출처 - 행정안전부 도로명주소 안내시스템 개발자센터

def fetch_coor_data(addr_list):
    roadname_url = 'https://www.juso.go.kr/addrlink/addrLinkApi.do?'
    roadname_apikey = 'devU01TX0FVVEgyMDIxMDUwNDE1NTMwMDExMTEyNzc='
    coor_base_url = 'https://www.juso.go.kr/addrlink/addrCoordApi.do?'
    coor_apikey = 'devU01TX0FVVEgyMDIxMDIyNjExMDQwMDExMDg1ODU='
    # 도로명주소 검색 api key 만료일 2021년 8월 2일
    # 좌표검색 api key 만료일 2021년 5월 27일
    #apikey 만료시 https://www.juso.go.kr/addrlink/devAddrLinkRequestWrite.do?returnFn=write&cntcMenu=URL 가서 새로 받을 것.
    
    coor_data_df = pd.DataFrame({'지번주소':[], '도로명주소':[], 'x좌표':[], 'y좌표':[]})
    
    for i, address in enumerate(addr_list):     
        address_no_zero = address
        
        roadname_result = requests.get(roadname_url + 'confmKey=' + roadname_apikey + '&currentPage=1' + '&countPerPage=5' + '&keyword=' \
                                       + address_no_zero + '&resultType=json' + '&hstryYn=Y')
        sleep(1)
        roadname_info = roadname_result.json()['results']['juso']
        
        if roadname_info == []:
            print(address_no_zero)
            if address_no_zero.endswith('-0'):
                address_no_zero = address_no_zero[:-2]
            
            roadname_result = requests.get(roadname_url + 'confmKey=' + roadname_apikey + '&currentPage=1' + '&countPerPage=5' + '&keyword=' \
                                       + address_no_zero + '&resultType=json' + '&hstryYn=Y')
            sleep(1)
            roadname_info = roadname_result.json()['results']['juso']
            
            if roadname_info == []:
                print(address)
                print('was not able to get roadname info')
            
                continue
                                
        roadname_info = roadname_info[0]               
        
        coor_result = requests.get(coor_base_url + 'confmKey=' + coor_apikey + '&admCd=' + roadname_info['admCd']\
                                   + '&rnMgtSn=' + roadname_info['rnMgtSn'] + '&udrtYn=' + roadname_info['udrtYn']\
                                   + '&buldMnnm=' + roadname_info['buldMnnm'] + '&buldSlno=' + roadname_info['buldSlno']\
                                   + '&resultType=json')
        sleep(1)
        #return coor_result
        
        if coor_result.json()['results']['juso'] == None:
            print(address_no_zero)
            continue
        
        coor_info = coor_result.json()['results']['juso'][0]
        
        coor_x = pd.to_numeric(coor_info['entX'])
        coor_y = pd.to_numeric(coor_info['entY'])
        
        roadname_addr = roadname_info['roadAddrPart1']
        
        coor_data_df.loc[i,'지번주소'] = address
        coor_data_df.loc[i,'도로명주소'] = roadname_addr
        coor_data_df.loc[i, 'x좌표'] = coor_x
        coor_data_df.loc[i, 'y좌표'] = coor_y
        
    
    
    return coor_data_df

# %%
def landnum_modifier(x):
    # x is a string
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x).replace('외', '').replace(' ','')
        splitted = x.split('-')
        if len(splitted) == 1:
            return x + '-0'
        else:
            return x

# %%
def get_year(x):
    if pd.isna(x) == True:
        return x
    else:
        return int(x.split('.')[0])

# %%
def date_modifier(x):
    # x is a string or datetime
    if pd.isna(x) == True:
        return x
    else:
        x = str(x)
        if '-' in x:
            x = x.replace('-', '.')
            
        splitted = x.split('.')
        
        if len(splitted) == 1:
            return np.nan
        else:
            return x.split(' ')[0]

# %%
def get_bd_type(x):
    # x is a string
    
    if pd.isna(x) == True:
        return x
    else:
        if '오피' in x:
            return '오피스텔'
        else:
            return '연립다세대'

# %%
model_names = [f for f in os.listdir('./Training/training_data_ver_22/') if ('catboost_multiclass' in f) & ('lower_lr' not in f)]
model_names

# %%
from catboost import CatBoostClassifier

# %%
basedir = './Training/training_data_ver_22/'
models_list = []
for name in tqdm(model_names):
    model = CatBoostClassifier().load_model(basedir + name)
    models_list.append(model)

# %%
training_data_sample = next(pd.read_csv(basedir + 'training_data_ver_22.csv', chunksize=1))
print(training_data_sample.shape)
training_data_sample

# %%
training_columns = training_data_sample.columns
print(len(training_columns))

# %%
cols_to_drop = ['지번주소', '도로명주소', '건물(단지)명', '전용면적(㎡)', '거래금액(만원)', '계약날짜', '가격_면적', '년', '가격_면적_classes']

# %%
training_cols = []
for col in training_columns:
    if col not in cols_to_drop:
        training_cols.append(col)

# %%
last_df['토지면적'] = last_df['토지면적'].apply(np.log)
last_df.rename(columns={'토지면적':'토지면적_log'}, inplace=True)

# %%
ls_cols = last_df.columns
ls_cols

# %%
ls_cols_to_drop = []

# %%
for col in ls_cols:
    if col not in training_cols:
        ls_cols_to_drop.append(col)

# %%
ls_cols_to_drop.remove('지번주소')

# %%
lp_cols = land_plans_df.columns
lp_cols

# %%
lp_cols_to_drop = []

# %%
for col in lp_cols:
    if col not in training_cols:
        lp_cols_to_drop.append(col)

# %%
lp_cols_to_drop.remove('지번주소')

# %%
def house_area_into_classes(x):
    # x is a number
    
    if pd.isna(x) == True:
        return x
    else:
        for i in range(100):
            if x <= ((i+1)*5):
                return '{}~{}'.format((i*5), (i+1)*5)
        return '500초과'

# %%
coor_minmax_df = pd.read_csv('./Training/training_data_ver_22/coor_minmax.csv')
coor_minmax_df

# %%
xmax = coor_minmax_df['xmax'].iloc[0]
xmin = coor_minmax_df['xmin'].iloc[0]
ymax = coor_minmax_df['ymax'].iloc[0]
ymin = coor_minmax_df['ymin'].iloc[0]

# %%
subway_df = pd.read_csv('./지하철역/subway_coor_2.csv').sort_values(['역명']).reset_index(drop=True)
subway_df['역명'] = subway_df['역명'].apply(lambda x: x.split('_')[0]) + '_' + subway_df['노선명']
print(subway_df.shape)
subway_df.head()

# %%
cat_cols = cat_cols_df = pd.read_csv(basedir + 'cat_cols.csv')['colname'].tolist()
cat_cols

# %%
map_files = [f for f in os.listdir(basedir + 'feature_maps/') if f.endswith('.csv')]
map_files

# %%
for map_file in map_files:
    map_df = pd.read_csv(basedir + 'feature_maps/' + map_file)
    print(map_df.shape)
    display(map_df.head())

# %%
map_files.remove('가격_면적_classes_map.csv')

# %%
def month_circular_sine_func(x):
    return math.sin(2*math.pi*x)

def month_circular_cosine_func(x):
    return math.cos(2*math.pi*x)

# %%
target_addr = '서울특별시 동대문구 전농동 1-70'

# %%
gu = target_addr.split(' ')[1]
dong = target_addr.split(' ')[2]
print(gu)
print(dong)

# %%
timepoint = pd.to_datetime(datetime.datetime.now(), format='%Y.%m.%d')
timepoint

# %%
bdtype = '연립다세대'
btyear = 2021

# %%
land_specs_df['토지이동상황'].value_counts()

# %%
current_usage = '연립'

# %%
addr_df = last_df[last_df['지번주소'] == target_addr]
print(addr_df.shape)
addr_df.head()

# %%
addr_df = addr_df.merge(land_plans_df, on=['지번주소'])
print(addr_df.shape)
addr_df.head()

# %%
addr_df = addr_df.drop(columns=ls_cols_to_drop + lp_cols_to_drop)

# %%
coor_df = fetch_coor_data([target_addr])
coor_df

# %%
addr_df['x좌표'] = coor_df['x좌표'].iloc[0]
addr_df['y좌표'] = coor_df['y좌표'].iloc[0]

# %%
print('가장 가까운 지하철역 역명과 거리를 가져오는 중...')

for j in tqdm(range(subway_df.shape[0])):
    station_name = subway_df['역명'].loc[j]
    subway_x = subway_df['x좌표'].loc[j]
    subway_y = subway_df['y좌표'].loc[j]

    addr_df['{}_distance'.format(station_name)] = np.sqrt((addr_df['x좌표'] - subway_x)**2\
    + (addr_df['y좌표'] - subway_y)**2)

distance_cols = [col for col in addr_df.columns if '_distance' in col]

addr_df['distance_nearest_station'] = addr_df[distance_cols].min(axis=1)
addr_df['nearest_station_name'] = addr_df[distance_cols].idxmin(axis=1).apply(lambda x: x.replace('_distance', ''))
addr_df = addr_df.drop(columns=distance_cols)

# %%
addr_df['xnorm'] = (addr_df['x좌표'] - xmin - ((xmax - xmin)/2))
addr_df['ynorm'] = (addr_df['y좌표'] - ymin - ((ymax - ymin)/2))
addr_df['x_2nd'] = addr_df['xnorm']**2 / 2
addr_df['y_2nd'] = addr_df['ynorm']**2 / 2
addr_df['xy'] = addr_df['xnorm'] * addr_df['ynorm']

addr_df.drop(columns=['x좌표', 'y좌표'], inplace=True)

# %%
addr_df['층'] = '지상'
    
addr_df['부동산유형'] = bdtype

addr_df['건축년도'] = int(btyear)

addr_df['계약날짜기준_건물연식'] = timepoint.year - int(btyear)

addr_df['전용면적_classes'] = house_area_into_classes(60)

addr_df['구'] = gu
addr_df['동'] = dong

addr_df['year_linear'] = (timepoint - pd.to_datetime('2006-01-01')).days / 365

addr_df['year_sin'] = addr_df['year_linear'].apply(month_circular_sine_func)
addr_df['year_cos'] = addr_df['year_linear'].apply(month_circular_cosine_func)

addr_df['지목명'] = '대'

addr_df['토지이동상황'] = current_usage

addr_df = addr_df.drop(columns=['지번주소'])
addr_df = addr_df[training_cols]

# %%
print(addr_df.shape)
display(addr_df)

for file in map_files:
    map_df = pd.read_csv(basedir + 'feature_maps/' + file)
    map_dict = {}
    for j in range(map_df.shape[0]):
        map_dict[map_df.loc[j, 'cat']] = map_df.loc[j, 'map']

    addr_df[file.replace('_map.csv', '')] = addr_df[file.replace('_map.csv', '')].map(map_dict)

print(addr_df.shape)
display(addr_df)

# %%
from catboost import Pool

# %%
preds_list = []
for model in models_list:
    addr_pool = Pool(addr_df, cat_features=cat_cols)
    preds = model.predict_proba(addr_pool)
    preds_list.append(preds)

mean_preds = np.mean(preds_list, axis=0)

# %%
y_map_df = pd.read_csv(basedir + 'feature_maps/가격_면적_classes_map.csv')
print(y_map_df.shape)
y_map_df.head()

# %%
y_map_df['확률'] = mean_preds.T

# %%
y_map_df

# %%
fig = plt.figure(figsize=(50,20))
ax = fig.add_subplot(111)
ax.set_xticklabels(labels=y_map_df['cat'], rotation = 90)
sns.barplot(x=y_map_df['cat'], y=y_map_df['확률'])
plt.savefig('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_{}/기계학습_결과_확률분포도.png'.format(target_gu, target_dong, target_house))
plt.show()
plt.clf()
