# %%
import multiprocess as mp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import math
from tqdm import tqdm
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
import datetime
from sklearn.preprocessing import quantile_transform
pd.options.mode.chained_assignment = None  # default='warn'
import gc

# %%
# %%time
main_data_df = pd.read_csv('./prepped_data/main_data_ver_2.3.csv')
# Out:
# 1
# c:\users\max6296\ml\lib\site-packages\IPython\core\magic.py:187: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# 2
# 3
# 4
# 5
# Wall time: 23.1 s

# %%
main_data_df.head()
# Out:
#              시군구     번지   본번  부번             건물명 전월세매매구분  전용면적(㎡)    계약년월  \
# 0  서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)      매매    77.75  201309
# 1  서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)      매매    77.75  201312
# 2  서울특별시 강남구 개포동  658-1  658   1  개포6차우성아파트1동~8동      매매    67.28  201302
# 3  서울특별시 강남구 개포동  658-1  658   1  개포6차우성아파트1동~8동      매매    67.28  201302
# 4  서울특별시 강남구 개포동  658-1  658   1  개포6차우성아파트1동~8동      매매    67.28  201305
#
#    계약일  금액(만원)  월세(만원)  층  건축년도      도로명       가격/면적  year  month      시    구  \
# 0    8   57000       0  2  1988  언주로 103  733.118971  2013      9  서울특별시  강남구
# 1   16   57000       0  2  1988  언주로 103  733.118971  2013     12  서울특별시  강남구
# 2   11   55000       0  5  1987    언주로 3  817.479191  2013      2  서울특별시  강남구
# 3   22   58250       0  4  1987    언주로 3  865.784780  2013      2  서울특별시  강남구
# 4   10   60000       0  5  1987    언주로 3  891.795482  2013      5  서울특별시  강남구
#
#    target_log_transformed  target/area_log_transformed              동 건물종류  \
# 0               10.950807                     6.597308  서울특별시 강남구 개포동  아파트
# 1               10.950807                     6.597308  서울특별시 강남구 개포동  아파트
# 2               10.915088                     6.706225  서울특별시 강남구 개포동  아파트
# 3               10.972499                     6.763636  서울특별시 강남구 개포동  아파트
# 4               11.002100                     6.793237  서울특별시 강남구 개포동  아파트
#
#   trade_type                 지번주소  대장구분코드 대장구분명                도로명주소
# 0     아파트_매매  서울특별시 강남구 개포동 655-2       1    일반  서울특별시 강남구 언주로 103-0
# 1     아파트_매매  서울특별시 강남구 개포동 655-2       1    일반  서울특별시 강남구 언주로 103-0
# 2     아파트_매매  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0
# 3     아파트_매매  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0
# 4     아파트_매매  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0

# %%
main_data_df.drop(columns=['시군구', '번지', '본번', '부번', '건물명', '도로명', '시', '구', '동'], inplace=True)
main_data_df.head()
# Out:
#   전월세매매구분  전용면적(㎡)    계약년월  계약일  금액(만원)  월세(만원)  층  건축년도       가격/면적  year  \
# 0      매매    77.75  201309    8   57000       0  2  1988  733.118971  2013
# 1      매매    77.75  201312   16   57000       0  2  1988  733.118971  2013
# 2      매매    67.28  201302   11   55000       0  5  1987  817.479191  2013
# 3      매매    67.28  201302   22   58250       0  4  1987  865.784780  2013
# 4      매매    67.28  201305   10   60000       0  5  1987  891.795482  2013
#
#    month  target_log_transformed  target/area_log_transformed 건물종류 trade_type  \
# 0      9               10.950807                     6.597308  아파트     아파트_매매
# 1     12               10.950807                     6.597308  아파트     아파트_매매
# 2      2               10.915088                     6.706225  아파트     아파트_매매
# 3      2               10.972499                     6.763636  아파트     아파트_매매
# 4      5               11.002100                     6.793237  아파트     아파트_매매
#
#                   지번주소  대장구분코드 대장구분명                도로명주소
# 0  서울특별시 강남구 개포동 655-2       1    일반  서울특별시 강남구 언주로 103-0
# 1  서울특별시 강남구 개포동 655-2       1    일반  서울특별시 강남구 언주로 103-0
# 2  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0
# 3  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0
# 4  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0

# %%
main_data_df['대장구분명'].value_counts()
# Out:
# 일반       4553162
# BL          3759
# 산           2091
# 가            508
# 지구BL         346
# Name: 대장구분명, dtype: int64

# %%
main_data_df['대장구분코드'].value_counts()
# Out:
# 1    4553162
# 5       3759
# 2       2091
# 3        508
# 7        346
# Name: 대장구분코드, dtype: int64

# %%
main_data_df['대장구분명'] = main_data_df['대장구분명'].apply(lambda x: '산' if x == '산' else '일반')

# %%
main_data_df['대장구분명'].value_counts()
# Out:
# 일반    4557775
# 산        2091
# Name: 대장구분명, dtype: int64

# %%
main_data_df['대장구분코드'] = main_data_df['대장구분명'].apply(lambda x: 1 if x == '일반' else 2)
main_data_df['대장구분코드'].value_counts()
# Out:
# 1    4557775
# 2       2091
# Name: 대장구분코드, dtype: int64

# %%
main_data_df.head()
# Out:
#   전월세매매구분  전용면적(㎡)    계약년월  계약일  금액(만원)  월세(만원)  층  건축년도       가격/면적  year  \
# 0      매매    77.75  201309    8   57000       0  2  1988  733.118971  2013
# 1      매매    77.75  201312   16   57000       0  2  1988  733.118971  2013
# 2      매매    67.28  201302   11   55000       0  5  1987  817.479191  2013
# 3      매매    67.28  201302   22   58250       0  4  1987  865.784780  2013
# 4      매매    67.28  201305   10   60000       0  5  1987  891.795482  2013
#
#    month  target_log_transformed  target/area_log_transformed 건물종류 trade_type  \
# 0      9               10.950807                     6.597308  아파트     아파트_매매
# 1     12               10.950807                     6.597308  아파트     아파트_매매
# 2      2               10.915088                     6.706225  아파트     아파트_매매
# 3      2               10.972499                     6.763636  아파트     아파트_매매
# 4      5               11.002100                     6.793237  아파트     아파트_매매
#
#                   지번주소  대장구분코드 대장구분명                도로명주소
# 0  서울특별시 강남구 개포동 655-2       1    일반  서울특별시 강남구 언주로 103-0
# 1  서울특별시 강남구 개포동 655-2       1    일반  서울특별시 강남구 언주로 103-0
# 2  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0
# 3  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0
# 4  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0

# %%
main_data_df.drop(columns=['전월세매매구분'], inplace=True)

# %%
main_data_df.head()
# Out:
#    전용면적(㎡)    계약년월  계약일  금액(만원)  월세(만원)  층  건축년도       가격/면적  year  month  \
# 0    77.75  201309    8   57000       0  2  1988  733.118971  2013      9
# 1    77.75  201312   16   57000       0  2  1988  733.118971  2013     12
# 2    67.28  201302   11   55000       0  5  1987  817.479191  2013      2
# 3    67.28  201302   22   58250       0  4  1987  865.784780  2013      2
# 4    67.28  201305   10   60000       0  5  1987  891.795482  2013      5
#
#    target_log_transformed  target/area_log_transformed 건물종류 trade_type  \
# 0               10.950807                     6.597308  아파트     아파트_매매
# 1               10.950807                     6.597308  아파트     아파트_매매
# 2               10.915088                     6.706225  아파트     아파트_매매
# 3               10.972499                     6.763636  아파트     아파트_매매
# 4               11.002100                     6.793237  아파트     아파트_매매
#
#                   지번주소  대장구분코드 대장구분명                도로명주소
# 0  서울특별시 강남구 개포동 655-2       1    일반  서울특별시 강남구 언주로 103-0
# 1  서울특별시 강남구 개포동 655-2       1    일반  서울특별시 강남구 언주로 103-0
# 2  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0
# 3  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0
# 4  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0

# %%
main_data_df.drop(columns=['계약년월', '계약일'], inplace=True)
main_data_df.head()
# Out:
#    전용면적(㎡)  금액(만원)  월세(만원)  층  건축년도       가격/면적  year  month  \
# 0    77.75   57000       0  2  1988  733.118971  2013      9
# 1    77.75   57000       0  2  1988  733.118971  2013     12
# 2    67.28   55000       0  5  1987  817.479191  2013      2
# 3    67.28   58250       0  4  1987  865.784780  2013      2
# 4    67.28   60000       0  5  1987  891.795482  2013      5
#
#    target_log_transformed  target/area_log_transformed 건물종류 trade_type  \
# 0               10.950807                     6.597308  아파트     아파트_매매
# 1               10.950807                     6.597308  아파트     아파트_매매
# 2               10.915088                     6.706225  아파트     아파트_매매
# 3               10.972499                     6.763636  아파트     아파트_매매
# 4               11.002100                     6.793237  아파트     아파트_매매
#
#                   지번주소  대장구분코드 대장구분명                도로명주소
# 0  서울특별시 강남구 개포동 655-2       1    일반  서울특별시 강남구 언주로 103-0
# 1  서울특별시 강남구 개포동 655-2       1    일반  서울특별시 강남구 언주로 103-0
# 2  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0
# 3  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0
# 4  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0

# %%
main_data_df.rename(columns={'year':'년', 'month':'월'}, inplace=True)
main_data_df.head()
# Out:
#    전용면적(㎡)  금액(만원)  월세(만원)  층  건축년도       가격/면적     년   월  \
# 0    77.75   57000       0  2  1988  733.118971  2013   9
# 1    77.75   57000       0  2  1988  733.118971  2013  12
# 2    67.28   55000       0  5  1987  817.479191  2013   2
# 3    67.28   58250       0  4  1987  865.784780  2013   2
# 4    67.28   60000       0  5  1987  891.795482  2013   5
#
#    target_log_transformed  target/area_log_transformed 건물종류 trade_type  \
# 0               10.950807                     6.597308  아파트     아파트_매매
# 1               10.950807                     6.597308  아파트     아파트_매매
# 2               10.915088                     6.706225  아파트     아파트_매매
# 3               10.972499                     6.763636  아파트     아파트_매매
# 4               11.002100                     6.793237  아파트     아파트_매매
#
#                   지번주소  대장구분코드 대장구분명                도로명주소
# 0  서울특별시 강남구 개포동 655-2       1    일반  서울특별시 강남구 언주로 103-0
# 1  서울특별시 강남구 개포동 655-2       1    일반  서울특별시 강남구 언주로 103-0
# 2  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0
# 3  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0
# 4  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0

# %%
main_data_df.drop(columns=['건물종류'], inplace=True)
main_data_df.head()
# Out:
#    전용면적(㎡)  금액(만원)  월세(만원)  층  건축년도       가격/면적     년   월  \
# 0    77.75   57000       0  2  1988  733.118971  2013   9
# 1    77.75   57000       0  2  1988  733.118971  2013  12
# 2    67.28   55000       0  5  1987  817.479191  2013   2
# 3    67.28   58250       0  4  1987  865.784780  2013   2
# 4    67.28   60000       0  5  1987  891.795482  2013   5
#
#    target_log_transformed  target/area_log_transformed trade_type  \
# 0               10.950807                     6.597308     아파트_매매
# 1               10.950807                     6.597308     아파트_매매
# 2               10.915088                     6.706225     아파트_매매
# 3               10.972499                     6.763636     아파트_매매
# 4               11.002100                     6.793237     아파트_매매
#
#                   지번주소  대장구분코드 대장구분명                도로명주소
# 0  서울특별시 강남구 개포동 655-2       1    일반  서울특별시 강남구 언주로 103-0
# 1  서울특별시 강남구 개포동 655-2       1    일반  서울특별시 강남구 언주로 103-0
# 2  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0
# 3  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0
# 4  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0

# %%
main_data_df['건물나이'] = main_data_df['년'] - main_data_df['건축년도']

# %%
main_data_df.head()
# Out:
#    전용면적(㎡)  금액(만원)  월세(만원)  층  건축년도       가격/면적     년   월  \
# 0    77.75   57000       0  2  1988  733.118971  2013   9
# 1    77.75   57000       0  2  1988  733.118971  2013  12
# 2    67.28   55000       0  5  1987  817.479191  2013   2
# 3    67.28   58250       0  4  1987  865.784780  2013   2
# 4    67.28   60000       0  5  1987  891.795482  2013   5
#
#    target_log_transformed  target/area_log_transformed trade_type  \
# 0               10.950807                     6.597308     아파트_매매
# 1               10.950807                     6.597308     아파트_매매
# 2               10.915088                     6.706225     아파트_매매
# 3               10.972499                     6.763636     아파트_매매
# 4               11.002100                     6.793237     아파트_매매
#
#                   지번주소  대장구분코드 대장구분명                도로명주소  건물나이
# 0  서울특별시 강남구 개포동 655-2       1    일반  서울특별시 강남구 언주로 103-0    25
# 1  서울특별시 강남구 개포동 655-2       1    일반  서울특별시 강남구 언주로 103-0    25
# 2  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0    26
# 3  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0    26
# 4  서울특별시 강남구 개포동 658-1       1    일반    서울특별시 강남구 언주로 3-0    26

# %%
main_data_df = main_data_df[['지번주소', '도로명주소', '대장구분명', '대장구분코드', 'trade_type', '전용면적(㎡)',
                             '금액(만원)', '월세(만원)', '가격/면적', '층', '년', '월', '건축년도', '건물나이',
                             'target_log_transformed', 'target/area_log_transformed'
                            ]]

# %%
main_data_df.head()
# Out:
#                   지번주소                도로명주소 대장구분명  대장구분코드 trade_type  전용면적(㎡)  \
# 0  서울특별시 강남구 개포동 655-2  서울특별시 강남구 언주로 103-0    일반       1     아파트_매매    77.75
# 1  서울특별시 강남구 개포동 655-2  서울특별시 강남구 언주로 103-0    일반       1     아파트_매매    77.75
# 2  서울특별시 강남구 개포동 658-1    서울특별시 강남구 언주로 3-0    일반       1     아파트_매매    67.28
# 3  서울특별시 강남구 개포동 658-1    서울특별시 강남구 언주로 3-0    일반       1     아파트_매매    67.28
# 4  서울특별시 강남구 개포동 658-1    서울특별시 강남구 언주로 3-0    일반       1     아파트_매매    67.28
#
#    금액(만원)  월세(만원)       가격/면적  층     년   월  건축년도  건물나이  \
# 0   57000       0  733.118971  2  2013   9  1988    25
# 1   57000       0  733.118971  2  2013  12  1988    25
# 2   55000       0  817.479191  5  2013   2  1987    26
# 3   58250       0  865.784780  4  2013   2  1987    26
# 4   60000       0  891.795482  5  2013   5  1987    26
#
#    target_log_transformed  target/area_log_transformed
# 0               10.950807                     6.597308
# 1               10.950807                     6.597308
# 2               10.915088                     6.706225
# 3               10.972499                     6.763636
# 4               11.002100                     6.793237

# %%
main_data_df.to_csv('main_data_ver_2.4.csv', index=False)
