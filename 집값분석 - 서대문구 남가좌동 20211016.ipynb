# %%
# 2021/09/16 업데이트 내용
# 더 이상 폴더 생성시 연립다세대_오피스텔 입력하지 않아도 됨

# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
pd.options.mode.chained_assignment = None  # default='warn'
plt.rcParams['font.family'] = 'Malgun Gothic'
import datetime

# %%
target_gu = '서대문구' # 구 명
target_dong = '남가좌' # 동 명: 동 명에서 마지막 글자 '동' 뺄 것
#target_purpose = '준주거' # 종 명: 건드릴 필요 없음
target_building_age = 5 # 건물연식: 건드릴 필요 없음
target_period = 36 # 계약날짜 검색범위: 건드릴 필요 없음
target_starting_year = 2018 # 검색 시작 계약 년도: 건드릴 필요 없음

# %%
date_today = pd.to_datetime(datetime.datetime.now().strftime('%Y-%m-%d'), format='%Y-%m-%d')

# %%
date_today_record = str(date_today).split(' ')[0].replace('-', '')
date_today_record
# Out:
# '20211016'

# %%
def day_modifier(x):
    # x is a number
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x)
        if len(x) == 1:
            return '0' + x
        else:
            return x

# %%
def landnum_modifier(x):
    # x is a string
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x).replace('외', '').replace(' ','')
        splitted = x.split('-')
        if len(splitted) == 1:
            return x + '-0'
        else:
            return x

# %%
def data_prep(bdtype, tradetype, starting_year=2018):
    # bdtype is a string: one of 아파트, 연립다세대 or 오피스텔
    # tradetype is a string: one of 매매 or 전월세
    if (tradetype != '매매') & (tradetype != '전월세'):
        raise ValueError('두번째 변수는 매매 또는 전월세만 입력 가능')
    
    
    basedir = './국토교통부_실거래가_공개시스템/{}/{}/'.format(bdtype, tradetype)
    filenames = [f for f in os.listdir(basedir) if (f.endswith('.csv'))&('(' in f)]
    
    dfs_list = []
    for i, f in tqdm(enumerate(filenames)):
        splitted_filename = f.split('실거래가_')       
        file_year = int(splitted_filename[-1][:4])
        
        if file_year < starting_year:
            continue
        
        try:
            df = pd.read_csv(basedir + f, encoding='euc-kr', header=15)
        except:
            try:
                df = pd.read_csv(basedir + f, encoding='utf-8', header=15)
            except:
                df = pd.read_csv(basedir + f, header=15)
        
        if '건물명' in df.columns:
            df.rename(columns={'건물명':'건물(단지)명'}, inplace=True)
        elif '단지명' in df.columns:
            df.rename(columns={'단지명':'건물(단지)명'}, inplace=True)
            
        if '대지권면적(㎡)' in df.columns:
            df = df.drop(columns=['대지권면적(㎡)'])
                
            
        if '해제사유발생일' in df.columns.tolist():
            df = df[df['해제사유발생일'].isna()]
            df = df.drop(columns=['해제사유발생일'])
            
        dfs_list.append(df)
    
    concat_df = pd.concat(dfs_list).reset_index(drop=True)
    
    if tradetype == '전월세':
        concat_df = concat_df.rename(columns={'전월세구분':'거래구분', '보증금(만원)':'거래금액(만원)'})
        concat_df = concat_df.drop(columns=['월세(만원)'])
        concat_df = concat_df[concat_df['거래구분'] == '전세']
    elif tradetype == '매매':
        concat_df['거래구분'] = '매매'
        
    concat_df['번지'] = concat_df['번지'].apply(landnum_modifier)
    
    concat_df['계약년월'] = concat_df['계약년월'].astype('Int64')
    concat_df['계약일'] = concat_df['계약일'].astype('Int64')
    
    concat_df['계약년월'] = concat_df['계약년월'].apply(str)
    concat_df['계약일'] = concat_df['계약일'].apply(str)
    
    concat_df['계약날짜기준_건물연식'] = concat_df['계약년월'].apply(lambda x: int(x[:4])) - concat_df['건축년도']
    
    concat_df['계약일'] = concat_df['계약일'].apply(day_modifier)
    
    concat_df['계약날짜'] = concat_df['계약년월'].apply(lambda x: x[:4]) + '-' + concat_df['계약년월'].apply(lambda x: x[-2:])\
    + '-' + concat_df['계약일']
    
    concat_df['계약날짜'] = pd.to_datetime(concat_df['계약날짜'], format='%Y-%m-%d')
    
    concat_df['거래금액(만원)'] = concat_df['거래금액(만원)'].apply(lambda x: int(x.replace(',','')))
    concat_df['단가(만원/㎡)'] = concat_df['거래금액(만원)'] / concat_df['전용면적(㎡)']
    
    concat_df['지번주소'] = concat_df['시군구'] + ' ' + concat_df['번지']
        
    cols_to_drop = ['시군구', '번지', '본번', '부번', '지번주소', '계약년월', '계약일', '도로명']
        
    concat_df = concat_df[['지번주소', '도로명'] + [col for col in concat_df.columns if col not in cols_to_drop]]
    
    date_today = pd.to_datetime(datetime.datetime.now().strftime('%Y-%m-%d'), format='%Y-%m-%d')
    concat_df['건물연식'] = date_today.year - concat_df['건축년도']
    
    concat_df = concat_df.dropna(subset=['지번주소'])
    
    concat_df = concat_df[concat_df['층'] >= 0].reset_index(drop=True)
    
    return concat_df

# %%
apart_trade_df = data_prep('아파트', '매매')
apart_lease_df = data_prep('아파트', '전월세')
apart_df = pd.concat([apart_trade_df, apart_lease_df]).reset_index(drop=True)
del apart_trade_df, apart_lease_df
apart_df['부동산유형'] = '아파트'
print(apart_df.shape)
apart_df.head()
# Out:
# 16it [00:00, 30.96it/s]
# 13it [00:00, 47.27it/s]c:\users\max6296\ml\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# 16it [00:01, 14.63it/s]
# (740807, 13)
#                   지번주소    도로명         건물(단지)명  전용면적(㎡)  거래금액(만원)  층  건축년도  \
# 0  서울특별시 강남구 개포동 658-1  언주로 3  개포6차우성아파트1동~8동    79.97    130000  4  1987
# 1  서울특별시 강남구 개포동 658-1  언주로 3  개포6차우성아파트1동~8동    79.97    117000  2  1987
# 2  서울특별시 강남구 개포동 658-1  언주로 3  개포6차우성아파트1동~8동    79.97    130000  1  1987
# 3  서울특별시 강남구 개포동 658-1  언주로 3  개포6차우성아파트1동~8동    79.97    139500  2  1987
# 4  서울특별시 강남구 개포동 658-1  언주로 3  개포6차우성아파트1동~8동    54.98    107500  5  1987
#
#   거래구분  계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식 부동산유형
# 0   매매           31 2018-01-03  1625.609604    34   아파트
# 1   매매           31 2018-01-08  1463.048643    34   아파트
# 2   매매           31 2018-01-11  1625.609604    34   아파트
# 3   매매           31 2018-03-19  1744.404152    34   아파트
# 4   매매           31 2018-04-05  1955.256457    34   아파트

# %%
yunrip_trade_df = data_prep('연립다세대', '매매')
yunrip_lease_df = data_prep('연립다세대', '전월세')
yunrip_df = pd.concat([yunrip_trade_df, yunrip_lease_df]).reset_index(drop=True)
del yunrip_trade_df, yunrip_lease_df
yunrip_df['부동산유형'] = '연립다세대'
print(yunrip_df.shape)
yunrip_df.head()
# Out:
# 16it [00:00, 33.61it/s]
# 16it [00:00, 21.01it/s]
# (440964, 13)
#                    지번주소         도로명   건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 0  서울특별시 강남구 개포동 1172-2  논현로6길 22-6  (1172-2)    29.95     25000  4  2012.0
# 1  서울특별시 강남구 개포동 1216-4   개포로26길 16  (1216-4)    29.12     25300  4  2012.0
# 2  서울특별시 강남구 개포동 1187-8    논현로8길 17    1187-8    55.96     45500  4  2015.0
# 3  서울특별시 강남구 개포동 1187-8    논현로8길 17    1187-8    59.84     51000  3  2015.0
# 4  서울특별시 강남구 개포동 1187-8    논현로8길 17    1187-8    59.84     51000  2  2015.0
#
#   거래구분  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형
# 0   매매          6.0 2018-01-13  834.724541   9.0  연립다세대
# 1   매매          6.0 2018-10-23  868.818681   9.0  연립다세대
# 2   매매          3.0 2018-01-04  813.080772   6.0  연립다세대
# 3   매매          3.0 2018-03-09  852.272727   6.0  연립다세대
# 4   매매          3.0 2018-04-14  852.272727   6.0  연립다세대

# %%
officetel_trade_df = data_prep('오피스텔', '매매')
officetel_lease_df = data_prep('오피스텔', '전월세')
officetel_df = pd.concat([officetel_trade_df, officetel_lease_df]).reset_index(drop=True)
del officetel_trade_df, officetel_lease_df
officetel_df['부동산유형'] = '오피스텔'
print(officetel_df.shape)
officetel_df.head()
# Out:
# 16it [00:00, 128.79it/s]
# 16it [00:00, 45.01it/s]
# (141017, 13)
#                  지번주소      도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)   층    건축년도 거래구분  \
# 0  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    31.91     18500  20  1997.0   매매
# 1  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    31.91     19900  14  1997.0   매매
# 2  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44     20000  26  1997.0   매매
# 3  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44     20000  26  1997.0   매매
# 4  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44     21000  22  1997.0   매매
#
#    계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식 부동산유형
# 0         21.0 2018-01-02  579.755563  24.0  오피스텔
# 1         21.0 2018-01-04  623.628956  24.0  오피스텔
# 2         21.0 2018-01-08  616.522811  24.0  오피스텔
# 3         21.0 2018-01-18  616.522811  24.0  오피스텔
# 4         21.0 2018-01-20  647.348952  24.0  오피스텔

# %%
house_df = pd.concat([apart_df, yunrip_df, officetel_df]).sort_values(['지번주소', '건축년도', '전용면적(㎡)', '계약날짜']).reset_index(drop=True)
del apart_df, yunrip_df, officetel_df
print(house_df.shape)
house_df.head()
# Out:
# (1322788, 13)
#                    지번주소     도로명   건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도 거래구분  \
# 0  서울특별시 강남구 개포동 1163-4  논현로 10  (1163-4)    13.56     10000  5  2013.0   전세
# 1  서울특별시 강남구 개포동 1163-4  논현로 10  (1163-4)    21.88     15000  4  2013.0   전세
# 2  서울특별시 강남구 개포동 1163-4  논현로 10  (1163-4)    21.88     15000  3  2013.0   전세
# 3  서울특별시 강남구 개포동 1163-4  논현로 10  (1163-4)    21.88     16000  4  2013.0   전세
# 4  서울특별시 강남구 개포동 1163-4  논현로 10  (1163-4)    21.88     16000  3  2013.0   전세
#
#    계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형
# 0          5.0 2018-07-09  737.463127   8.0  연립다세대
# 1          5.0 2018-04-03  685.557587   8.0  연립다세대
# 2          6.0 2019-02-24  685.557587   8.0  연립다세대
# 3          6.0 2019-03-16  731.261426   8.0  연립다세대
# 4          6.0 2019-04-02  731.261426   8.0  연립다세대

# %%
'''land_specs_df = pd.read_csv('./prepped_data/land_specs_ver_4.csv')
print(land_specs_df.shape)
land_specs_df.head()'''
# Out:
# "land_specs_df = pd.read_csv('./prepped_data/land_specs_ver_4.csv')\nprint(land_specs_df.shape)\nland_specs_df.head()"

# %%
'''last_df = land_specs_df.drop_duplicates(subset=['지번주소'], keep='last').drop(columns=['년', '공시지가']).reset_index(drop=True)
print(last_df.shape)
last_df.head()'''
# Out:
# "last_df = land_specs_df.drop_duplicates(subset=['지번주소'], keep='last').drop(columns=['년', '공시지가']).reset_index(drop=True)\nprint(last_df.shape)\nlast_df.head()"

# %%
'''house_merge_df = house_df.merge(last_df, on=['지번주소']).reset_index(drop=True)
print(house_merge_df.shape)'''
# Out:
# "house_merge_df = house_df.merge(last_df, on=['지번주소']).reset_index(drop=True)\nprint(house_merge_df.shape)"

# %%
house_df['구'] = house_df['지번주소'].apply(lambda x: x.split(' ')[1])
house_df['동'] = house_df['지번주소'].apply(lambda x: x.split(' ')[2])
#house_merge_df['구'] = house_merge_df['지번주소'].apply(lambda x: x.split(' ')[1])
#house_merge_df['동'] = house_merge_df['지번주소'].apply(lambda x: x.split(' ')[2])

# %%
house_df['일괄계약'] = 'N'

# %%
#house_df = house_df.merge(last_df, on=['지번주소']).reset_index(drop=True)

# %%
'''print(house_df.shape)
house_df.head()'''
# Out:
# 'print(house_df.shape)\nhouse_df.head()'

# %%
def identify_bulk_contract(df):
    df = df.copy()
    
    for addr in tqdm(df['지번주소'].unique()):
        addr_df = df[df['지번주소'] == addr]
        
        for btyear in addr_df['건축년도'].unique():
            btyear_df = addr_df[addr_df['건축년도'] == btyear]
        
            for contract_date in btyear_df['계약날짜'].unique():
                contract_date_df = btyear_df[btyear_df['계약날짜'] == contract_date]

                if contract_date_df.shape[0] >= 5:
                    df.loc[contract_date_df.index, '일괄계약'] = 'Y'
    
    return df

# %%
target_1_12_df = house_df[
    (house_df['지번주소'].str.contains(target_gu + ' ' + target_dong))
    #&(house_df['동'] == target_dong)
    &(house_df['계약날짜'] >= (date_today - pd.DateOffset(months=6)))
    &(house_df['건물연식'] <= target_building_age)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_1_12_df.shape)
target_1_12_df.head()
# Out:
# (134, 16)
#                           지번주소           도로명       건물(단지)명  전용면적(㎡)  거래금액(만원)  \
# 724235   서울특별시 서대문구 남가좌동 3-100       명지대7길 6  라임하우스(3-100)   49.610     26400
# 724255    서울특별시 서대문구 남가좌동 3-39   명지대5길 22-12         거북하우스   25.675     15000
# 724295  서울특별시 서대문구 남가좌동 325-10  증가로10길 36-21           우선빌   28.680     15750
# 724382  서울특별시 서대문구 남가좌동 331-10    가재울로2안길 11         루체비스타   46.440     33100
# 724383  서울특별시 서대문구 남가좌동 331-10    가재울로2안길 11         루체비스타   46.440     33100
#
#         층    건축년도 거래구분  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형     구  \
# 724235  3  2018.0   매매          3.0 2021-09-23  532.150776   3.0  연립다세대  서대문구
# 724255  5  2016.0   전세          5.0 2021-07-30  584.225901   5.0  연립다세대  서대문구
# 724295  3  2017.0   전세          4.0 2021-10-12  549.163180   4.0  연립다세대  서대문구
# 724382  3  2021.0   매매          0.0 2021-06-30  712.747631   0.0  연립다세대  서대문구
# 724383  2  2021.0   매매          0.0 2021-06-30  712.747631   0.0  연립다세대  서대문구
#
#            동 일괄계약
# 724235  남가좌동    N
# 724255  남가좌동    N
# 724295  남가좌동    N
# 724382  남가좌동    N
# 724383  남가좌동    N

# %%
target_2_24_df = house_df[
    (house_df['지번주소'].str.contains(target_gu + ' ' + target_dong))
    #&(house_df['동'] == target_dong)
    &(house_df['계약날짜'] >= (date_today - pd.DateOffset(months=12)))
    &(house_df['건물연식'] <= target_building_age)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_2_24_df.shape)
target_2_24_df.head()
# Out:
# (326, 16)
#                           지번주소           도로명       건물(단지)명  전용면적(㎡)  거래금액(만원)  \
# 724233   서울특별시 서대문구 남가좌동 3-100       명지대7길 6  라임하우스(3-100)   49.610     23000
# 724234   서울특별시 서대문구 남가좌동 3-100       명지대7길 6  라임하우스(3-100)   49.610     23000
# 724235   서울특별시 서대문구 남가좌동 3-100       명지대7길 6  라임하우스(3-100)   49.610     26400
# 724255    서울특별시 서대문구 남가좌동 3-39   명지대5길 22-12         거북하우스   25.675     15000
# 724295  서울특별시 서대문구 남가좌동 325-10  증가로10길 36-21           우선빌   28.680     15750
#
#         층    건축년도 거래구분  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형     구  \
# 724233  3  2018.0   전세          2.0 2020-10-30  463.616206   3.0  연립다세대  서대문구
# 724234  3  2018.0   전세          2.0 2020-10-30  463.616206   3.0  연립다세대  서대문구
# 724235  3  2018.0   매매          3.0 2021-09-23  532.150776   3.0  연립다세대  서대문구
# 724255  5  2016.0   전세          5.0 2021-07-30  584.225901   5.0  연립다세대  서대문구
# 724295  3  2017.0   전세          4.0 2021-10-12  549.163180   4.0  연립다세대  서대문구
#
#            동 일괄계약
# 724233  남가좌동    N
# 724234  남가좌동    N
# 724235  남가좌동    N
# 724255  남가좌동    N
# 724295  남가좌동    N

# %%
target_3_36_df = house_df[
    (house_df['지번주소'].str.contains(target_gu + ' ' + target_dong))
    #&(house_df['동'] == target_dong)
    &(house_df['계약날짜'] >= (date_today - pd.DateOffset(months=24)))
    &(house_df['건물연식'] <= target_building_age)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_3_36_df.shape)
target_3_36_df.head()
# Out:
# (721, 16)
#                          지번주소          도로명       건물(단지)명  전용면적(㎡)  거래금액(만원)  \
# 724233  서울특별시 서대문구 남가좌동 3-100      명지대7길 6  라임하우스(3-100)   49.610     23000
# 724234  서울특별시 서대문구 남가좌동 3-100      명지대7길 6  라임하우스(3-100)   49.610     23000
# 724235  서울특별시 서대문구 남가좌동 3-100      명지대7길 6  라임하우스(3-100)   49.610     26400
# 724254   서울특별시 서대문구 남가좌동 3-39  명지대5길 22-12         거북하우스   25.675     14000
# 724255   서울특별시 서대문구 남가좌동 3-39  명지대5길 22-12         거북하우스   25.675     15000
#
#         층    건축년도 거래구분  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형     구  \
# 724233  3  2018.0   전세          2.0 2020-10-30  463.616206   3.0  연립다세대  서대문구
# 724234  3  2018.0   전세          2.0 2020-10-30  463.616206   3.0  연립다세대  서대문구
# 724235  3  2018.0   매매          3.0 2021-09-23  532.150776   3.0  연립다세대  서대문구
# 724254  5  2016.0   전세          4.0 2020-05-04  545.277507   5.0  연립다세대  서대문구
# 724255  5  2016.0   전세          5.0 2021-07-30  584.225901   5.0  연립다세대  서대문구
#
#            동 일괄계약
# 724233  남가좌동    N
# 724234  남가좌동    N
# 724235  남가좌동    N
# 724254  남가좌동    N
# 724255  남가좌동    N

# %%
target_5_60_df = house_df[
    (house_df['지번주소'].str.contains(target_gu + ' ' + target_dong))
    #&(house_df['동'] == target_dong)
    &(house_df['계약날짜'] >= (date_today - pd.DateOffset(months=36)))
    &(house_df['건물연식'] <= target_building_age)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_5_60_df.shape)
target_5_60_df.head()
# Out:
# (1034, 16)
#                          지번주소      도로명       건물(단지)명  전용면적(㎡)  거래금액(만원)  층  \
# 724227  서울특별시 서대문구 남가좌동 3-100  명지대7길 6  라임하우스(3-100)    28.10     17000  4
# 724229  서울특별시 서대문구 남가좌동 3-100  명지대7길 6  라임하우스(3-100)    49.61     23000  3
# 724230  서울특별시 서대문구 남가좌동 3-100  명지대7길 6  라임하우스(3-100)    49.61     22000  3
# 724231  서울특별시 서대문구 남가좌동 3-100  명지대7길 6  라임하우스(3-100)    49.61     22000  2
# 724232  서울특별시 서대문구 남가좌동 3-100  명지대7길 6  라임하우스(3-100)    49.61     21000  2
#
#           건축년도 거래구분  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형     구  \
# 724227  2018.0   전세          0.0 2018-12-20  604.982206   3.0  연립다세대  서대문구
# 724229  2018.0   전세          0.0 2018-11-06  463.616206   3.0  연립다세대  서대문구
# 724230  2018.0   전세          0.0 2018-12-17  443.458980   3.0  연립다세대  서대문구
# 724231  2018.0   전세          1.0 2019-02-02  443.458980   3.0  연립다세대  서대문구
# 724232  2018.0   전세          1.0 2019-10-05  423.301754   3.0  연립다세대  서대문구
#
#            동 일괄계약
# 724227  남가좌동    N
# 724229  남가좌동    N
# 724230  남가좌동    N
# 724231  남가좌동    N
# 724232  남가좌동    N

# %%
target_1_12_df = identify_bulk_contract(target_1_12_df)
print(target_1_12_df.shape)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 16/16 [00:00<00:00, 275.86it/s]
# (134, 16)

# %%
target_2_24_df = identify_bulk_contract(target_2_24_df)
print(target_2_24_df.shape)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 178.22it/s]
# (326, 16)

# %%
target_3_36_df = identify_bulk_contract(target_3_36_df)
print(target_3_36_df.shape)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 164.47it/s]
# (721, 16)

# %%
target_5_60_df = identify_bulk_contract(target_5_60_df)
print(target_5_60_df.shape)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 106.12it/s]
# (1034, 16)

# %%
sales_idx_basedir = './한국부동산원/실거래가격지수/'
filenames = [f for f in os.listdir(sales_idx_basedir) if '연립다세대' in f]

sales_idx_df = pd.read_excel(sales_idx_basedir + filenames[0], header=[10, 11])

sales_idx_cols_list = []
for i in range(sales_idx_df.shape[1]):
    if i == 0:
        sales_idx_cols_list.append(sales_idx_df.columns[i][0])
    else:
        sales_idx_cols_list.append(sales_idx_df.columns[i][0] + '_' + sales_idx_df.columns[i][1])

sales_idx_df.columns = sales_idx_cols_list

# %%
print(sales_idx_df.shape)
sales_idx_df.head()
# Out:
# (1, 375)
#   지 역  2006년 01월_지수 2006년 01월_변동률  2006년 02월_지수  2006년 02월_변동률  2006년 03월_지수  \
# 0  서울        50.223             -        49.897          -0.65        51.643
#
#    2006년 03월_변동률  2006년 04월_지수  2006년 04월_변동률  2006년 05월_지수  2006년 05월_변동률  \
# 0            3.5        52.911           2.45        53.494            1.1
#
#    2006년 06월_지수  2006년 06월_변동률  2006년 07월_지수  2006년 07월_변동률  2006년 08월_지수  \
# 0        53.571           0.14        55.067           2.79        57.287
#
#    2006년 08월_변동률  2006년 09월_지수  2006년 09월_변동률  2006년 10월_지수  2006년 10월_변동률  \
# 0           4.03        59.277           3.47         62.23           4.98
#
#    2006년 11월_지수  2006년 11월_변동률  2006년 12월_지수  2006년 12월_변동률  2007년 01월_지수  \
# 0        64.493           3.64        65.723           1.91        67.501
#
#    2007년 01월_변동률  2007년 02월_지수  2007년 02월_변동률  2007년 03월_지수  2007년 03월_변동률  \
# 0           2.71        67.381          -0.18        68.878           2.22
#
#    2007년 04월_지수  2007년 04월_변동률  2007년 05월_지수  2007년 05월_변동률  2007년 06월_지수  \
# 0        70.867           2.89        71.332           0.66        73.711
#
#    2007년 06월_변동률  2007년 07월_지수  2007년 07월_변동률  2007년 08월_지수  2007년 08월_변동률  \
# 0           3.34        75.585           2.54        76.403           1.08
#
#    2007년 09월_지수  2007년 09월_변동률  2007년 10월_지수  2007년 10월_변동률  2007년 11월_지수  \
# 0        77.788           1.81        80.505           3.49        81.347
#
#    2007년 11월_변동률  2007년 12월_지수  2007년 12월_변동률  2008년 01월_지수  2008년 01월_변동률  \
# 0           1.05        82.994           2.02        85.398            2.9
#
#    2008년 02월_지수  2008년 02월_변동률  2008년 03월_지수  2008년 03월_변동률  2008년 04월_지수  \
# 0        87.003           1.88        91.171           4.79        94.562
#
#    2008년 04월_변동률  2008년 05월_지수  2008년 05월_변동률  2008년 06월_지수  2008년 06월_변동률  \
# 0           3.72        97.186           2.78        98.025           0.86
#
#    2008년 07월_지수  2008년 07월_변동률  2008년 08월_지수  2008년 08월_변동률  2008년 09월_지수  \
# 0        96.774          -1.28        95.482          -1.34        95.046
#
#    2008년 09월_변동률  2008년 10월_지수  2008년 10월_변동률  2008년 11월_지수  2008년 11월_변동률  \
# 0          -0.46        91.893          -3.32        87.371          -4.92
#
#    2008년 12월_지수  2008년 12월_변동률  2009년 01월_지수  2009년 01월_변동률  2009년 02월_지수  \
# 0        84.372          -3.43        84.496           0.15         85.81
#
#    2009년 02월_변동률  2009년 03월_지수  2009년 03월_변동률  2009년 04월_지수  2009년 04월_변동률  \
# 0           1.56        86.507           0.81        88.271           2.04
#
#    2009년 05월_지수  2009년 05월_변동률  2009년 06월_지수  2009년 06월_변동률  2009년 07월_지수  \
# 0        90.382           2.39        91.056           0.75         92.93
#
#    2009년 07월_변동률  2009년 08월_지수  2009년 08월_변동률  2009년 09월_지수  2009년 09월_변동률  \
# 0           2.06         94.91           2.13        96.368           1.54
#
#    2009년 10월_지수  2009년 10월_변동률  2009년 11월_지수  2009년 11월_변동률  2009년 12월_지수  \
# 0        95.693           -0.7        94.632          -1.11        94.782
#
#    2009년 12월_변동률  2010년 01월_지수  2010년 01월_변동률  2010년 02월_지수  2010년 02월_변동률  \
# 0           0.16        96.238           1.54        96.013          -0.23
#
#    2010년 03월_지수  2010년 03월_변동률  2010년 04월_지수  2010년 04월_변동률  2010년 05월_지수  \
# 0        95.445          -0.59        94.998          -0.47          94.6
#
#    2010년 05월_변동률  2010년 06월_지수  2010년 06월_변동률  2010년 07월_지수  2010년 07월_변동률  \
# 0          -0.42        92.702          -2.01        92.078          -0.67
#
#    2010년 08월_지수  2010년 08월_변동률  2010년 09월_지수  2010년 09월_변동률  2010년 10월_지수  \
# 0        91.605          -0.51        91.496          -0.12        90.884
#
#    2010년 10월_변동률  2010년 11월_지수  2010년 11월_변동률  2010년 12월_지수  2010년 12월_변동률  \
# 0          -0.67        91.546           0.73        91.717           0.19
#
#    2011년 01월_지수  2011년 01월_변동률  2011년 02월_지수  2011년 02월_변동률  2011년 03월_지수  \
# 0         92.03           0.34        92.846           0.89        93.011
#
#    2011년 03월_변동률  2011년 04월_지수  2011년 04월_변동률  2011년 05월_지수  2011년 05월_변동률  \
# 0           0.18        92.466          -0.59        92.734           0.29
#
#    2011년 06월_지수  2011년 06월_변동률  2011년 07월_지수  2011년 07월_변동률  2011년 08월_지수  \
# 0        91.992           -0.8        91.738          -0.28         91.19
#
#    2011년 08월_변동률  2011년 09월_지수  2011년 09월_변동률  2011년 10월_지수  2011년 10월_변동률  \
# 0           -0.6         92.06           0.95        91.498          -0.61
#
#    2011년 11월_지수  2011년 11월_변동률  2011년 12월_지수  2011년 12월_변동률  2012년 01월_지수  \
# 0        90.733          -0.84        89.997          -0.81        90.623
#
#    2012년 01월_변동률  2012년 02월_지수  2012년 02월_변동률  2012년 03월_지수  2012년 03월_변동률  \
# 0            0.7        90.209          -0.46            90          -0.23
#
#    2012년 04월_지수  2012년 04월_변동률  2012년 05월_지수  2012년 05월_변동률  2012년 06월_지수  \
# 0        88.699          -1.45        87.547           -1.3        88.178
#
#    2012년 06월_변동률  2012년 07월_지수  2012년 07월_변동률  2012년 08월_지수  2012년 08월_변동률  \
# 0           0.72        86.212          -2.23        86.476           0.31
#
#    2012년 09월_지수  2012년 09월_변동률  2012년 10월_지수  2012년 10월_변동률  2012년 11월_지수  \
# 0        86.805           0.38        85.366          -1.66        85.653
#
#    2012년 11월_변동률  2012년 12월_지수  2012년 12월_변동률  2013년 01월_지수  2013년 01월_변동률  \
# 0           0.34        84.578          -1.25        84.863           0.34
#
#    2013년 02월_지수  2013년 02월_변동률  2013년 03월_지수  2013년 03월_변동률  2013년 04월_지수  \
# 0        85.068           0.24        85.538           0.55        85.832
#
#    2013년 04월_변동률  2013년 05월_지수  2013년 05월_변동률  2013년 06월_지수  2013년 06월_변동률  \
# 0           0.34        84.709          -1.31          84.5          -0.25
#
#    2013년 07월_지수  2013년 07월_변동률  2013년 08월_지수  2013년 08월_변동률  2013년 09월_지수  \
# 0        85.373           1.03        85.294          -0.09        85.974
#
#    2013년 09월_변동률  2013년 10월_지수  2013년 10월_변동률  2013년 11월_지수  2013년 11월_변동률  \
# 0            0.8        85.598          -0.44         85.37          -0.27
#
#    2013년 12월_지수  2013년 12월_변동률  2014년 01월_지수  2014년 01월_변동률  2014년 02월_지수  \
# 0        83.607          -2.07        84.814           1.44        85.606
#
#    2014년 02월_변동률  2014년 03월_지수  2014년 03월_변동률  2014년 04월_지수  2014년 04월_변동률  \
# 0           0.93        85.919           0.37        85.943           0.03
#
#    2014년 05월_지수  2014년 05월_변동률  2014년 06월_지수  2014년 06월_변동률  2014년 07월_지수  \
# 0         85.24          -0.82        85.105          -0.16        85.144
#
#    2014년 07월_변동률  2014년 08월_지수  2014년 08월_변동률  2014년 09월_지수  2014년 09월_변동률  \
# 0           0.05        85.647           0.59        86.303           0.77
#
#    2014년 10월_지수  2014년 10월_변동률  2014년 11월_지수  2014년 11월_변동률  2014년 12월_지수  \
# 0         86.29          -0.02        85.453          -0.97        85.594
#
#    2014년 12월_변동률  2015년 01월_지수  2015년 01월_변동률  2015년 02월_지수  2015년 02월_변동률  \
# 0           0.17        86.238           0.75         87.21           1.13
#
#    2015년 03월_지수  2015년 03월_변동률  2015년 04월_지수  2015년 04월_변동률  2015년 05월_지수  \
# 0          87.9           0.79        88.429            0.6        88.595
#
#    2015년 05월_변동률  2015년 06월_지수  2015년 06월_변동률  2015년 07월_지수  2015년 07월_변동률  \
# 0           0.19        88.938           0.39        89.434           0.56
#
#    2015년 08월_지수  2015년 08월_변동률  2015년 09월_지수  2015년 09월_변동률  2015년 10월_지수  \
# 0         90.62           1.33         90.78           0.18        91.464
#
#    2015년 10월_변동률  2015년 11월_지수  2015년 11월_변동률  2015년 12월_지수  2015년 12월_변동률  \
# 0           0.75        90.714          -0.82        89.932          -0.86
#
#    2016년 01월_지수  2016년 01월_변동률  2016년 02월_지수  2016년 02월_변동률  2016년 03월_지수  \
# 0        91.456           1.69         91.87           0.45        92.216
#
#    2016년 03월_변동률  2016년 04월_지수  2016년 04월_변동률  2016년 05월_지수  2016년 05월_변동률  \
# 0           0.38        92.451           0.26        92.725            0.3
#
#    2016년 06월_지수  2016년 06월_변동률  2016년 07월_지수  2016년 07월_변동률  2016년 08월_지수  \
# 0        92.908            0.2        93.494           0.63        94.709
#
#    2016년 08월_변동률  2016년 09월_지수  2016년 09월_변동률  2016년 10월_지수  2016년 10월_변동률  \
# 0            1.3        95.023           0.33        95.812           0.83
#
#    2016년 11월_지수  2016년 11월_변동률  2016년 12월_지수  2016년 12월_변동률  2017년 01월_지수  \
# 0         95.65          -0.17        95.535          -0.12        95.731
#
#    2017년 01월_변동률  2017년 02월_지수  2017년 02월_변동률  2017년 03월_지수  2017년 03월_변동률  \
# 0            0.2        96.116            0.4        96.641           0.55
#
#    2017년 04월_지수  2017년 04월_변동률  2017년 05월_지수  2017년 05월_변동률  2017년 06월_지수  \
# 0         97.14           0.52        97.781           0.66        98.934
#
#    2017년 06월_변동률  2017년 07월_지수  2017년 07월_변동률  2017년 08월_지수  2017년 08월_변동률  \
# 0           1.18       100.044           1.12        99.045             -1
#
#    2017년 09월_지수  2017년 09월_변동률  2017년 10월_지수  2017년 10월_변동률  2017년 11월_지수  \
# 0         99.34            0.3           100           0.66           100
#
#    2017년 11월_변동률  2017년 12월_지수  2017년 12월_변동률  2018년 01월_지수  2018년 01월_변동률  \
# 0              0        99.715          -0.28       100.237           0.52
#
#    2018년 02월_지수  2018년 02월_변동률  2018년 03월_지수  2018년 03월_변동률  2018년 04월_지수  \
# 0       101.108           0.87       101.755           0.64       102.075
#
#    2018년 04월_변동률  2018년 05월_지수  2018년 05월_변동률  2018년 06월_지수  2018년 06월_변동률  \
# 0           0.31       102.235           0.16       103.107           0.85
#
#    2018년 07월_지수  2018년 07월_변동률  2018년 08월_지수  2018년 08월_변동률  2018년 09월_지수  \
# 0       104.088           0.95       105.392           1.25       106.296
#
#    2018년 09월_변동률  2018년 10월_지수  2018년 10월_변동률  2018년 11월_지수  2018년 11월_변동률  \
# 0           0.86       105.728          -0.53       104.675             -1
#
#    2018년 12월_지수  2018년 12월_변동률  2019년 01월_지수  2019년 01월_변동률  2019년 02월_지수  \
# 0       104.488          -0.18       104.203          -0.27       105.175
#
#    2019년 02월_변동률  2019년 03월_지수  2019년 03월_변동률  2019년 04월_지수  2019년 04월_변동률  \
# 0           0.93        105.12          -0.05       105.669           0.52
#
#    2019년 05월_지수  2019년 05월_변동률  2019년 06월_지수  2019년 06월_변동률  2019년 07월_지수  \
# 0       105.792           0.12       107.631           1.74       107.649
#
#    2019년 07월_변동률  2019년 08월_지수  2019년 08월_변동률  2019년 09월_지수  2019년 09월_변동률  \
# 0           0.02       107.748           0.09       108.048           0.28
#
#    2019년 10월_지수  2019년 10월_변동률  2019년 11월_지수  2019년 11월_변동률  2019년 12월_지수  \
# 0       109.336           1.19       111.481           1.96        110.34
#
#    2019년 12월_변동률  2020년 01월_지수  2020년 01월_변동률  2020년 02월_지수  2020년 02월_변동률  \
# 0          -1.02       109.661          -0.62       111.702           1.86
#
#    2020년 03월_지수  2020년 03월_변동률  2020년 04월_지수  2020년 04월_변동률  2020년 05월_지수  \
# 0       110.895          -0.72       110.065          -0.75       111.984
#
#    2020년 05월_변동률  2020년 06월_지수  2020년 06월_변동률  2020년 07월_지수  2020년 07월_변동률  \
# 0           1.74       114.772           2.49       116.236           1.28
#
#    2020년 08월_지수  2020년 08월_변동률  2020년 09월_지수  2020년 09월_변동률  2020년 10월_지수  \
# 0       116.367           0.11       118.319           1.68       118.473
#
#    2020년 10월_변동률  2020년 11월_지수  2020년 11월_변동률  2020년 12월_지수  2020년 12월_변동률  \
# 0           0.13       120.904           2.05       121.748            0.7
#
#    2021년 01월_지수  2021년 01월_변동률  2021년 02월_지수  2021년 02월_변동률  2021년 03월_지수  \
# 0       123.192           1.19       123.155          -0.03       124.284
#
#    2021년 03월_변동률  2021년 04월_지수  2021년 04월_변동률  2021년 05월_지수  2021년 05월_변동률  \
# 0           0.92       126.364           1.67       128.355           1.58
#
#    2021년 06월_지수  2021년 06월_변동률  2021년 07월_지수  2021년 07월_변동률
# 0       130.869           1.96       132.173              1

# %%
def get_sales_idx(x):
    # x is a pandas timestamp
    
    df = sales_idx_df.copy()
    
    if pd.isna(x) == True:
        return x
    else:
        year = str(x.year)
        month = str(x.month)
        if len(month) == 1:
            month = '0'+month
        
        try:
            idx = df[year+'년 '+month+'월_지수'].iloc[0]
            return idx
        
        except:
            return '지수없음'

# %%
def get_index_applied_prices(df):
    df = df.copy()
    
    last_idx = sales_idx_df.iloc[0,-2]
    
    df['계약날짜_실거래지수'] = df['계약날짜'].apply(get_sales_idx)
    
    df_idx_positive = df[df['계약날짜_실거래지수'] != '지수없음']
    
    df['지수적용단가'] = df['단가(만원/㎡)']
    
    df_idx_positive['지수적용단가'] = df_idx_positive['단가(만원/㎡)'] / df_idx_positive['계약날짜_실거래지수'] * last_idx
    
    df.loc[df_idx_positive.index, '지수적용단가'] = df_idx_positive['지수적용단가']
    
    df['지수적용단가'] = df['지수적용단가'].astype('float')
    
    df['지수적용날짜'] = '지수없음'
    
    last_date = sales_idx_df.columns[-1].split('_')[0]
    df.loc[df_idx_positive.index, '지수적용날짜'] = last_date
    
    return df

# %%
target_1_12_df = get_index_applied_prices(target_1_12_df)
print(target_1_12_df.shape)
target_1_12_df.head()
# Out:
# (134, 19)
#                           지번주소           도로명       건물(단지)명  전용면적(㎡)  거래금액(만원)  \
# 724235   서울특별시 서대문구 남가좌동 3-100       명지대7길 6  라임하우스(3-100)   49.610     26400
# 724255    서울특별시 서대문구 남가좌동 3-39   명지대5길 22-12         거북하우스   25.675     15000
# 724295  서울특별시 서대문구 남가좌동 325-10  증가로10길 36-21           우선빌   28.680     15750
# 724382  서울특별시 서대문구 남가좌동 331-10    가재울로2안길 11         루체비스타   46.440     33100
# 724383  서울특별시 서대문구 남가좌동 331-10    가재울로2안길 11         루체비스타   46.440     33100
#
#         층    건축년도 거래구분  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형     구  \
# 724235  3  2018.0   매매          3.0 2021-09-23  532.150776   3.0  연립다세대  서대문구
# 724255  5  2016.0   전세          5.0 2021-07-30  584.225901   5.0  연립다세대  서대문구
# 724295  3  2017.0   전세          4.0 2021-10-12  549.163180   4.0  연립다세대  서대문구
# 724382  3  2021.0   매매          0.0 2021-06-30  712.747631   0.0  연립다세대  서대문구
# 724383  2  2021.0   매매          0.0 2021-06-30  712.747631   0.0  연립다세대  서대문구
#
#            동 일괄계약 계약날짜_실거래지수      지수적용단가     지수적용날짜
# 724235  남가좌동    N       지수없음  532.150776       지수없음
# 724255  남가좌동    N    132.173  584.225901  2021년 07월
# 724295  남가좌동    N       지수없음  549.163180       지수없음
# 724382  남가좌동    Y    130.869  719.849565  2021년 07월
# 724383  남가좌동    Y    130.869  719.849565  2021년 07월

# %%
target_2_24_df = get_index_applied_prices(target_2_24_df)
print(target_2_24_df.shape)
target_2_24_df.head()
# Out:
# (326, 19)
#                           지번주소           도로명       건물(단지)명  전용면적(㎡)  거래금액(만원)  \
# 724233   서울특별시 서대문구 남가좌동 3-100       명지대7길 6  라임하우스(3-100)   49.610     23000
# 724234   서울특별시 서대문구 남가좌동 3-100       명지대7길 6  라임하우스(3-100)   49.610     23000
# 724235   서울특별시 서대문구 남가좌동 3-100       명지대7길 6  라임하우스(3-100)   49.610     26400
# 724255    서울특별시 서대문구 남가좌동 3-39   명지대5길 22-12         거북하우스   25.675     15000
# 724295  서울특별시 서대문구 남가좌동 325-10  증가로10길 36-21           우선빌   28.680     15750
#
#         층    건축년도 거래구분  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형     구  \
# 724233  3  2018.0   전세          2.0 2020-10-30  463.616206   3.0  연립다세대  서대문구
# 724234  3  2018.0   전세          2.0 2020-10-30  463.616206   3.0  연립다세대  서대문구
# 724235  3  2018.0   매매          3.0 2021-09-23  532.150776   3.0  연립다세대  서대문구
# 724255  5  2016.0   전세          5.0 2021-07-30  584.225901   5.0  연립다세대  서대문구
# 724295  3  2017.0   전세          4.0 2021-10-12  549.163180   4.0  연립다세대  서대문구
#
#            동 일괄계약 계약날짜_실거래지수      지수적용단가     지수적용날짜
# 724233  남가좌동    N    118.473  517.227933  2021년 07월
# 724234  남가좌동    N    118.473  517.227933  2021년 07월
# 724235  남가좌동    N       지수없음  532.150776       지수없음
# 724255  남가좌동    N    132.173  584.225901  2021년 07월
# 724295  남가좌동    N       지수없음  549.163180       지수없음

# %%
target_3_36_df = get_index_applied_prices(target_3_36_df)
print(target_3_36_df.shape)
target_3_36_df.head()
# Out:
# (721, 19)
#                          지번주소          도로명       건물(단지)명  전용면적(㎡)  거래금액(만원)  \
# 724233  서울특별시 서대문구 남가좌동 3-100      명지대7길 6  라임하우스(3-100)   49.610     23000
# 724234  서울특별시 서대문구 남가좌동 3-100      명지대7길 6  라임하우스(3-100)   49.610     23000
# 724235  서울특별시 서대문구 남가좌동 3-100      명지대7길 6  라임하우스(3-100)   49.610     26400
# 724254   서울특별시 서대문구 남가좌동 3-39  명지대5길 22-12         거북하우스   25.675     14000
# 724255   서울특별시 서대문구 남가좌동 3-39  명지대5길 22-12         거북하우스   25.675     15000
#
#         층    건축년도 거래구분  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형     구  \
# 724233  3  2018.0   전세          2.0 2020-10-30  463.616206   3.0  연립다세대  서대문구
# 724234  3  2018.0   전세          2.0 2020-10-30  463.616206   3.0  연립다세대  서대문구
# 724235  3  2018.0   매매          3.0 2021-09-23  532.150776   3.0  연립다세대  서대문구
# 724254  5  2016.0   전세          4.0 2020-05-04  545.277507   5.0  연립다세대  서대문구
# 724255  5  2016.0   전세          5.0 2021-07-30  584.225901   5.0  연립다세대  서대문구
#
#            동 일괄계약 계약날짜_실거래지수      지수적용단가     지수적용날짜
# 724233  남가좌동    N    118.473  517.227933  2021년 07월
# 724234  남가좌동    N    118.473  517.227933  2021년 07월
# 724235  남가좌동    N       지수없음  532.150776       지수없음
# 724254  남가좌동    N    111.984  643.582690  2021년 07월
# 724255  남가좌동    N    132.173  584.225901  2021년 07월

# %%
target_5_60_df = get_index_applied_prices(target_5_60_df)
print(target_5_60_df.shape)
target_5_60_df.head()
# Out:
# (1034, 19)
#                          지번주소      도로명       건물(단지)명  전용면적(㎡)  거래금액(만원)  층  \
# 724227  서울특별시 서대문구 남가좌동 3-100  명지대7길 6  라임하우스(3-100)    28.10     17000  4
# 724229  서울특별시 서대문구 남가좌동 3-100  명지대7길 6  라임하우스(3-100)    49.61     23000  3
# 724230  서울특별시 서대문구 남가좌동 3-100  명지대7길 6  라임하우스(3-100)    49.61     22000  3
# 724231  서울특별시 서대문구 남가좌동 3-100  명지대7길 6  라임하우스(3-100)    49.61     22000  2
# 724232  서울특별시 서대문구 남가좌동 3-100  명지대7길 6  라임하우스(3-100)    49.61     21000  2
#
#           건축년도 거래구분  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형     구  \
# 724227  2018.0   전세          0.0 2018-12-20  604.982206   3.0  연립다세대  서대문구
# 724229  2018.0   전세          0.0 2018-11-06  463.616206   3.0  연립다세대  서대문구
# 724230  2018.0   전세          0.0 2018-12-17  443.458980   3.0  연립다세대  서대문구
# 724231  2018.0   전세          1.0 2019-02-02  443.458980   3.0  연립다세대  서대문구
# 724232  2018.0   전세          1.0 2019-10-05  423.301754   3.0  연립다세대  서대문구
#
#            동 일괄계약 계약날짜_실거래지수      지수적용단가     지수적용날짜
# 724227  남가좌동    N    104.488  765.277478  2021년 07월
# 724229  남가좌동    N    104.675  585.407641  2021년 07월
# 724230  남가좌동    N    104.488  560.957275  2021년 07월
# 724231  남가좌동    N    105.175  557.293119  2021년 07월
# 724232  남가좌동    N    109.336  511.716751  2021년 07월

# %%
cols_to_include = [
    '지번주소', '건물(단지)명', '건물연식', '층', '거래구분', '전용면적(㎡)', '계약날짜', '거래금액(만원)', '단가(만원/㎡)',
    '부동산유형', '일괄계약', '지수적용날짜', '지수적용단가'
]

# %%
target_1_12_df = target_1_12_df.sort_values(['지번주소', '건축년도', '부동산유형', '거래구분', '계약날짜', '전용면적(㎡)']).reset_index(drop=True)
target_1_12_df1 = target_1_12_df[cols_to_include]
target_1_12_df1.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_{}/실거래가_건물연식{}년_계약최근6개월.xlsx'.format(target_gu, target_dong, date_today_record, target_building_age), index=False)

# %%
target_2_24_df = target_2_24_df.sort_values(['지번주소', '건축년도', '부동산유형', '거래구분', '계약날짜', '전용면적(㎡)']).reset_index(drop=True)
target_2_24_df1 = target_2_24_df[cols_to_include]
target_2_24_df1.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_{}/실거래가_건물연식{}년_계약최근12개월.xlsx'.format(target_gu, target_dong, date_today_record, target_building_age), index=False)

# %%
target_3_36_df = target_3_36_df.sort_values(['지번주소', '건축년도', '부동산유형', '거래구분', '계약날짜', '전용면적(㎡)']).reset_index(drop=True)
target_3_36_df1 = target_3_36_df[cols_to_include]
target_3_36_df1.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_{}/실거래가_건물연식{}년_계약최근24개월.xlsx'.format(target_gu, target_dong, date_today_record, target_building_age), index=False)

# %%
target_5_60_df = target_5_60_df.sort_values(['지번주소', '건축년도', '부동산유형', '거래구분', '계약날짜', '전용면적(㎡)']).reset_index(drop=True)
target_5_60_df1 = target_5_60_df[cols_to_include]
target_5_60_df1.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_{}/실거래가_건물연식{}년_계약최근36개월.xlsx'.format(target_gu, target_dong, date_today_record, target_building_age), index=False)

# %%
target_df = target_3_36_df.copy()

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('최근 {}개월 {} {} 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 {}건의 전용면적 단가'.format(target_period, target_gu, target_dong, target_building_age, target_df.shape[0]))
plt.grid(True)
ax.xaxis.update_units(target_df['계약날짜'])
sns.regplot(x=ax.xaxis.convert_units(target_df['계약날짜']), y=target_df['단가(만원/㎡)'])
plt.savefig('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_{}/산포도.png'.format(target_gu, target_dong, date_today_record))

# %%
target_last_df = target_df.drop_duplicates(subset=['지번주소', '건축년도'], keep='last').reset_index(drop=True)

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('최근 {}개월 {} {} 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 {}건의 전용면적 단가'.format(target_period, target_gu, target_dong, target_building_age, target_last_df.shape[0]))
plt.grid(True)
ax.xaxis.update_units(target_last_df['계약날짜'])
sns.regplot(x=ax.xaxis.convert_units(target_last_df['계약날짜']), y=target_last_df['단가(만원/㎡)'])
plt.savefig('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_{}/마지막_산포도.png'.format(target_gu, target_dong, date_today_record))

# %%
target_last_df.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_{}/마지막_실거래가.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
target_df2 = house_df[
    (house_df['지번주소'].str.contains(target_gu + ' ' + target_dong))
    #&(house_df['동'] == target_dong)
    #&(house_merge_df['계약날짜'] >= (date_today - pd.DateOffset(months=target_period)))
    &(house_df['계약날짜기준_건물연식'] <= target_building_age)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_df2.shape)
target_df2.head()
# Out:
# (2378, 16)
#                          지번주소      도로명       건물(단지)명  전용면적(㎡)  거래금액(만원)  층  \
# 724225  서울특별시 서대문구 남가좌동 3-100  명지대7길 6  라임하우스(3-100)    25.06     15000  5
# 724226  서울특별시 서대문구 남가좌동 3-100  명지대7길 6  라임하우스(3-100)    25.06     15000  5
# 724227  서울특별시 서대문구 남가좌동 3-100  명지대7길 6  라임하우스(3-100)    28.10     17000  4
# 724228  서울특별시 서대문구 남가좌동 3-100  명지대7길 6  라임하우스(3-100)    49.61     23000  2
# 724229  서울특별시 서대문구 남가좌동 3-100  명지대7길 6  라임하우스(3-100)    49.61     23000  3
#
#           건축년도 거래구분  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형     구  \
# 724225  2018.0   전세          0.0 2018-07-20  598.563448   3.0  연립다세대  서대문구
# 724226  2018.0   전세          0.0 2018-10-09  598.563448   3.0  연립다세대  서대문구
# 724227  2018.0   전세          0.0 2018-12-20  604.982206   3.0  연립다세대  서대문구
# 724228  2018.0   전세          0.0 2018-10-11  463.616206   3.0  연립다세대  서대문구
# 724229  2018.0   전세          0.0 2018-11-06  463.616206   3.0  연립다세대  서대문구
#
#            동 일괄계약
# 724225  남가좌동    N
# 724226  남가좌동    N
# 724227  남가좌동    N
# 724228  남가좌동    N
# 724229  남가좌동    N

# %%
target_df2 = get_index_applied_prices(target_df2)

# %%
font = {'size': 12}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(12,6))
plt.title('{} {} 계약날짜기준 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 {}건의 전용면적 단가'.format(target_gu, target_dong, target_building_age, target_df2.shape[0]))
plt.grid(True)
sns.histplot(target_df2['단가(만원/㎡)'], kde=True)
# Out:
# <AxesSubplot:title={'center':'서대문구 남가좌 계약날짜기준 건물연식 5년이하 연립다세대 및 오피스텔 매매 실거래 2378건의 전용면적 단가'}, xlabel='단가(만원/㎡)', ylabel='Count'>

# %%
target_df3 = target_df2[['지번주소', '건물(단지)명', '건축년도', '층', '전용면적(㎡)', '계약날짜', '단가(만원/㎡)', '부동산유형']]
target_df3 = target_df3.sort_values(['지번주소', '건축년도', '계약날짜']).reset_index(drop=True)
target_df3.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_{}/전체_실거래가.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
target_df3_30 = target_df3[
    (target_df3['전용면적(㎡)'] >= 28)
    &(target_df3['전용면적(㎡)'] <= 32)
]

# %%
target_df3_30.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_{}/전체_실거래가_30.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
concat_df = pd.concat([target_df2])

# %%
concat_df = concat_df.sort_values(['지번주소', '건축년도', '전용면적(㎡)', '계약날짜']).reset_index(drop=True)
concat_df = concat_df.drop_duplicates(['지번주소', '건축년도', '전용면적(㎡)'], keep='last').reset_index(drop=True)

# %%
concat_df['단가평균'] = concat_df[['지번주소', '건축년도', '단가(만원/㎡)']].groupby(['지번주소', '건축년도']).transform('mean')['단가(만원/㎡)']
concat_df['지수적용단가평균'] = concat_df[['지번주소', '건축년도', '지수적용단가']].groupby(['지번주소', '건축년도']).transform('mean')['지수적용단가']

# %%
concat_df = concat_df.sort_values(['지번주소', '건축년도', '지수적용날짜']).reset_index(drop=True)
print(concat_df.shape)
concat_df.head()
# Out:
# (166, 21)
#                     지번주소          도로명       건물(단지)명  전용면적(㎡)  거래금액(만원)  층  \
# 0  서울특별시 서대문구 남가좌동 3-100      명지대7길 6  라임하우스(3-100)    25.06     15000  5
# 1  서울특별시 서대문구 남가좌동 3-100      명지대7길 6  라임하우스(3-100)    28.10     17000  4
# 2  서울특별시 서대문구 남가좌동 3-100      명지대7길 6  라임하우스(3-100)    49.61     26400  3
# 3   서울특별시 서대문구 남가좌동 3-36  명지대5길 22-16     광진아람아트빌4차    32.94     17000  5
# 4   서울특별시 서대문구 남가좌동 3-36  명지대5길 22-16     광진아람아트빌4차    44.38     23400  4
#
#      건축년도 거래구분  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형     구     동  \
# 0  2018.0   전세          0.0 2018-10-09  598.563448   3.0  연립다세대  서대문구  남가좌동
# 1  2018.0   전세          0.0 2018-12-20  604.982206   3.0  연립다세대  서대문구  남가좌동
# 2  2018.0   매매          3.0 2021-09-23  532.150776   3.0  연립다세대  서대문구  남가좌동
# 3  2018.0   매매          0.0 2018-12-06  516.089860   3.0  연립다세대  서대문구  남가좌동
# 4  2018.0   매매          0.0 2018-12-06  527.264534   3.0  연립다세대  서대문구  남가좌동
#
#   일괄계약 계약날짜_실거래지수      지수적용단가     지수적용날짜        단가평균    지수적용단가평균
# 0    N    105.728  748.277907  2021년 07월  578.565477  681.902054
# 1    N    104.488  765.277478  2021년 07월  578.565477  681.902054
# 2    N       지수없음  532.150776       지수없음  578.565477  681.902054
# 3    N    104.488  652.832336  2021년 07월  511.954339  647.601072
# 4    N    104.488  666.967836  2021년 07월  511.954339  647.601072

# %%
concat_last_df = concat_df.drop_duplicates(subset=['지번주소', '건축년도'], keep='last')
print(concat_last_df.shape)
concat_last_df.head()
# Out:
# (40, 21)
#                       지번주소          도로명       건물(단지)명  전용면적(㎡)  거래금액(만원)  층  \
# 2    서울특별시 서대문구 남가좌동 3-100      명지대7길 6  라임하우스(3-100)   49.610     26400  3
# 6     서울특별시 서대문구 남가좌동 3-36  명지대5길 22-16     광진아람아트빌4차   59.400     30000  2
# 8     서울특별시 서대문구 남가좌동 3-39  명지대5길 22-12         거북하우스   58.845     24000  3
# 10    서울특별시 서대문구 남가좌동 3-90  명지대5길 10-12         태양아트빌   62.240     24000  5
# 11  서울특별시 서대문구 남가좌동 324-38    증가로10길 47      (324-38)   16.200      6000  2
#
#       건축년도 거래구분  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형     구     동  \
# 2   2018.0   매매          3.0 2021-09-23  532.150776   3.0  연립다세대  서대문구  남가좌동
# 6   2018.0   매매          0.0 2018-12-06  505.050505   3.0  연립다세대  서대문구  남가좌동
# 8   2016.0   전세          4.0 2020-05-15  407.851134   5.0  연립다세대  서대문구  남가좌동
# 10  2014.0   전세          4.0 2018-10-03  385.604113   7.0  연립다세대  서대문구  남가좌동
# 11  2013.0   전세          5.0 2018-02-19  370.370370   8.0  연립다세대  서대문구  남가좌동
#
#    일괄계약 계약날짜_실거래지수      지수적용단가     지수적용날짜        단가평균    지수적용단가평균
# 2     N       지수없음  532.150776       지수없음  578.565477  681.902054
# 6     N    104.488  638.868008  2021년 07월  511.954339  647.601072
# 8     N    111.984  481.380447  2021년 07월  496.038518  532.803174
# 10    N    105.728  482.052554  2021년 07월  407.994654  508.605971
# 11    N    101.108  484.165081  2021년 07월  370.370370  484.165081

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('{} {} 계약날짜기준 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 지번별 {}곳의 전용면적 실거래가격지수 적용후 단가평균'.format(target_gu, target_dong, target_building_age, concat_last_df.shape[0]))
plt.grid(True)
sns.histplot(concat_last_df['지수적용단가'], kde=True)
plt.savefig('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_{}/지번별_분포도.png'.format(target_gu, target_dong, date_today_record))

# %%
concat_last_df = concat_last_df.sort_values(['지번주소']).reset_index(drop=True)

# %%
concat_last_df = concat_last_df[['지번주소', '건물(단지)명', '건축년도', '전용면적(㎡)', '층', '계약날짜', '단가(만원/㎡)', '지수적용날짜', '지수적용단가', '부동산유형']]
concat_last_df.rename(columns={'계약날짜':'마지막_계약날짜'}, inplace=True)
concat_last_df.head()
# Out:
#                      지번주소       건물(단지)명    건축년도  전용면적(㎡)  층   마지막_계약날짜  \
# 0   서울특별시 서대문구 남가좌동 3-100  라임하우스(3-100)  2018.0   49.610  3 2021-09-23
# 1    서울특별시 서대문구 남가좌동 3-36     광진아람아트빌4차  2018.0   59.400  2 2018-12-06
# 2    서울특별시 서대문구 남가좌동 3-39         거북하우스  2016.0   58.845  3 2020-05-15
# 3    서울특별시 서대문구 남가좌동 3-90         태양아트빌  2014.0   62.240  5 2018-10-03
# 4  서울특별시 서대문구 남가좌동 324-38      (324-38)  2013.0   16.200  2 2018-02-19
#
#      단가(만원/㎡)     지수적용날짜      지수적용단가  부동산유형
# 0  532.150776       지수없음  532.150776  연립다세대
# 1  505.050505  2021년 07월  638.868008  연립다세대
# 2  407.851134  2021년 07월  481.380447  연립다세대
# 3  385.604113  2021년 07월  482.052554  연립다세대
# 4  370.370370  2021년 07월  484.165081  연립다세대

# %%
concat_last_df.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_{}/전체_마지막_실거래가.xlsx'.format(target_gu, target_dong, date_today_record), index=False)
