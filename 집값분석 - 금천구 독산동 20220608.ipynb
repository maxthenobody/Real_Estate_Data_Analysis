# %%
# 2022/05/25 업데이트 내용:
# 경기도, 인천 포함

# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
pd.options.mode.chained_assignment = None  # default='warn'
plt.rcParams['font.family'] = 'Malgun Gothic'
import datetime
tqdm.tqdm.pandas()

# %%
target_sido = '서울' # 시도 명: 서울, 인천, 경기 중 하나 선택
target_gu = '금천구' # 구 명
target_dong = '독산' # 동 명: 동 명에서 마지막 글자 '동' 뺄 것.
target_ri = '' # 리 명
#target_purpose = '준주거' # 종 명: 건드릴 필요 없음
target_building_age = 5 # 건물연식: 건드릴 필요 없음
target_period = 36 # 계약날짜 검색범위: 건드릴 필요 없음
target_starting_year = 2018 # 검색 시작 계약 년도: 건드릴 필요 없음

# %%
date_today = pd.to_datetime(datetime.datetime.now().strftime('%Y-%m-%d'), format='%Y-%m-%d')

# %%
date_today_record = str(date_today).split(' ')[0].replace('-', '')
date_today_record
# Out:
# '20220608'

# %%
def day_modifier(x):
    # x is a number
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x)
        if len(x) == 1:
            return '0' + x
        else:
            return x

# %%
def landnum_modifier(x):
    # x is a string
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x).replace('외', '').replace(' ','')
        splitted = x.split('-')
        if len(splitted) == 1:
            return x + '-0'
        else:
            return x

# %%
def data_prep(bdtype, tradetype, starting_year=2018, sido=target_sido):
    # bdtype is a string: one of 아파트, 연립다세대 or 오피스텔
    # tradetype is a string: one of 매매 or 전월세
    if (tradetype != '매매') & (tradetype != '전월세'):
        raise ValueError('두번째 변수는 매매 또는 전월세만 입력 가능')
    
    if sido == '서울':
        basedir = './국토교통부_실거래가_공개시스템/{}/{}/'.format(bdtype, tradetype)
    elif sido == '인천':
        basedir = './국토교통부_실거래가_공개시스템/인천/{}/{}/'.format(bdtype, tradetype)
    elif sido == '경기':
        basedir = './국토교통부_실거래가_공개시스템/경기도/{}/{}/'.format(bdtype, tradetype)
    
    filenames = [f for f in os.listdir(basedir) if (f.endswith('.csv'))&('(' in f)]
    
    dfs_list = []
    for i, f in tqdm.tqdm_notebook(enumerate(filenames)):
        splitted_filename = f.split('실거래가_')       
        file_year = int(splitted_filename[-1][:4])
        
        if file_year < starting_year:
            continue
        
        try:
            df = pd.read_csv(basedir + f, encoding='euc-kr', header=15)
        except:
            try:
                df = pd.read_csv(basedir + f, encoding='utf-8', header=15)
            except:
                df = pd.read_csv(basedir + f, header=15)
        
        if '건물명' in df.columns:
            df.rename(columns={'건물명':'건물(단지)명'}, inplace=True)
        elif '단지명' in df.columns:
            df.rename(columns={'단지명':'건물(단지)명'}, inplace=True)
            
        if '대지권면적(㎡)' in df.columns:
            df = df.drop(columns=['대지권면적(㎡)'])
                
            
        if '해제사유발생일' in df.columns.tolist():
            df = df[df['해제사유발생일'].isna()]
            df = df.drop(columns=['해제사유발생일'])
            
        dfs_list.append(df)
    
    concat_df = pd.concat(dfs_list).reset_index(drop=True)
    
    if tradetype == '전월세':
        concat_df = concat_df.rename(columns={'전월세구분':'거래구분', '보증금(만원)':'거래금액(만원)'})
        concat_df = concat_df.drop(columns=['월세(만원)'])
        concat_df = concat_df[concat_df['거래구분'] == '전세']
    elif tradetype == '매매':
        concat_df['거래구분'] = '매매'
        
    concat_df['번지'] = concat_df['번지'].apply(landnum_modifier)
    
    concat_df['계약년월'] = concat_df['계약년월'].astype('Int64')
    concat_df['계약일'] = concat_df['계약일'].astype('Int64')
    
    concat_df['계약년월'] = concat_df['계약년월'].apply(str)
    concat_df['계약일'] = concat_df['계약일'].apply(str)
    
    concat_df['계약날짜기준_건물연식'] = concat_df['계약년월'].apply(lambda x: int(x[:4])) - concat_df['건축년도']
    
    concat_df['계약일'] = concat_df['계약일'].apply(day_modifier)
    
    concat_df['계약날짜'] = concat_df['계약년월'].apply(lambda x: x[:4]) + '-' + concat_df['계약년월'].apply(lambda x: x[-2:])\
    + '-' + concat_df['계약일']
    
    concat_df['계약날짜'] = pd.to_datetime(concat_df['계약날짜'], format='%Y-%m-%d')
    
    concat_df['거래금액(만원)'] = concat_df['거래금액(만원)'].apply(lambda x: int(x.replace(',','')))
    concat_df['단가(만원/㎡)'] = concat_df['거래금액(만원)'] / concat_df['전용면적(㎡)']
    
    concat_df['지번주소'] = concat_df['시군구'] + ' ' + concat_df['번지']
        
    cols_to_drop = ['번지', '지번주소', '계약년월', '계약일', '도로명']
        
    concat_df = concat_df[['지번주소', '도로명'] + [col for col in concat_df.columns if col not in cols_to_drop]]
    
    date_today = pd.to_datetime(datetime.datetime.now().strftime('%Y-%m-%d'), format='%Y-%m-%d')
    concat_df['건물연식'] = date_today.year - concat_df['건축년도']
    
    concat_df = concat_df.dropna(subset=['지번주소'])
    
    concat_df = concat_df[concat_df['층'] >= 0].reset_index(drop=True)
    
    return concat_df

# %%
apart_trade_df = data_prep('아파트', '매매')
apart_lease_df = data_prep('아파트', '전월세')
apart_df = pd.concat([apart_trade_df, apart_lease_df]).reset_index(drop=True)
del apart_trade_df, apart_lease_df
apart_df['부동산유형'] = '아파트'
print(apart_df.shape)
apart_df.head()
# Out:
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:17: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:2: DtypeWarning: Columns (10,18) have mixed types.Specify dtype option on import or set low_memory=False.
#
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:2: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
# (846610, 23)
#                   지번주소    도로명            시군구     본번   부번         건물(단지)명  \
# 0  서울특별시 강남구 개포동 658-1  언주로 3  서울특별시 강남구 개포동  658.0  1.0  개포6차우성아파트1동~8동
# 1  서울특별시 강남구 개포동 658-1  언주로 3  서울특별시 강남구 개포동  658.0  1.0  개포6차우성아파트1동~8동
# 2  서울특별시 강남구 개포동 658-1  언주로 3  서울특별시 강남구 개포동  658.0  1.0  개포6차우성아파트1동~8동
# 3  서울특별시 강남구 개포동 658-1  언주로 3  서울특별시 강남구 개포동  658.0  1.0  개포6차우성아파트1동~8동
# 4  서울특별시 강남구 개포동 658-1  언주로 3  서울특별시 강남구 개포동  658.0  1.0  개포6차우성아파트1동~8동
#
#    전용면적(㎡)  거래금액(만원)  층    건축년도 거래유형 중개사소재지 거래구분  계약날짜기준_건물연식       계약날짜  \
# 0    79.97    130000  4  1987.0    -      -   매매         31.0 2018-01-03
# 1    79.97    117000  2  1987.0    -      -   매매         31.0 2018-01-08
# 2    79.97    130000  1  1987.0    -      -   매매         31.0 2018-01-11
# 3    79.97    139500  2  1987.0    -      -   매매         31.0 2018-03-19
# 4    54.98    107500  5  1987.0    -      -   매매         31.0 2018-04-05
#
#       단가(만원/㎡)  건물연식 계약기간 계약구분 갱신요구권 사용 종전계약 보증금 (만원) 종전계약 월세 (만원) 부동산유형
# 0  1625.609604  35.0  NaN  NaN      NaN           NaN          NaN   아파트
# 1  1463.048643  35.0  NaN  NaN      NaN           NaN          NaN   아파트
# 2  1625.609604  35.0  NaN  NaN      NaN           NaN          NaN   아파트
# 3  1744.404152  35.0  NaN  NaN      NaN           NaN          NaN   아파트
# 4  1955.256457  35.0  NaN  NaN      NaN           NaN          NaN   아파트

# %%
yunrip_trade_df = data_prep('연립다세대', '매매')
yunrip_lease_df = data_prep('연립다세대', '전월세')
yunrip_df = pd.concat([yunrip_trade_df, yunrip_lease_df]).reset_index(drop=True)
del yunrip_trade_df, yunrip_lease_df
yunrip_df['부동산유형'] = '연립다세대'
print(yunrip_df.shape)
yunrip_df.head()
# Out:
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:17: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:2: DtypeWarning: Columns (10,18) have mixed types.Specify dtype option on import or set low_memory=False.
# (517406, 23)
#                    지번주소         도로명            시군구    본번  부번   건물(단지)명  \
# 0  서울특별시 강남구 개포동 1172-2  논현로6길 22-6  서울특별시 강남구 개포동  1172   2  (1172-2)
# 1  서울특별시 강남구 개포동 1216-4   개포로26길 16  서울특별시 강남구 개포동  1216   4  (1216-4)
# 2  서울특별시 강남구 개포동 1187-8    논현로8길 17  서울특별시 강남구 개포동  1187   8    1187-8
# 3  서울특별시 강남구 개포동 1187-8    논현로8길 17  서울특별시 강남구 개포동  1187   8    1187-8
# 4  서울특별시 강남구 개포동 1187-8    논현로8길 17  서울특별시 강남구 개포동  1187   8    1187-8
#
#    전용면적(㎡)  거래금액(만원)  층    건축년도 거래유형 중개사소재지 거래구분  계약날짜기준_건물연식       계약날짜  \
# 0    29.95     25000  4  2012.0    -      -   매매          6.0 2018-01-13
# 1    29.12     25300  4  2012.0    -      -   매매          6.0 2018-10-23
# 2    55.96     45500  4  2015.0    -      -   매매          3.0 2018-01-04
# 3    59.84     51000  3  2015.0    -      -   매매          3.0 2018-03-09
# 4    59.84     51000  2  2015.0    -      -   매매          3.0 2018-04-14
#
#      단가(만원/㎡)  건물연식 계약기간 계약구분 갱신요구권 사용 종전계약 보증금 (만원) 종전계약 월세 (만원)  부동산유형
# 0  834.724541  10.0  NaN  NaN      NaN           NaN          NaN  연립다세대
# 1  868.818681  10.0  NaN  NaN      NaN           NaN          NaN  연립다세대
# 2  813.080772   7.0  NaN  NaN      NaN           NaN          NaN  연립다세대
# 3  852.272727   7.0  NaN  NaN      NaN           NaN          NaN  연립다세대
# 4  852.272727   7.0  NaN  NaN      NaN           NaN          NaN  연립다세대

# %%
officetel_trade_df = data_prep('오피스텔', '매매')
officetel_lease_df = data_prep('오피스텔', '전월세')
officetel_df = pd.concat([officetel_trade_df, officetel_lease_df]).reset_index(drop=True)
del officetel_trade_df, officetel_lease_df
officetel_df['부동산유형'] = '오피스텔'
print(officetel_df.shape)
officetel_df.head()
# Out:
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:17: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:2: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:2: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
# (170886, 23)
#                  지번주소      도로명            시군구  본번  부번 건물(단지)명  전용면적(㎡)  \
# 0  서울특별시 강남구 개포동 13-3  개포로 623  서울특별시 강남구 개포동  13   3    대청타워    31.91
# 1  서울특별시 강남구 개포동 13-3  개포로 623  서울특별시 강남구 개포동  13   3    대청타워    31.91
# 2  서울특별시 강남구 개포동 13-3  개포로 623  서울특별시 강남구 개포동  13   3    대청타워    32.44
# 3  서울특별시 강남구 개포동 13-3  개포로 623  서울특별시 강남구 개포동  13   3    대청타워    32.44
# 4  서울특별시 강남구 개포동 13-3  개포로 623  서울특별시 강남구 개포동  13   3    대청타워    32.44
#
#    거래금액(만원)   층    건축년도 거래유형 중개사소재지 거래구분  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  \
# 0     18500  20  1997.0    -      -   매매         21.0 2018-01-02  579.755563
# 1     19900  14  1997.0    -      -   매매         21.0 2018-01-04  623.628956
# 2     20000  26  1997.0    -      -   매매         21.0 2018-01-08  616.522811
# 3     20000  26  1997.0    -      -   매매         21.0 2018-01-18  616.522811
# 4     21000  22  1997.0    -      -   매매         21.0 2018-01-20  647.348952
#
#    건물연식 계약기간 계약구분 갱신요구권 사용 종전계약 보증금 (만원) 종전계약 월세 (만원) 부동산유형
# 0  25.0  NaN  NaN      NaN           NaN          NaN  오피스텔
# 1  25.0  NaN  NaN      NaN           NaN          NaN  오피스텔
# 2  25.0  NaN  NaN      NaN           NaN          NaN  오피스텔
# 3  25.0  NaN  NaN      NaN           NaN          NaN  오피스텔
# 4  25.0  NaN  NaN      NaN           NaN          NaN  오피스텔

# %%
house_df = pd.concat([apart_df, yunrip_df, officetel_df]).sort_values(['시군구', '본번', '부번', '건축년도', '전용면적(㎡)', '계약날짜']).reset_index(drop=True)
del apart_df, yunrip_df, officetel_df
print(house_df.shape)
house_df.head()
# Out:
# (1534902, 23)
#                  지번주소        도로명            시군구    본번   부번     건물(단지)명  \
# 0  서울특별시 강남구 개포동 12-0  개포로109길 9  서울특별시 강남구 개포동  12.0  0.0  성원대치2단지아파트
# 1  서울특별시 강남구 개포동 12-0  개포로109길 9  서울특별시 강남구 개포동  12.0  0.0  성원대치2단지아파트
# 2  서울특별시 강남구 개포동 12-0  개포로109길 9  서울특별시 강남구 개포동  12.0  0.0  성원대치2단지아파트
# 3  서울특별시 강남구 개포동 12-0  개포로109길 9  서울특별시 강남구 개포동  12.0  0.0  성원대치2단지아파트
# 4  서울특별시 강남구 개포동 12-0  개포로109길 9  서울특별시 강남구 개포동  12.0  0.0  성원대치2단지아파트
#
#    전용면적(㎡)  거래금액(만원)   층    건축년도 거래유형 중개사소재지 거래구분  계약날짜기준_건물연식       계약날짜  \
# 0    33.18     25000  13  1992.0  NaN    NaN   전세         26.0 2018-01-03
# 1    33.18     26000   6  1992.0  NaN    NaN   전세         26.0 2018-01-12
# 2    33.18     27000  13  1992.0  NaN    NaN   전세         26.0 2018-01-13
# 3    33.18     27000  12  1992.0  NaN    NaN   전세         26.0 2018-01-17
# 4    33.18     71000   4  1992.0    -      -   매매         26.0 2018-01-20
#
#       단가(만원/㎡)  건물연식 계약기간 계약구분 갱신요구권 사용 종전계약 보증금 (만원) 종전계약 월세 (만원) 부동산유형
# 0   753.465943  30.0  NaN  NaN      NaN           NaN          NaN   아파트
# 1   783.604581  30.0  NaN  NaN      NaN           NaN          NaN   아파트
# 2   813.743219  30.0  NaN  NaN      NaN           NaN          NaN   아파트
# 3   813.743219  30.0  NaN  NaN      NaN           NaN          NaN   아파트
# 4  2139.843279  30.0  NaN  NaN      NaN           NaN          NaN   아파트

# %%
'''land_specs_df = pd.read_csv('./prepped_data/land_specs_ver_4.csv')
print(land_specs_df.shape)
land_specs_df.head()'''
# Out:
# "land_specs_df = pd.read_csv('./prepped_data/land_specs_ver_4.csv')\nprint(land_specs_df.shape)\nland_specs_df.head()"

# %%
'''last_df = land_specs_df.drop_duplicates(subset=['지번주소'], keep='last').drop(columns=['년', '공시지가']).reset_index(drop=True)
print(last_df.shape)
last_df.head()'''
# Out:
# "last_df = land_specs_df.drop_duplicates(subset=['지번주소'], keep='last').drop(columns=['년', '공시지가']).reset_index(drop=True)\nprint(last_df.shape)\nlast_df.head()"

# %%
'''house_merge_df = house_df.merge(last_df, on=['지번주소']).reset_index(drop=True)
print(house_merge_df.shape)'''
# Out:
# "house_merge_df = house_df.merge(last_df, on=['지번주소']).reset_index(drop=True)\nprint(house_merge_df.shape)"

# %%
house_df['구'] = house_df['지번주소'].apply(lambda x: x.split(' ')[1])
house_df['동'] = house_df['지번주소'].apply(lambda x: x.split(' ')[2])
house_df['리'] = house_df['지번주소'].apply(lambda x: x.split(' ')[3])
#house_merge_df['구'] = house_merge_df['지번주소'].apply(lambda x: x.split(' ')[1])
#house_merge_df['동'] = house_merge_df['지번주소'].apply(lambda x: x.split(' ')[2])

# %%
house_df['일괄계약'] = 'N'

# %%
#house_df = house_df.merge(last_df, on=['지번주소']).reset_index(drop=True)

# %%
'''print(house_df.shape)
house_df.head()'''
# Out:
# 'print(house_df.shape)\nhouse_df.head()'

# %%
def identify_bulk_contract(df):
    df = df.copy()
    
    for addr in tqdm.tqdm_notebook(df['지번주소'].unique()):
        addr_df = df[df['지번주소'] == addr]
        
        for btyear in addr_df['건축년도'].unique():
            btyear_df = addr_df[addr_df['건축년도'] == btyear]
        
            for contract_date in btyear_df['계약날짜'].unique():
                contract_date_df = btyear_df[btyear_df['계약날짜'] == contract_date]

                if contract_date_df.shape[0] >= 5:
                    df.loc[contract_date_df.index, '일괄계약'] = 'Y'
    
    return df

# %%
target_1_12_df = house_df[
    (house_df['지번주소'].str.contains(target_gu + ' ' + target_dong))
    &(house_df['지번주소'].str.contains(target_ri))
    #&(house_df['동'] == target_dong)
    &(house_df['계약날짜'] >= (date_today - pd.DateOffset(months=6)))
    #&(house_df['건물연식'] <= target_building_age)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_1_12_df.shape)
target_1_12_df.head()
# Out:
# (1755, 27)
#                        지번주소            도로명            시군구     본번    부번  \
# 509175   서울특별시 금천구 독산동 47-3   남부순환로132길 14  서울특별시 금천구 독산동   47.0   3.0
# 509190  서울특별시 금천구 독산동 47-28   독산로108길 86-7  서울특별시 금천구 독산동   47.0  28.0
# 509258  서울특별시 금천구 독산동 144-4  시흥대로141길 81-2  서울특별시 금천구 독산동  144.0   4.0
# 509259  서울특별시 금천구 독산동 144-4  시흥대로141길 81-2  서울특별시 금천구 독산동  144.0   4.0
# 509289  서울특별시 금천구 독산동 145-2       시흥대로 485  서울특별시 금천구 독산동  145.0   2.0
#
#              건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도 거래유형 중개사소재지 거래구분  \
# 509175        HYTOWN    28.68     12000  4  2012.0  NaN    NaN   전세
# 509190  메트로타운(47-28)    29.90     27500  4  2020.0  NaN    NaN   전세
# 509258        영진오피스텔    23.79      6500  5  2001.0  NaN    NaN   전세
# 509259        영진오피스텔    23.79      6300  1  2001.0  NaN    NaN   전세
# 509289      한영솔레이유시티    29.51     24100  6  2018.0  NaN    NaN   전세
#
#         계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식           계약기간 계약구분 갱신요구권 사용  \
# 509175         10.0 2022-01-25  418.410042  10.0              -    -        -
# 509190          2.0 2022-01-18  919.732441   2.0  202202~202402   신규        -
# 509258         21.0 2022-01-21  273.224044  21.0  202202~202402   신규        -
# 509259         21.0 2022-02-28  264.817150  21.0              -    -        -
# 509289          4.0 2022-04-30  816.672314   4.0              -    -        -
#
#        종전계약 보증금 (만원) 종전계약 월세 (만원)  부동산유형    구    동      리 일괄계약
# 509175           NaN          NaN  연립다세대  금천구  독산동   47-3    N
# 509190             0          0.0  연립다세대  금천구  독산동  47-28    N
# 509258             0          0.0   오피스텔  금천구  독산동  144-4    N
# 509259           NaN          NaN   오피스텔  금천구  독산동  144-4    N
# 509289           NaN          NaN  연립다세대  금천구  독산동  145-2    N

# %%
target_2_24_df = house_df[
    (house_df['지번주소'].str.contains(target_gu + ' ' + target_dong))
    &(house_df['지번주소'].str.contains(target_ri))
    #&(house_df['동'] == target_dong)
    &(house_df['계약날짜'] >= (date_today - pd.DateOffset(months=12)))
    #&(house_df['건물연식'] <= target_building_age)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_2_24_df.shape)
target_2_24_df.head()
# Out:
# (3780, 27)
#                        지번주소            도로명            시군구     본번    부번  \
# 509175   서울특별시 금천구 독산동 47-3   남부순환로132길 14  서울특별시 금천구 독산동   47.0   3.0
# 509190  서울특별시 금천구 독산동 47-28   독산로108길 86-7  서울특별시 금천구 독산동   47.0  28.0
# 509239  서울특별시 금천구 독산동 144-4  시흥대로141길 81-2  서울특별시 금천구 독산동  144.0   4.0
# 509241  서울특별시 금천구 독산동 144-4  시흥대로141길 81-2  서울특별시 금천구 독산동  144.0   4.0
# 509257  서울특별시 금천구 독산동 144-4  시흥대로141길 81-2  서울특별시 금천구 독산동  144.0   4.0
#
#              건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도 거래유형 중개사소재지 거래구분  \
# 509175        HYTOWN    28.68     12000  4  2012.0  NaN    NaN   전세
# 509190  메트로타운(47-28)    29.90     27500  4  2020.0  NaN    NaN   전세
# 509239        영진오피스텔    22.94      6500  1  2001.0  NaN    NaN   전세
# 509241        영진오피스텔    23.40     11000  7  2001.0  NaN    NaN   전세
# 509257        영진오피스텔    23.79      6500  1  2001.0  NaN    NaN   전세
#
#         계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식           계약기간 계약구분 갱신요구권 사용  \
# 509175         10.0 2022-01-25  418.410042  10.0              -    -        -
# 509190          2.0 2022-01-18  919.732441   2.0  202202~202402   신규        -
# 509239         20.0 2021-11-15  283.347864  21.0  202112~202312   신규        -
# 509241         20.0 2021-06-22  470.085470  21.0  202107~202307   신규        -
# 509257         20.0 2021-08-28  273.224044  21.0  202109~202309   신규        -
#
#        종전계약 보증금 (만원) 종전계약 월세 (만원)  부동산유형    구    동      리 일괄계약
# 509175           NaN          NaN  연립다세대  금천구  독산동   47-3    N
# 509190             0          0.0  연립다세대  금천구  독산동  47-28    N
# 509239           NaN          NaN   오피스텔  금천구  독산동  144-4    N
# 509241           NaN          NaN   오피스텔  금천구  독산동  144-4    N
# 509257           NaN          NaN   오피스텔  금천구  독산동  144-4    N

# %%
target_3_36_df = house_df[
    (house_df['지번주소'].str.contains(target_gu + ' ' + target_dong))
    &(house_df['지번주소'].str.contains(target_ri))
    #&(house_df['동'] == target_dong)
    &(house_df['계약날짜'] >= (date_today - pd.DateOffset(months=24)))
    #&(house_df['건물연식'] <= target_building_age)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_3_36_df.shape)
target_3_36_df.head()
# Out:
# (8033, 27)
#                        지번주소           도로명            시군구    본번    부번 건물(단지)명  \
# 509174   서울특별시 금천구 독산동 47-3  남부순환로132길 14  서울특별시 금천구 독산동  47.0   3.0  HYTOWN
# 509175   서울특별시 금천구 독산동 47-3  남부순환로132길 14  서울특별시 금천구 독산동  47.0   3.0  HYTOWN
# 509181  서울특별시 금천구 독산동 47-28  독산로108길 86-7  서울특별시 금천구 독산동  47.0  28.0   메트로타운
# 509182  서울특별시 금천구 독산동 47-28  독산로108길 86-7  서울특별시 금천구 독산동  47.0  28.0   메트로타운
# 509183  서울특별시 금천구 독산동 47-28  독산로108길 86-1  서울특별시 금천구 독산동  47.0  28.0   메트로타운
#
#         전용면적(㎡)  거래금액(만원)  층    건축년도 거래유형 중개사소재지 거래구분  계약날짜기준_건물연식       계약날짜  \
# 509174    28.68     12000  5  2012.0  NaN    NaN   전세          8.0 2020-09-21
# 509175    28.68     12000  4  2012.0  NaN    NaN   전세         10.0 2022-01-25
# 509181    27.89     25500  5  2020.0    -      -   매매          0.0 2020-12-14
# 509182    29.30     27900  5  2020.0    -      -   매매          0.0 2020-11-30
# 509183    29.90     27500  4  2020.0    -      -   매매          0.0 2020-07-13
#
#           단가(만원/㎡)  건물연식 계약기간 계약구분 갱신요구권 사용 종전계약 보증금 (만원) 종전계약 월세 (만원)  부동산유형  \
# 509174  418.410042  10.0  NaN  NaN      NaN           NaN          NaN  연립다세대
# 509175  418.410042  10.0    -    -        -           NaN          NaN  연립다세대
# 509181  914.306203   2.0  NaN  NaN      NaN           NaN          NaN  연립다세대
# 509182  952.218430   2.0  NaN  NaN      NaN           NaN          NaN  연립다세대
# 509183  919.732441   2.0  NaN  NaN      NaN           NaN          NaN  연립다세대
#
#           구    동      리 일괄계약
# 509174  금천구  독산동   47-3    N
# 509175  금천구  독산동   47-3    N
# 509181  금천구  독산동  47-28    N
# 509182  금천구  독산동  47-28    N
# 509183  금천구  독산동  47-28    N

# %%
target_5_60_df = house_df[
    (house_df['지번주소'].str.contains(target_gu + ' ' + target_dong))
    &(house_df['지번주소'].str.contains(target_ri))
    #&(house_df['동'] == target_dong)
    &(house_df['계약날짜'] >= (date_today - pd.DateOffset(months=36)))
    #&(house_df['건물연식'] <= target_building_age)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_5_60_df.shape)
target_5_60_df.head()
# Out:
# (11631, 27)
#                        지번주소           도로명            시군구    본번    부번 건물(단지)명  \
# 509174   서울특별시 금천구 독산동 47-3  남부순환로132길 14  서울특별시 금천구 독산동  47.0   3.0  HYTOWN
# 509175   서울특별시 금천구 독산동 47-3  남부순환로132길 14  서울특별시 금천구 독산동  47.0   3.0  HYTOWN
# 509181  서울특별시 금천구 독산동 47-28  독산로108길 86-7  서울특별시 금천구 독산동  47.0  28.0   메트로타운
# 509182  서울특별시 금천구 독산동 47-28  독산로108길 86-7  서울특별시 금천구 독산동  47.0  28.0   메트로타운
# 509183  서울특별시 금천구 독산동 47-28  독산로108길 86-1  서울특별시 금천구 독산동  47.0  28.0   메트로타운
#
#         전용면적(㎡)  거래금액(만원)  층    건축년도 거래유형 중개사소재지 거래구분  계약날짜기준_건물연식       계약날짜  \
# 509174    28.68     12000  5  2012.0  NaN    NaN   전세          8.0 2020-09-21
# 509175    28.68     12000  4  2012.0  NaN    NaN   전세         10.0 2022-01-25
# 509181    27.89     25500  5  2020.0    -      -   매매          0.0 2020-12-14
# 509182    29.30     27900  5  2020.0    -      -   매매          0.0 2020-11-30
# 509183    29.90     27500  4  2020.0    -      -   매매          0.0 2020-07-13
#
#           단가(만원/㎡)  건물연식 계약기간 계약구분 갱신요구권 사용 종전계약 보증금 (만원) 종전계약 월세 (만원)  부동산유형  \
# 509174  418.410042  10.0  NaN  NaN      NaN           NaN          NaN  연립다세대
# 509175  418.410042  10.0    -    -        -           NaN          NaN  연립다세대
# 509181  914.306203   2.0  NaN  NaN      NaN           NaN          NaN  연립다세대
# 509182  952.218430   2.0  NaN  NaN      NaN           NaN          NaN  연립다세대
# 509183  919.732441   2.0  NaN  NaN      NaN           NaN          NaN  연립다세대
#
#           구    동      리 일괄계약
# 509174  금천구  독산동   47-3    N
# 509175  금천구  독산동   47-3    N
# 509181  금천구  독산동  47-28    N
# 509182  금천구  독산동  47-28    N
# 509183  금천구  독산동  47-28    N

# %%
target_1_12_df = identify_bulk_contract(target_1_12_df)
print(target_1_12_df.shape)
# Out:
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
#   0%|          | 0/410 [00:00<?, ?it/s]
# (1755, 27)

# %%
target_2_24_df = identify_bulk_contract(target_2_24_df)
print(target_2_24_df.shape)
# Out:
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
#   0%|          | 0/636 [00:00<?, ?it/s]
# (3780, 27)

# %%
target_3_36_df = identify_bulk_contract(target_3_36_df)
print(target_3_36_df.shape)
# Out:
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
#   0%|          | 0/883 [00:00<?, ?it/s]
# (8033, 27)

# %%
target_5_60_df = identify_bulk_contract(target_5_60_df)
print(target_5_60_df.shape)
# Out:
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
#   0%|          | 0/988 [00:00<?, ?it/s]
# (11631, 27)

# %%
sales_idx_basedir = './한국부동산원/실거래가격지수/'
filenames = [f for f in os.listdir(sales_idx_basedir) if '연립다세대' in f]

sales_idx_df = pd.read_excel(sales_idx_basedir + filenames[0], header=[10, 11])

sales_idx_cols_list = []
for i in range(sales_idx_df.shape[1]):
    if i == 0:
        sales_idx_cols_list.append(sales_idx_df.columns[i][0])
    else:
        sales_idx_cols_list.append(sales_idx_df.columns[i][0] + '_' + sales_idx_df.columns[i][1])

sales_idx_df.columns = sales_idx_cols_list

# %%
print(sales_idx_df.shape)
sales_idx_df.head()
# Out:
# (3, 391)
#   지 역  2006년 01월_지수 2006년 01월_변동률  2006년 02월_지수  2006년 02월_변동률  2006년 03월_지수  \
# 0  서울        50.221             -        49.911          -0.62        51.637
# 1  인천        45.241             -        46.807           3.46        47.270
# 2  경기        52.509             -        51.845          -1.27        52.454
#
#    2006년 03월_변동률  2006년 04월_지수  2006년 04월_변동률  2006년 05월_지수  2006년 05월_변동률  \
# 0           3.46        52.910           2.47        53.493           1.10
# 1           0.99        47.144          -0.27        48.542           2.97
# 2           1.18        52.248          -0.39        54.236           3.81
#
#    2006년 06월_지수  2006년 06월_변동률  2006년 07월_지수  2006년 07월_변동률  2006년 08월_지수  \
# 0        53.589           0.18        55.091           2.80        57.278
# 1        49.024           0.99        50.325           2.65        52.552
# 2        55.223           1.82        55.475           0.46        57.364
#
#    2006년 08월_변동률  2006년 09월_지수  2006년 09월_변동률  2006년 10월_지수  2006년 10월_변동률  \
# 0           3.97        59.286           3.51        62.241           4.98
# 1           4.42        53.958           2.68        55.260           2.41
# 2           3.40        60.894           6.15        65.515           7.59
#
#    2006년 11월_지수  2006년 11월_변동률  2006년 12월_지수  2006년 12월_변동률  2007년 01월_지수  \
# 0        64.506           3.64        65.767           1.96        67.553
# 1        57.571           4.18        59.262           2.94        61.548
# 2        69.404           5.94        70.017           0.88        72.483
#
#    2007년 01월_변동률  2007년 02월_지수  2007년 02월_변동률  2007년 03월_지수  2007년 03월_변동률  \
# 0           2.72        67.417          -0.20        68.926           2.24
# 1           3.86        63.373           2.96        66.647           5.17
# 2           3.52        74.553           2.86        74.763           0.28
#
#    2007년 04월_지수  2007년 04월_변동률  2007년 05월_지수  2007년 05월_변동률  2007년 06월_지수  \
# 0        70.919           2.89        71.327           0.57        73.746
# 1        70.311           5.50        73.082           3.94        76.952
# 2        76.760           2.67        78.811           2.67        79.722
#
#    2007년 06월_변동률  2007년 07월_지수  2007년 07월_변동률  2007년 08월_지수  2007년 08월_변동률  \
# 0           3.39        75.635           2.56        76.482           1.12
# 1           5.30        80.114           4.11        82.674           3.20
# 2           1.16        82.139           3.03        83.608           1.79
#
#    2007년 09월_지수  2007년 09월_변동률  2007년 10월_지수  2007년 10월_변동률  2007년 11월_지수  \
# 0        77.790           1.71        80.564           3.57        81.383
# 1        85.794           3.77        89.107           3.86        91.072
# 2        84.974           1.63        87.484           2.95        89.242
#
#    2007년 11월_변동률  2007년 12월_지수  2007년 12월_변동률  2008년 01월_지수  2008년 01월_변동률  \
# 0           1.02        83.058           2.06        85.470           2.90
# 1           2.21        93.385           2.54        96.514           3.35
# 2           2.01        90.566           1.48        92.239           1.85
#
#    2008년 02월_지수  2008년 02월_변동률  2008년 03월_지수  2008년 03월_변동률  2008년 04월_지수  \
# 0        87.108           1.92        91.242           4.75        94.647
# 1        98.704           2.27       102.057           3.40       108.135
# 2        94.293           2.23        97.770           3.69       102.257
#
#    2008년 04월_변동률  2008년 05월_지수  2008년 05월_변동률  2008년 06월_지수  2008년 06월_변동률  \
# 0           3.73        97.319           2.82        98.112           0.81
# 1           5.96       115.201           6.53       120.309           4.43
# 2           4.59       105.793           3.46       107.969           2.06
#
#    2008년 07월_지수  2008년 07월_변동률  2008년 08월_지수  2008년 08월_변동률  2008년 09월_지수  \
# 0        96.807          -1.33        95.523          -1.33        95.174
# 1       123.255           2.45       126.152           2.35       125.056
# 2       108.246           0.26       108.093          -0.14       107.605
#
#    2008년 09월_변동률  2008년 10월_지수  2008년 10월_변동률  2008년 11월_지수  2008년 11월_변동률  \
# 0          -0.36        91.971          -3.37        87.479          -4.88
# 1          -0.87       122.590          -1.97       113.690          -7.26
# 2          -0.45       103.122          -4.17        98.654          -4.33
#
#    2008년 12월_지수  2008년 12월_변동률  2009년 01월_지수  2009년 01월_변동률  2009년 02월_지수  \
# 0        84.508          -3.40        84.640           0.16        85.891
# 1       110.113          -3.15       111.766           1.50       112.200
# 2        93.503          -5.22        92.972          -0.57        93.902
#
#    2009년 02월_변동률  2009년 03월_지수  2009년 03월_변동률  2009년 04월_지수  2009년 04월_변동률  \
# 0           1.48        86.584           0.81        88.334           2.02
# 1           0.39       114.044           1.64       115.535           1.31
# 2           1.00        94.655           0.80        96.361           1.80
#
#    2009년 05월_지수  2009년 05월_변동률  2009년 06월_지수  2009년 06월_변동률  2009년 07월_지수  \
# 0        90.432           2.37        91.126           0.77        93.032
# 1       117.236           1.47       118.780           1.32       117.990
# 2        97.072           0.74        99.122           2.11       101.023
#
#    2009년 07월_변동률  2009년 08월_지수  2009년 08월_변동률  2009년 09월_지수  2009년 09월_변동률  \
# 0           2.09        94.987           2.10        96.483           1.57
# 1          -0.67       117.628          -0.31       120.765           2.67
# 2           1.92       101.799           0.77       103.454           1.63
#
#    2009년 10월_지수  2009년 10월_변동률  2009년 11월_지수  2009년 11월_변동률  2009년 12월_지수  \
# 0        95.762          -0.75        94.721          -1.09        94.869
# 1       119.561          -1.00       119.451          -0.09       117.345
# 2       102.239          -1.17       100.844          -1.37       100.339
#
#    2009년 12월_변동률  2010년 01월_지수  2010년 01월_변동률  2010년 02월_지수  2010년 02월_변동률  \
# 0           0.16        96.310           1.52        96.033          -0.29
# 1          -1.76       117.750           0.34       117.582          -0.14
# 2          -0.50       100.638           0.30       100.689           0.05
#
#    2010년 03월_지수  2010년 03월_변동률  2010년 04월_지수  2010년 04월_변동률  2010년 05월_지수  \
# 0        95.504          -0.55        95.132          -0.39        94.660
# 1       115.292          -1.95       115.039          -0.22       113.634
# 2       100.416          -0.27        99.541          -0.87        98.489
#
#    2010년 05월_변동률  2010년 06월_지수  2010년 06월_변동률  2010년 07월_지수  2010년 07월_변동률  \
# 0          -0.50        92.782          -1.98        92.166          -0.66
# 1          -1.22       113.494          -0.12       115.510           1.78
# 2          -1.06        97.381          -1.12        96.745          -0.65
#
#    2010년 08월_지수  2010년 08월_변동률  2010년 09월_지수  2010년 09월_변동률  2010년 10월_지수  \
# 0        91.717          -0.49        91.512          -0.22        90.927
# 1       112.936          -2.23       111.155          -1.58       110.791
# 2        95.648          -1.13        95.917           0.28        95.729
#
#    2010년 10월_변동률  2010년 11월_지수  2010년 11월_변동률  2010년 12월_지수  2010년 12월_변동률  \
# 0          -0.64        91.683           0.83        91.778           0.10
# 1          -0.33       113.083           2.07       109.442          -3.22
# 2          -0.20        96.041           0.33        96.104           0.07
#
#    2011년 01월_지수  2011년 01월_변동률  2011년 02월_지수  2011년 02월_변동률  2011년 03월_지수  \
# 0        92.110           0.36        92.903           0.86        93.089
# 1       109.685           0.22       109.102          -0.53       109.503
# 2        96.183           0.08        96.904           0.75        97.594
#
#    2011년 03월_변동률  2011년 04월_지수  2011년 04월_변동률  2011년 05월_지수  2011년 05월_변동률  \
# 0           0.20        92.623          -0.50        92.842           0.24
# 1           0.37       110.740           1.13       108.517          -2.01
# 2           0.71        97.511          -0.08        97.141          -0.38
#
#    2011년 06월_지수  2011년 06월_변동률  2011년 07월_지수  2011년 07월_변동률  2011년 08월_지수  \
# 0        92.080          -0.82        91.791          -0.31        91.255
# 1       106.085          -2.24       105.727          -0.34       104.528
# 2        96.806          -0.34        96.340          -0.48        96.852
#
#    2011년 08월_변동률  2011년 09월_지수  2011년 09월_변동률  2011년 10월_지수  2011년 10월_변동률  \
# 0          -0.58        92.121           0.95        91.589          -0.58
# 1          -1.13       104.454          -0.07       104.207          -0.24
# 2           0.53        97.124           0.28        96.557          -0.58
#
#    2011년 11월_지수  2011년 11월_변동률  2011년 12월_지수  2011년 12월_변동률  2012년 01월_지수  \
# 0        90.845          -0.81        90.054          -0.87        90.683
# 1       103.451          -0.73       101.047          -2.32       101.830
# 2        94.690          -1.93        94.646          -0.05        95.562
#
#    2012년 01월_변동률  2012년 02월_지수  2012년 02월_변동률  2012년 03월_지수  2012년 03월_변동률  \
# 0           0.70        90.234          -0.49        90.079          -0.17
# 1           0.78       100.564          -1.24        98.760          -1.79
# 2           0.97        94.464          -1.15        95.058           0.63
#
#    2012년 04월_지수  2012년 04월_변동률  2012년 05월_지수  2012년 05월_변동률  2012년 06월_지수  \
# 0        88.763          -1.46        87.533          -1.39        88.248
# 1        99.654           0.91        98.722          -0.94        98.277
# 2        95.163           0.11        95.312           0.16        94.173
#
#    2012년 06월_변동률  2012년 07월_지수  2012년 07월_변동률  2012년 08월_지수  2012년 08월_변동률  \
# 0           0.82        86.264          -2.25        86.476           0.25
# 1          -0.45        97.584          -0.70        96.134          -1.49
# 2          -1.20        92.569          -1.70        92.682           0.12
#
#    2012년 09월_지수  2012년 09월_변동률  2012년 10월_지수  2012년 10월_변동률  2012년 11월_지수  \
# 0        86.873           0.46        85.413          -1.68        85.702
# 1        96.016          -0.12        94.481          -1.60        93.466
# 2        92.163          -0.56        91.565          -0.65        90.511
#
#    2012년 11월_변동률  2012년 12월_지수  2012년 12월_변동률  2013년 01월_지수  2013년 01월_변동률  \
# 0           0.34        84.620          -1.26        84.836           0.25
# 1          -1.07        92.451          -1.09        91.915          -0.58
# 2          -1.15        90.174          -0.37        90.415           0.27
#
#    2013년 02월_지수  2013년 02월_변동률  2013년 03월_지수  2013년 03월_변동률  2013년 04월_지수  \
# 0        85.104           0.32        85.590           0.57        85.897
# 1        91.322          -0.65        92.376           1.15        90.553
# 2        90.678           0.29        90.133          -0.60        90.739
#
#    2013년 04월_변동률  2013년 05월_지수  2013년 05월_변동률  2013년 06월_지수  2013년 06월_변동률  \
# 0           0.36        84.768          -1.31        84.612          -0.18
# 1          -1.97        90.449          -0.12        89.815          -0.70
# 2           0.67        91.093           0.39        89.354          -1.91
#
#    2013년 07월_지수  2013년 07월_변동률  2013년 08월_지수  2013년 08월_변동률  2013년 09월_지수  \
# 0        85.441           0.98        85.358          -0.10        85.891
# 1        89.343          -0.53        90.532           1.33        89.356
# 2        90.332           1.10        90.465           0.15        90.467
#
#    2013년 09월_변동률  2013년 10월_지수  2013년 10월_변동률  2013년 11월_지수  2013년 11월_변동률  \
# 0           0.63        85.620          -0.32        85.427          -0.23
# 1          -1.30        89.256          -0.11        90.207           1.07
# 2           0.00        90.188          -0.31        89.872          -0.35
#
#    2013년 12월_지수  2013년 12월_변동률  2014년 01월_지수  2014년 01월_변동률  2014년 02월_지수  \
# 0         83.66          -2.07        84.820           1.39        85.638
# 1         89.61          -0.66        89.101          -0.57        89.665
# 2         89.14          -0.81        89.714           0.64        89.667
#
#    2014년 02월_변동률  2014년 03월_지수  2014년 03월_변동률  2014년 04월_지수  2014년 04월_변동률  \
# 0           0.96        85.965           0.38        86.044           0.09
# 1           0.63        90.262           0.67        90.509           0.27
# 2          -0.05        90.044           0.42        90.475           0.48
#
#    2014년 05월_지수  2014년 05월_변동률  2014년 06월_지수  2014년 06월_변동률  2014년 07월_지수  \
# 0        85.322          -0.84        85.134          -0.22        85.204
# 1        90.670           0.18        90.678           0.01        90.297
# 2        89.188          -1.42        89.211           0.03        89.118
#
#    2014년 07월_변동률  2014년 08월_지수  2014년 08월_변동률  2014년 09월_지수  2014년 09월_변동률  \
# 0           0.08        85.740           0.63        86.309           0.66
# 1          -0.42        90.230          -0.07        90.300           0.08
# 2          -0.10        89.374           0.29        89.855           0.54
#
#    2014년 10월_지수  2014년 10월_변동률  2014년 11월_지수  2014년 11월_변동률  2014년 12월_지수  \
# 0        86.317           0.01        85.519          -0.92        85.623
# 1        90.879           0.64        89.943          -1.03        90.019
# 2        89.708          -0.16        90.635           1.03        89.576
#
#    2014년 12월_변동률  2015년 01월_지수  2015년 01월_변동률  2015년 02월_지수  2015년 02월_변동률  \
# 0           0.12        86.297           0.79        87.218           1.07
# 1           0.08        89.288          -0.81        91.426           2.40
# 2          -1.17        89.071          -0.56        90.770           1.91
#
#    2015년 03월_지수  2015년 03월_변동률  2015년 04월_지수  2015년 04월_변동률  2015년 05월_지수  \
# 0        87.931           0.82        88.453           0.59        88.694
# 1        91.034          -0.43        91.674           0.70        91.541
# 2        91.192           0.47        91.613           0.46        92.291
#
#    2015년 05월_변동률  2015년 06월_지수  2015년 06월_변동률  2015년 07월_지수  2015년 07월_변동률  \
# 0           0.27        88.982           0.33        89.497           0.58
# 1          -0.15        91.868           0.36        93.332           1.59
# 2           0.74        92.261          -0.03        93.138           0.95
#
#    2015년 08월_지수  2015년 08월_변동률  2015년 09월_지수  2015년 09월_변동률  2015년 10월_지수  \
# 0        90.703           1.35        90.835           0.14        91.492
# 1        93.475           0.15        93.702           0.24        93.799
# 2        93.221           0.09        93.729           0.54        93.985
#
#    2015년 10월_변동률  2015년 11월_지수  2015년 11월_변동률  2015년 12월_지수  2015년 12월_변동률  \
# 0           0.72        90.762          -0.80        89.895          -0.95
# 1           0.10        94.146           0.37        94.680           0.57
# 2           0.27        94.405           0.45        93.756          -0.69
#
#    2016년 01월_지수  2016년 01월_변동률  2016년 02월_지수  2016년 02월_변동률  2016년 03월_지수  \
# 0        91.423           1.70        91.861           0.48        92.264
# 1        92.606          -2.19        94.506           2.05        94.591
# 2        94.595           0.90        94.268          -0.35        94.803
#
#    2016년 03월_변동률  2016년 04월_지수  2016년 04월_변동률  2016년 05월_지수  2016년 05월_변동률  \
# 0           0.44        92.520           0.28        92.775           0.28
# 1           0.09        95.576           1.04        94.993          -0.61
# 2           0.57        94.800          -0.00        95.446           0.68
#
#    2016년 06월_지수  2016년 06월_변동률  2016년 07월_지수  2016년 07월_변동률  2016년 08월_지수  \
# 0        92.914           0.15        93.513           0.64        94.704
# 1        96.659           1.75        96.642          -0.02        97.560
# 2        94.970          -0.50        96.389           1.49        96.651
#
#    2016년 08월_변동률  2016년 09월_지수  2016년 09월_변동률  2016년 10월_지수  2016년 10월_변동률  \
# 0           1.27        95.085           0.40        95.838           0.79
# 1           0.95        97.553          -0.01        97.220          -0.34
# 2           0.27        97.345           0.72        97.725           0.39
#
#    2016년 11월_지수  2016년 11월_변동률  2016년 12월_지수  2016년 12월_변동률  2017년 01월_지수  \
# 0        95.609          -0.24        95.614           0.01        95.781
# 1        97.741           0.54        96.779          -0.98        97.446
# 2        97.485          -0.25        97.259          -0.23        97.323
#
#    2017년 01월_변동률  2017년 02월_지수  2017년 02월_변동률  2017년 03월_지수  2017년 03월_변동률  \
# 0           0.17        96.102           0.34        96.618           0.54
# 1           0.69        98.017           0.59        98.232           0.22
# 2           0.07        97.670           0.36        98.393           0.74
#
#    2017년 04월_지수  2017년 04월_변동률  2017년 05월_지수  2017년 05월_변동률  2017년 06월_지수  \
# 0        97.145           0.55        97.795           0.67        98.913
# 1        97.843          -0.40        99.652           1.85        98.884
# 2        98.227          -0.17        98.714           0.50        99.604
#
#    2017년 06월_변동률  2017년 07월_지수  2017년 07월_변동률  2017년 08월_지수  2017년 08월_변동률  \
# 0           1.14       100.035           1.13        99.069          -0.97
# 1          -0.77        99.224           0.34        99.279           0.06
# 2           0.90        99.581          -0.02       100.081           0.50
#
#    2017년 09월_지수  2017년 09월_변동률  2017년 10월_지수  2017년 10월_변동률  2017년 11월_지수  \
# 0        99.311           0.25        99.951           0.64         100.0
# 1        99.687           0.41        99.656          -0.03         100.0
# 2       100.797           0.71       100.661          -0.13         100.0
#
#    2017년 11월_변동률  2017년 12월_지수  2017년 12월_변동률  2018년 01월_지수  2018년 01월_변동률  \
# 0           0.05        99.724          -0.28       100.245           0.52
# 1           0.35        99.248          -0.75        99.288           0.04
# 2          -0.66       100.492           0.49       100.737           0.24
#
#    2018년 02월_지수  2018년 02월_변동률  2018년 03월_지수  2018년 03월_변동률  2018년 04월_지수  \
# 0       101.066           0.82       101.728           0.66       101.980
# 1        99.451           0.16        98.619          -0.84        99.335
# 2       101.088           0.35       100.492          -0.59       101.343
#
#    2018년 04월_변동률  2018년 05월_지수  2018년 05월_변동률  2018년 06월_지수  2018년 06월_변동률  \
# 0           0.25       102.107           0.12       103.092           0.96
# 1           0.73        98.909          -0.43        99.099           0.19
# 2           0.85       101.509           0.16       101.560           0.05
#
#    2018년 07월_지수  2018년 07월_변동률  2018년 08월_지수  2018년 08월_변동률  2018년 09월_지수  \
# 0       103.865           0.75       105.117           1.21       106.155
# 1        99.615           0.52       100.977           1.37       101.631
# 2       102.550           0.97       103.195           0.63       103.580
#
#    2018년 09월_변동률  2018년 10월_지수  2018년 10월_변동률  2018년 11월_지수  2018년 11월_변동률  \
# 0           0.99       105.647          -0.48       104.609          -0.98
# 1           0.65       100.422          -1.19       100.956           0.53
# 2           0.37       102.559          -0.99       101.610          -0.93
#
#    2018년 12월_지수  2018년 12월_변동률  2019년 01월_지수  2019년 01월_변동률  2019년 02월_지수  \
# 0       104.322          -0.27       104.147          -0.17       105.189
# 1       100.007          -0.94       101.500           1.49       100.743
# 2       102.943           1.31       101.046          -1.84       101.327
#
#    2019년 02월_변동률  2019년 03월_지수  2019년 03월_변동률  2019년 04월_지수  2019년 04월_변동률  \
# 0           1.00       105.075          -0.11       105.600           0.50
# 1          -0.75       100.893           0.15       102.535           1.63
# 2           0.28       101.325          -0.00       100.834          -0.48
#
#    2019년 05월_지수  2019년 05월_변동률  2019년 06월_지수  2019년 06월_변동률  2019년 07월_지수  \
# 0       105.763           0.15       107.465           1.61       107.412
# 1       101.802          -0.71       101.511          -0.29       102.453
# 2        99.929          -0.90       102.432           2.50       102.440
#
#    2019년 07월_변동률  2019년 08월_지수  2019년 08월_변동률  2019년 09월_지수  2019년 09월_변동률  \
# 0          -0.05       107.537           0.12       107.862           0.30
# 1           0.93       102.505           0.05       102.509           0.00
# 2           0.01       102.809           0.36       102.890           0.08
#
#    2019년 10월_지수  2019년 10월_변동률  2019년 11월_지수  2019년 11월_변동률  2019년 12월_지수  \
# 0       109.095           1.14       111.298           2.02       110.183
# 1       103.174           0.65       104.436           1.22       104.991
# 2       104.037           1.12       105.207           1.12       106.006
#
#    2019년 12월_변동률  2020년 01월_지수  2020년 01월_변동률  2020년 02월_지수  2020년 02월_변동률  \
# 0          -1.00       109.390          -0.72       111.463           1.90
# 1           0.53       103.658          -1.27       106.503           2.74
# 2           0.76       106.476           0.44       106.626           0.14
#
#    2020년 03월_지수  2020년 03월_변동률  2020년 04월_지수  2020년 04월_변동률  2020년 05월_지수  \
# 0       110.696          -0.69       109.964          -0.66       111.645
# 1       106.790           0.27       106.794           0.00       107.444
# 2       105.724          -0.85       105.398          -0.31       107.039
#
#    2020년 05월_변동률  2020년 06월_지수  2020년 06월_변동률  2020년 07월_지수  2020년 07월_변동률  \
# 0           1.53       114.492           2.55       115.996           1.31
# 1           0.61       107.044          -0.37       105.464          -1.48
# 2           1.56       109.247           2.06       107.811          -1.32
#
#    2020년 08월_지수  2020년 08월_변동률  2020년 09월_지수  2020년 09월_변동률  2020년 10월_지수  \
# 0       116.033           0.03       118.083           1.77       118.033
# 1       104.172          -1.23       103.719          -0.43       103.736
# 2       106.077          -1.61       107.058           0.93       108.034
#
#    2020년 10월_변동률  2020년 11월_지수  2020년 11월_변동률  2020년 12월_지수  2020년 12월_변동률  \
# 0          -0.04       120.423           2.02       121.368           0.78
# 1           0.02       107.187           3.33       107.528           0.32
# 2           0.91       110.552           2.33       111.741           1.08
#
#    2021년 01월_지수  2021년 01월_변동률  2021년 02월_지수  2021년 02월_변동률  2021년 03월_지수  \
# 0       122.641           1.05       122.737           0.08       123.597
# 1       107.815           0.27       108.169           0.33       110.675
# 2       113.216           1.32       113.106          -0.10       112.310
#
#    2021년 03월_변동률  2021년 04월_지수  2021년 04월_변동률  2021년 05월_지수  2021년 05월_변동률  \
# 0           0.70       125.542           1.57       127.664           1.69
# 1           2.32       111.752           0.97       112.283           0.47
# 2          -0.70       114.159           1.65       115.252           0.96
#
#    2021년 06월_지수  2021년 06월_변동률  2021년 07월_지수  2021년 07월_변동률  2021년 08월_지수  \
# 0       129.783           1.66       131.129           1.04       132.265
# 1       113.308           0.91       115.935           2.32       116.125
# 2       116.098           0.73       117.499           1.21       118.073
#
#    2021년 08월_변동률  2021년 09월_지수  2021년 09월_변동률  2021년 10월_지수  2021년 10월_변동률  \
# 0           0.87       134.761           1.89       136.283           1.13
# 1           0.16       119.165           2.62       120.600           1.20
# 2           0.49       119.293           1.03       120.316           0.86
#
#    2021년 11월_지수  2021년 11월_변동률  2021년 12월_지수  2021년 12월_변동률  2022년 01월_지수  \
# 0       136.657           0.27       136.484          -0.13       137.810
# 1       120.783           0.15       121.804           0.85       122.117
# 2       120.639           0.27       120.799           0.13       122.463
#
#    2022년 01월_변동률  2022년 02월_지수  2022년 02월_변동률  2022년 03월_지수  2022년 03월_변동률
# 0           0.97       137.920           0.08       139.583           1.21
# 1           0.26       124.197           1.70       124.993           0.64
# 2           1.38       120.740          -1.41       122.912           1.80

# %%
sales_idx_df = sales_idx_df[sales_idx_df['지 역'] == target_sido]
print(sales_idx_df.shape)
sales_idx_df.head()
# Out:
# (1, 391)
#   지 역  2006년 01월_지수 2006년 01월_변동률  2006년 02월_지수  2006년 02월_변동률  2006년 03월_지수  \
# 0  서울        50.221             -        49.911          -0.62        51.637
#
#    2006년 03월_변동률  2006년 04월_지수  2006년 04월_변동률  2006년 05월_지수  2006년 05월_변동률  \
# 0           3.46         52.91           2.47        53.493            1.1
#
#    2006년 06월_지수  2006년 06월_변동률  2006년 07월_지수  2006년 07월_변동률  2006년 08월_지수  \
# 0        53.589           0.18        55.091            2.8        57.278
#
#    2006년 08월_변동률  2006년 09월_지수  2006년 09월_변동률  2006년 10월_지수  2006년 10월_변동률  \
# 0           3.97        59.286           3.51        62.241           4.98
#
#    2006년 11월_지수  2006년 11월_변동률  2006년 12월_지수  2006년 12월_변동률  2007년 01월_지수  \
# 0        64.506           3.64        65.767           1.96        67.553
#
#    2007년 01월_변동률  2007년 02월_지수  2007년 02월_변동률  2007년 03월_지수  2007년 03월_변동률  \
# 0           2.72        67.417           -0.2        68.926           2.24
#
#    2007년 04월_지수  2007년 04월_변동률  2007년 05월_지수  2007년 05월_변동률  2007년 06월_지수  \
# 0        70.919           2.89        71.327           0.57        73.746
#
#    2007년 06월_변동률  2007년 07월_지수  2007년 07월_변동률  2007년 08월_지수  2007년 08월_변동률  \
# 0           3.39        75.635           2.56        76.482           1.12
#
#    2007년 09월_지수  2007년 09월_변동률  2007년 10월_지수  2007년 10월_변동률  2007년 11월_지수  \
# 0         77.79           1.71        80.564           3.57        81.383
#
#    2007년 11월_변동률  2007년 12월_지수  2007년 12월_변동률  2008년 01월_지수  2008년 01월_변동률  \
# 0           1.02        83.058           2.06         85.47            2.9
#
#    2008년 02월_지수  2008년 02월_변동률  2008년 03월_지수  2008년 03월_변동률  2008년 04월_지수  \
# 0        87.108           1.92        91.242           4.75        94.647
#
#    2008년 04월_변동률  2008년 05월_지수  2008년 05월_변동률  2008년 06월_지수  2008년 06월_변동률  \
# 0           3.73        97.319           2.82        98.112           0.81
#
#    2008년 07월_지수  2008년 07월_변동률  2008년 08월_지수  2008년 08월_변동률  2008년 09월_지수  \
# 0        96.807          -1.33        95.523          -1.33        95.174
#
#    2008년 09월_변동률  2008년 10월_지수  2008년 10월_변동률  2008년 11월_지수  2008년 11월_변동률  \
# 0          -0.36        91.971          -3.37        87.479          -4.88
#
#    2008년 12월_지수  2008년 12월_변동률  2009년 01월_지수  2009년 01월_변동률  2009년 02월_지수  \
# 0        84.508           -3.4         84.64           0.16        85.891
#
#    2009년 02월_변동률  2009년 03월_지수  2009년 03월_변동률  2009년 04월_지수  2009년 04월_변동률  \
# 0           1.48        86.584           0.81        88.334           2.02
#
#    2009년 05월_지수  2009년 05월_변동률  2009년 06월_지수  2009년 06월_변동률  2009년 07월_지수  \
# 0        90.432           2.37        91.126           0.77        93.032
#
#    2009년 07월_변동률  2009년 08월_지수  2009년 08월_변동률  2009년 09월_지수  2009년 09월_변동률  \
# 0           2.09        94.987            2.1        96.483           1.57
#
#    2009년 10월_지수  2009년 10월_변동률  2009년 11월_지수  2009년 11월_변동률  2009년 12월_지수  \
# 0        95.762          -0.75        94.721          -1.09        94.869
#
#    2009년 12월_변동률  2010년 01월_지수  2010년 01월_변동률  2010년 02월_지수  2010년 02월_변동률  \
# 0           0.16         96.31           1.52        96.033          -0.29
#
#    2010년 03월_지수  2010년 03월_변동률  2010년 04월_지수  2010년 04월_변동률  2010년 05월_지수  \
# 0        95.504          -0.55        95.132          -0.39         94.66
#
#    2010년 05월_변동률  2010년 06월_지수  2010년 06월_변동률  2010년 07월_지수  2010년 07월_변동률  \
# 0           -0.5        92.782          -1.98        92.166          -0.66
#
#    2010년 08월_지수  2010년 08월_변동률  2010년 09월_지수  2010년 09월_변동률  2010년 10월_지수  \
# 0        91.717          -0.49        91.512          -0.22        90.927
#
#    2010년 10월_변동률  2010년 11월_지수  2010년 11월_변동률  2010년 12월_지수  2010년 12월_변동률  \
# 0          -0.64        91.683           0.83        91.778            0.1
#
#    2011년 01월_지수  2011년 01월_변동률  2011년 02월_지수  2011년 02월_변동률  2011년 03월_지수  \
# 0         92.11           0.36        92.903           0.86        93.089
#
#    2011년 03월_변동률  2011년 04월_지수  2011년 04월_변동률  2011년 05월_지수  2011년 05월_변동률  \
# 0            0.2        92.623           -0.5        92.842           0.24
#
#    2011년 06월_지수  2011년 06월_변동률  2011년 07월_지수  2011년 07월_변동률  2011년 08월_지수  \
# 0         92.08          -0.82        91.791          -0.31        91.255
#
#    2011년 08월_변동률  2011년 09월_지수  2011년 09월_변동률  2011년 10월_지수  2011년 10월_변동률  \
# 0          -0.58        92.121           0.95        91.589          -0.58
#
#    2011년 11월_지수  2011년 11월_변동률  2011년 12월_지수  2011년 12월_변동률  2012년 01월_지수  \
# 0        90.845          -0.81        90.054          -0.87        90.683
#
#    2012년 01월_변동률  2012년 02월_지수  2012년 02월_변동률  2012년 03월_지수  2012년 03월_변동률  \
# 0            0.7        90.234          -0.49        90.079          -0.17
#
#    2012년 04월_지수  2012년 04월_변동률  2012년 05월_지수  2012년 05월_변동률  2012년 06월_지수  \
# 0        88.763          -1.46        87.533          -1.39        88.248
#
#    2012년 06월_변동률  2012년 07월_지수  2012년 07월_변동률  2012년 08월_지수  2012년 08월_변동률  \
# 0           0.82        86.264          -2.25        86.476           0.25
#
#    2012년 09월_지수  2012년 09월_변동률  2012년 10월_지수  2012년 10월_변동률  2012년 11월_지수  \
# 0        86.873           0.46        85.413          -1.68        85.702
#
#    2012년 11월_변동률  2012년 12월_지수  2012년 12월_변동률  2013년 01월_지수  2013년 01월_변동률  \
# 0           0.34         84.62          -1.26        84.836           0.25
#
#    2013년 02월_지수  2013년 02월_변동률  2013년 03월_지수  2013년 03월_변동률  2013년 04월_지수  \
# 0        85.104           0.32         85.59           0.57        85.897
#
#    2013년 04월_변동률  2013년 05월_지수  2013년 05월_변동률  2013년 06월_지수  2013년 06월_변동률  \
# 0           0.36        84.768          -1.31        84.612          -0.18
#
#    2013년 07월_지수  2013년 07월_변동률  2013년 08월_지수  2013년 08월_변동률  2013년 09월_지수  \
# 0        85.441           0.98        85.358           -0.1        85.891
#
#    2013년 09월_변동률  2013년 10월_지수  2013년 10월_변동률  2013년 11월_지수  2013년 11월_변동률  \
# 0           0.63         85.62          -0.32        85.427          -0.23
#
#    2013년 12월_지수  2013년 12월_변동률  2014년 01월_지수  2014년 01월_변동률  2014년 02월_지수  \
# 0         83.66          -2.07         84.82           1.39        85.638
#
#    2014년 02월_변동률  2014년 03월_지수  2014년 03월_변동률  2014년 04월_지수  2014년 04월_변동률  \
# 0           0.96        85.965           0.38        86.044           0.09
#
#    2014년 05월_지수  2014년 05월_변동률  2014년 06월_지수  2014년 06월_변동률  2014년 07월_지수  \
# 0        85.322          -0.84        85.134          -0.22        85.204
#
#    2014년 07월_변동률  2014년 08월_지수  2014년 08월_변동률  2014년 09월_지수  2014년 09월_변동률  \
# 0           0.08         85.74           0.63        86.309           0.66
#
#    2014년 10월_지수  2014년 10월_변동률  2014년 11월_지수  2014년 11월_변동률  2014년 12월_지수  \
# 0        86.317           0.01        85.519          -0.92        85.623
#
#    2014년 12월_변동률  2015년 01월_지수  2015년 01월_변동률  2015년 02월_지수  2015년 02월_변동률  \
# 0           0.12        86.297           0.79        87.218           1.07
#
#    2015년 03월_지수  2015년 03월_변동률  2015년 04월_지수  2015년 04월_변동률  2015년 05월_지수  \
# 0        87.931           0.82        88.453           0.59        88.694
#
#    2015년 05월_변동률  2015년 06월_지수  2015년 06월_변동률  2015년 07월_지수  2015년 07월_변동률  \
# 0           0.27        88.982           0.33        89.497           0.58
#
#    2015년 08월_지수  2015년 08월_변동률  2015년 09월_지수  2015년 09월_변동률  2015년 10월_지수  \
# 0        90.703           1.35        90.835           0.14        91.492
#
#    2015년 10월_변동률  2015년 11월_지수  2015년 11월_변동률  2015년 12월_지수  2015년 12월_변동률  \
# 0           0.72        90.762           -0.8        89.895          -0.95
#
#    2016년 01월_지수  2016년 01월_변동률  2016년 02월_지수  2016년 02월_변동률  2016년 03월_지수  \
# 0        91.423            1.7        91.861           0.48        92.264
#
#    2016년 03월_변동률  2016년 04월_지수  2016년 04월_변동률  2016년 05월_지수  2016년 05월_변동률  \
# 0           0.44         92.52           0.28        92.775           0.28
#
#    2016년 06월_지수  2016년 06월_변동률  2016년 07월_지수  2016년 07월_변동률  2016년 08월_지수  \
# 0        92.914           0.15        93.513           0.64        94.704
#
#    2016년 08월_변동률  2016년 09월_지수  2016년 09월_변동률  2016년 10월_지수  2016년 10월_변동률  \
# 0           1.27        95.085            0.4        95.838           0.79
#
#    2016년 11월_지수  2016년 11월_변동률  2016년 12월_지수  2016년 12월_변동률  2017년 01월_지수  \
# 0        95.609          -0.24        95.614           0.01        95.781
#
#    2017년 01월_변동률  2017년 02월_지수  2017년 02월_변동률  2017년 03월_지수  2017년 03월_변동률  \
# 0           0.17        96.102           0.34        96.618           0.54
#
#    2017년 04월_지수  2017년 04월_변동률  2017년 05월_지수  2017년 05월_변동률  2017년 06월_지수  \
# 0        97.145           0.55        97.795           0.67        98.913
#
#    2017년 06월_변동률  2017년 07월_지수  2017년 07월_변동률  2017년 08월_지수  2017년 08월_변동률  \
# 0           1.14       100.035           1.13        99.069          -0.97
#
#    2017년 09월_지수  2017년 09월_변동률  2017년 10월_지수  2017년 10월_변동률  2017년 11월_지수  \
# 0        99.311           0.25        99.951           0.64         100.0
#
#    2017년 11월_변동률  2017년 12월_지수  2017년 12월_변동률  2018년 01월_지수  2018년 01월_변동률  \
# 0           0.05        99.724          -0.28       100.245           0.52
#
#    2018년 02월_지수  2018년 02월_변동률  2018년 03월_지수  2018년 03월_변동률  2018년 04월_지수  \
# 0       101.066           0.82       101.728           0.66        101.98
#
#    2018년 04월_변동률  2018년 05월_지수  2018년 05월_변동률  2018년 06월_지수  2018년 06월_변동률  \
# 0           0.25       102.107           0.12       103.092           0.96
#
#    2018년 07월_지수  2018년 07월_변동률  2018년 08월_지수  2018년 08월_변동률  2018년 09월_지수  \
# 0       103.865           0.75       105.117           1.21       106.155
#
#    2018년 09월_변동률  2018년 10월_지수  2018년 10월_변동률  2018년 11월_지수  2018년 11월_변동률  \
# 0           0.99       105.647          -0.48       104.609          -0.98
#
#    2018년 12월_지수  2018년 12월_변동률  2019년 01월_지수  2019년 01월_변동률  2019년 02월_지수  \
# 0       104.322          -0.27       104.147          -0.17       105.189
#
#    2019년 02월_변동률  2019년 03월_지수  2019년 03월_변동률  2019년 04월_지수  2019년 04월_변동률  \
# 0            1.0       105.075          -0.11         105.6            0.5
#
#    2019년 05월_지수  2019년 05월_변동률  2019년 06월_지수  2019년 06월_변동률  2019년 07월_지수  \
# 0       105.763           0.15       107.465           1.61       107.412
#
#    2019년 07월_변동률  2019년 08월_지수  2019년 08월_변동률  2019년 09월_지수  2019년 09월_변동률  \
# 0          -0.05       107.537           0.12       107.862            0.3
#
#    2019년 10월_지수  2019년 10월_변동률  2019년 11월_지수  2019년 11월_변동률  2019년 12월_지수  \
# 0       109.095           1.14       111.298           2.02       110.183
#
#    2019년 12월_변동률  2020년 01월_지수  2020년 01월_변동률  2020년 02월_지수  2020년 02월_변동률  \
# 0           -1.0        109.39          -0.72       111.463            1.9
#
#    2020년 03월_지수  2020년 03월_변동률  2020년 04월_지수  2020년 04월_변동률  2020년 05월_지수  \
# 0       110.696          -0.69       109.964          -0.66       111.645
#
#    2020년 05월_변동률  2020년 06월_지수  2020년 06월_변동률  2020년 07월_지수  2020년 07월_변동률  \
# 0           1.53       114.492           2.55       115.996           1.31
#
#    2020년 08월_지수  2020년 08월_변동률  2020년 09월_지수  2020년 09월_변동률  2020년 10월_지수  \
# 0       116.033           0.03       118.083           1.77       118.033
#
#    2020년 10월_변동률  2020년 11월_지수  2020년 11월_변동률  2020년 12월_지수  2020년 12월_변동률  \
# 0          -0.04       120.423           2.02       121.368           0.78
#
#    2021년 01월_지수  2021년 01월_변동률  2021년 02월_지수  2021년 02월_변동률  2021년 03월_지수  \
# 0       122.641           1.05       122.737           0.08       123.597
#
#    2021년 03월_변동률  2021년 04월_지수  2021년 04월_변동률  2021년 05월_지수  2021년 05월_변동률  \
# 0            0.7       125.542           1.57       127.664           1.69
#
#    2021년 06월_지수  2021년 06월_변동률  2021년 07월_지수  2021년 07월_변동률  2021년 08월_지수  \
# 0       129.783           1.66       131.129           1.04       132.265
#
#    2021년 08월_변동률  2021년 09월_지수  2021년 09월_변동률  2021년 10월_지수  2021년 10월_변동률  \
# 0           0.87       134.761           1.89       136.283           1.13
#
#    2021년 11월_지수  2021년 11월_변동률  2021년 12월_지수  2021년 12월_변동률  2022년 01월_지수  \
# 0       136.657           0.27       136.484          -0.13        137.81
#
#    2022년 01월_변동률  2022년 02월_지수  2022년 02월_변동률  2022년 03월_지수  2022년 03월_변동률
# 0           0.97        137.92           0.08       139.583           1.21

# %%
def get_sales_idx(x):
    # x is a pandas timestamp
    
    df = sales_idx_df.copy()
    
    if pd.isna(x) == True:
        return x
    else:
        year = str(x.year)
        month = str(x.month)
        if len(month) == 1:
            month = '0'+month
        
        try:
            idx = df[year+'년 '+month+'월_지수'].iloc[0]
            return idx
        
        except:
            return '지수없음'

# %%
def get_index_applied_prices(df):
    df = df.copy()
    
    last_idx = sales_idx_df.iloc[0,-2]
    
    df['계약날짜_실거래지수'] = df['계약날짜'].apply(get_sales_idx)
    
    df_idx_positive = df[df['계약날짜_실거래지수'] != '지수없음']
    
    df['지수적용단가'] = df['단가(만원/㎡)']
    
    df_idx_positive['지수적용단가'] = df_idx_positive['단가(만원/㎡)'] / df_idx_positive['계약날짜_실거래지수'] * last_idx
    
    df.loc[df_idx_positive.index, '지수적용단가'] = df_idx_positive['지수적용단가']
    
    df['지수적용단가'] = df['지수적용단가'].astype('float')
    
    df['지수적용날짜'] = '지수없음'
    
    last_date = sales_idx_df.columns[-1].split('_')[0]
    df.loc[df_idx_positive.index, '지수적용날짜'] = last_date
    
    return df

# %%
target_1_12_df = get_index_applied_prices(target_1_12_df)
print(target_1_12_df.shape)
target_1_12_df.head()
# Out:
# (1755, 30)
#                        지번주소            도로명            시군구     본번    부번  \
# 509175   서울특별시 금천구 독산동 47-3   남부순환로132길 14  서울특별시 금천구 독산동   47.0   3.0
# 509190  서울특별시 금천구 독산동 47-28   독산로108길 86-7  서울특별시 금천구 독산동   47.0  28.0
# 509258  서울특별시 금천구 독산동 144-4  시흥대로141길 81-2  서울특별시 금천구 독산동  144.0   4.0
# 509259  서울특별시 금천구 독산동 144-4  시흥대로141길 81-2  서울특별시 금천구 독산동  144.0   4.0
# 509289  서울특별시 금천구 독산동 145-2       시흥대로 485  서울특별시 금천구 독산동  145.0   2.0
#
#              건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도 거래유형 중개사소재지 거래구분  \
# 509175        HYTOWN    28.68     12000  4  2012.0  NaN    NaN   전세
# 509190  메트로타운(47-28)    29.90     27500  4  2020.0  NaN    NaN   전세
# 509258        영진오피스텔    23.79      6500  5  2001.0  NaN    NaN   전세
# 509259        영진오피스텔    23.79      6300  1  2001.0  NaN    NaN   전세
# 509289      한영솔레이유시티    29.51     24100  6  2018.0  NaN    NaN   전세
#
#         계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식           계약기간 계약구분 갱신요구권 사용  \
# 509175         10.0 2022-01-25  418.410042  10.0              -    -        -
# 509190          2.0 2022-01-18  919.732441   2.0  202202~202402   신규        -
# 509258         21.0 2022-01-21  273.224044  21.0  202202~202402   신규        -
# 509259         21.0 2022-02-28  264.817150  21.0              -    -        -
# 509289          4.0 2022-04-30  816.672314   4.0              -    -        -
#
#        종전계약 보증금 (만원) 종전계약 월세 (만원)  부동산유형    구    동      리 일괄계약 계약날짜_실거래지수  \
# 509175           NaN          NaN  연립다세대  금천구  독산동   47-3    N     137.81
# 509190             0          0.0  연립다세대  금천구  독산동  47-28    N     137.81
# 509258             0          0.0   오피스텔  금천구  독산동  144-4    N     137.81
# 509259           NaN          NaN   오피스텔  금천구  독산동  144-4    N     137.92
# 509289           NaN          NaN  연립다세대  금천구  독산동  145-2    N       지수없음
#
#             지수적용단가     지수적용날짜
# 509175  423.793113  2022년 03월
# 509190  931.565296  2022년 03월
# 509258  276.739218  2022년 03월
# 509259  268.010240  2022년 03월
# 509289  816.672314       지수없음

# %%
target_2_24_df = get_index_applied_prices(target_2_24_df)
print(target_2_24_df.shape)
target_2_24_df.head()
# Out:
# (3780, 30)
#                        지번주소            도로명            시군구     본번    부번  \
# 509175   서울특별시 금천구 독산동 47-3   남부순환로132길 14  서울특별시 금천구 독산동   47.0   3.0
# 509190  서울특별시 금천구 독산동 47-28   독산로108길 86-7  서울특별시 금천구 독산동   47.0  28.0
# 509239  서울특별시 금천구 독산동 144-4  시흥대로141길 81-2  서울특별시 금천구 독산동  144.0   4.0
# 509241  서울특별시 금천구 독산동 144-4  시흥대로141길 81-2  서울특별시 금천구 독산동  144.0   4.0
# 509257  서울특별시 금천구 독산동 144-4  시흥대로141길 81-2  서울특별시 금천구 독산동  144.0   4.0
#
#              건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도 거래유형 중개사소재지 거래구분  \
# 509175        HYTOWN    28.68     12000  4  2012.0  NaN    NaN   전세
# 509190  메트로타운(47-28)    29.90     27500  4  2020.0  NaN    NaN   전세
# 509239        영진오피스텔    22.94      6500  1  2001.0  NaN    NaN   전세
# 509241        영진오피스텔    23.40     11000  7  2001.0  NaN    NaN   전세
# 509257        영진오피스텔    23.79      6500  1  2001.0  NaN    NaN   전세
#
#         계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식           계약기간 계약구분 갱신요구권 사용  \
# 509175         10.0 2022-01-25  418.410042  10.0              -    -        -
# 509190          2.0 2022-01-18  919.732441   2.0  202202~202402   신규        -
# 509239         20.0 2021-11-15  283.347864  21.0  202112~202312   신규        -
# 509241         20.0 2021-06-22  470.085470  21.0  202107~202307   신규        -
# 509257         20.0 2021-08-28  273.224044  21.0  202109~202309   신규        -
#
#        종전계약 보증금 (만원) 종전계약 월세 (만원)  부동산유형    구    동      리 일괄계약 계약날짜_실거래지수  \
# 509175           NaN          NaN  연립다세대  금천구  독산동   47-3    N     137.81
# 509190             0          0.0  연립다세대  금천구  독산동  47-28    N     137.81
# 509239           NaN          NaN   오피스텔  금천구  독산동  144-4    N    136.657
# 509241           NaN          NaN   오피스텔  금천구  독산동  144-4    N    129.783
# 509257           NaN          NaN   오피스텔  금천구  독산동  144-4    N    132.265
#
#             지수적용단가     지수적용날짜
# 509175  423.793113  2022년 03월
# 509190  931.565296  2022년 03월
# 509239  289.414702  2022년 03월
# 509241  505.581934  2022년 03월
# 509257  288.341071  2022년 03월

# %%
target_3_36_df = get_index_applied_prices(target_3_36_df)
print(target_3_36_df.shape)
target_3_36_df.head()
# Out:
# (8033, 30)
#                        지번주소           도로명            시군구    본번    부번 건물(단지)명  \
# 509174   서울특별시 금천구 독산동 47-3  남부순환로132길 14  서울특별시 금천구 독산동  47.0   3.0  HYTOWN
# 509175   서울특별시 금천구 독산동 47-3  남부순환로132길 14  서울특별시 금천구 독산동  47.0   3.0  HYTOWN
# 509181  서울특별시 금천구 독산동 47-28  독산로108길 86-7  서울특별시 금천구 독산동  47.0  28.0   메트로타운
# 509182  서울특별시 금천구 독산동 47-28  독산로108길 86-7  서울특별시 금천구 독산동  47.0  28.0   메트로타운
# 509183  서울특별시 금천구 독산동 47-28  독산로108길 86-1  서울특별시 금천구 독산동  47.0  28.0   메트로타운
#
#         전용면적(㎡)  거래금액(만원)  층    건축년도 거래유형 중개사소재지 거래구분  계약날짜기준_건물연식       계약날짜  \
# 509174    28.68     12000  5  2012.0  NaN    NaN   전세          8.0 2020-09-21
# 509175    28.68     12000  4  2012.0  NaN    NaN   전세         10.0 2022-01-25
# 509181    27.89     25500  5  2020.0    -      -   매매          0.0 2020-12-14
# 509182    29.30     27900  5  2020.0    -      -   매매          0.0 2020-11-30
# 509183    29.90     27500  4  2020.0    -      -   매매          0.0 2020-07-13
#
#           단가(만원/㎡)  건물연식 계약기간 계약구분 갱신요구권 사용 종전계약 보증금 (만원) 종전계약 월세 (만원)  부동산유형  \
# 509174  418.410042  10.0  NaN  NaN      NaN           NaN          NaN  연립다세대
# 509175  418.410042  10.0    -    -        -           NaN          NaN  연립다세대
# 509181  914.306203   2.0  NaN  NaN      NaN           NaN          NaN  연립다세대
# 509182  952.218430   2.0  NaN  NaN      NaN           NaN          NaN  연립다세대
# 509183  919.732441   2.0  NaN  NaN      NaN           NaN          NaN  연립다세대
#
#           구    동      리 일괄계약 계약날짜_실거래지수       지수적용단가     지수적용날짜
# 509174  금천구  독산동   47-3    N    118.083   494.592184  2022년 03월
# 509175  금천구  독산동   47-3    N     137.81   423.793113  2022년 03월
# 509181  금천구  독산동  47-28    N    121.368  1051.525960  2022년 03월
# 509182  금천구  독산동  47-28    N    120.423  1103.721923  2022년 03월
# 509183  금천구  독산동  47-28    N    115.996  1106.753796  2022년 03월

# %%
target_5_60_df = get_index_applied_prices(target_5_60_df)
print(target_5_60_df.shape)
target_5_60_df.head()
# Out:
# (11631, 30)
#                        지번주소           도로명            시군구    본번    부번 건물(단지)명  \
# 509174   서울특별시 금천구 독산동 47-3  남부순환로132길 14  서울특별시 금천구 독산동  47.0   3.0  HYTOWN
# 509175   서울특별시 금천구 독산동 47-3  남부순환로132길 14  서울특별시 금천구 독산동  47.0   3.0  HYTOWN
# 509181  서울특별시 금천구 독산동 47-28  독산로108길 86-7  서울특별시 금천구 독산동  47.0  28.0   메트로타운
# 509182  서울특별시 금천구 독산동 47-28  독산로108길 86-7  서울특별시 금천구 독산동  47.0  28.0   메트로타운
# 509183  서울특별시 금천구 독산동 47-28  독산로108길 86-1  서울특별시 금천구 독산동  47.0  28.0   메트로타운
#
#         전용면적(㎡)  거래금액(만원)  층    건축년도 거래유형 중개사소재지 거래구분  계약날짜기준_건물연식       계약날짜  \
# 509174    28.68     12000  5  2012.0  NaN    NaN   전세          8.0 2020-09-21
# 509175    28.68     12000  4  2012.0  NaN    NaN   전세         10.0 2022-01-25
# 509181    27.89     25500  5  2020.0    -      -   매매          0.0 2020-12-14
# 509182    29.30     27900  5  2020.0    -      -   매매          0.0 2020-11-30
# 509183    29.90     27500  4  2020.0    -      -   매매          0.0 2020-07-13
#
#           단가(만원/㎡)  건물연식 계약기간 계약구분 갱신요구권 사용 종전계약 보증금 (만원) 종전계약 월세 (만원)  부동산유형  \
# 509174  418.410042  10.0  NaN  NaN      NaN           NaN          NaN  연립다세대
# 509175  418.410042  10.0    -    -        -           NaN          NaN  연립다세대
# 509181  914.306203   2.0  NaN  NaN      NaN           NaN          NaN  연립다세대
# 509182  952.218430   2.0  NaN  NaN      NaN           NaN          NaN  연립다세대
# 509183  919.732441   2.0  NaN  NaN      NaN           NaN          NaN  연립다세대
#
#           구    동      리 일괄계약 계약날짜_실거래지수       지수적용단가     지수적용날짜
# 509174  금천구  독산동   47-3    N    118.083   494.592184  2022년 03월
# 509175  금천구  독산동   47-3    N     137.81   423.793113  2022년 03월
# 509181  금천구  독산동  47-28    N    121.368  1051.525960  2022년 03월
# 509182  금천구  독산동  47-28    N    120.423  1103.721923  2022년 03월
# 509183  금천구  독산동  47-28    N    115.996  1106.753796  2022년 03월

# %%
cols_to_include = [
    '지번주소', '건물(단지)명', '건물연식', '층', '거래구분', '전용면적(㎡)', '계약날짜', '거래금액(만원)', '단가(만원/㎡)',
    '부동산유형', '일괄계약', '지수적용날짜', '지수적용단가'
]

# %%
target_dir = './국토교통부_실거래가_공개시스템/집값분석/{}_{}_{}_{}_{}/'.format(target_sido, target_gu, target_dong, target_ri, date_today_record)

# %%
try:
    os.makedirs(target_dir)
except:
    pass

# %%
target_1_12_df = target_1_12_df.sort_values(['시군구', '본번', '부번', '건축년도', '부동산유형', '거래구분', '계약날짜', '전용면적(㎡)']).reset_index(drop=True)
target_1_12_df1 = target_1_12_df[cols_to_include]
target_1_12_df1.to_excel(target_dir + '실거래가_건물연식없음_계약최근6개월.xlsx', index=False)

# %%
target_1_12_30_df1 = target_1_12_df1[target_1_12_df1['전용면적(㎡)'] <= 30]
target_1_12_30_df1.to_excel(target_dir + '실거래가_건물연식{}년_계약최근6개월_30제곱미터미만.xlsx'.format(target_building_age), index=False)

# %%
target_1_12_bdyr2_df1 = target_1_12_df1[target_1_12_df1['건물연식'] <= 2]
target_1_12_bdyr2_df1.to_excel(target_dir + '실거래가_건물연식{}년_계약최근6개월.xlsx'.format(2), index=False)

# %%
target_1_12_bdyr5_df1 = target_1_12_df1[target_1_12_df1['건물연식'] <= 5]
target_1_12_bdyr5_df1.to_excel(target_dir + '실거래가_건물연식{}년_계약최근6개월.xlsx'.format(5), index=False)

# %%
target_2_24_df = target_2_24_df.sort_values(['시군구', '본번', '부번', '건축년도', '부동산유형', '거래구분', '계약날짜', '전용면적(㎡)']).reset_index(drop=True)
target_2_24_df1 = target_2_24_df[cols_to_include]
target_2_24_df1.to_excel(target_dir + '실거래가_건물연식없음년_계약최근12개월.xlsx', index=False)

# %%
target_2_24_30_df1 = target_2_24_df1[target_2_24_df1['전용면적(㎡)'] <= 30]
target_2_24_30_df1.to_excel(target_dir + '실거래가_건물연식{}년_계약최근12개월_30제곱미터미만.xlsx'.format(target_building_age), index=False)

# %%
target_2_24_bdyr2_df1 = target_2_24_df1[target_2_24_df1['건물연식'] <= 2]
target_2_24_bdyr2_df1.to_excel(target_dir + '실거래가_건물연식{}년_계약최근12개월.xlsx'.format(2), index=False)

# %%
target_2_24_bdyr5_df1 = target_2_24_df1[target_2_24_df1['건물연식'] <= 5]
target_2_24_bdyr5_df1.to_excel(target_dir + '실거래가_건물연식{}년_계약최근12개월.xlsx'.format(5), index=False)

# %%
target_3_36_df = target_3_36_df.sort_values(['시군구', '본번', '부번', '건축년도', '부동산유형', '거래구분', '계약날짜', '전용면적(㎡)']).reset_index(drop=True)
target_3_36_df1 = target_3_36_df[cols_to_include]
target_3_36_df1.to_excel(target_dir + '실거래가_건물연식없음_계약최근24개월.xlsx', index=False)

# %%
target_3_36_30_df1 = target_3_36_df1[target_3_36_df1['전용면적(㎡)'] <= 30]
target_3_36_30_df1.to_excel(target_dir + '실거래가_건물연식{}년_계약최근24개월_30제곱미터미만.xlsx'.format(target_building_age), index=False)

# %%
target_3_36_bdyr2_df1 = target_3_36_df1[target_3_36_df1['건물연식'] <= 2]
target_3_36_bdyr2_df1.to_excel(target_dir + '실거래가_건물연식{}년_계약최근24개월.xlsx'.format(2), index=False)

# %%
target_3_36_bdyr5_df1 = target_3_36_df1[target_3_36_df1['건물연식'] <= 5]
target_3_36_bdyr5_df1.to_excel(target_dir + '실거래가_건물연식{}년_계약최근24개월.xlsx'.format(5), index=False)

# %%
target_5_60_df = target_5_60_df.sort_values(['시군구', '본번', '부번', '건축년도', '부동산유형', '거래구분', '계약날짜', '전용면적(㎡)']).reset_index(drop=True)
target_5_60_df1 = target_5_60_df[cols_to_include]
target_5_60_df1.to_excel(target_dir + '실거래가_건물연식없음_계약최근36개월.xlsx', index=False)

# %%
target_5_60_30_df1 = target_5_60_df1[target_5_60_df1['전용면적(㎡)'] <= 30]
target_5_60_30_df1.to_excel(target_dir + '실거래가_건물연식{}년_계약최근36개월_30제곱미터미만.xlsx'.format(target_building_age), index=False)

# %%
target_5_60_bdyr2_df1 = target_5_60_df1[target_5_60_df1['건물연식'] <= 2]
target_5_60_bdyr2_df1.to_excel(target_dir + '실거래가_건물연식{}년_계약최근36개월.xlsx'.format(2), index=False)

# %%
target_5_60_bdyr5_df1 = target_5_60_df1[target_5_60_df1['건물연식'] <= 5]
target_5_60_bdyr5_df1.to_excel(target_dir + '실거래가_건물연식{}년_계약최근36개월.xlsx'.format(5), index=False)

# %%
print(target_2_24_bdyr2_df1.shape)
target_2_24_bdyr2_df1.head()
# Out:
# (1170, 13)
#                     지번주소       건물(단지)명  건물연식  층 거래구분  전용면적(㎡)       계약날짜  \
# 1    서울특별시 금천구 독산동 47-28  메트로타운(47-28)   2.0  4   전세    29.90 2022-01-18
# 20  서울특별시 금천구 독산동 146-16      아카데미하우스Ⅱ   2.0  7   전세    29.30 2021-07-16
# 37  서울특별시 금천구 독산동 147-52         희경하우징   2.0  5   매매    28.83 2021-06-28
# 38  서울특별시 금천구 독산동 147-52         희경하우징   2.0  2   매매    27.52 2021-06-30
# 39  서울특별시 금천구 독산동 147-52         희경하우징   2.0  5   매매    22.88 2021-07-26
#
#     거래금액(만원)     단가(만원/㎡)  부동산유형 일괄계약     지수적용날짜       지수적용단가
# 1      27500   919.732441  연립다세대    N  2022년 03월   931.565296
# 20     27000   921.501706  연립다세대    N  2022년 03월   980.911718
# 37     36800  1276.448144  연립다세대    N  2022년 03월  1372.833586
# 38     33200  1206.395349  연립다세대    N  2022년 03월  1297.491058
# 39     33800  1477.272727  연립다세대    N  2022년 03월  1572.513777

# %%
def create_price_range_statistics_df(tradetype='매매', real_estate_type='연립다세대'):
    range_statistics_df = pd.DataFrame()
    range_statistics_df['전용면적구간'] = np.nan
    range_statistics_df['거래대상수'] = np.nan
    range_statistics_df['평균거래단가(만원/㎡)'] = np.nan
    
    for i, v in tqdm.tqdm_notebook(enumerate(range(17, 40))):
        range_min = v
        range_max = v + 1

        range_statistics_df.loc[i, '전용면적구간'] = '{}이상 {}미만'.format(range_min, range_max)

        range_df = target_2_24_bdyr2_df1[
            (target_2_24_bdyr2_df1['전용면적(㎡)'] >= range_min)
            &(target_2_24_bdyr2_df1['전용면적(㎡)'] < range_max)
            &(target_2_24_bdyr2_df1['거래구분'] == tradetype)
            &(target_2_24_bdyr2_df1['부동산유형'] == real_estate_type)
        ]

        range_statistics_df.loc[i, '거래대상수'] = range_df.shape[0]
        range_statistics_df.loc[i, '평균거래단가(만원/㎡)'] = range_df['단가(만원/㎡)'].mean()
        
    for i, v in tqdm.tqdm_notebook(enumerate(range(40, 65, 5))):
        range_min = v
        range_max = v + 5

        i = i+23

        range_statistics_df.loc[i, '전용면적구간'] = '{}이상 {}미만'.format(range_min, range_max)

        range_df = target_2_24_bdyr2_df1[
            (target_2_24_bdyr2_df1['전용면적(㎡)'] >= range_min)
            &(target_2_24_bdyr2_df1['전용면적(㎡)'] < range_max)
            &(target_2_24_bdyr2_df1['거래구분'] == tradetype)
            &(target_2_24_bdyr2_df1['부동산유형'] == real_estate_type)
        ]

        range_statistics_df.loc[i, '거래대상수'] = range_df.shape[0]
        range_statistics_df.loc[i, '평균거래단가(만원/㎡)'] = range_df['단가(만원/㎡)'].mean()
        
    range_statistics_df.loc[28, '전용면적구간'] = '{}이상 {}미만'.format(65, 100)

    range_df = target_2_24_bdyr2_df1[
        (target_2_24_bdyr2_df1['전용면적(㎡)'] >= 65)
        &(target_2_24_bdyr2_df1['전용면적(㎡)'] < 100)
        &(target_2_24_bdyr2_df1['거래구분'] == tradetype)
        &(target_2_24_bdyr2_df1['부동산유형'] == real_estate_type)
    ]

    range_statistics_df.loc[28, '거래대상수'] = range_df.shape[0]
    range_statistics_df.loc[28, '평균거래단가(만원/㎡)'] = range_df['단가(만원/㎡)'].mean()
    
    return range_statistics_df

# %%
range_statistics_df = create_price_range_statistics_df()
# Out:
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
# 0it [00:00, ?it/s]
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:23: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# 0it [00:00, ?it/s]

# %%
print(range_statistics_df.shape)
range_statistics_df.head()
# Out:
# (29, 3)
#       전용면적구간  거래대상수  평균거래단가(만원/㎡)
# 0  17이상 18미만    0.0           NaN
# 1  18이상 19미만    0.0           NaN
# 2  19이상 20미만    0.0           NaN
# 3  20이상 21미만    4.0    906.460945
# 4  21이상 22미만    9.0    846.309561

# %%
range_statistics_jeonse_df = create_price_range_statistics_df(tradetype='전세')
# Out:
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
# 0it [00:00, ?it/s]
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:23: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# 0it [00:00, ?it/s]

# %%
print(range_statistics_jeonse_df.shape)
range_statistics_jeonse_df.head()
# Out:
# (29, 3)
#       전용면적구간  거래대상수  평균거래단가(만원/㎡)
# 0  17이상 18미만    4.0   1345.738786
# 1  18이상 19미만    5.0   1221.313281
# 2  19이상 20미만    0.0           NaN
# 3  20이상 21미만    0.0           NaN
# 4  21이상 22미만    1.0   1130.104463

# %%
range_statistics_df.to_excel(target_dir + '전용면적구간별통계자료_연립다세대_매매_실거래가_건물연식{}년_계약최근12개월.xlsx'.format(3), index=False)

# %%
range_statistics_jeonse_df.to_excel(target_dir + '전용면적구간별통계자료_연립다세대_전세_실거래가_건물연식{}년_계약최근12개월.xlsx'.format(3), index=False)

# %%
range_statistics_df['거래유형'] = '매매'
range_statistics_jeonse_df['거래유형'] = '전세'

# %%
concat_df = pd.concat([range_statistics_df, range_statistics_jeonse_df]).sort_values(['전용면적구간', '거래유형']).reset_index(drop=True)
print(concat_df.shape)
concat_df.head()
# Out:
# (58, 4)
#       전용면적구간  거래대상수  평균거래단가(만원/㎡) 거래유형
# 0  17이상 18미만    0.0           NaN   매매
# 1  17이상 18미만    4.0   1345.738786   전세
# 2  18이상 19미만    0.0           NaN   매매
# 3  18이상 19미만    5.0   1221.313281   전세
# 4  19이상 20미만    0.0           NaN   매매

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
sns.factorplot(x='전용면적구간', y='평균거래단가(만원/㎡)', hue='거래유형', data=concat_df, kind='bar', size=15, aspect=4/3)
plt.xticks(rotation=40)
plt.title('연립다세대 전용면적구간별 평균거래단가 건물연식 3년이하 계약 최근 12개월')
plt.tight_layout()
plt.savefig(target_dir + '전용면적구간별_연립다세대_평균거래단가_건물연식3년_계약최근12개월.png')
# Out:
# c:\users\max6296\ml\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# c:\users\max6296\ml\lib\site-packages\seaborn\categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
officetel_range_statistics_df = create_price_range_statistics_df(real_estate_type='오피스텔')
officetel_jeonse_range_statistics_df = create_price_range_statistics_df(tradetype='전세', real_estate_type='오피스텔')
# Out:
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
# 0it [00:00, ?it/s]
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:23: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
officetel_range_statistics_df.to_excel(target_dir + '전용면적구간별통계자료_오피스텔_매매_실거래가_건물연식{}년_계약최근12개월.xlsx'.format(3), index=False)

# %%
officetel_jeonse_range_statistics_df.to_excel(target_dir + '전용면적구간별통계자료_오피스텔_전세_실거래가_건물연식{}년_계약최근12개월.xlsx'.format(3), index=False)

# %%
officetel_range_statistics_df['거래유형'] = '매매'
officetel_jeonse_range_statistics_df['거래유형'] = '전세'

# %%
concat_df = pd.concat([officetel_range_statistics_df, officetel_jeonse_range_statistics_df]).sort_values(['전용면적구간', '거래유형']).reset_index(drop=True)
print(concat_df.shape)
concat_df.head()
# Out:
# (58, 4)
#       전용면적구간  거래대상수  평균거래단가(만원/㎡) 거래유형
# 0  17이상 18미만    0.0           NaN   매매
# 1  17이상 18미만    0.0           NaN   전세
# 2  18이상 19미만    0.0           NaN   매매
# 3  18이상 19미만    0.0           NaN   전세
# 4  19이상 20미만    0.0           NaN   매매

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
sns.factorplot(x='전용면적구간', y='평균거래단가(만원/㎡)', hue='거래유형', data=concat_df, kind='bar', size=15, aspect=4/3)
plt.xticks(rotation=40)
plt.title('오피스텔 전용면적구간별 평균거래단가 건물연식 3년이하 계약 최근 12개월')
plt.tight_layout()
plt.savefig(target_dir + '전용면적구간별_오피스텔_평균거래단가_건물연식3년_계약최근12개월.png')
# Out:
# c:\users\max6296\ml\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# c:\users\max6296\ml\lib\site-packages\seaborn\categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
target_df = target_3_36_df.copy()

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('최근 {}개월 {} {} {} 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 {}건의 전용면적 단가'.format(target_period, target_gu, target_dong, target_ri, target_building_age, target_df.shape[0]))
plt.grid(True)
ax.xaxis.update_units(target_df['계약날짜'])
sns.regplot(x=ax.xaxis.convert_units(target_df['계약날짜']), y=target_df['단가(만원/㎡)'])
plt.savefig(target_dir + '산포도.png')

# %%
target_last_df = target_df.drop_duplicates(subset=['지번주소', '건축년도'], keep='last').reset_index(drop=True)

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('최근 {}개월 {} {} {} 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 {}건의 전용면적 단가'.format(target_period, target_gu, target_dong, target_ri, target_building_age, target_last_df.shape[0]))
plt.grid(True)
ax.xaxis.update_units(target_last_df['계약날짜'])
sns.regplot(x=ax.xaxis.convert_units(target_last_df['계약날짜']), y=target_last_df['단가(만원/㎡)'])
plt.savefig(target_dir + '마지막_산포도.png')

# %%
target_last_df.to_excel(target_dir + '마지막_실거래가.xlsx', index=False)

# %%
target_df2 = house_df[
    (house_df['지번주소'].str.contains(target_gu + ' ' + target_dong))
    &(house_df['지번주소'].str.contains(target_ri))
    #&(house_df['동'] == target_dong)
    #&(house_merge_df['계약날짜'] >= (date_today - pd.DateOffset(months=target_period)))
    &(house_df['계약날짜기준_건물연식'] <= target_building_age)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_df2.shape)
target_df2.head()
# Out:
# (8929, 27)
#                        지번주소           도로명            시군구    본번    부번 건물(단지)명  \
# 509181  서울특별시 금천구 독산동 47-28  독산로108길 86-7  서울특별시 금천구 독산동  47.0  28.0   메트로타운
# 509182  서울특별시 금천구 독산동 47-28  독산로108길 86-7  서울특별시 금천구 독산동  47.0  28.0   메트로타운
# 509183  서울특별시 금천구 독산동 47-28  독산로108길 86-1  서울특별시 금천구 독산동  47.0  28.0   메트로타운
# 509184  서울특별시 금천구 독산동 47-28  독산로108길 86-7  서울특별시 금천구 독산동  47.0  28.0   메트로타운
# 509185  서울특별시 금천구 독산동 47-28  독산로108길 86-7  서울특별시 금천구 독산동  47.0  28.0   메트로타운
#
#         전용면적(㎡)  거래금액(만원)  층    건축년도 거래유형 중개사소재지 거래구분  계약날짜기준_건물연식       계약날짜  \
# 509181    27.89     25500  5  2020.0    -      -   매매          0.0 2020-12-14
# 509182    29.30     27900  5  2020.0    -      -   매매          0.0 2020-11-30
# 509183    29.90     27500  4  2020.0    -      -   매매          0.0 2020-07-13
# 509184    29.90     27900  4  2020.0    -      -   매매          0.0 2020-08-21
# 509185    29.90     27800  3  2020.0    -      -   매매          0.0 2020-09-15
#
#           단가(만원/㎡)  건물연식 계약기간 계약구분 갱신요구권 사용 종전계약 보증금 (만원) 종전계약 월세 (만원)  부동산유형  \
# 509181  914.306203   2.0  NaN  NaN      NaN           NaN          NaN  연립다세대
# 509182  952.218430   2.0  NaN  NaN      NaN           NaN          NaN  연립다세대
# 509183  919.732441   2.0  NaN  NaN      NaN           NaN          NaN  연립다세대
# 509184  933.110368   2.0  NaN  NaN      NaN           NaN          NaN  연립다세대
# 509185  929.765886   2.0  NaN  NaN      NaN           NaN          NaN  연립다세대
#
#           구    동      리 일괄계약
# 509181  금천구  독산동  47-28    N
# 509182  금천구  독산동  47-28    N
# 509183  금천구  독산동  47-28    N
# 509184  금천구  독산동  47-28    N
# 509185  금천구  독산동  47-28    N

# %%
target_df2 = get_index_applied_prices(target_df2)

# %%
font = {'size': 12}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(12,6))
plt.title('{} {} {} 계약날짜기준 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 {}건의 전용면적 단가'.format(target_gu, target_dong, target_ri, target_building_age, target_df2.shape[0]))
plt.grid(True)
sns.histplot(target_df2['단가(만원/㎡)'], kde=True)
# Out:
# <AxesSubplot:title={'center':'금천구 독산  계약날짜기준 건물연식 5년이하 연립다세대 및 오피스텔 매매 실거래 8929건의 전용면적 단가'}, xlabel='단가(만원/㎡)', ylabel='Count'>

# %%
target_df3 = target_df2[['지번주소', '건물(단지)명', '건축년도', '층', '전용면적(㎡)', '계약날짜', '단가(만원/㎡)', '부동산유형']]
target_df3 = target_df3.sort_values(['지번주소', '건축년도', '계약날짜']).reset_index(drop=True)
target_df3.to_excel(target_dir + '전체_실거래가.xlsx', index=False)

# %%
target_df3_30 = target_df3[
    (target_df3['전용면적(㎡)'] >= 28)
    &(target_df3['전용면적(㎡)'] <= 32)
]

# %%
target_df3_30.to_excel(target_dir + '전체_실거래가_30.xlsx', index=False)

# %%
concat_df = pd.concat([target_df2])

# %%
concat_df = concat_df.sort_values(['지번주소', '건축년도', '전용면적(㎡)', '계약날짜']).reset_index(drop=True)
concat_df = concat_df.drop_duplicates(['지번주소', '건축년도', '전용면적(㎡)'], keep='last').reset_index(drop=True)

# %%
concat_df['단가평균'] = concat_df[['지번주소', '건축년도', '단가(만원/㎡)']].groupby(['지번주소', '건축년도']).transform('mean')['단가(만원/㎡)']
concat_df['지수적용단가평균'] = concat_df[['지번주소', '건축년도', '지수적용단가']].groupby(['지번주소', '건축년도']).transform('mean')['지수적용단가']

# %%
concat_df = concat_df.sort_values(['지번주소', '건축년도', '지수적용날짜']).reset_index(drop=True)
print(concat_df.shape)
concat_df.head()
# Out:
# (1491, 32)
#                     지번주소        도로명            시군구      본번    부번 건물(단지)명  \
# 0   서울특별시 금천구 독산동 1000-5  벚꽃로 154-1  서울특별시 금천구 독산동  1000.0   5.0  아크로타워Ⅱ
# 1   서울특별시 금천구 독산동 1000-5  벚꽃로 154-1  서울특별시 금천구 독산동  1000.0   5.0  아크로타워Ⅱ
# 2   서울특별시 금천구 독산동 1000-5  벚꽃로 154-1  서울특별시 금천구 독산동  1000.0   5.0  아크로타워Ⅱ
# 3   서울특별시 금천구 독산동 1000-5  벚꽃로 154-1  서울특별시 금천구 독산동  1000.0   5.0  아크로타워Ⅱ
# 4  서울특별시 금천구 독산동 1003-19             서울특별시 금천구 독산동  1003.0  19.0   블라썸시티
#
#    전용면적(㎡)  거래금액(만원)   층    건축년도 거래유형 중개사소재지 거래구분  계약날짜기준_건물연식       계약날짜  \
# 0    22.10     23000   8  2022.0  NaN    NaN   전세          0.0 2022-05-10
# 1    22.22     22400   4  2022.0  NaN    NaN   전세          0.0 2022-06-01
# 2    24.35     22800   8  2022.0  NaN    NaN   전세          0.0 2022-04-26
# 3    24.95     23400  13  2022.0  NaN    NaN   전세          0.0 2022-04-12
# 4    22.16     15000   3  2017.0  NaN    NaN   전세          3.0 2020-11-18
#
#       단가(만원/㎡)  건물연식           계약기간 계약구분 갱신요구권 사용 종전계약 보증금 (만원) 종전계약 월세 (만원)  \
# 0  1040.723982   0.0              -    -        -           NaN          NaN
# 1  1008.100810   0.0              -    -        -           NaN          NaN
# 2   936.344969   0.0  202205~202405   신규        -             0          0.0
# 3   937.875752   0.0  202205~202405   신규        -             0          0.0
# 4   676.895307   5.0              -    -        -           NaN          NaN
#
#   부동산유형    구    동        리 일괄계약 계약날짜_실거래지수       지수적용단가     지수적용날짜  \
# 0  오피스텔  금천구  독산동   1000-5    N       지수없음  1040.723982       지수없음
# 1  오피스텔  금천구  독산동   1000-5    N       지수없음  1008.100810       지수없음
# 2  오피스텔  금천구  독산동   1000-5    N       지수없음   936.344969       지수없음
# 3  오피스텔  금천구  독산동   1000-5    N       지수없음   937.875752       지수없음
# 4  오피스텔  금천구  독산동  1003-19    N    120.423   784.593289  2022년 03월
#
#          단가평균    지수적용단가평균
# 0  980.761378  980.761378
# 1  980.761378  980.761378
# 2  980.761378  980.761378
# 3  980.761378  980.761378
# 4  656.244264  760.656544

# %%
concat_last_df = concat_df.drop_duplicates(subset=['지번주소', '건축년도'], keep='last')
print(concat_last_df.shape)
concat_last_df.head()
# Out:
# (436, 32)
#                      지번주소        도로명            시군구      본번    부번  건물(단지)명  \
# 3    서울특별시 금천구 독산동 1000-5  벚꽃로 154-1  서울특별시 금천구 독산동  1000.0   5.0   아크로타워Ⅱ
# 5   서울특별시 금천구 독산동 1003-19             서울특별시 금천구 독산동  1003.0  19.0    블라썸시티
# 6   서울특별시 금천구 독산동 1004-13    벚꽃로 110  서울특별시 금천구 독산동  1004.0  13.0   명남더블레스
# 9    서울특별시 금천구 독산동 1005-1  범안로12길 44  서울특별시 금천구 독산동  1005.0   1.0  독산 보세쥬르
# 11   서울특별시 금천구 독산동 1005-3  범안로12길 50  서울특별시 금천구 독산동  1005.0   3.0       1동
#
#     전용면적(㎡)  거래금액(만원)   층    건축년도  거래유형  중개사소재지 거래구분  계약날짜기준_건물연식       계약날짜  \
# 3     24.95     23400  13  2022.0   NaN     NaN   전세          0.0 2022-04-12
# 5     23.60     15000   2  2017.0   NaN     NaN   전세          3.0 2020-11-14
# 6     16.22     15000   6  2018.0  중개거래  서울 금천구   매매          4.0 2022-05-25
# 9     29.59     25760   2  2021.0   직거래       -   매매          0.0 2021-11-04
# 11    29.93     24700   6  2021.0     -       -   매매          0.0 2021-02-05
#
#       단가(만원/㎡)  건물연식           계약기간 계약구분 갱신요구권 사용 종전계약 보증금 (만원) 종전계약 월세 (만원)  \
# 3   937.875752   0.0  202205~202405   신규        -             0          0.0
# 5   635.593220   5.0              -    -        -           NaN          NaN
# 6   924.784217   4.0            NaN  NaN      NaN           NaN          NaN
# 9   870.564380   1.0            NaN  NaN      NaN           NaN          NaN
# 11  825.258938   1.0            NaN  NaN      NaN           NaN          NaN
#
#    부동산유형    구    동        리 일괄계약 계약날짜_실거래지수      지수적용단가     지수적용날짜  \
# 3   오피스텔  금천구  독산동   1000-5    N       지수없음  937.875752       지수없음
# 5   오피스텔  금천구  독산동  1003-19    N    120.423  736.719800  2022년 03월
# 6   오피스텔  금천구  독산동  1004-13    N       지수없음  924.784217       지수없음
# 9   오피스텔  금천구  독산동   1005-1    N    136.657  889.204269  2022년 03월
# 11  오피스텔  금천구  독산동   1005-3    N    122.737  938.528058  2022년 03월
#
#           단가평균    지수적용단가평균
# 3   980.761378  980.761378
# 5   656.244264  760.656544
# 6   924.784217  924.784217
# 9   871.885038  897.427446
# 11  825.396848  938.684898

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('{} {} {} 계약날짜기준 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 지번별 {}곳의 전용면적 실거래가격지수 적용후 단가평균'.format(target_gu, target_dong, target_ri, target_building_age, concat_last_df.shape[0]))
plt.grid(True)
sns.histplot(concat_last_df['지수적용단가'], kde=True)
plt.savefig(target_dir + '지번별_분포도.png')

# %%
concat_last_df = concat_last_df.sort_values(['지번주소']).reset_index(drop=True)

# %%
concat_last_df = concat_last_df[['지번주소', '건물(단지)명', '건축년도', '전용면적(㎡)', '층', '계약날짜', '단가(만원/㎡)', '지수적용날짜', '지수적용단가', '부동산유형']]
concat_last_df.rename(columns={'계약날짜':'마지막_계약날짜'}, inplace=True)
concat_last_df.head()
# Out:
#                     지번주소  건물(단지)명    건축년도  전용면적(㎡)   층   마지막_계약날짜    단가(만원/㎡)  \
# 0   서울특별시 금천구 독산동 1000-5   아크로타워Ⅱ  2022.0    24.95  13 2022-04-12  937.875752
# 1  서울특별시 금천구 독산동 1003-19    블라썸시티  2017.0    23.60   2 2020-11-14  635.593220
# 2  서울특별시 금천구 독산동 1004-13   명남더블레스  2018.0    16.22   6 2022-05-25  924.784217
# 3   서울특별시 금천구 독산동 1005-1  독산 보세쥬르  2021.0    29.59   2 2021-11-04  870.564380
# 4   서울특별시 금천구 독산동 1005-3       1동  2021.0    29.93   6 2021-02-05  825.258938
#
#       지수적용날짜      지수적용단가 부동산유형
# 0       지수없음  937.875752  오피스텔
# 1  2022년 03월  736.719800  오피스텔
# 2       지수없음  924.784217  오피스텔
# 3  2022년 03월  889.204269  오피스텔
# 4  2022년 03월  938.528058  오피스텔

# %%
concat_last_df.to_excel(target_dir + '전체_마지막_실거래가.xlsx', index=False)
