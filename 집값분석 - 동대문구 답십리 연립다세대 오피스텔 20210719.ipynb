# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
pd.options.mode.chained_assignment = None  # default='warn'
plt.rcParams['font.family'] = 'Malgun Gothic'
import datetime

# %%
target_gu = '동대문구'
target_dong = '답십리'
#target_purpose = '준주거'
target_building_age = 3
target_period = 36 # in months

# %%
date_today = pd.to_datetime(datetime.datetime.now().strftime('%Y-%m-%d'), format='%Y-%m-%d')

# %%
date_today_record = str(date_today).split(' ')[0].replace('-', '')
date_today_record
# Out:
# '20210719'

# %%
def day_modifier(x):
    # x is a number
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x)
        if len(x) == 1:
            return '0' + x
        else:
            return x

# %%
def landnum_modifier(x):
    # x is a string
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x).replace('외', '').replace(' ','')
        splitted = x.split('-')
        if len(splitted) == 1:
            return x + '-0'
        else:
            return x

# %%
def data_prep(bdtype, tradetype):
    # bdtype is a string: one of 아파트, 연립다세대 or 오피스텔
    # tradetype is a string: one of 매매 or 전월세
    
    basedir = './국토교통부_실거래가_공개시스템/{}/{}/'.format(bdtype, tradetype)
    filenames = [f for f in os.listdir(basedir) if (f.endswith('.csv'))&('(' in f)]
    
    dfs_list = []
    for i, f in tqdm(enumerate(filenames)):
        df = pd.read_csv(basedir + f, encoding='euc-kr', header=15)
        if '해제사유발생일' in df.columns.tolist():
            df = df[df['해제사유발생일'].isna()]
            df = df.drop(columns=['해제사유발생일'])

        dfs_list.append(df)
    
    concat_df = pd.concat(dfs_list).reset_index(drop=True)
        
    concat_df['번지'] = concat_df['번지'].apply(landnum_modifier)
    
    concat_df['계약년월'] = concat_df['계약년월'].apply(str)
    concat_df['계약일'] = concat_df['계약일'].apply(str)
    
    concat_df['계약날짜기준_건물연식'] = concat_df['계약년월'].apply(lambda x: int(x[:4])) - concat_df['건축년도']
    
    concat_df['계약일'] = concat_df['계약일'].apply(day_modifier)
    
    concat_df['계약날짜'] = concat_df['계약년월'].apply(lambda x: x[:4]) + '-' + concat_df['계약년월'].apply(lambda x: x[-2:])\
    + '-' + concat_df['계약일']
    
    concat_df['계약날짜'] = pd.to_datetime(concat_df['계약날짜'], format='%Y-%m-%d')
    
    concat_df['거래금액(만원)'] = concat_df['거래금액(만원)'].apply(lambda x: int(x.replace(',','')))
    concat_df['단가(만원/㎡)'] = concat_df['거래금액(만원)'] / concat_df['전용면적(㎡)']
    
    concat_df['지번주소'] = concat_df['시군구'] + ' ' + concat_df['번지']
        
    cols_to_drop = ['시군구', '번지', '본번', '부번', '지번주소', '계약년월', '계약일', '도로명']
        
    concat_df = concat_df[['지번주소', '도로명'] + [col for col in concat_df.columns if col not in cols_to_drop]]
    
    date_today = pd.to_datetime(datetime.datetime.now().strftime('%Y-%m-%d'), format='%Y-%m-%d')
    concat_df['건물연식'] = date_today.year - concat_df['건축년도']
    
    concat_df = concat_df.dropna(subset=['지번주소'])
    
    if '건물명' in concat_df.columns:
        concat_df.rename(columns={'건물명':'건물(단지)명'}, inplace=True)
    elif '단지명' in concat_df.columns:
        concat_df.rename(columns={'단지명':'건물(단지)명'}, inplace=True)
    
    concat_df = concat_df[concat_df['층'] >= 0].reset_index(drop=True)
    
    return concat_df

# %%
yunrip_df = data_prep('연립다세대', '매매')
yunrip_df['부동산유형'] = '연립다세대'
print(yunrip_df.shape)
yunrip_df.head()
# Out:
# 16it [00:01,  8.83it/s]
# (643890, 13)
#                    지번주소         도로명   건물(단지)명  전용면적(㎡)  대지권면적(㎡)  거래금액(만원)  층  \
# 0  서울특별시 강남구 개포동 171-13   선릉로14길 11  (171-13)    68.08     56.10     56500  2
# 1  서울특별시 강남구 개포동 1239-7   개포로15길 25   강남빌라 가동    52.59     45.00     40500  2
# 2  서울특별시 강남구 개포동 1239-7   개포로15길 25   강남빌라 가동    52.59     45.00     42000  1
# 3  서울특별시 강남구 개포동 1239-6   개포로15길 27   강남빌라 나동    52.75     44.68     22000  2
# 4  서울특별시 강남구 개포동 1175-2  논현로6길 36-8      강남파크    49.43     23.70     17000  4
#
#      건축년도  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형
# 0  1988.0         18.0 2006-12-20  829.905993  33.0  연립다세대
# 1  1988.0         18.0 2006-12-09  770.108386  33.0  연립다세대
# 2  1988.0         18.0 2006-12-19  798.630918  33.0  연립다세대
# 3  1988.0         18.0 2006-11-02  417.061611  33.0  연립다세대
# 4  1993.0         13.0 2006-07-19  343.920696  28.0  연립다세대

# %%
officetel_df = data_prep('오피스텔', '매매')
officetel_df['부동산유형'] = '오피스텔'
print(officetel_df.shape)
officetel_df.head()
# Out:
# 16it [00:00, 31.19it/s]
# (182808, 12)
#                  지번주소      도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)   층    건축년도  \
# 0  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44      6400   8  1997.0
# 1  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44      7100   7  1997.0
# 2  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44      7300  11  1997.0
# 3  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    31.91      7500  10  1997.0
# 4  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44      7400  15  1997.0
#
#    계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식 부동산유형
# 0          9.0 2006-01-10  197.287300  24.0  오피스텔
# 1          9.0 2006-01-10  218.865598  24.0  오피스텔
# 2          9.0 2006-01-11  225.030826  24.0  오피스텔
# 3          9.0 2006-01-18  235.036039  24.0  오피스텔
# 4          9.0 2006-01-19  228.113440  24.0  오피스텔

# %%
yunrip_df = yunrip_df.drop(columns=['대지권면적(㎡)'])
house_df = pd.concat([yunrip_df, officetel_df]).sort_values(['지번주소', '건축년도', '전용면적(㎡)', '계약날짜']).reset_index(drop=True)
print(house_df.shape)
house_df.head()
# Out:
# (826698, 12)
#                     지번주소       도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 0   서울특별시 강남구 개포동 1164-0   논현로2길 6    골드캐슬    58.05     57500  2  2017.0
# 1   서울특별시 강남구 개포동 1164-0   논현로2길 6    골드캐슬    58.05     57000  1  2017.0
# 2   서울특별시 강남구 개포동 1164-0   논현로2길 6    골드캐슬    58.05     63000  2  2017.0
# 3  서울특별시 강남구 개포동 1164-26  논현로2길 64   슈베르트빌    34.47     31000  4  2015.0
# 4  서울특별시 강남구 개포동 1164-26  논현로2길 64   슈베르트빌    34.47     30000  3  2015.0
#
#    계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형
# 0          1.0 2018-01-20   990.525409   4.0  연립다세대
# 1          1.0 2018-06-01   981.912145   4.0  연립다세대
# 2          2.0 2019-01-19  1085.271318   4.0  연립다세대
# 3          1.0 2016-03-01   899.332753   6.0  연립다세대
# 4          1.0 2016-03-20   870.322019   6.0  연립다세대

# %%
'''land_specs_df = pd.read_csv('./prepped_data/land_specs_ver_4.csv')
print(land_specs_df.shape)
land_specs_df.head()'''
# Out:
# "land_specs_df = pd.read_csv('./prepped_data/land_specs_ver_4.csv')\nprint(land_specs_df.shape)\nland_specs_df.head()"

# %%
'''last_df = land_specs_df.drop_duplicates(subset=['지번주소'], keep='last').drop(columns=['년', '공시지가']).reset_index(drop=True)
print(last_df.shape)
last_df.head()'''
# Out:
# "last_df = land_specs_df.drop_duplicates(subset=['지번주소'], keep='last').drop(columns=['년', '공시지가']).reset_index(drop=True)\nprint(last_df.shape)\nlast_df.head()"

# %%
'''house_merge_df = house_df.merge(last_df, on=['지번주소']).reset_index(drop=True)
print(house_merge_df.shape)'''
# Out:
# "house_merge_df = house_df.merge(last_df, on=['지번주소']).reset_index(drop=True)\nprint(house_merge_df.shape)"

# %%
house_df['구'] = house_df['지번주소'].apply(lambda x: x.split(' ')[1])
house_df['동'] = house_df['지번주소'].apply(lambda x: x.split(' ')[2])
#house_merge_df['구'] = house_merge_df['지번주소'].apply(lambda x: x.split(' ')[1])
#house_merge_df['동'] = house_merge_df['지번주소'].apply(lambda x: x.split(' ')[2])

# %%
target_df = house_df[
    (house_df['지번주소'].str.contains(target_gu + ' ' + target_dong))
    #&(house_df['동'] == target_dong)
    &(house_df['계약날짜'] >= (date_today - pd.DateOffset(months=target_period)))
    &(house_df['건물연식'] <= target_building_age)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_df.shape)
target_df.head()
# Out:
# (155, 14)
#                         지번주소         도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층  \
# 360455  서울특별시 동대문구 답십리동 27-7  한천로11다길 84   미소홈타운    46.77     35900  5
# 360456  서울특별시 동대문구 답십리동 27-7  한천로11다길 84   미소홈타운    50.21     37350  5
# 360457  서울특별시 동대문구 답십리동 27-7  한천로11다길 84   미소홈타운    53.77     38850  3
# 360458  서울특별시 동대문구 답십리동 27-7  한천로11다길 84   미소홈타운    53.77     38650  2
# 360459  서울특별시 동대문구 답십리동 27-7  한천로11다길 84   미소홈타운    54.70     41400  3
#
#           건축년도  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형     구     동
# 360455  2020.0          1.0 2021-01-13  767.586059   1.0  연립다세대  동대문구  답십리동
# 360456  2020.0          1.0 2021-01-13  743.875722   1.0  연립다세대  동대문구  답십리동
# 360457  2020.0          1.0 2021-01-13  722.521852   1.0  연립다세대  동대문구  답십리동
# 360458  2020.0          1.0 2021-01-13  718.802306   1.0  연립다세대  동대문구  답십리동
# 360459  2020.0          1.0 2021-01-13  756.855576   1.0  연립다세대  동대문구  답십리동

# %%
sales_idx_basedir = './한국부동산원/실거래가격지수/'
filenames = [f for f in os.listdir(sales_idx_basedir) if '연립다세대' in f]

sales_idx_df = pd.read_excel(sales_idx_basedir + filenames[0], header=[10, 11])

sales_idx_cols_list = []
for i in range(sales_idx_df.shape[1]):
    if i == 0:
        sales_idx_cols_list.append(sales_idx_df.columns[i][0])
    else:
        sales_idx_cols_list.append(sales_idx_df.columns[i][0] + '_' + sales_idx_df.columns[i][1])

sales_idx_df.columns = sales_idx_cols_list

# %%
def get_sales_idx(x):
    # x is a pandas timestamp
    
    df = sales_idx_df.copy()
    
    if pd.isna(x) == True:
        return x
    else:
        year = str(x.year)
        month = str(x.month)
        if len(month) == 1:
            month = '0'+month
        
        idx = df[year+'년 '+month+'월_지수'].iloc[0]
        
        return idx

# %%
def get_index_applied_prices(df):
    df = df.copy()
    
    last_idx = sales_idx_df.iloc[0,-2]
    
    last_date = sales_idx_df.columns[-1].split('_')[0]
    
    last_date = last_date.split(' ')[0].replace('년','') + '-' + last_date.split(' ')[1].replace('월','') + '-01'
    
    target_upper_limit_df = df[df['계약날짜'] < pd.to_datetime(last_date)]
    target_upper_limit_df['계약날짜_실거래지수'] = target_upper_limit_df['계약날짜'].apply(get_sales_idx)
    target_upper_limit_df['지수적용단가'] = target_upper_limit_df['단가(만원/㎡)'] / target_upper_limit_df['계약날짜_실거래지수'] * last_idx
    df['지수적용단가'] = df['단가(만원/㎡)']
    df.loc[target_upper_limit_df.index, '지수적용단가'] = target_upper_limit_df['지수적용단가']
    df['평가날짜'] = df['계약날짜']
    df.loc[target_upper_limit_df.index, '평가날짜'] = pd.to_datetime(last_date[:-2] + '01')
    
    return df

# %%
target_df = get_index_applied_prices(target_df)
print(target_df.shape)
target_df.head()
# Out:
# (155, 16)
#                         지번주소         도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층  \
# 360455  서울특별시 동대문구 답십리동 27-7  한천로11다길 84   미소홈타운    46.77     35900  5
# 360456  서울특별시 동대문구 답십리동 27-7  한천로11다길 84   미소홈타운    50.21     37350  5
# 360457  서울특별시 동대문구 답십리동 27-7  한천로11다길 84   미소홈타운    53.77     38850  3
# 360458  서울특별시 동대문구 답십리동 27-7  한천로11다길 84   미소홈타운    53.77     38650  2
# 360459  서울특별시 동대문구 답십리동 27-7  한천로11다길 84   미소홈타운    54.70     41400  3
#
#           건축년도  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형     구     동  \
# 360455  2020.0          1.0 2021-01-13  767.586059   1.0  연립다세대  동대문구  답십리동
# 360456  2020.0          1.0 2021-01-13  743.875722   1.0  연립다세대  동대문구  답십리동
# 360457  2020.0          1.0 2021-01-13  722.521852   1.0  연립다세대  동대문구  답십리동
# 360458  2020.0          1.0 2021-01-13  718.802306   1.0  연립다세대  동대문구  답십리동
# 360459  2020.0          1.0 2021-01-13  756.855576   1.0  연립다세대  동대문구  답십리동
#
#             지수적용단가       평가날짜
# 360455  800.034154 2021-05-01
# 360456  775.321512 2021-05-01
# 360457  753.064952 2021-05-01
# 360458  749.188170 2021-05-01
# 360459  788.850062 2021-05-01

# %%
target_df = target_df.sort_values(['지번주소', '건축년도', '계약날짜']).reset_index(drop=True)
target_df1 = target_df[['지번주소', '건물(단지)명', '건물연식', '층', '전용면적(㎡)', '계약날짜', '거래금액(만원)', '단가(만원/㎡)', '평가날짜', '지수적용단가', '부동산유형']]
target_df1.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/실거래가.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
target_df1.head()
# Out:
#                    지번주소 건물(단지)명  건물연식  층  전용면적(㎡)       계약날짜  거래금액(만원)  \
# 0  서울특별시 동대문구 답십리동 27-7   미소홈타운   1.0  5    46.77 2021-01-13     35900
# 1  서울특별시 동대문구 답십리동 27-7   미소홈타운   1.0  5    50.21 2021-01-13     37350
# 2  서울특별시 동대문구 답십리동 27-7   미소홈타운   1.0  3    53.77 2021-01-13     38850
# 3  서울특별시 동대문구 답십리동 27-7   미소홈타운   1.0  2    53.77 2021-01-13     38650
# 4  서울특별시 동대문구 답십리동 27-7   미소홈타운   1.0  3    54.70 2021-01-13     41400
#
#      단가(만원/㎡)       평가날짜      지수적용단가  부동산유형
# 0  767.586059 2021-05-01  800.034154  연립다세대
# 1  743.875722 2021-05-01  775.321512  연립다세대
# 2  722.521852 2021-05-01  753.064952  연립다세대
# 3  718.802306 2021-05-01  749.188170  연립다세대
# 4  756.855576 2021-05-01  788.850062  연립다세대

# %%
target_df1_30 = target_df1[
    (target_df1['전용면적(㎡)'] >= 28)
    &(target_df1['전용면적(㎡)'] <= 32)
]

# %%
target_df1_30.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/실거래가_30.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('최근 {}개월 {} {} 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 {}건의 전용면적 단가'.format(target_period, target_gu, target_dong, target_building_age, target_df.shape[0]))
plt.grid(True)
ax.xaxis.update_units(target_df['계약날짜'])
sns.regplot(x=ax.xaxis.convert_units(target_df['계약날짜']), y=target_df['단가(만원/㎡)'])
plt.savefig('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/산포도.png'.format(target_gu, target_dong, date_today_record))

# %%
target_last_df = target_df.drop_duplicates(subset=['지번주소', '건축년도'], keep='last').reset_index(drop=True)

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('최근 {}개월 {} {} 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 {}건의 전용면적 단가'.format(target_period, target_gu, target_dong, target_building_age, target_last_df.shape[0]))
plt.grid(True)
ax.xaxis.update_units(target_last_df['계약날짜'])
sns.regplot(x=ax.xaxis.convert_units(target_last_df['계약날짜']), y=target_last_df['단가(만원/㎡)'])
plt.savefig('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/마지막_산포도.png'.format(target_gu, target_dong, date_today_record))

# %%
target_last_df.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/마지막_실거래가.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
target_df2 = house_df[
    (house_df['지번주소'].str.contains(target_gu + ' ' + target_dong))
    #&(house_df['동'] == target_dong)
    #&(house_merge_df['계약날짜'] >= (date_today - pd.DateOffset(months=target_period)))
    &(house_df['계약날짜기준_건물연식'] <= target_building_age)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_df2.shape)
target_df2.head()
# Out:
# (725, 14)
#                           지번주소         도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층  \
# 360166   서울특별시 동대문구 답십리동 1-119  답십리로59길 57    우성타운    63.04      8000  5
# 360177  서울특별시 동대문구 답십리동 1006-0  답십리로40길 18    누리마루    29.16     22600  5
# 360178  서울특별시 동대문구 답십리동 1006-0  답십리로40길 18    누리마루    29.16     22600  3
# 360179  서울특별시 동대문구 답십리동 1006-0  답십리로40길 18    누리마루    29.16     22600  3
# 360180  서울특별시 동대문구 답십리동 1006-0  답십리로40길 18    누리마루    29.16     22600  2
#
#           건축년도  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형     구     동
# 360166  2003.0          3.0 2006-03-17  126.903553  18.0  연립다세대  동대문구  답십리동
# 360177  2017.0          0.0 2017-07-24  775.034294   4.0  연립다세대  동대문구  답십리동
# 360178  2017.0          0.0 2017-07-24  775.034294   4.0  연립다세대  동대문구  답십리동
# 360179  2017.0          0.0 2017-09-01  775.034294   4.0  연립다세대  동대문구  답십리동
# 360180  2017.0          0.0 2017-09-10  775.034294   4.0  연립다세대  동대문구  답십리동

# %%
target_df2 = get_index_applied_prices(target_df2)

# %%
font = {'size': 12}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(12,6))
plt.title('{} {} 계약날짜기준 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 {}건의 전용면적 단가'.format(target_gu, target_dong, target_building_age, target_df2.shape[0]))
plt.grid(True)
sns.histplot(target_df2['단가(만원/㎡)'], kde=True)
# Out:
# <AxesSubplot:title={'center':'동대문구 답십리 계약날짜기준 건물연식 3년이하 연립다세대 및 오피스텔 매매 실거래 725건의 전용면적 단가'}, xlabel='단가(만원/㎡)', ylabel='Count'>

# %%
target_df3 = target_df2[['지번주소', '건물(단지)명', '건축년도', '층', '전용면적(㎡)', '계약날짜', '단가(만원/㎡)', '평가날짜', '지수적용단가', '부동산유형']]
target_df3 = target_df3.sort_values(['지번주소', '건축년도', '계약날짜']).reset_index(drop=True)
target_df3.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/지수적용_실거래가.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
target_df3_30 = target_df3[
    (target_df3['전용면적(㎡)'] >= 28)
    &(target_df3['전용면적(㎡)'] <= 32)
]

# %%
target_df3_30.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/지수적용_실거래가_30.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
concat_df = pd.concat([target_df2])

# %%
concat_df = concat_df.sort_values(['지번주소', '건축년도', '전용면적(㎡)', '계약날짜']).reset_index(drop=True)
concat_df = concat_df.drop_duplicates(['지번주소', '건축년도', '전용면적(㎡)'], keep='last').reset_index(drop=True)

# %%
concat_df['단가평균'] = concat_df[['지번주소', '건축년도', '단가(만원/㎡)']].groupby(['지번주소', '건축년도']).transform('mean')['단가(만원/㎡)']
concat_df['지수적용단가평균'] = concat_df[['지번주소', '건축년도', '지수적용단가']].groupby(['지번주소', '건축년도']).transform('mean')['지수적용단가']

# %%
concat_df = concat_df.sort_values(['지번주소', '건축년도', '평가날짜']).reset_index(drop=True)
print(concat_df.shape)
concat_df.head()
# Out:
# (177, 18)
#                      지번주소         도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 0   서울특별시 동대문구 답십리동 1-119  답십리로59길 57    우성타운    63.04      8000  5  2003.0
# 1  서울특별시 동대문구 답십리동 1006-0  답십리로40길 18    누리마루    29.16     24000  6  2017.0
# 2  서울특별시 동대문구 답십리동 1006-0  답십리로40길 18    누리마루    29.31     22600  4  2017.0
# 3  서울특별시 동대문구 답십리동 1006-0  답십리로40길 18    누리마루    29.45     26000  4  2017.0
# 4  서울특별시 동대문구 답십리동 1006-0  답십리로40길 18    누리마루    29.77     25000  2  2017.0
#
#    계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형     구     동       지수적용단가  \
# 0          3.0 2006-03-17  126.903553  18.0  연립다세대  동대문구  답십리동   316.320204
# 1          0.0 2017-10-20  823.045267   4.0  연립다세대  동대문구  답십리동  1059.510902
# 2          0.0 2017-08-20  771.067895   4.0  연립다세대  동대문구  답십리동  1002.049649
# 3          0.0 2017-09-30  882.852292   4.0  연립다세대  동대문구  답십리동  1144.512577
# 4          2.0 2019-12-17  839.771582   4.0  연립다세대  동대문구  답십리동   979.691654
#
#         평가날짜        단가평균    지수적용단가평균
# 0 2021-05-01  126.903553  316.320204
# 1 2021-05-01  807.409405  962.698542
# 2 2021-05-01  807.409405  962.698542
# 3 2021-05-01  807.409405  962.698542
# 4 2021-05-01  807.409405  962.698542

# %%
concat_last_df = concat_df.drop_duplicates(subset=['지번주소', '건축년도'], keep='last')
print(concat_last_df.shape)
concat_last_df
# Out:
# (45, 18)
#                         지번주소             도로명            건물(단지)명  전용면적(㎡)  \
# 0      서울특별시 동대문구 답십리동 1-119      답십리로59길 57               우성타운    63.04
# 11    서울특별시 동대문구 답십리동 1006-0      답십리로40길 18               누리마루    58.42
# 12     서울특별시 동대문구 답십리동 104-6      답십리로43길 26               금성빌라    52.54
# 14     서울특별시 동대문구 답십리동 2-174    답십리로59길 39-9              우성하이츠    81.75
# 17     서울특별시 동대문구 답십리동 2-253      답십리로60길 81          명품가A,B,C동    58.80
# 18     서울특별시 동대문구 답십리동 2-290    답십리로59길 39-7               우성빌라    52.59
# 22     서울특별시 동대문구 답십리동 25-10      한천로11다길 61           퍼시픽타운50차    89.69
# 23      서울특별시 동대문구 답십리동 25-5      한천로11다길 61          퍼시픽타운49th    54.31
# 32      서울특별시 동대문구 답십리동 27-5      한천로11다길 80               금영파크    31.51
# 39      서울특별시 동대문구 답십리동 27-7      한천로11다길 84              미소홈타운    59.08
# 45      서울특별시 동대문구 답십리동 3-79     답십리로 214-17              삼성아트빌    60.89
# 46    서울특별시 동대문구 답십리동 39-602      천호대로37길 56      천우네오젠(39-602)    44.37
# 57      서울특별시 동대문구 답십리동 4-41       한천로17길 24              엘림하우스    59.80
# 58    서울특별시 동대문구 답십리동 467-20      답십리로40길 25               세종캐슬    49.00
# 60    서울특별시 동대문구 답십리동 467-22      답십리로40길 31           MI HOUSE    53.37
# 62     서울특별시 동대문구 답십리동 467-4      답십리로40길 59      내일리버파크(467-4)    44.73
# 65    서울특별시 동대문구 답십리동 467-62        황물로1길 16           로얄팰리스 B동    29.58
# 68    서울특별시 동대문구 답십리동 467-63         사가정로 23           로얄팰리스 A동    29.05
# 73    서울특별시 동대문구 답십리동 468-28   답십리로38길 47-11               대운빌라    44.16
# 78     서울특별시 동대문구 답십리동 470-1  서울시립대로2길 71-19              엘림파크뷰    56.46
# 82    서울특별시 동대문구 답십리동 470-28  서울시립대로2길 71-18              샤인파크빌    26.97
# 83   서울특별시 동대문구 답십리동 475-105      답십리로40길 13        주함해븐빌 1동,2동    57.69
# 85   서울특별시 동대문구 답십리동 475-133      답십리로40길 17       주함해븐빌 3동, 4동    57.69
# 87    서울특별시 동대문구 답십리동 482-51     사가정로2길 10-7               라브리빌    40.51
# 101   서울특별시 동대문구 답십리동 482-56    사가정로2길 10-10              해성빌리지    29.99
# 113   서울특별시 동대문구 답십리동 482-65      천호대로67길 35              명성파크뷰    57.68
# 115   서울특별시 동대문구 답십리동 488-26       황물로13길 19                테크빌    28.80
# 120  서울특별시 동대문구 답십리동 488-338          전농로 20              스타클래스    37.31
# 125    서울특별시 동대문구 답십리동 492-4        천호대로 319         답십리한화오벨리스크    34.53
# 126    서울특별시 동대문구 답십리동 494-1        천호대로 289             한일노벨리아    19.05
# 129   서울특별시 동대문구 답십리동 497-23        천호대로 257          청계 푸르지오시티    39.71
# 133    서울특별시 동대문구 답십리동 497-9        천호대로 249               젠트리움    19.78
# 141    서울특별시 동대문구 답십리동 498-5        천호대로 247             메트로팰리스    44.18
# 143    서울특별시 동대문구 답십리동 498-7          사가정로 6  청계 G well estates    26.84
# 145     서울특별시 동대문구 답십리동 50-4      답십리로52길 26               성신빌라    45.73
# 147   서울특별시 동대문구 답십리동 530-17         황물로 168             한성아펠시티    22.14
# 150    서울특별시 동대문구 답십리동 530-4          황물로 90               보광타워    29.62
# 153    서울특별시 동대문구 답십리동 59-14      답십리로58길 36              태성골드빌    47.70
# 158     서울특별시 동대문구 답십리동 60-1        답십리로 180         덕산맨션(60-1)    44.53
# 159     서울특별시 동대문구 답십리동 63-7      답십리로 175-7             (63-7)    47.85
# 163     서울특별시 동대문구 답십리동 71-2    답십리로51길 14-5               프라하임    80.90
# 166     서울특별시 동대문구 답십리동 75-0      답십리로53길 29            대은팰리스빌1    78.12
# 167     서울특별시 동대문구 답십리동 75-5    답십리로53길 31-1            대은팰리스빌2    75.13
# 171   서울특별시 동대문구 답십리동 956-34     황물로15길 30-6               26빌라    71.43
# 176    서울특별시 동대문구 답십리동 999-0        천호대로 241          청계벽산메가트리움    59.81
#
#      거래금액(만원)   층    건축년도  계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형  \
# 0        8000   5  2003.0          3.0 2006-03-17   126.903553  18.0  연립다세대
# 11      40500   5  2017.0          3.0 2020-09-02   693.255734   4.0  연립다세대
# 12      24200   1  2009.0          0.0 2009-06-25   460.601447  12.0  연립다세대
# 14      14500   2  2003.0          3.0 2006-07-21   177.370031  18.0  연립다세대
# 17      25500   4  2014.0          0.0 2014-09-30   433.673469   7.0  연립다세대
# 18      10500   2  2003.0          3.0 2006-10-14   199.657730  18.0  연립다세대
# 22      25200   4  2003.0          3.0 2006-11-15   280.967778  18.0  연립다세대
# 23      17000   3  2003.0          3.0 2006-11-20   313.017860  18.0  연립다세대
# 32      17200   4  2017.0          0.0 2017-12-27   545.858458   4.0  연립다세대
# 39      42200   4  2020.0          1.0 2021-01-13   714.285714   1.0  연립다세대
# 45      26000   2  2008.0          1.0 2009-10-15   426.999507  13.0  연립다세대
# 46      34800   6  2017.0          3.0 2020-01-21   784.313725   4.0  연립다세대
# 57      43700   3  2020.0          1.0 2021-04-12   730.769231   1.0  연립다세대
# 58      44700   6  2017.0          3.0 2020-11-28   912.244898   4.0  연립다세대
# 60      58500   5  2020.0          0.0 2020-11-09  1096.121417   1.0  연립다세대
# 62      36000   6  2016.0          2.0 2018-10-16   804.828974   5.0  연립다세대
# 65      26500   4  2019.0          1.0 2020-10-19   895.875592   2.0  연립다세대
# 68      29000   3  2019.0          1.0 2020-07-28   998.278830   2.0  연립다세대
# 73      20200   2  2009.0          3.0 2012-02-01   457.427536  12.0  연립다세대
# 78      53500   5  2019.0          1.0 2020-05-24   947.573503   2.0  연립다세대
# 82      32000   2  2019.0          2.0 2021-06-15  1186.503522   2.0  연립다세대
# 83      25000   5  2014.0          3.0 2017-09-18   433.350667   7.0  연립다세대
# 85      31000   3  2014.0          2.0 2016-11-28   537.354828   7.0  연립다세대
# 87      36000   4  2019.0          1.0 2020-02-23   888.669464   2.0  연립다세대
# 101     16800   4  2018.0          0.0 2018-09-05   560.186729   3.0  연립다세대
# 113     39300   5  2020.0          0.0 2020-02-19   681.345354   1.0  연립다세대
# 115     12000   5  2010.0          2.0 2012-05-09   416.666667  11.0   오피스텔
# 120     25700   3  2019.0          0.0 2019-06-20   688.823372   2.0   오피스텔
# 125     10200  13  2004.0          3.0 2007-12-15   295.395308  17.0   오피스텔
# 126     14000   4  2016.0          3.0 2019-12-10   734.908136   5.0   오피스텔
# 129     27000   7  2015.0          3.0 2018-09-13   679.929489   6.0   오피스텔
# 133     31100   5  2020.0          1.0 2021-06-02  1572.295248   1.0   오피스텔
# 141     14500  15  2005.0          3.0 2008-08-08   328.202807  16.0   오피스텔
# 143     15000   6  2012.0          3.0 2015-05-14   558.867362   9.0   오피스텔
# 145     20000   3  2009.0          3.0 2012-04-04   437.349661  12.0  연립다세대
# 147     19750  13  2019.0          2.0 2021-06-14   892.050587   2.0   오피스텔
# 150     24000   5  2019.0          1.0 2020-10-24   810.263336   2.0   오피스텔
# 153     40500   2  2019.0          1.0 2020-07-17   849.056604   2.0  연립다세대
# 158     27000   3  2014.0          3.0 2017-05-09   606.332809   7.0  연립다세대
# 159     19500   2  2014.0          0.0 2014-03-01   407.523511   7.0  연립다세대
# 163     25000   4  2006.0          1.0 2007-01-02   309.023486  15.0  연립다세대
# 166     18000   4  2005.0          2.0 2007-09-10   230.414747  16.0  연립다세대
# 167     20000   2  2005.0          3.0 2008-02-25   266.205244  16.0  연립다세대
# 171     26000   3  2009.0          1.0 2010-10-01   363.992720  12.0  연립다세대
# 176     20138  13  2006.0          1.0 2007-09-19   336.699549  15.0   오피스텔
#
#         구     동       지수적용단가       평가날짜         단가평균     지수적용단가평균
# 0    동대문구  답십리동   316.320204 2021-05-01   126.903553   316.320204
# 11   동대문구  답십리동   753.225670 2021-05-01   807.409405   962.698542
# 12   동대문구  답십리동   651.442071 2021-05-01   460.601447   651.442071
# 14   동대문구  답십리동   414.842008 2021-05-01   202.807697   435.308766
# 17   동대문구  답십리동   647.279539 2021-05-01   491.543665   662.436714
# 18   동대문구  답십리동   412.915947 2021-05-01   199.657730   412.915947
# 22   동대문구  답십리동   561.055148 2021-05-01   276.501896   606.615260
# 23   동대문구  답십리동   625.054885 2021-05-01   313.017860   625.054885
# 32   동대문구  답십리동   704.681016 2021-05-01   533.523341   688.756884
# 39   동대문구  답십리동   744.480648 2021-05-01   736.356001   767.483910
# 45   동대문구  답십리동   574.737997 2021-05-01   438.483026   593.607554
# 46   동대문구  답십리동   919.895561 2021-05-01   784.313725   919.895561
# 57   동대문구  답십리동   742.659584 2021-05-01   739.330054   751.359701
# 58   동대문구  답십리동   969.418350 2021-05-01   912.244898   969.418350
# 60   동대문구  답십리동  1164.819027 2021-05-01  1025.441931  1086.228638
# 62   동대문구  답십리동   979.679292 2021-05-01   767.068490   980.061362
# 65   동대문구  답십리동   972.765541 2021-05-01  1039.306186  1132.744707
# 68   동대문구  답십리동  1104.168454 2021-05-01  1052.095660  1149.130363
# 73   동대문구  답십리동   653.073642 2021-05-01   492.123023   682.755310
# 78   동대문구  답십리동  1089.110099 2021-05-01   898.007772  1021.919050
# 82   동대문구  답십리동  1186.503522 2021-06-15  1281.790528  1442.929179
# 83   동대문구  답십리동   561.787395 2021-05-01   433.350667   561.787395
# 85   동대문구  답십리동   723.494778 2021-05-01   575.895549   760.996049
# 87   동대문구  답십리동  1023.326470 2021-05-01  1356.004100  1561.474705
# 101  동대문구  답십리동   677.996589 2021-05-01   548.354490   663.675976
# 113  동대문구  답십리동   784.587255 2021-05-01   754.471255   868.793671
# 115  동대문구  답십리동   612.997482 2021-05-01   463.154270   681.389763
# 120  동대문구  답십리동   823.565763 2021-05-01  1071.307017  1178.155212
# 125  동대문구  답십리동   458.361225 2021-05-01   294.363144   468.848483
# 126  동대문구  답십리동   857.356195 2021-05-01   734.908136   857.356195
# 129  동대문구  답십리동   822.921806 2021-05-01   665.988855   814.454275
# 133  동대문구  답십리동  1572.295248 2021-06-02  1380.491050  1408.057967
# 141  동대문구  답십리동   442.725910 2021-05-01   361.144649   510.493237
# 143  동대문구  답십리동   812.617928 2021-05-01   526.856361   754.711104
# 145  동대문구  답십리동   635.093654 2021-05-01   363.013396   513.743514
# 147  동대문구  답십리동   892.050587 2021-06-14   942.182995   973.278865
# 150  동대문구  답십리동   879.805477 2021-05-01   771.440179   905.300262
# 153  동대문구  답십리동   939.117899 2021-05-01   930.136574  1028.469285
# 158  동대문구  답십리동   798.469698 2021-05-01   603.291768   856.478155
# 159  동대문구  답십리동   610.713588 2021-05-01   407.523511   610.713588
# 163  동대문구  답십리동   589.551319 2021-05-01   289.938904   533.032288
# 166  동대문구  답십리동   381.455425 2021-05-01   223.496317   492.795266
# 167  동대문구  답십리동   394.062496 2021-05-01   266.205244   394.062496
# 171  동대문구  답십리동   515.899486 2021-05-01   369.403199   517.341468
# 176  동대문구  답십리동   557.411673 2021-05-01   380.759718   533.563972

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('{} {} 계약날짜기준 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 지번별 {}곳의 전용면적 실거래가격지수 적용후 단가평균'.format(target_gu, target_dong, target_building_age, concat_last_df.shape[0]))
plt.grid(True)
sns.histplot(concat_last_df['지수적용단가'], kde=True)
plt.savefig('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/지번별_분포도.png'.format(target_gu, target_dong, date_today_record))

# %%
concat_last_df = concat_last_df.sort_values(['지번주소']).reset_index(drop=True)

# %%
concat_last_df = concat_last_df[['지번주소', '건물(단지)명', '건축년도', '전용면적(㎡)', '층', '계약날짜', '단가(만원/㎡)', '평가날짜', '지수적용단가', '부동산유형']]
concat_last_df.rename(columns={'계약날짜':'마지막_계약날짜'}, inplace=True)
concat_last_df.head()
# Out:
#                      지번주소    건물(단지)명    건축년도  전용면적(㎡)  층   마지막_계약날짜  \
# 0   서울특별시 동대문구 답십리동 1-119       우성타운  2003.0    63.04  5 2006-03-17
# 1  서울특별시 동대문구 답십리동 1006-0       누리마루  2017.0    58.42  5 2020-09-02
# 2   서울특별시 동대문구 답십리동 104-6       금성빌라  2009.0    52.54  1 2009-06-25
# 3   서울특별시 동대문구 답십리동 2-174      우성하이츠  2003.0    81.75  2 2006-07-21
# 4   서울특별시 동대문구 답십리동 2-253  명품가A,B,C동  2014.0    58.80  4 2014-09-30
#
#      단가(만원/㎡)       평가날짜      지수적용단가  부동산유형
# 0  126.903553 2021-05-01  316.320204  연립다세대
# 1  693.255734 2021-05-01  753.225670  연립다세대
# 2  460.601447 2021-05-01  651.442071  연립다세대
# 3  177.370031 2021-05-01  414.842008  연립다세대
# 4  433.673469 2021-05-01  647.279539  연립다세대

# %%
concat_last_df.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/지수적용_마지막_실거래가.xlsx'.format(target_gu, target_dong, date_today_record), index=False)
