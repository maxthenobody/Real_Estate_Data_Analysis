# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
pd.options.mode.chained_assignment = None  # default='warn'
plt.rcParams['font.family'] = 'Malgun Gothic'
import datetime

# %%
target_gu = '영등포구'
target_dong = '당산동1가'
#target_purpose = '준주거'
target_building_age = 3
target_period = 36 # in months

# %%
date_today = pd.to_datetime(datetime.datetime.now().strftime('%Y-%m-%d'), format='%Y-%m-%d')

# %%
date_today_record = str(date_today).split(' ')[0].replace('-', '')
date_today_record
# Out:
# '20210629'

# %%
def day_modifier(x):
    # x is a number
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x)
        if len(x) == 1:
            return '0' + x
        else:
            return x

# %%
def landnum_modifier(x):
    # x is a string
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x).replace('외', '').replace(' ','')
        splitted = x.split('-')
        if len(splitted) == 1:
            return x + '-0'
        else:
            return x

# %%
def data_prep(bdtype, tradetype):
    # bdtype is a string: one of 아파트, 연립다세대 or 오피스텔
    # tradetype is a string: one of 매매 or 전월세
    
    basedir = './국토교통부_실거래가_공개시스템/{}/{}/'.format(bdtype, tradetype)
    filenames = [f for f in os.listdir(basedir) if (f.endswith('.csv'))&('(' in f)]
    
    dfs_list = []
    for i, f in tqdm(enumerate(filenames)):
        df = pd.read_csv(basedir + f, encoding='euc-kr', header=15)
        if '해제사유발생일' in df.columns.tolist():
            df = df[df['해제사유발생일'].isna()]
            df = df.drop(columns=['해제사유발생일'])

        dfs_list.append(df)
    
    concat_df = pd.concat(dfs_list).reset_index(drop=True)
        
    concat_df['번지'] = concat_df['번지'].apply(landnum_modifier)
    
    concat_df['계약년월'] = concat_df['계약년월'].apply(str)
    concat_df['계약일'] = concat_df['계약일'].apply(str)
    
    concat_df['계약날짜기준_건물연식'] = concat_df['계약년월'].apply(lambda x: int(x[:4])) - concat_df['건축년도']
    
    concat_df['계약일'] = concat_df['계약일'].apply(day_modifier)
    
    concat_df['계약날짜'] = concat_df['계약년월'].apply(lambda x: x[:4]) + '-' + concat_df['계약년월'].apply(lambda x: x[-2:])\
    + '-' + concat_df['계약일']
    
    concat_df['계약날짜'] = pd.to_datetime(concat_df['계약날짜'], format='%Y-%m-%d')
    
    concat_df['거래금액(만원)'] = concat_df['거래금액(만원)'].apply(lambda x: int(x.replace(',','')))
    concat_df['단가(만원/㎡)'] = concat_df['거래금액(만원)'] / concat_df['전용면적(㎡)']
    
    concat_df['지번주소'] = concat_df['시군구'] + ' ' + concat_df['번지']
        
    cols_to_drop = ['시군구', '번지', '본번', '부번', '지번주소', '계약년월', '계약일', '도로명']
        
    concat_df = concat_df[['지번주소', '도로명'] + [col for col in concat_df.columns if col not in cols_to_drop]]
    
    date_today = pd.to_datetime(datetime.datetime.now().strftime('%Y-%m-%d'), format='%Y-%m-%d')
    concat_df['건물연식'] = date_today.year - concat_df['건축년도']
    
    concat_df = concat_df.dropna(subset=['지번주소'])
    
    if '건물명' in concat_df.columns:
        concat_df.rename(columns={'건물명':'건물(단지)명'}, inplace=True)
    elif '단지명' in concat_df.columns:
        concat_df.rename(columns={'단지명':'건물(단지)명'}, inplace=True)
    
    concat_df = concat_df[concat_df['층'] >= 0].reset_index(drop=True)
    
    return concat_df

# %%
apart_df = data_prep('아파트', '매매')
apart_df['부동산유형'] = '아파트'
print(apart_df.shape)
apart_df.head()
# Out:
# 16it [00:02,  7.94it/s]
# (1200326, 12)
#                   지번주소      도로명         건물(단지)명  전용면적(㎡)  거래금액(만원)  층  건축년도  \
# 0  서울특별시 강남구 개포동 655-2  언주로 103  개포2차현대아파트(220)    77.75     59500  7  1988
# 1  서울특별시 강남구 개포동 655-2  언주로 103  개포2차현대아파트(220)    77.75     60000  6  1988
# 2  서울특별시 강남구 개포동 655-2  언주로 103  개포2차현대아파트(220)    77.75     67000  9  1988
# 3  서울특별시 강남구 개포동 655-2  언주로 103  개포2차현대아파트(220)    77.75     60000  4  1988
# 4  서울특별시 강남구 개포동 655-2  언주로 103  개포2차현대아파트(220)    77.75     72250  5  1988
#
#    계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식 부동산유형
# 0           18 2006-03-10  765.273312    33   아파트
# 1           18 2006-03-29  771.704180    33   아파트
# 2           18 2006-04-29  861.736334    33   아파트
# 3           18 2006-06-01  771.704180    33   아파트
# 4           18 2006-10-20  929.260450    33   아파트

# %%
yunrip_df = data_prep('연립다세대', '매매')
yunrip_df['부동산유형'] = '연립다세대'
print(yunrip_df.shape)
yunrip_df.head()
# Out:
# 16it [00:01, 10.96it/s]
# (640921, 13)
#                    지번주소         도로명   건물(단지)명  전용면적(㎡)  대지권면적(㎡)  거래금액(만원)  층  \
# 0  서울특별시 강남구 개포동 171-13   선릉로14길 11  (171-13)    68.08     56.10     56500  2
# 1  서울특별시 강남구 개포동 1239-7   개포로15길 25   강남빌라 가동    52.59     45.00     40500  2
# 2  서울특별시 강남구 개포동 1239-7   개포로15길 25   강남빌라 가동    52.59     45.00     42000  1
# 3  서울특별시 강남구 개포동 1239-6   개포로15길 27   강남빌라 나동    52.75     44.68     22000  2
# 4  서울특별시 강남구 개포동 1175-2  논현로6길 36-8      강남파크    49.43     23.70     17000  4
#
#      건축년도  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형
# 0  1988.0         18.0 2006-12-20  829.905993  33.0  연립다세대
# 1  1988.0         18.0 2006-12-09  770.108386  33.0  연립다세대
# 2  1988.0         18.0 2006-12-19  798.630918  33.0  연립다세대
# 3  1988.0         18.0 2006-11-02  417.061611  33.0  연립다세대
# 4  1993.0         13.0 2006-07-19  343.920696  28.0  연립다세대

# %%
officetel_df = data_prep('오피스텔', '매매')
officetel_df['부동산유형'] = '오피스텔'
print(officetel_df.shape)
officetel_df.head()
# Out:
# 16it [00:00, 39.60it/s]
# (182012, 12)
#                  지번주소      도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)   층    건축년도  \
# 0  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44      6400   8  1997.0
# 1  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44      7100   7  1997.0
# 2  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44      7300  11  1997.0
# 3  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    31.91      7500  10  1997.0
# 4  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44      7400  15  1997.0
#
#    계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식 부동산유형
# 0          9.0 2006-01-10  197.287300  24.0  오피스텔
# 1          9.0 2006-01-10  218.865598  24.0  오피스텔
# 2          9.0 2006-01-11  225.030826  24.0  오피스텔
# 3          9.0 2006-01-18  235.036039  24.0  오피스텔
# 4          9.0 2006-01-19  228.113440  24.0  오피스텔

# %%
yunrip_df = yunrip_df.drop(columns=['대지권면적(㎡)'])
house_df = pd.concat([apart_df, yunrip_df, officetel_df]).sort_values(['지번주소', '건축년도', '전용면적(㎡)', '계약날짜']).reset_index(drop=True)
print(house_df.shape)
house_df.head()
# Out:
# (2023259, 12)
#                     지번주소       도로명      건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 0   서울특별시 강남구 개포동 1164-0   논현로2길 6         골드캐슬    58.05     57500  2  2017.0
# 1   서울특별시 강남구 개포동 1164-0   논현로2길 6         골드캐슬    58.05     57000  1  2017.0
# 2   서울특별시 강남구 개포동 1164-0   논현로2길 6         골드캐슬    58.05     63000  2  2017.0
# 3  서울특별시 강남구 개포동 1164-12  논현로2길 34  새롬(1164-12)    71.72     64500  7  2000.0
# 4  서울특별시 강남구 개포동 1164-12  논현로2길 34  새롬(1164-12)    73.50     29800  4  2000.0
#
#    계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형
# 0          1.0 2018-01-20   990.525409   4.0  연립다세대
# 1          1.0 2018-06-01   981.912145   4.0  연립다세대
# 2          2.0 2019-01-19  1085.271318   4.0  연립다세대
# 3         17.0 2017-09-23   899.330731  21.0    아파트
# 4          6.0 2006-10-18   405.442177  21.0    아파트

# %%
'''land_specs_df = pd.read_csv('./prepped_data/land_specs_ver_4.csv')
print(land_specs_df.shape)
land_specs_df.head()'''
# Out:
# "land_specs_df = pd.read_csv('./prepped_data/land_specs_ver_4.csv')\nprint(land_specs_df.shape)\nland_specs_df.head()"

# %%
'''last_df = land_specs_df.drop_duplicates(subset=['지번주소'], keep='last').drop(columns=['년', '공시지가']).reset_index(drop=True)
print(last_df.shape)
last_df.head()'''
# Out:
# "last_df = land_specs_df.drop_duplicates(subset=['지번주소'], keep='last').drop(columns=['년', '공시지가']).reset_index(drop=True)\nprint(last_df.shape)\nlast_df.head()"

# %%
'''house_merge_df = house_df.merge(last_df, on=['지번주소']).reset_index(drop=True)
print(house_merge_df.shape)'''
# Out:
# "house_merge_df = house_df.merge(last_df, on=['지번주소']).reset_index(drop=True)\nprint(house_merge_df.shape)"

# %%
house_df['구'] = house_df['지번주소'].apply(lambda x: x.split(' ')[1])
house_df['동'] = house_df['지번주소'].apply(lambda x: x.split(' ')[2])
#house_merge_df['구'] = house_merge_df['지번주소'].apply(lambda x: x.split(' ')[1])
#house_merge_df['동'] = house_merge_df['지번주소'].apply(lambda x: x.split(' ')[2])

# %%
target_df = house_df[
    (house_df['지번주소'].str.contains(target_gu + ' ' + target_dong))
    #&(house_df['동'] == target_dong)
    &(house_df['계약날짜'] >= (date_today - pd.DateOffset(months=target_period)))
    &(house_df['건물연식'] <= target_building_age)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_df.shape)
target_df.head()
# Out:
# (50, 14)
#                            지번주소        도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층  \
# 1670248  서울특별시 영등포구 당산동1가 150-4  영신로43길 13    리버웨이    42.49     30000  3
# 1670249  서울특별시 영등포구 당산동1가 150-4  영신로43길 13    리버웨이    42.93     30000  3
# 1670250  서울특별시 영등포구 당산동1가 150-4  영신로43길 13    리버웨이    43.53     30000  3
# 1670257  서울특별시 영등포구 당산동1가 155-1  영신로41길 15   해강하우스    27.84     29500  4
# 1670258  서울특별시 영등포구 당산동1가 155-1  영신로41길 15   해강하우스    27.84     28600  5
#
#            건축년도  계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형     구      동
# 1670248  2019.0          0.0 2019-02-22   706.048482   2.0   오피스텔  영등포구  당산동1가
# 1670249  2019.0          0.0 2019-03-21   698.812020   2.0   오피스텔  영등포구  당산동1가
# 1670250  2019.0          0.0 2019-02-13   689.179876   2.0   오피스텔  영등포구  당산동1가
# 1670257  2018.0          0.0 2018-09-12  1059.626437   3.0  연립다세대  영등포구  당산동1가
# 1670258  2018.0          0.0 2018-10-13  1027.298851   3.0  연립다세대  영등포구  당산동1가

# %%
sales_idx_basedir = './한국부동산원/실거래가격지수/'
filenames = [f for f in os.listdir(sales_idx_basedir) if '연립다세대' in f]

sales_idx_df = pd.read_excel(sales_idx_basedir + filenames[0], header=[10, 11])

sales_idx_cols_list = []
for i in range(sales_idx_df.shape[1]):
    if i == 0:
        sales_idx_cols_list.append(sales_idx_df.columns[i][0])
    else:
        sales_idx_cols_list.append(sales_idx_df.columns[i][0] + '_' + sales_idx_df.columns[i][1])

sales_idx_df.columns = sales_idx_cols_list

# %%
def get_sales_idx(x):
    # x is a pandas timestamp
    
    df = sales_idx_df.copy()
    
    if pd.isna(x) == True:
        return x
    else:
        year = str(x.year)
        month = str(x.month)
        if len(month) == 1:
            month = '0'+month
        
        idx = df[year+'년 '+month+'월_지수'].iloc[0]
        
        return idx

# %%
def get_index_applied_prices(df):
    df = df.copy()
    
    last_idx = sales_idx_df.iloc[0,-2]
    
    last_date = sales_idx_df.columns[-1].split('_')[0]
    
    last_date = last_date.split(' ')[0].replace('년','') + '-' + last_date.split(' ')[1].replace('월','') + '-01'
    
    target_upper_limit_df = df[df['계약날짜'] < pd.to_datetime(last_date)]
    target_upper_limit_df['계약날짜_실거래지수'] = target_upper_limit_df['계약날짜'].apply(get_sales_idx)
    target_upper_limit_df['지수적용단가'] = target_upper_limit_df['단가(만원/㎡)'] / target_upper_limit_df['계약날짜_실거래지수'] * last_idx
    df['지수적용단가'] = df['단가(만원/㎡)']
    df.loc[target_upper_limit_df.index, '지수적용단가'] = target_upper_limit_df['지수적용단가']
    df['평가날짜'] = df['계약날짜']
    df.loc[target_upper_limit_df.index, '평가날짜'] = pd.to_datetime(last_date[:-2] + '01')
    
    return df

# %%
target_df = get_index_applied_prices(target_df)
print(target_df.shape)
target_df.head()
# Out:
# (50, 16)
#                            지번주소        도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층  \
# 1670248  서울특별시 영등포구 당산동1가 150-4  영신로43길 13    리버웨이    42.49     30000  3
# 1670249  서울특별시 영등포구 당산동1가 150-4  영신로43길 13    리버웨이    42.93     30000  3
# 1670250  서울특별시 영등포구 당산동1가 150-4  영신로43길 13    리버웨이    43.53     30000  3
# 1670257  서울특별시 영등포구 당산동1가 155-1  영신로41길 15   해강하우스    27.84     29500  4
# 1670258  서울특별시 영등포구 당산동1가 155-1  영신로41길 15   해강하우스    27.84     28600  5
#
#            건축년도  계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형     구  \
# 1670248  2019.0          0.0 2019-02-22   706.048482   2.0   오피스텔  영등포구
# 1670249  2019.0          0.0 2019-03-21   698.812020   2.0   오피스텔  영등포구
# 1670250  2019.0          0.0 2019-02-13   689.179876   2.0   오피스텔  영등포구
# 1670257  2018.0          0.0 2018-09-12  1059.626437   3.0  연립다세대  영등포구
# 1670258  2018.0          0.0 2018-10-13  1027.298851   3.0  연립다세대  영등포구
#
#              동       지수적용단가       평가날짜
# 1670248  당산동1가   852.413834 2021-04-01
# 1670249  당산동1가   844.150412 2021-04-01
# 1670250  당산동1가   832.048330 2021-04-01
# 1670257  당산동1가  1265.332450 2021-04-01
# 1670258  당산동1가  1233.288516 2021-04-01

# %%
target_df = target_df.sort_values(['지번주소', '건축년도', '계약날짜']).reset_index(drop=True)
target_df1 = target_df[['지번주소', '건물(단지)명', '건물연식', '층', '전용면적(㎡)', '계약날짜', '거래금액(만원)', '단가(만원/㎡)', '평가날짜', '지수적용단가', '부동산유형']]
target_df1.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/실거래가.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
target_df1.head()
# Out:
#                      지번주소 건물(단지)명  건물연식  층  전용면적(㎡)       계약날짜  거래금액(만원)  \
# 0  서울특별시 영등포구 당산동1가 150-4    리버웨이   2.0  3    43.53 2019-02-13     30000
# 1  서울특별시 영등포구 당산동1가 150-4    리버웨이   2.0  3    42.49 2019-02-22     30000
# 2  서울특별시 영등포구 당산동1가 150-4    리버웨이   2.0  3    42.93 2019-03-21     30000
# 3  서울특별시 영등포구 당산동1가 155-1   해강하우스   3.0  2    45.77 2018-07-31     27900
# 4  서울특별시 영등포구 당산동1가 155-1   해강하우스   3.0  4    27.84 2018-09-12     29500
#
#       단가(만원/㎡)       평가날짜       지수적용단가  부동산유형
# 0   689.179876 2021-04-01   832.048330   오피스텔
# 1   706.048482 2021-04-01   852.413834   오피스텔
# 2   698.812020 2021-04-01   844.150412   오피스텔
# 3   609.569587 2021-04-01   742.908002   오피스텔
# 4  1059.626437 2021-04-01  1265.332450  연립다세대

# %%
target_df1_30 = target_df1[
    (target_df1['전용면적(㎡)'] >= 28)
    &(target_df1['전용면적(㎡)'] <= 32)
]

# %%
target_df1_30.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/실거래가_30.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('최근 {}개월 {} {} 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 {}건의 전용면적 단가'.format(target_period, target_gu, target_dong, target_building_age, target_df.shape[0]))
plt.grid(True)
ax.xaxis.update_units(target_df['계약날짜'])
sns.regplot(x=ax.xaxis.convert_units(target_df['계약날짜']), y=target_df['단가(만원/㎡)'])
plt.savefig('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/산포도.png'.format(target_gu, target_dong, date_today_record))

# %%
target_last_df = target_df.drop_duplicates(subset=['지번주소', '건축년도'], keep='last').reset_index(drop=True)

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('최근 {}개월 {} {} 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 {}건의 전용면적 단가'.format(target_period, target_gu, target_dong, target_building_age, target_last_df.shape[0]))
plt.grid(True)
ax.xaxis.update_units(target_last_df['계약날짜'])
sns.regplot(x=ax.xaxis.convert_units(target_last_df['계약날짜']), y=target_last_df['단가(만원/㎡)'])
plt.savefig('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/마지막_산포도.png'.format(target_gu, target_dong, date_today_record))

# %%
target_last_df.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/마지막_실거래가.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
target_df2 = house_df[
    (house_df['지번주소'].str.contains(target_gu + ' ' + target_dong))
    #&(house_df['동'] == target_dong)
    #&(house_merge_df['계약날짜'] >= (date_today - pd.DateOffset(months=target_period)))
    &(house_df['계약날짜기준_건물연식'] <= target_building_age)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_df2.shape)
target_df2.head()
# Out:
# (180, 14)
#                            지번주소        도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층  \
# 1670204  서울특별시 영등포구 당산동1가 113-0  당산로10길 21    프라임빌    29.83     18000  3
# 1670205  서울특별시 영등포구 당산동1가 113-0  당산로10길 21    프라임빌    29.83     23900  4
# 1670206  서울특별시 영등포구 당산동1가 113-0  당산로10길 21    프라임빌    29.83     24000  4
# 1670212  서울특별시 영등포구 당산동1가 113-0  당산로10길 21    프라임빌    29.97     21800  4
# 1670213  서울특별시 영등포구 당산동1가 113-0  당산로10길 21    프라임빌    29.97     22500  5
#
#            건축년도  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형     구      동
# 1670204  2015.0          2.0 2017-07-07  603.419376   6.0  연립다세대  영등포구  당산동1가
# 1670205  2015.0          2.0 2017-07-31  801.206839   6.0  연립다세대  영등포구  당산동1가
# 1670206  2015.0          2.0 2017-09-18  804.559169   6.0  연립다세대  영등포구  당산동1가
# 1670212  2015.0          3.0 2018-03-28  727.394061   6.0  연립다세대  영등포구  당산동1가
# 1670213  2015.0          3.0 2018-12-29  750.750751   6.0  연립다세대  영등포구  당산동1가

# %%
target_df2 = get_index_applied_prices(target_df2)

# %%
font = {'size': 12}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(12,6))
plt.title('{} {} 계약날짜기준 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 {}건의 전용면적 단가'.format(target_gu, target_dong, target_building_age, target_df2.shape[0]))
plt.grid(True)
sns.histplot(target_df2['단가(만원/㎡)'], kde=True)
# Out:
# <AxesSubplot:title={'center':'영등포구 당산동1가 계약날짜기준 건물연식 3년이하 연립다세대 및 오피스텔 매매 실거래 180건의 전용면적 단가'}, xlabel='단가(만원/㎡)', ylabel='Count'>

# %%
target_df3 = target_df2[['지번주소', '건물(단지)명', '건축년도', '층', '전용면적(㎡)', '계약날짜', '단가(만원/㎡)', '평가날짜', '지수적용단가', '부동산유형']]
target_df3 = target_df3.sort_values(['지번주소', '건축년도', '계약날짜']).reset_index(drop=True)
target_df3.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/지수적용_실거래가.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
target_df3_30 = target_df3[
    (target_df3['전용면적(㎡)'] >= 28)
    &(target_df3['전용면적(㎡)'] <= 32)
]

# %%
target_df3_30.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/지수적용_실거래가_30.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
concat_df = pd.concat([target_df2])

# %%
concat_df = concat_df.sort_values(['지번주소', '건축년도', '전용면적(㎡)', '계약날짜']).reset_index(drop=True)
concat_df = concat_df.drop_duplicates(['지번주소', '건축년도', '전용면적(㎡)'], keep='last').reset_index(drop=True)

# %%
concat_df['단가평균'] = concat_df[['지번주소', '건축년도', '단가(만원/㎡)']].groupby(['지번주소', '건축년도']).transform('mean')['단가(만원/㎡)']
concat_df['지수적용단가평균'] = concat_df[['지번주소', '건축년도', '지수적용단가']].groupby(['지번주소', '건축년도']).transform('mean')['지수적용단가']

# %%
concat_df = concat_df.sort_values(['지번주소', '건축년도', '평가날짜']).reset_index(drop=True)
print(concat_df.shape)
concat_df.head()
# Out:
# (67, 18)
#                      지번주소          도로명    건물(단지)명  전용면적(㎡)  거래금액(만원)  층  \
# 0  서울특별시 영등포구 당산동1가 113-0    당산로10길 21       프라임빌    29.83     24000  4
# 1  서울특별시 영등포구 당산동1가 113-0    당산로10길 21       프라임빌    29.97     22500  5
# 2  서울특별시 영등포구 당산동1가 137-0  영신로39길 16-1  밀레니엄(137)    24.36     23700  3
# 3  서울특별시 영등포구 당산동1가 137-0  영신로39길 16-1  밀레니엄(137)    24.48     22000  6
# 4  서울특별시 영등포구 당산동1가 137-0  영신로39길 16-1  밀레니엄(137)    25.70     22000  5
#
#      건축년도  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형     구      동  \
# 0  2015.0          2.0 2017-09-18  804.559169   6.0  연립다세대  영등포구  당산동1가
# 1  2015.0          3.0 2018-12-29  750.750751   6.0  연립다세대  영등포구  당산동1가
# 2  2016.0          3.0 2019-12-30  972.906404   5.0  연립다세대  영등포구  당산동1가
# 3  2016.0          2.0 2018-09-11  898.692810   5.0  연립다세대  영등포구  당산동1가
# 4  2016.0          1.0 2017-04-27  856.031128   5.0  연립다세대  영등포구  당산동1가
#
#         지수적용단가       평가날짜        단가평균     지수적용단가평균
# 0  1028.912381 2021-04-01  777.654960   970.398311
# 1   911.884242 2021-04-01  777.654960   970.398311
# 2  1119.396879 2021-04-01  898.754155  1111.844819
# 3  1073.156668 2021-04-01  898.754155  1111.844819
# 4  1119.984636 2021-04-01  898.754155  1111.844819

# %%
concat_last_df = concat_df.drop_duplicates(subset=['지번주소', '건축년도'], keep='last')
print(concat_last_df.shape)
concat_last_df
# Out:
# (28, 18)
#                         지번주소           도로명     건물(단지)명  전용면적(㎡)  거래금액(만원)  층  \
# 1     서울특별시 영등포구 당산동1가 113-0     당산로10길 21        프라임빌    29.97     22500  5
# 5     서울특별시 영등포구 당산동1가 137-0   영신로39길 16-1   밀레니엄(137)    25.94     22500  4
# 7     서울특별시 영등포구 당산동1가 139-0   영신로39길 16-5        LG빌딩    25.34     14000  6
# 10    서울특별시 영등포구 당산동1가 140-1     영신로43길 17      현대가우스빌    39.24     24900  2
# 11    서울특별시 영등포구 당산동1가 143-0    영등포로27길 12      다솔시티하임    28.71     30000  6
# 12    서울특별시 영등포구 당산동1가 144-0                    블리스다임빌    29.22     30287  3
# 15    서울특별시 영등포구 당산동1가 150-4     영신로43길 13        리버웨이    43.53     30000  3
# 19    서울특별시 영등포구 당산동1가 152-0     영신로41길 13        썬샤인빌    29.98     26800  3
# 21    서울특별시 영등포구 당산동1가 155-1     영신로41길 15       해강하우스    45.77     27900  2
# 23    서울특별시 영등포구 당산동1가 166-1    영신로41길 5-2      에이원하우징    51.33     28000  2
# 24    서울특별시 영등포구 당산동1가 181-0      영신로41길 6         썬샤인    27.80     25500  3
# 26   서울특별시 영등포구 당산동1가 185-22     당산로16길 27     J.W 카리스    38.66     29800  3
# 29  서울특별시 영등포구 당산동1가 186-105   영신로43길 8-16    파비앵 104동    64.78     27000  2
# 31  서울특별시 영등포구 당산동1가 186-106   영신로43길 16-7  파비엥노블레스101    29.95     25000  4
# 32   서울특별시 영등포구 당산동1가 186-63  영신로43길 16-14  파비엥노블레스102    29.94     30400  5
# 33   서울특별시 영등포구 당산동1가 186-99                       파비엥    26.46     16500  2
# 34    서울특별시 영등포구 당산동1가 194-1    영신로47길 9-1       A-클래스    28.97     30900  9
# 38   서울특별시 영등포구 당산동1가 223-12     당산로20길 24       당산빌리지    29.75     23300  4
# 40    서울특별시 영등포구 당산동1가 236-0  영등포로27길 24-1       세인트 빌    25.30     26800  5
# 41  서울특별시 영등포구 당산동1가 256-137   당산로16길 26-1   (256-137)    28.57     24800  6
# 43  서울특별시 영등포구 당산동1가 256-179  당산로16길 24-11       푸르미르빌    29.98     19000  6
# 49    서울특별시 영등포구 당산동1가 256-8     당산로12길 15      퍼스트빌리지    42.33     45500  7
# 50   서울특별시 영등포구 당산동1가 256-85   당산로12길 16-1       당산아트빌    42.75     11000  5
# 51    서울특별시 영등포구 당산동1가 260-0       양산로 142     더채움오피스텔    27.94     30000  4
# 53    서울특별시 영등포구 당산동1가 388-1    당산로16길 9-4      에이스하우징    29.99     34200  4
# 55    서울특별시 영등포구 당산동1가 457-0      영신로33길 3     신동아파밀리에    84.96     40000  1
# 61    서울특별시 영등포구 당산동1가 458-0     당산로16길 26          康南    23.76     14000  5
# 66     서울특별시 영등포구 당산동1가 96-2     영등포로29길 8       비다펠리즈    29.92     22000  2
#
#       건축년도  계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형     구      동  \
# 1   2015.0          3.0 2018-12-29   750.750751   6.0  연립다세대  영등포구  당산동1가
# 5   2016.0          1.0 2017-04-15   867.386276   5.0  연립다세대  영등포구  당산동1가
# 7   2016.0          3.0 2019-02-02   552.486188   5.0  연립다세대  영등포구  당산동1가
# 10  2016.0          1.0 2017-05-12   634.556575   5.0   오피스텔  영등포구  당산동1가
# 11  2017.0          3.0 2020-12-07  1044.932079   4.0  연립다세대  영등포구  당산동1가
# 12  2017.0          3.0 2020-08-07  1036.516085   4.0   오피스텔  영등포구  당산동1가
# 15  2019.0          0.0 2019-02-13   689.179876   2.0   오피스텔  영등포구  당산동1가
# 19  2017.0          2.0 2019-04-25   893.929286   4.0  연립다세대  영등포구  당산동1가
# 21  2018.0          0.0 2018-07-31   609.569587   3.0   오피스텔  영등포구  당산동1가
# 23  2018.0          0.0 2018-08-15   545.489967   3.0   오피스텔  영등포구  당산동1가
# 24  2017.0          3.0 2020-06-09   917.266187   4.0  연립다세대  영등포구  당산동1가
# 26  2018.0          1.0 2019-01-26   770.822556   3.0   오피스텔  영등포구  당산동1가
# 29  2018.0          2.0 2020-07-08   416.795307   3.0   오피스텔  영등포구  당산동1가
# 31  2017.0          3.0 2020-02-29   834.724541   4.0  연립다세대  영등포구  당산동1가
# 32  2017.0          3.0 2020-08-26  1015.364061   4.0  연립다세대  영등포구  당산동1가
# 33  2018.0          0.0 2018-09-13   623.582766   3.0   오피스텔  영등포구  당산동1가
# 34  2019.0          1.0 2020-09-11  1066.620642   2.0  연립다세대  영등포구  당산동1가
# 38  2015.0          3.0 2018-12-27   783.193277   6.0  연립다세대  영등포구  당산동1가
# 40  2017.0          2.0 2019-05-11  1059.288538   4.0  연립다세대  영등포구  당산동1가
# 41  2015.0          1.0 2016-12-13   868.043402   6.0  연립다세대  영등포구  당산동1가
# 43  2013.0          2.0 2015-02-23   633.755837   8.0  연립다세대  영등포구  당산동1가
# 49  2018.0          3.0 2021-05-24  1074.887786   3.0  연립다세대  영등포구  당산동1가
# 50  2006.0          0.0 2006-11-01   257.309942  15.0  연립다세대  영등포구  당산동1가
# 51  2020.0          1.0 2021-06-09  1073.729420   1.0   오피스텔  영등포구  당산동1가
# 53  2021.0          0.0 2021-05-07  1140.380127   0.0  연립다세대  영등포구  당산동1가
# 55  2008.0          0.0 2008-03-22   470.809793  13.0    아파트  영등포구  당산동1가
# 61  2012.0          1.0 2013-08-20   589.225589   9.0  연립다세대  영등포구  당산동1가
# 66  2019.0          0.0 2019-05-23   735.294118   2.0   오피스텔  영등포구  당산동1가
#
#          지수적용단가       평가날짜         단가평균     지수적용단가평균
# 1    911.884242 2021-04-01   777.654960   970.398311
# 5   1134.841094 2021-04-01   898.754155  1111.844819
# 7    667.017750 2021-04-01   543.463997   656.125239
# 10   824.531646 2021-04-01   851.084404  1017.886116
# 11  1084.859754 2021-04-01  1044.932079  1084.859754
# 12  1129.593284 2021-04-01  1036.516085  1129.593284
# 15   832.048330 2021-04-01   698.013459   842.870859
# 19  1075.828924 2021-04-01   874.459135  1004.349487
# 21   742.908002 2021-04-01   818.434219   988.098259
# 23   657.234961 2021-04-01   769.732935   948.965177
# 24  1012.292313 2021-04-01   917.266187  1012.292313
# 26   938.668550 2021-04-01   957.353724  1130.555085
# 29   454.277285 2021-04-01   703.006308   773.936793
# 31   948.260271 2021-04-01   831.012736  1000.975408
# 32  1106.541849 2021-04-01  1015.364061  1106.541849
# 33   744.639321 2021-04-01   623.582766   744.639321
# 34  1143.291732 2021-04-01  1066.620642  1143.291732
# 38   951.289902 2021-04-01   815.249411   984.292122
# 40  1271.068227 2021-04-01  1113.411630  1394.071148
# 41  1154.855695 2021-04-01   868.043402  1154.855695
# 43   923.681506 2021-04-01   623.410582   919.017074
# 49  1074.887786 2021-05-24   902.982934  1002.611683
# 50   506.862015 2021-04-01   257.309942   506.862015
# 51  1073.729420 2021-06-09  1073.729420  1073.729420
# 53  1140.380127 2021-05-07  1146.404469  1146.404469
# 55   656.258252 2021-04-01   561.162472   788.169749
# 61   877.921188 2021-04-01   742.793874  1106.731433
# 66   882.298786 2021-04-01   859.984474  1024.379066

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('{} {} 계약날짜기준 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 지번별 {}곳의 전용면적 실거래가격지수 적용후 단가평균'.format(target_gu, target_dong, target_building_age, concat_last_df.shape[0]))
plt.grid(True)
sns.histplot(concat_last_df['지수적용단가'], kde=True)
plt.savefig('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/지번별_분포도.png'.format(target_gu, target_dong, date_today_record))

# %%
concat_last_df = concat_last_df.sort_values(['지번주소']).reset_index(drop=True)

# %%
concat_last_df = concat_last_df[['지번주소', '건물(단지)명', '건축년도', '전용면적(㎡)', '층', '계약날짜', '단가(만원/㎡)', '평가날짜', '지수적용단가', '부동산유형']]
concat_last_df.rename(columns={'계약날짜':'마지막_계약날짜'}, inplace=True)
concat_last_df.head()
# Out:
#                      지번주소    건물(단지)명    건축년도  전용면적(㎡)  층   마지막_계약날짜  \
# 0  서울특별시 영등포구 당산동1가 113-0       프라임빌  2015.0    29.97  5 2018-12-29
# 1  서울특별시 영등포구 당산동1가 137-0  밀레니엄(137)  2016.0    25.94  4 2017-04-15
# 2  서울특별시 영등포구 당산동1가 139-0       LG빌딩  2016.0    25.34  6 2019-02-02
# 3  서울특별시 영등포구 당산동1가 140-1     현대가우스빌  2016.0    39.24  2 2017-05-12
# 4  서울특별시 영등포구 당산동1가 143-0     다솔시티하임  2017.0    28.71  6 2020-12-07
#
#       단가(만원/㎡)       평가날짜       지수적용단가  부동산유형
# 0   750.750751 2021-04-01   911.884242  연립다세대
# 1   867.386276 2021-04-01  1134.841094  연립다세대
# 2   552.486188 2021-04-01   667.017750  연립다세대
# 3   634.556575 2021-04-01   824.531646   오피스텔
# 4  1044.932079 2021-04-01  1084.859754  연립다세대

# %%
concat_last_df.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/지수적용_마지막_실거래가.xlsx'.format(target_gu, target_dong, date_today_record), index=False)
