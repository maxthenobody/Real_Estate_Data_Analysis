# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
pd.options.mode.chained_assignment = None  # default='warn'
plt.rcParams['font.family'] = 'Malgun Gothic'
import datetime
import time

# %%
def day_modifier(x):
    # x is a number
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x)
        if len(x) == 1:
            return '0' + x
        else:
            return x

# %%
def landnum_modifier(x):
    # x is a string
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x).replace(' ','')
        splitted = x.split('-')
        if len(splitted) == 1:
            return x + '-0'
        else:
            return x

# %%
def data_prep(bdtype, tradetype):
    # bdtype is a string: one of 아파트, 연립다세대 or 오피스텔
    # tradetype is a string: one of 매매 or 전월세
    
    basedir = './국토교통부_실거래가_공개시스템/{}/{}/'.format(bdtype, tradetype)
    filenames = [f for f in os.listdir(basedir) if (f.endswith('.csv'))&('(' in f)]
    
    dfs_list = []
    for i, f in tqdm(enumerate(filenames)):
        df = pd.read_csv(basedir + f, encoding='euc-kr', header=15)
        if '해제사유발생일' in df.columns.tolist():
            df = df[df['해제사유발생일'].isna()]
            df = df.drop(columns=['해제사유발생일'])

        dfs_list.append(df)
    
    concat_df = pd.concat(dfs_list).reset_index(drop=True)
        
    concat_df['번지'] = concat_df['번지'].apply(landnum_modifier)
    
    concat_df['계약년월'] = concat_df['계약년월'].apply(str)
    concat_df['계약일'] = concat_df['계약일'].apply(str)
    
    concat_df['계약날짜기준_건물연식'] = concat_df['계약년월'].apply(lambda x: int(x[:4])) - concat_df['건축년도']
    
    concat_df['계약일'] = concat_df['계약일'].apply(day_modifier)
    
    concat_df['계약날짜'] = concat_df['계약년월'].apply(lambda x: x[:4]) + '-' + concat_df['계약년월'].apply(lambda x: x[-2:])\
    + '-' + concat_df['계약일']
    
    concat_df['계약날짜'] = pd.to_datetime(concat_df['계약날짜'], format='%Y-%m-%d')
    
    concat_df['거래금액(만원)'] = concat_df['거래금액(만원)'].apply(lambda x: int(x.replace(',','')))
    concat_df['단가(만원/㎡)'] = concat_df['거래금액(만원)'] / concat_df['전용면적(㎡)']
    
    concat_df['지번주소'] = concat_df['시군구'] + ' ' + concat_df['번지']
        
    cols_to_drop = ['시군구', '번지', '본번', '부번', '지번주소', '계약년월', '계약일', '도로명']
        
    concat_df = concat_df[['지번주소', '도로명'] + [col for col in concat_df.columns if col not in cols_to_drop]]
    
    date_today = pd.to_datetime(datetime.datetime.now().strftime('%Y-%m-%d'), format='%Y-%m-%d')
    concat_df['건물연식'] = date_today.year - concat_df['건축년도']
    
    concat_df = concat_df.dropna(subset=['지번주소'])
    
    if '건물명' in concat_df.columns:
        concat_df.rename(columns={'건물명':'건물(단지)명'}, inplace=True)
    elif '단지명' in concat_df.columns:
        concat_df.rename(columns={'단지명':'건물(단지)명'}, inplace=True)
    
    concat_df = concat_df[concat_df['층'] >= 0].reset_index(drop=True)
    
    return concat_df

# %%
yunrip_df = data_prep('연립다세대', '매매')
yunrip_df = yunrip_df[(yunrip_df['계약날짜'] >= pd.to_datetime('2015-01-01'))
                      #&(yunrip_df['계약날짜기준_건물연식'] <= 5)
                     ]
yunrip_df = yunrip_df.reset_index(drop=True)
yunrip_df['부동산유형'] = '연립다세대'
yunrip_df.drop(columns=['대지권면적(㎡)'], inplace=True)
print(yunrip_df.shape)
yunrip_df.head()
# Out:
# 16it [00:01, 10.39it/s]
# (318821, 12)
#                    지번주소        도로명   건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 0  서울특별시 강남구 개포동 1216-4  개포로26길 16  (1216-4)    33.77     24800  4  2012.0
# 1  서울특별시 강남구 개포동 1216-4  개포로26길 16  (1216-4)    35.87     27200  4  2012.0
# 2  서울특별시 강남구 개포동 1216-4  개포로26길 16  (1216-4)    29.12     22200  4  2012.0
# 3  서울특별시 강남구 개포동 1216-4  개포로26길 16  (1216-4)    29.97     22500  3  2012.0
# 4  서울특별시 강남구 개포동 170-18  선릉로12길 17  (170-18)    26.60     21000  1  1988.0
#
#    계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형
# 0          3.0 2015-03-26  734.379627   9.0  연립다세대
# 1          3.0 2015-06-23  758.293839   9.0  연립다세대
# 2          3.0 2015-07-20  762.362637   9.0  연립다세대
# 3          3.0 2015-08-06  750.750751   9.0  연립다세대
# 4         27.0 2015-08-21  789.473684  33.0  연립다세대

# %%
officetel_df = data_prep('오피스텔', '매매')
officetel_df = officetel_df[(officetel_df['계약날짜'] >= pd.to_datetime('2015-01-01'))
                            #&(officetel_df['계약날짜기준_건물연식'] <= 5)
                           ]
officetel_df = officetel_df.reset_index(drop=True)
officetel_df['부동산유형'] = '오피스텔'
print(officetel_df.shape)
officetel_df.head()
# Out:
# 16it [00:00, 41.12it/s]
# (82013, 12)
#                  지번주소      도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)   층    건축년도  \
# 0  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    43.24     22000  14  1997.0
# 1  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44     15800  21  1997.0
# 2  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44     16000  10  1997.0
# 3  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44     15400  21  1997.0
# 4  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    31.91     16000  26  1997.0
#
#    계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식 부동산유형
# 0         18.0 2015-01-08  508.788159  24.0  오피스텔
# 1         18.0 2015-01-12  487.053021  24.0  오피스텔
# 2         18.0 2015-01-19  493.218249  24.0  오피스텔
# 3         18.0 2015-01-26  474.722565  24.0  오피스텔
# 4         18.0 2015-01-28  501.410216  24.0  오피스텔

# %%
apart_df = data_prep('아파트', '매매')
apart_df = apart_df[(apart_df['계약날짜'] >= pd.to_datetime('2015-01-01'))
                    #&(apart_df['계약날짜기준_건물연식'] <= 5)
                   ]
apart_df = apart_df.reset_index(drop=True)
apart_df['부동산유형'] = '아파트'
print(apart_df.shape)
apart_df.head()
# Out:
# 16it [00:02,  7.90it/s]
# (596180, 12)
#                   지번주소      도로명         건물(단지)명  전용면적(㎡)  거래금액(만원)  층  건축년도  \
# 0  서울특별시 강남구 개포동 655-2  언주로 103  개포2차현대아파트(220)    77.75     60000  5  1988
# 1  서울특별시 강남구 개포동 655-2  언주로 103  개포2차현대아파트(220)    77.75     65000  5  1988
# 2  서울특별시 강남구 개포동 655-2  언주로 103  개포2차현대아파트(220)    77.75     62500  2  1988
# 3  서울특별시 강남구 개포동 655-2  언주로 103  개포2차현대아파트(220)    77.75     68000  6  1988
# 4  서울특별시 강남구 개포동 658-1    언주로 3  개포6차우성아파트1동~8동    79.97     73000  5  1987
#
#    계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식 부동산유형
# 0           27 2015-01-11  771.704180    33   아파트
# 1           27 2015-03-03  836.012862    33   아파트
# 2           27 2015-03-07  803.858521    33   아파트
# 3           27 2015-08-16  874.598071    33   아파트
# 4           28 2015-01-29  912.842316    34   아파트

# %%
concat_df = pd.concat([yunrip_df, officetel_df, apart_df]).sort_values(['지번주소', '건축년도', '계약날짜', '전용면적(㎡)']).reset_index(drop=True)
print(concat_df.shape)
concat_df.head()
# Out:
# (997014, 12)
#                     지번주소       도로명      건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 0   서울특별시 강남구 개포동 1164-0   논현로2길 6         골드캐슬    58.05     57500  2  2017.0
# 1   서울특별시 강남구 개포동 1164-0   논현로2길 6         골드캐슬    58.05     57000  1  2017.0
# 2   서울특별시 강남구 개포동 1164-0   논현로2길 6         골드캐슬    58.05     63000  2  2017.0
# 3  서울특별시 강남구 개포동 1164-12  논현로2길 34  새롬(1164-12)    73.50     42000  3  2000.0
# 4  서울특별시 강남구 개포동 1164-12  논현로2길 34  새롬(1164-12)    73.50     55400  2  2000.0
#
#    계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형
# 0          1.0 2018-01-20   990.525409   4.0  연립다세대
# 1          1.0 2018-06-01   981.912145   4.0  연립다세대
# 2          2.0 2019-01-19  1085.271318   4.0  연립다세대
# 3         15.0 2015-07-28   571.428571  21.0    아파트
# 4         17.0 2017-07-21   753.741497  21.0    아파트

# %%
def find_bulktrade(df):
    idx_list = []
    for addr in tqdm(df['지번주소'].unique()):
        addr_df = df[df['지번주소'] == addr]
        
        for built_year in addr_df['건축년도'].unique():
            built_year_df = addr_df[addr_df['건축년도'] == built_year]

            for date in built_year_df['계약날짜'].unique():
                date_df = built_year_df[built_year_df['계약날짜'] == date]

                if date_df.shape[0] >= 10:
                    [idx_list.append(idx) for idx in date_df.index]
    
    selected_df = df.loc[idx_list,:]
    
    return selected_df

# %%
concat_selected_df = find_bulktrade(concat_df)
print(concat_selected_df.shape)
concat_selected_df.head()
# Out:
#  52%|███████████████████████████████████████▋                                    | 42050/80471 [36:47<33:37, 19.05it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-cd0676729235> in <module>
# ----> 1 concat_selected_df = find_bulktrade(concat_df)
#       2 print(concat_selected_df.shape)
#       3 concat_selected_df.head()
#
# <ipython-input-9-551591df398a> in find_bulktrade(df)
#       2     idx_list = []
#       3     for addr in tqdm(df['지번주소'].unique()):
# ----> 4         addr_df = df[df['지번주소'] == addr]
#       5
#       6         for built_year in addr_df['건축년도'].unique():
#
# c:\users\max6296\ml\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# c:\users\max6296\ml\lib\site-packages\pandas\core\arraylike.py in __eq__(self, other)
#      27     @unpack_zerodim_and_defer("__eq__")
#      28     def __eq__(self, other):
# ---> 29         return self._cmp_method(other, operator.eq)
#      30
#      31     @unpack_zerodim_and_defer("__ne__")
#
# c:\users\max6296\ml\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    4976         rvalues = extract_array(other, extract_numpy=True)
#    4977
# -> 4978         res_values = ops.comparison_op(lvalues, rvalues, op)
#    4979
#    4980         return self._construct_result(res_values, name=res_name)
#
# c:\users\max6296\ml\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     241
#     242     elif is_object_dtype(lvalues.dtype):
# --> 243         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     244
#     245     else:
#
# c:\users\max6296\ml\lib\site-packages\pandas\core\ops\array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      54     else:
#      55         result = libops.scalar_compare(x.ravel(), y, op)
# ---> 56     return result.reshape(x.shape)
#      57
#      58
#
# KeyboardInterrupt:

# %%
idx_to_drop = []
for addr in tqdm(concat_selected_df['지번주소'].unique()):
    addr_df = concat_selected_df[concat_selected_df['지번주소'] == addr]
    if addr_df['건축년도'].nunique() > 1:
        non_max_df = addr_df[addr_df['건축년도'] != addr_df['건축년도'].max()]
        [idx_to_drop.append(i) for i in non_max_df.index]

# %%
len(idx_to_drop)

# %%
concat_selected_df.shape

# %%
concat_selected_df = concat_selected_df.drop(idx_to_drop).reset_index(drop=True)
print(concat_selected_df.shape)
concat_selected_df.head()

# %%
bulktrade_basedir = './국토교통부_실거래가_공개시스템/집값분석/일괄구매/10호이상/'

# %%
# %%time
concat_selected_df.to_csv(bulktrade_basedir+'아파트_연립다세대_오피스텔_일괄구매_전체.csv')
# Out:
# Wall time: 355 ms

# %%
yunrip_officetel_complete_df = pd.read_excel(bulktrade_basedir + '2018년부터/2018년01월01일부터_2021년06월07일까지_SH_LH_거래사례_요약본_빠진애들_채워넣음.xlsx')
yunrip_officetel_complete_df = yunrip_officetel_complete_df.drop(columns=['Unnamed: 16'])
yunrip_officetel_complete_df['지번주소'] = '서울특별시 ' + yunrip_officetel_complete_df['지번주소']
print(yunrip_officetel_complete_df.shape)
yunrip_officetel_complete_df.head()
# Out:
# (829, 16)
#                     지번주소 건물(단지)명  건축년도       계약날짜  부동산유형 소유자  평균 전용면적(㎡)  \
# 0   서울특별시 강남구 개포동 1237-7     한별2  2021 2021-06-01   오피스텔  SH   29.665000
# 1   서울특별시 강남구 개포동 1237-7     한별2  2021 2021-06-01  연립다세대  SH   29.946667
# 2   서울특별시 강남구 개포동 1216-7     백년빌  2020 2020-03-18  연립다세대  SH   26.686000
# 3  서울특별시 강남구 개포동 1195-10     동영빌  2020 2020-03-02  연립다세대  SH   28.814667
# 4   서울특별시 강남구 개포동 1199-7   개포백년빌  2019 2019-12-19  연립다세대  LH   27.905000
#
#    총 전용면적(㎡)  전용면적 표준편차(㎡)   평균 거래금액(만원)  총 거래금액(만원)  거래금액 표준편차(만원)  최대 층  \
# 0     118.66      0.390000  33565.250000      134261     437.500000     2
# 1     449.20      0.037544  38163.333333      572450      44.185755     6
# 2     400.29      2.367074  30573.333333      458600    2134.651750     5
# 3     432.22      4.855684  31463.333333      471950    4139.637090     5
# 4     390.67      3.070186  28857.142857      404000    3536.722578     5
#
#      평균 단가(만원)  단가 표준편차(만원)  세대 수
# 0  1131.477759     0.128995     4
# 1  1274.376854     0.358219    15
# 2  1147.330195    25.484846    15
# 3  1097.178201    36.299709    15
# 4  1033.367584    37.609677    14

# %%
except_df = concat_selected_df[concat_selected_df['지번주소'].isin(yunrip_officetel_complete_df['지번주소'].unique()) == False]
print(except_df.shape)
except_df.head()

# %%
included_df = concat_selected_df[concat_selected_df['지번주소'].isin(yunrip_officetel_complete_df['지번주소'].unique())]
print(included_df.shape)
included_df.head()

# %%
count = 0
for addr in included_df['지번주소'].unique():
    addr_df = included_df[included_df['지번주소'] == addr]
    
    if '아파트' in addr_df['부동산유형'].unique():
        print(addr)
        print(addr_df.shape)
        display(addr_df)
        count += 1
    
    if count > 5:
        break

# %%
count = 0
for addr in concat_selected_df['지번주소'].unique():
    addr_df = concat_selected_df[concat_selected_df['지번주소'] == addr]
    
    
    if '아파트' in addr_df['부동산유형'].unique():
        print(addr)
        print(addr_df.shape)
        display(addr_df.head(20))

        count += 1
    
    if count > 5:
        break
# Out:
# 서울특별시 강남구 논현동 9-2
# (13, 13)
#                   지번주소         도로명    건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 685  서울특별시 강남구 논현동 9-2  도산대로24길 19  논현인텔(9-2)    17.22     18773  4  1996.0
# 686  서울특별시 강남구 논현동 9-2  도산대로24길 19  논현인텔(9-2)    21.24     23153  2  1996.0
# 687  서울특별시 강남구 논현동 9-2  도산대로24길 19  논현인텔(9-2)    21.24     23153  3  1996.0
# 688  서울특별시 강남구 논현동 9-2  도산대로24길 19  논현인텔(9-2)    21.84     23803  5  1996.0
# 689  서울특별시 강남구 논현동 9-2  도산대로24길 19  논현인텔(9-2)    21.84     23803  3  1996.0
# 690  서울특별시 강남구 논현동 9-2  도산대로24길 19  논현인텔(9-2)    21.84     23803  2  1996.0
# 691  서울특별시 강남구 논현동 9-2  도산대로24길 19  논현인텔(9-2)    22.05     24033  5  1996.0
# 692  서울특별시 강남구 논현동 9-2  도산대로24길 19  논현인텔(9-2)    23.10     25179  5  1996.0
# 693  서울특별시 강남구 논현동 9-2  도산대로24길 19  논현인텔(9-2)    31.11     33912  5  1996.0
# 694  서울특별시 강남구 논현동 9-2  도산대로24길 19  논현인텔(9-2)    33.32     36322  3  1996.0
# 695  서울특별시 강남구 논현동 9-2  도산대로24길 19  논현인텔(9-2)    33.32     36322  4  1996.0
# 696  서울특별시 강남구 논현동 9-2  도산대로24길 19  논현인텔(9-2)    45.16     49226  3  1996.0
# 697  서울특별시 강남구 논현동 9-2  도산대로24길 19  논현인텔(9-2)    83.45     90963  4  1996.0
#
#      계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식 부동산유형  소유자
# 685         23.0 2019-03-28  1090.185830  25.0   아파트  NaN
# 686         23.0 2019-03-28  1090.065913  25.0   아파트  NaN
# 687         23.0 2019-03-28  1090.065913  25.0   아파트  NaN
# 688         23.0 2019-03-28  1089.880952  25.0   아파트  NaN
# 689         23.0 2019-03-28  1089.880952  25.0   아파트  NaN
# 690         23.0 2019-03-28  1089.880952  25.0   아파트  NaN
# 691         23.0 2019-03-28  1089.931973  25.0   아파트  NaN
# 692         23.0 2019-03-28  1090.000000  25.0   아파트  NaN
# 693         23.0 2019-03-28  1090.067502  25.0   아파트  NaN
# 694         23.0 2019-03-28  1090.096038  25.0   아파트  NaN
# 695         23.0 2019-03-28  1090.096038  25.0   아파트  NaN
# 696         23.0 2019-03-28  1090.035430  25.0   아파트  NaN
# 697         23.0 2019-03-28  1090.029958  25.0   아파트  NaN
# 서울특별시 강남구 삼성동 3-1
# (56, 13)
#                    지번주소      도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)   층    건축년도  \
# 1008  서울특별시 강남구 삼성동 3-1  학동로 408  삼성월드타워   58.776     69000   2  1997.0
# 1009  서울특별시 강남구 삼성동 3-1  학동로 408  삼성월드타워   58.776     67000   2  1997.0
# 1010  서울특별시 강남구 삼성동 3-1  학동로 408  삼성월드타워   58.776     70000   3  1997.0
# 1011  서울특별시 강남구 삼성동 3-1  학동로 408  삼성월드타워   58.776     70000   3  1997.0
# 1012  서울특별시 강남구 삼성동 3-1  학동로 408  삼성월드타워   58.776     71000   4  1997.0
# 1013  서울특별시 강남구 삼성동 3-1  학동로 408  삼성월드타워   58.776     70000   4  1997.0
# 1014  서울특별시 강남구 삼성동 3-1  학동로 408  삼성월드타워   58.776     74000  10  1997.0
# 1015  서울특별시 강남구 삼성동 3-1  학동로 408  삼성월드타워   58.776     74000  10  1997.0
# 1016  서울특별시 강남구 삼성동 3-1  학동로 408  삼성월드타워   58.776     74000   5  1997.0
# 1017  서울특별시 강남구 삼성동 3-1  학동로 408  삼성월드타워   58.776     74000   5  1997.0
# 1018  서울특별시 강남구 삼성동 3-1  학동로 408  삼성월드타워   58.776     74000   6  1997.0
# 1019  서울특별시 강남구 삼성동 3-1  학동로 408  삼성월드타워   58.776     74000   6  1997.0
# 1020  서울특별시 강남구 삼성동 3-1  학동로 408  삼성월드타워   58.776     74000   7  1997.0
# 1021  서울특별시 강남구 삼성동 3-1  학동로 408  삼성월드타워   58.776     72000   7  1997.0
# 1022  서울특별시 강남구 삼성동 3-1  학동로 408  삼성월드타워   58.776     73000   8  1997.0
# 1023  서울특별시 강남구 삼성동 3-1  학동로 408  삼성월드타워   58.776     74000   9  1997.0
# 1024  서울특별시 강남구 삼성동 3-1  학동로 408  삼성월드타워   58.776     74000   9  1997.0
# 1025  서울특별시 강남구 삼성동 3-1  학동로 408  삼성월드타워   58.776     74000   8  1997.0
# 1026  서울특별시 강남구 삼성동 3-1  학동로 408  삼성월드타워   58.776     74000  11  1997.0
# 1027  서울특별시 강남구 삼성동 3-1  학동로 408  삼성월드타워   58.776     74000  11  1997.0
#
#       계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식 부동산유형  소유자
# 1008         23.0 2020-06-19  1173.948550  24.0   아파트  NaN
# 1009         23.0 2020-06-19  1139.921056  24.0   아파트  NaN
# 1010         23.0 2020-06-19  1190.962298  24.0   아파트  NaN
# 1011         23.0 2020-06-19  1190.962298  24.0   아파트  NaN
# 1012         23.0 2020-06-19  1207.976045  24.0   아파트  NaN
# 1013         23.0 2020-06-19  1190.962298  24.0   아파트  NaN
# 1014         23.0 2020-06-19  1259.017286  24.0   아파트  NaN
# 1015         23.0 2020-06-19  1259.017286  24.0   아파트  NaN
# 1016         23.0 2020-06-19  1259.017286  24.0   아파트  NaN
# 1017         23.0 2020-06-19  1259.017286  24.0   아파트  NaN
# 1018         23.0 2020-06-19  1259.017286  24.0   아파트  NaN
# 1019         23.0 2020-06-19  1259.017286  24.0   아파트  NaN
# 1020         23.0 2020-06-19  1259.017286  24.0   아파트  NaN
# 1021         23.0 2020-06-19  1224.989792  24.0   아파트  NaN
# 1022         23.0 2020-06-19  1242.003539  24.0   아파트  NaN
# 1023         23.0 2020-06-19  1259.017286  24.0   아파트  NaN
# 1024         23.0 2020-06-19  1259.017286  24.0   아파트  NaN
# 1025         23.0 2020-06-19  1259.017286  24.0   아파트  NaN
# 1026         23.0 2020-06-19  1259.017286  24.0   아파트  NaN
# 1027         23.0 2020-06-19  1259.017286  24.0   아파트  NaN
# 서울특별시 강남구 역삼동 831-29
# (63, 13)
#                       지번주소         도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)   층    건축년도  \
# 2555  서울특별시 강남구 역삼동 831-29  역삼로3길 17-4     에레프    14.31     17505   4  2013.0
# 2556  서울특별시 강남구 역삼동 831-29  역삼로3길 17-4     에레프    14.31     17505   9  2013.0
# 2557  서울특별시 강남구 역삼동 831-29  역삼로3길 17-4     에레프    14.31     17505  10  2013.0
# 2558  서울특별시 강남구 역삼동 831-29  역삼로3길 17-4     에레프    14.31     17505   4  2013.0
# 2559  서울특별시 강남구 역삼동 831-29  역삼로3길 17-4     에레프    14.31     17505   4  2013.0
# 2560  서울특별시 강남구 역삼동 831-29  역삼로3길 17-4     에레프    14.31     17505   5  2013.0
# 2561  서울특별시 강남구 역삼동 831-29  역삼로3길 17-4     에레프    14.31     17505   5  2013.0
# 2562  서울특별시 강남구 역삼동 831-29  역삼로3길 17-4     에레프    14.31     17505   5  2013.0
# 2563  서울특별시 강남구 역삼동 831-29  역삼로3길 17-4     에레프    14.31     17505   5  2013.0
# 2564  서울특별시 강남구 역삼동 831-29  역삼로3길 17-4     에레프    14.31     17505   5  2013.0
# 2565  서울특별시 강남구 역삼동 831-29  역삼로3길 17-4     에레프    14.31     17505   5  2013.0
# 2566  서울특별시 강남구 역삼동 831-29  역삼로3길 17-4     에레프    14.31     17505   6  2013.0
# 2567  서울특별시 강남구 역삼동 831-29  역삼로3길 17-4     에레프    14.31     17505   6  2013.0
# 2568  서울특별시 강남구 역삼동 831-29  역삼로3길 17-4     에레프    14.31     17505   6  2013.0
# 2569  서울특별시 강남구 역삼동 831-29  역삼로3길 17-4     에레프    14.31     17505   6  2013.0
# 2570  서울특별시 강남구 역삼동 831-29  역삼로3길 17-4     에레프    14.31     17505   9  2013.0
# 2571  서울특별시 강남구 역삼동 831-29  역삼로3길 17-4     에레프    14.31     17505  10  2013.0
# 2572  서울특별시 강남구 역삼동 831-29  역삼로3길 17-4     에레프    14.31     17505  10  2013.0
# 2573  서울특별시 강남구 역삼동 831-29  역삼로3길 17-4     에레프    14.31     17505  10  2013.0
# 2574  서울특별시 강남구 역삼동 831-29  역삼로3길 17-4     에레프    14.31     17505  10  2013.0
#
#       계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식 부동산유형  소유자
# 2555          3.0 2016-10-27  1223.27044   8.0   아파트  NaN
# 2556          3.0 2016-10-27  1223.27044   8.0   아파트  NaN
# 2557          3.0 2016-10-27  1223.27044   8.0   아파트  NaN
# 2558          3.0 2016-10-27  1223.27044   8.0   아파트  NaN
# 2559          3.0 2016-10-27  1223.27044   8.0   아파트  NaN
# 2560          3.0 2016-10-27  1223.27044   8.0   아파트  NaN
# 2561          3.0 2016-10-27  1223.27044   8.0   아파트  NaN
# 2562          3.0 2016-10-27  1223.27044   8.0   아파트  NaN
# 2563          3.0 2016-10-27  1223.27044   8.0   아파트  NaN
# 2564          3.0 2016-10-27  1223.27044   8.0   아파트  NaN
# 2565          3.0 2016-10-27  1223.27044   8.0   아파트  NaN
# 2566          3.0 2016-10-27  1223.27044   8.0   아파트  NaN
# 2567          3.0 2016-10-27  1223.27044   8.0   아파트  NaN
# 2568          3.0 2016-10-27  1223.27044   8.0   아파트  NaN
# 2569          3.0 2016-10-27  1223.27044   8.0   아파트  NaN
# 2570          3.0 2016-10-27  1223.27044   8.0   아파트  NaN
# 2571          3.0 2016-10-27  1223.27044   8.0   아파트  NaN
# 2572          3.0 2016-10-27  1223.27044   8.0   아파트  NaN
# 2573          3.0 2016-10-27  1223.27044   8.0   아파트  NaN
# 2574          3.0 2016-10-27  1223.27044   8.0   아파트  NaN
# 서울특별시 강남구 역삼동 835-33
# (13, 13)
#                       지번주소        도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 2630  서울특별시 강남구 역삼동 835-33  도곡로11길 10  광평하우스빌    29.28     15132  4  1997.0
# 2631  서울특별시 강남구 역삼동 835-33  도곡로11길 10  광평하우스빌    29.28     15132  3  1997.0
# 2632  서울특별시 강남구 역삼동 835-33  도곡로11길 10  광평하우스빌    29.28     15132  5  1997.0
# 2633  서울특별시 강남구 역삼동 835-33  도곡로11길 10  광평하우스빌    35.68     18421  4  1997.0
# 2634  서울특별시 강남구 역삼동 835-33  도곡로11길 10  광평하우스빌    35.68     18421  3  1997.0
# 2635  서울특별시 강남구 역삼동 835-33  도곡로11길 10  광평하우스빌    35.68     18421  5  1997.0
# 2636  서울특별시 강남구 역삼동 835-33  도곡로11길 10  광평하우스빌    42.13     21711  4  1997.0
# 2637  서울특별시 강남구 역삼동 835-33  도곡로11길 10  광평하우스빌    42.13     21711  5  1997.0
# 2638  서울특별시 강남구 역삼동 835-33  도곡로11길 10  광평하우스빌    42.13     21711  3  1997.0
# 2639  서울특별시 강남구 역삼동 835-33  도곡로11길 10  광평하우스빌    45.30     23520  3  1997.0
# 2640  서울특별시 강남구 역삼동 835-33  도곡로11길 10  광평하우스빌    45.30     23520  4  1997.0
# 2641  서울특별시 강남구 역삼동 835-33  도곡로11길 10  광평하우스빌    45.30     23520  5  1997.0
# 2642  서울특별시 강남구 역삼동 835-33  도곡로11길 10  광평하우스빌   132.75     64475  6  1997.0
#
#       계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식 부동산유형  소유자
# 2630         20.0 2017-04-29  516.803279  24.0   아파트  NaN
# 2631         20.0 2017-04-29  516.803279  24.0   아파트  NaN
# 2632         20.0 2017-04-29  516.803279  24.0   아파트  NaN
# 2633         20.0 2017-04-29  516.283632  24.0   아파트  NaN
# 2634         20.0 2017-04-29  516.283632  24.0   아파트  NaN
# 2635         20.0 2017-04-29  516.283632  24.0   아파트  NaN
# 2636         20.0 2017-04-29  515.333492  24.0   아파트  NaN
# 2637         20.0 2017-04-29  515.333492  24.0   아파트  NaN
# 2638         20.0 2017-04-29  515.333492  24.0   아파트  NaN
# 2639         20.0 2017-04-29  519.205298  24.0   아파트  NaN
# 2640         20.0 2017-04-29  519.205298  24.0   아파트  NaN
# 2641         20.0 2017-04-29  519.205298  24.0   아파트  NaN
# 2642         20.0 2017-04-29  485.687382  24.0   아파트  NaN
# 서울특별시 강남구 역삼동 837-31
# (30, 13)
#                       지번주소       도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 2643  서울특별시 강남구 역삼동 837-31  도곡로1길 22   경민리빙텔    31.62     36755  4  1998.0
# 2644  서울특별시 강남구 역삼동 837-31  도곡로1길 22   경민리빙텔    31.62     36755  4  1998.0
# 2645  서울특별시 강남구 역삼동 837-31  도곡로1길 22   경민리빙텔    31.62     37852  5  1998.0
# 2646  서울특별시 강남구 역삼동 837-31  도곡로1길 22   경민리빙텔    31.62     37852  7  1998.0
# 2647  서울특별시 강남구 역삼동 837-31  도곡로1길 22   경민리빙텔    31.62     37852  8  1998.0
# 2648  서울특별시 강남구 역삼동 837-31  도곡로1길 22   경민리빙텔    31.62     37852  8  1998.0
# 2649  서울특별시 강남구 역삼동 837-31  도곡로1길 22   경민리빙텔    31.62     37852  9  1998.0
# 2650  서울특별시 강남구 역삼동 837-31  도곡로1길 22   경민리빙텔    31.62     37852  5  1998.0
# 2651  서울특별시 강남구 역삼동 837-31  도곡로1길 22   경민리빙텔    31.62     37852  6  1998.0
# 2652  서울특별시 강남구 역삼동 837-31  도곡로1길 22   경민리빙텔    31.62     37852  9  1998.0
# 2653  서울특별시 강남구 역삼동 837-31  도곡로1길 22   경민리빙텔    31.62     37852  6  1998.0
# 2654  서울특별시 강남구 역삼동 837-31  도곡로1길 22   경민리빙텔    31.62     37852  7  1998.0
# 2655  서울특별시 강남구 역삼동 837-31  도곡로1길 22   경민리빙텔    31.62     35383  3  1998.0
# 2656  서울특별시 강남구 역삼동 837-31  도곡로1길 22   경민리빙텔    31.62     35383  3  1998.0
# 2657  서울특별시 강남구 역삼동 837-31  도곡로1길 22   경민리빙텔    38.28     43612  4  1998.0
# 2658  서울특별시 강남구 역삼동 837-31  도곡로1길 22   경민리빙텔    38.28     43612  4  1998.0
# 2659  서울특별시 강남구 역삼동 837-31  도곡로1길 22   경민리빙텔    38.28     44709  8  1998.0
# 2660  서울특별시 강남구 역삼동 837-31  도곡로1길 22   경민리빙텔    38.28     44709  8  1998.0
# 2661  서울특별시 강남구 역삼동 837-31  도곡로1길 22   경민리빙텔    38.28     44709  5  1998.0
# 2662  서울특별시 강남구 역삼동 837-31  도곡로1길 22   경민리빙텔    38.28     44709  5  1998.0
#
#       계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식 부동산유형  소유자
# 2643         22.0 2020-05-29  1162.397217  23.0   아파트  NaN
# 2644         22.0 2020-05-29  1162.397217  23.0   아파트  NaN
# 2645         22.0 2020-05-29  1197.090449  23.0   아파트  NaN
# 2646         22.0 2020-05-29  1197.090449  23.0   아파트  NaN
# 2647         22.0 2020-05-29  1197.090449  23.0   아파트  NaN
# 2648         22.0 2020-05-29  1197.090449  23.0   아파트  NaN
# 2649         22.0 2020-05-29  1197.090449  23.0   아파트  NaN
# 2650         22.0 2020-05-29  1197.090449  23.0   아파트  NaN
# 2651         22.0 2020-05-29  1197.090449  23.0   아파트  NaN
# 2652         22.0 2020-05-29  1197.090449  23.0   아파트  NaN
# 2653         22.0 2020-05-29  1197.090449  23.0   아파트  NaN
# 2654         22.0 2020-05-29  1197.090449  23.0   아파트  NaN
# 2655         22.0 2020-05-29  1119.006958  23.0   아파트  NaN
# 2656         22.0 2020-05-29  1119.006958  23.0   아파트  NaN
# 2657         22.0 2020-05-29  1139.289446  23.0   아파트  NaN
# 2658         22.0 2020-05-29  1139.289446  23.0   아파트  NaN
# 2659         22.0 2020-05-29  1167.946708  23.0   아파트  NaN
# 2660         22.0 2020-05-29  1167.946708  23.0   아파트  NaN
# 2661         22.0 2020-05-29  1167.946708  23.0   아파트  NaN
# 2662         22.0 2020-05-29  1167.946708  23.0   아파트  NaN
# 서울특별시 강동구 길동 343-1
# (27, 13)
#                     지번주소       도로명      건물(단지)명  전용면적(㎡)  거래금액(만원)   층  \
# 2949  서울특별시 강동구 길동 343-1  천중로53길 6  현대웰하임(101동)   16.959     13600  11
# 2950  서울특별시 강동구 길동 343-1  천중로53길 6  현대웰하임(101동)   16.959     13600  11
# 2951  서울특별시 강동구 길동 343-1  천중로53길 6  현대웰하임(101동)   16.959     13600  12
# 2952  서울특별시 강동구 길동 343-1  천중로53길 6  현대웰하임(101동)   16.959     13900  12
# 2953  서울특별시 강동구 길동 343-1  천중로53길 6  현대웰하임(101동)   16.959     13900  12
# 2954  서울특별시 강동구 길동 343-1  천중로53길 6  현대웰하임(101동)   16.959     13600  13
# 2955  서울특별시 강동구 길동 343-1  천중로53길 6  현대웰하임(101동)   16.959     13900  15
# 2956  서울특별시 강동구 길동 343-1  천중로53길 6  현대웰하임(101동)   16.959     13600  13
# 2957  서울특별시 강동구 길동 343-1  천중로53길 6  현대웰하임(101동)   16.959     13600  14
# 2958  서울특별시 강동구 길동 343-1  천중로53길 6  현대웰하임(101동)   16.959     13600  15
# 2959  서울특별시 강동구 길동 343-1  천중로53길 6  현대웰하임(101동)   16.959     13600  15
# 2960  서울특별시 강동구 길동 343-1  천중로53길 6  현대웰하임(101동)   16.959     13000   2
# 2961  서울특별시 강동구 길동 343-1  천중로53길 6  현대웰하임(101동)   16.959     13300   7
# 2962  서울특별시 강동구 길동 343-1  천중로53길 6  현대웰하임(101동)   16.959     13000   2
# 2963  서울특별시 강동구 길동 343-1  천중로53길 6  현대웰하임(101동)   16.959     13300   5
# 2964  서울특별시 강동구 길동 343-1  천중로53길 6  현대웰하임(101동)   16.959     13300   6
# 2965  서울특별시 강동구 길동 343-1  천중로53길 6  현대웰하임(101동)   16.959     13600   6
# 2966  서울특별시 강동구 길동 343-1  천중로53길 6  현대웰하임(101동)   16.959     13600   7
# 2967  서울특별시 강동구 길동 343-1  천중로53길 6  현대웰하임(101동)   16.959     13300   8
# 2968  서울특별시 강동구 길동 343-1  천중로53길 6  현대웰하임(101동)   16.959     13300   9
#
#         건축년도  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식 부동산유형  소유자
# 2949  2012.0          7.0 2019-10-31  801.934076   9.0   아파트  NaN
# 2950  2012.0          7.0 2019-10-31  801.934076   9.0   아파트  NaN
# 2951  2012.0          7.0 2019-10-31  801.934076   9.0   아파트  NaN
# 2952  2012.0          7.0 2019-10-31  819.623799   9.0   아파트  NaN
# 2953  2012.0          7.0 2019-10-31  819.623799   9.0   아파트  NaN
# 2954  2012.0          7.0 2019-10-31  801.934076   9.0   아파트  NaN
# 2955  2012.0          7.0 2019-10-31  819.623799   9.0   아파트  NaN
# 2956  2012.0          7.0 2019-10-31  801.934076   9.0   아파트  NaN
# 2957  2012.0          7.0 2019-10-31  801.934076   9.0   아파트  NaN
# 2958  2012.0          7.0 2019-10-31  801.934076   9.0   아파트  NaN
# 2959  2012.0          7.0 2019-10-31  801.934076   9.0   아파트  NaN
# 2960  2012.0          7.0 2019-10-31  766.554632   9.0   아파트  NaN
# 2961  2012.0          7.0 2019-10-31  784.244354   9.0   아파트  NaN
# 2962  2012.0          7.0 2019-10-31  766.554632   9.0   아파트  NaN
# 2963  2012.0          7.0 2019-10-31  784.244354   9.0   아파트  NaN
# 2964  2012.0          7.0 2019-10-31  784.244354   9.0   아파트  NaN
# 2965  2012.0          7.0 2019-10-31  801.934076   9.0   아파트  NaN
# 2966  2012.0          7.0 2019-10-31  801.934076   9.0   아파트  NaN
# 2967  2012.0          7.0 2019-10-31  784.244354   9.0   아파트  NaN
# 2968  2012.0          7.0 2019-10-31  784.244354   9.0   아파트  NaN

# %%
concat_selected_df['소유자'] = np.nan

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
driver.get("http://www.iros.go.kr/PMainJ.jsp")

# %%
driver.get("http://www.iros.go.kr/frontservlet?cmd=RISUWelcomeViewC")

# %%
def get_owner_name(df):
    df = df.copy()
    
    count = 0
    for addr in tqdm(df['지번주소'].unique()):
        owner_name = np.nan
        addr = addr.replace('-0', '')
        
        addr_df = df[df['지번주소'] == addr]
        driver.switch_to.default_content()
        
        
        driver.switch_to.frame("inputFrame")
        
        elem_search = driver.find_element_by_xpath('html/body/form[1]/div[24]/div/div/div/fieldset/div/table/tbody/tr[5]/td/span/input')
        elem_search.clear()
        elem_search.send_keys(addr)
        elem_search.send_keys(Keys.RETURN)
        time.sleep(2)
        
        try:
            driver.switch_to.alert.accept()
        except:
            pass
        
        driver.switch_to.default_content()
        driver.switch_to.frame('resultFrame')
        driver.switch_to.frame('frmOuterModal')
        
        try:
            driver.find_element_by_xpath('/html/body/div[2]/div[2]/table/tbody/tr[3]/td[6]/button').click()
        except:
            continue
        
        time.sleep(0.5)
        
        elem_result = driver.find_element_by_xpath('/html/body/div[2]/div[2]/table/tbody/tr/td[3]')
        
        owner_name = elem_result.text
        
        driver.switch_to.default_content()
        
        df.loc[addr_df.index, '소유자'] = owner_name
        
        count += 1
    
    return df

# %%
prac_df = get_owner_name(concat_selected_df)

# %%
concat_selected_df = prac_df.copy()

# %%
driver.close()

# %%
concat_selected_df.reset_index(drop=True, inplace=True)

# %%
concat_selected_df.to_csv(bulktrade_basedir+'연립다세대_오피스텔_일괄구매_전체_소유자_포함.csv', index=False)

# %%
yunrip_selected_df.head()

# %%
yunrip_selected_df['소유자'].value_counts()

# %%
inv_df = yunrip_selected_df[
    yunrip_selected_df['소유자'] == '에***~'
]
print(inv_df.shape)
inv_df.head()

# %%
count = 0
for addr in inv_df['지번주소'].unique():
    addr_df = inv_df[inv_df['지번주소'] == addr]
    
    print(addr_df.shape)
    display(addr_df)
    
    count += 1
    if count > 5:
        break

# %%
print(yunrip_selected_df.shape)
yunrip_selected_df = yunrip_selected_df[
    (yunrip_selected_df['소유자'] == '서***~')
    |(yunrip_selected_df['소유자'] == '한***~')
    |(yunrip_selected_df['소유자'] == '에***~')
]
print(yunrip_selected_df.shape)
yunrip_selected_df.head()

# %%
officetel_selected_df['소유자'].value_counts()

# %%
inv_df = officetel_selected_df[
    officetel_selected_df['소유자'] == '중***~'
]
print(inv_df.shape)
inv_df.head()

# %%
count = 0
for addr in inv_df['지번주소'].unique():
    addr_df = inv_df[inv_df['지번주소'] == addr]
    
    print(addr_df.shape)
    display(addr_df)
    
    count += 1
    if count > 5:
        break

# %%
officetel_selected_df = officetel_selected_df[
    (officetel_selected_df['소유자'] == '서***~')
    |(officetel_selected_df['소유자'] == '한***~')
]
print(officetel_selected_df.shape)
officetel_selected_df.head()

# %%
count = 0
for addr in officetel_selected_df['지번주소'].unique():
    addr_df = officetel_selected_df[officetel_selected_df['지번주소'] == addr]
    
    print(addr_df.shape)
    display(addr_df)
    
    count += 1
    if count > 5:
        break

# %%
yunrip_selected_df['지번주소'].nunique()

# %%
yunrip_selected_df.head()

# %%
yunrip_selected_df['구'] = yunrip_selected_df['지번주소'].apply(lambda x: x.split(' ')[1])
yunrip_selected_df['동'] = yunrip_selected_df['지번주소'].apply(lambda x: x.split(' ')[2])

# %%
yunrip_selected_df.head()

# %%
yunrip_selected_df['구'].value_counts()

# %%
def mean_prices_per_size(df):
    df = df.copy()
    
    df['크기별_평균단가'] = df[['지번주소', '건축년도', '계약날짜', '전용면적(㎡)', '단가(만원/㎡)']].groupby(['지번주소', '건축년도', '계약날짜', '전용면적(㎡)']).transform('mean')['단가(만원/㎡)']
    df['크기별_평균총액'] = df[['지번주소', '건축년도', '계약날짜', '전용면적(㎡)', '거래금액(만원)']].groupby(['지번주소', '건축년도', '계약날짜', '전용면적(㎡)']).transform('mean')['거래금액(만원)']
    df = df[['지번주소', '건축년도', '건물연식', '계약날짜', '계약날짜기준_건물연식', '전용면적(㎡)', '크기별_평균총액', '크기별_평균단가']]
    df = df.drop_duplicates().reset_index(drop=True)
    
    return df

# %%
yunrip_short_df = mean_prices_per_size(yunrip_selected_df)
print(yunrip_short_df.shape)
yunrip_short_df.head()
