# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
pd.options.mode.chained_assignment = None  # default='warn'
plt.rcParams['font.family'] = 'Malgun Gothic'
import datetime
import time
import math

# %%
def get_gu_dong(df):
    df = df.copy()
    
    df['구'] = df['지번주소'].apply(lambda x: x.split(' ')[1])
    df['동'] = df['지번주소'].apply(lambda x: x.split(' ')[2])
    
    return df

# %%
bulktrade_basedir = './국토교통부_실거래가_공개시스템/집값분석/일괄구매/10호이상/'

# %%
date_today = pd.to_datetime(datetime.datetime.now())
target_period = 6 # in months

# %%
concat_df = pd.read_csv(bulktrade_basedir+'연립다세대_오피스텔_일괄구매_전체_소유자_포함.csv')
missing_df = pd.read_csv(bulktrade_basedir+'빠진애들_채워넣음.csv')

# %%
concat_df.head()
# Out:
#                     지번주소         도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 0  서울특별시 강남구 개포동 1174-11  논현로6길 26-9   지호빌라B    32.89     24050  3  2016.0
# 1  서울특별시 강남구 개포동 1174-11  논현로6길 26-9   지호빌라B    32.89     24050  2  2016.0
# 2  서울특별시 강남구 개포동 1174-11  논현로6길 26-9   지호빌라B    33.06     22950  5  2016.0
# 3  서울특별시 강남구 개포동 1174-11  논현로6길 26-9   지호빌라B    39.91     28950  3  2016.0
# 4  서울특별시 강남구 개포동 1174-11  논현로6길 26-9   지호빌라B    39.91     28950  2  2016.0
#
#    계약날짜기준_건물연식        계약날짜    단가(만원/㎡)  건물연식  부동산유형    소유자
# 0          0.0  2016-11-29  731.225296   5.0  연립다세대  서***~
# 1          0.0  2016-11-29  731.225296   5.0  연립다세대  서***~
# 2          0.0  2016-11-29  694.192377   5.0  연립다세대  서***~
# 3          0.0  2016-11-29  725.382110   5.0  연립다세대  서***~
# 4          0.0  2016-11-29  725.382110   5.0  연립다세대  서***~

# %%
missing_df.head()
# Out:
#                   지번주소        도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 0  서울특별시 강남구 세곡동 582-0  헌릉로571길 7    강남레체    23.55     17000  5  2016.0
# 1  서울특별시 강남구 세곡동 582-0  헌릉로571길 7    강남레체    28.64     21000  5  2016.0
# 2  서울특별시 강남구 세곡동 582-0  헌릉로571길 7    강남레체    28.64     21000  6  2016.0
# 3  서울특별시 강남구 세곡동 582-0  헌릉로571길 7    강남레체    28.64     21000  8  2016.0
# 4  서울특별시 강남구 세곡동 582-0  헌릉로571길 7    강남레체    28.64     21000  5  2016.0
#
#    계약날짜기준_건물연식        계약날짜    단가(만원/㎡)  건물연식 부동산유형       소유자    구    동
# 0          2.0  2018-01-04  721.868365   5.0  오피스텔  주식회사하***  강남구  세곡동
# 1          2.0  2018-01-04  733.240223   5.0  오피스텔  주식회사하***  강남구  세곡동
# 2          2.0  2018-01-04  733.240223   5.0  오피스텔  주식회사하***  강남구  세곡동
# 3          2.0  2018-01-04  733.240223   5.0  오피스텔  주식회사하***  강남구  세곡동
# 4          2.0  2018-01-04  733.240223   5.0  오피스텔  주식회사하***  강남구  세곡동

# %%
missing_df = missing_df.drop(columns=['구', '동'])

# %%
concat_df = concat_df[concat_df['지번주소'].isin(missing_df['지번주소'].unique()) == False]
print(concat_df.shape)
# Out:
# (28060, 13)

# %%
concat_df = pd.concat([concat_df, missing_df])

concat_df['계약날짜'] = pd.to_datetime(concat_df['계약날짜'])
#yunrip_bulk_df = yunrip_bulk_df[yunrip_bulk_df['계약날짜']  >= (date_today - pd.DateOffset(months=target_period))]
concat_df = concat_df[
    (concat_df['소유자'] == '서***~')
    |(concat_df['소유자'] == '한***~')
].reset_index(drop=True)
concat_df = get_gu_dong(concat_df)
print(concat_df.shape)
concat_df.head()
# Out:
# (18126, 15)
#                     지번주소         도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 0  서울특별시 강남구 개포동 1174-11  논현로6길 26-9   지호빌라B    32.89     24050  3  2016.0
# 1  서울특별시 강남구 개포동 1174-11  논현로6길 26-9   지호빌라B    32.89     24050  2  2016.0
# 2  서울특별시 강남구 개포동 1174-11  논현로6길 26-9   지호빌라B    33.06     22950  5  2016.0
# 3  서울특별시 강남구 개포동 1174-11  논현로6길 26-9   지호빌라B    39.91     28950  3  2016.0
# 4  서울특별시 강남구 개포동 1174-11  논현로6길 26-9   지호빌라B    39.91     28950  2  2016.0
#
#    계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형    소유자    구    동
# 0          0.0 2016-11-29  731.225296   5.0  연립다세대  서***~  강남구  개포동
# 1          0.0 2016-11-29  731.225296   5.0  연립다세대  서***~  강남구  개포동
# 2          0.0 2016-11-29  694.192377   5.0  연립다세대  서***~  강남구  개포동
# 3          0.0 2016-11-29  725.382110   5.0  연립다세대  서***~  강남구  개포동
# 4          0.0 2016-11-29  725.382110   5.0  연립다세대  서***~  강남구  개포동

# %%
sales_idx_basedir = './한국부동산원/실거래가격지수/'
filenames = [f for f in os.listdir(sales_idx_basedir) if '연립다세대' in f]

sales_idx_df = pd.read_excel(sales_idx_basedir + filenames[0], header=[10, 11])

sales_idx_cols_list = []
for i in range(sales_idx_df.shape[1]):
    if i == 0:
        sales_idx_cols_list.append(sales_idx_df.columns[i][0])
    else:
        sales_idx_cols_list.append(sales_idx_df.columns[i][0] + '_' + sales_idx_df.columns[i][1])

sales_idx_df.columns = sales_idx_cols_list

# %%
def get_sales_idx(x):
    # x is a pandas timestamp
    
    df = sales_idx_df.copy()
    
    if pd.isna(x) == True:
        return x
    else:
        year = str(x.year)
        month = str(x.month)
        if len(month) == 1:
            month = '0'+month
        
        idx = df[year+'년 '+month+'월_지수'].iloc[0]
        
        return idx

# %%
def get_index_applied_prices(df):
    df = df.copy()
    
    last_idx = sales_idx_df.iloc[0,-2]
    
    last_date = sales_idx_df.columns[-1].split('_')[0]
    
    last_date = last_date.split(' ')[0].replace('년','') + '-' + last_date.split(' ')[1].replace('월','') + '-01'
    
    target_upper_limit_df = df[df['계약날짜'] < pd.to_datetime(last_date)]
    target_upper_limit_df['계약날짜_실거래지수'] = target_upper_limit_df['계약날짜'].apply(get_sales_idx)
    target_upper_limit_df['지수적용단가'] = target_upper_limit_df['단가(만원/㎡)'] / target_upper_limit_df['계약날짜_실거래지수'] * last_idx
    df['지수적용단가'] = df['단가(만원/㎡)']
    df.loc[target_upper_limit_df.index, '지수적용단가'] = target_upper_limit_df['지수적용단가']
    df['평가날짜'] = df['계약날짜']
    df.loc[target_upper_limit_df.index, '평가날짜'] = pd.to_datetime(last_date[:-2] + '01')
    
    return df

# %%
concat_df = get_index_applied_prices(concat_df)
print(concat_df.shape)
concat_df.head()
# Out:
# (18126, 17)
#                     지번주소         도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 0  서울특별시 강남구 개포동 1174-11  논현로6길 26-9   지호빌라B    32.89     24050  3  2016.0
# 1  서울특별시 강남구 개포동 1174-11  논현로6길 26-9   지호빌라B    32.89     24050  2  2016.0
# 2  서울특별시 강남구 개포동 1174-11  논현로6길 26-9   지호빌라B    33.06     22950  5  2016.0
# 3  서울특별시 강남구 개포동 1174-11  논현로6길 26-9   지호빌라B    39.91     28950  3  2016.0
# 4  서울특별시 강남구 개포동 1174-11  논현로6길 26-9   지호빌라B    39.91     28950  2  2016.0
#
#    계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형    소유자    구    동  \
# 0          0.0 2016-11-29  731.225296   5.0  연립다세대  서***~  강남구  개포동
# 1          0.0 2016-11-29  731.225296   5.0  연립다세대  서***~  강남구  개포동
# 2          0.0 2016-11-29  694.192377   5.0  연립다세대  서***~  강남구  개포동
# 3          0.0 2016-11-29  725.382110   5.0  연립다세대  서***~  강남구  개포동
# 4          0.0 2016-11-29  725.382110   5.0  연립다세대  서***~  강남구  개포동
#
#        지수적용단가       평가날짜
# 0  971.184032 2021-04-01
# 1  971.184032 2021-04-01
# 2  921.998398 2021-04-01
# 3  963.423346 2021-04-01
# 4  963.423346 2021-04-01

# %%
concat_df['구_동'] = concat_df['구'] + '_' + concat_df['동']

# %%
def change_name(x):
    # x is a string
    
    if pd.isna(x) == True:
        return x
    else:
        if x == '한***~':
            return '한국토지주택공사'
        elif x == '서***~':
            return '서울주택도시공사'
        else:
            return x

# %%
concat_df['소유자'] = concat_df['소유자'].apply(change_name)

# %%
concat_df['지번주소'].unique()
# Out:
# array(['서울특별시 강남구 개포동 1174-11', '서울특별시 강남구 개포동 1174-9',
#        '서울특별시 강남구 개포동 1186-4', ..., '서울특별시 종로구 연지동 231-0',
#        '서울특별시 중랑구 상봉동 311-0', '서울특별시 중랑구 중화동 10-0'], dtype=object)

# %%
concat_df['소유자'].value_counts()
# Out:
# 서울주택도시공사    10331
# 한국토지주택공사     7795
# Name: 소유자, dtype: int64

# %%
concat_df.head()
# Out:
#                     지번주소         도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 0  서울특별시 강남구 개포동 1174-11  논현로6길 26-9   지호빌라B    32.89     24050  3  2016.0
# 1  서울특별시 강남구 개포동 1174-11  논현로6길 26-9   지호빌라B    32.89     24050  2  2016.0
# 2  서울특별시 강남구 개포동 1174-11  논현로6길 26-9   지호빌라B    33.06     22950  5  2016.0
# 3  서울특별시 강남구 개포동 1174-11  논현로6길 26-9   지호빌라B    39.91     28950  3  2016.0
# 4  서울특별시 강남구 개포동 1174-11  논현로6길 26-9   지호빌라B    39.91     28950  2  2016.0
#
#    계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형       소유자    구    동  \
# 0          0.0 2016-11-29  731.225296   5.0  연립다세대  서울주택도시공사  강남구  개포동
# 1          0.0 2016-11-29  731.225296   5.0  연립다세대  서울주택도시공사  강남구  개포동
# 2          0.0 2016-11-29  694.192377   5.0  연립다세대  서울주택도시공사  강남구  개포동
# 3          0.0 2016-11-29  725.382110   5.0  연립다세대  서울주택도시공사  강남구  개포동
# 4          0.0 2016-11-29  725.382110   5.0  연립다세대  서울주택도시공사  강남구  개포동
#
#        지수적용단가       평가날짜      구_동
# 0  971.184032 2021-04-01  강남구_개포동
# 1  971.184032 2021-04-01  강남구_개포동
# 2  921.998398 2021-04-01  강남구_개포동
# 3  963.423346 2021-04-01  강남구_개포동
# 4  963.423346 2021-04-01  강남구_개포동

# %%
to_print_df = concat_df.drop(columns=['도로명', '계약날짜기준_건물연식', '건물연식', '구', '동', '지수적용단가', '평가날짜'])
print(to_print_df.shape)
to_print_df.head()
# Out:
# (18126, 11)
#                     지번주소 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도       계약날짜  \
# 0  서울특별시 강남구 개포동 1174-11   지호빌라B    32.89     24050  3  2016.0 2016-11-29
# 1  서울특별시 강남구 개포동 1174-11   지호빌라B    32.89     24050  2  2016.0 2016-11-29
# 2  서울특별시 강남구 개포동 1174-11   지호빌라B    33.06     22950  5  2016.0 2016-11-29
# 3  서울특별시 강남구 개포동 1174-11   지호빌라B    39.91     28950  3  2016.0 2016-11-29
# 4  서울특별시 강남구 개포동 1174-11   지호빌라B    39.91     28950  2  2016.0 2016-11-29
#
#      단가(만원/㎡)  부동산유형       소유자      구_동
# 0  731.225296  연립다세대  서울주택도시공사  강남구_개포동
# 1  731.225296  연립다세대  서울주택도시공사  강남구_개포동
# 2  694.192377  연립다세대  서울주택도시공사  강남구_개포동
# 3  725.382110  연립다세대  서울주택도시공사  강남구_개포동
# 4  725.382110  연립다세대  서울주택도시공사  강남구_개포동

# %%
to_print_df['구_동'].nunique()
# Out:
# 123

# %%
to_print_df = to_print_df[to_print_df['계약날짜'] >= pd.to_datetime('2018-01-01')]
print(to_print_df.shape)
to_print_df.head()
# Out:
# (14679, 11)
#                      지번주소 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도       계약날짜  \
# 31  서울특별시 강남구 개포동 1195-10     동영빌    25.39     28300  3  2020.0 2020-03-02
# 32  서울특별시 강남구 개포동 1195-10     동영빌    25.39     28300  2  2020.0 2020-03-02
# 33  서울특별시 강남구 개포동 1195-10     동영빌    25.46     28400  3  2020.0 2020-03-02
# 34  서울특별시 강남구 개포동 1195-10     동영빌    25.46     28400  2  2020.0 2020-03-02
# 35  서울특별시 강남구 개포동 1195-10     동영빌    25.55     28500  3  2020.0 2020-03-02
#
#        단가(만원/㎡)  부동산유형       소유자      구_동
# 31  1114.612052  연립다세대  서울주택도시공사  강남구_개포동
# 32  1114.612052  연립다세대  서울주택도시공사  강남구_개포동
# 33  1115.475255  연립다세대  서울주택도시공사  강남구_개포동
# 34  1115.475255  연립다세대  서울주택도시공사  강남구_개포동
# 35  1115.459883  연립다세대  서울주택도시공사  강남구_개포동

# %%
to_print_df['구_동'].nunique()
# Out:
# 116

# %%
to_print_df['계약날짜'].describe()
# Out:
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
# count                   14679
# unique                    428
# top       2020-12-28 00:00:00
# freq                      230
# first     2018-01-02 00:00:00
# last      2021-06-07 00:00:00
# Name: 계약날짜, dtype: object

# %%
for gudong in tqdm(to_print_df['구_동'].unique()):
    gudong_df = to_print_df[to_print_df['구_동'] == gudong].drop(columns=['구_동'])
    gudong_df.to_excel(bulktrade_basedir + '2018년부터/' + gudong + '.xlsx', index=False)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 116/116 [00:04<00:00, 24.54it/s]

# %%
to_print_df.head()
# Out:
#                      지번주소 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도       계약날짜  \
# 31  서울특별시 강남구 개포동 1195-10     동영빌    25.39     28300  3  2020.0 2020-03-02
# 32  서울특별시 강남구 개포동 1195-10     동영빌    25.39     28300  2  2020.0 2020-03-02
# 33  서울특별시 강남구 개포동 1195-10     동영빌    25.46     28400  3  2020.0 2020-03-02
# 34  서울특별시 강남구 개포동 1195-10     동영빌    25.46     28400  2  2020.0 2020-03-02
# 35  서울특별시 강남구 개포동 1195-10     동영빌    25.55     28500  3  2020.0 2020-03-02
#
#        단가(만원/㎡)  부동산유형       소유자      구_동
# 31  1114.612052  연립다세대  서울주택도시공사  강남구_개포동
# 32  1114.612052  연립다세대  서울주택도시공사  강남구_개포동
# 33  1115.475255  연립다세대  서울주택도시공사  강남구_개포동
# 34  1115.475255  연립다세대  서울주택도시공사  강남구_개포동
# 35  1115.459883  연립다세대  서울주택도시공사  강남구_개포동

# %%
to_print_df['평균_전용면적(㎡)'] = to_print_df[['지번주소', '건축년도', '부동산유형', '전용면적(㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('mean')['전용면적(㎡)']

# %%
to_print_df['총_전용면적(㎡)'] = to_print_df[['지번주소', '건축년도', '부동산유형', '전용면적(㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('sum')['전용면적(㎡)']

# %%
to_print_df['전용면적_표준편차(㎡)'] = to_print_df[['지번주소', '건축년도', '부동산유형', '전용면적(㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('std')['전용면적(㎡)']

# %%
to_print_df['평균_거래금액(만원)'] = to_print_df[['지번주소', '건축년도', '부동산유형', '거래금액(만원)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('mean')['거래금액(만원)']

# %%
to_print_df['총_거래금액(만원)'] = to_print_df[['지번주소', '건축년도', '부동산유형', '거래금액(만원)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('sum')['거래금액(만원)']

# %%
to_print_df['거래금액_표준편차(만원)'] = to_print_df[['지번주소', '건축년도', '부동산유형', '거래금액(만원)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('std')['거래금액(만원)']

# %%
to_print_df['최대_층'] = to_print_df[['지번주소', '건축년도', '부동산유형', '층']].groupby(['지번주소', '건축년도', '부동산유형']).transform('max')['층']

# %%
to_print_df['평균_단가(만원)'] = to_print_df[['지번주소', '건축년도', '부동산유형', '단가(만원/㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('mean')['단가(만원/㎡)']

# %%
to_print_df['단가_표준편차(만원)'] = to_print_df[['지번주소', '건축년도', '부동산유형', '단가(만원/㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('std')['단가(만원/㎡)']

# %%
to_print_df['세대_수'] = to_print_df[['지번주소', '건축년도', '부동산유형', '단가(만원/㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('count')['단가(만원/㎡)']

# %%
to_print_df.head(20)
# Out:
#                      지번주소 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도       계약날짜  \
# 31  서울특별시 강남구 개포동 1195-10     동영빌    25.39     28300  3  2020.0 2020-03-02
# 32  서울특별시 강남구 개포동 1195-10     동영빌    25.39     28300  2  2020.0 2020-03-02
# 33  서울특별시 강남구 개포동 1195-10     동영빌    25.46     28400  3  2020.0 2020-03-02
# 34  서울특별시 강남구 개포동 1195-10     동영빌    25.46     28400  2  2020.0 2020-03-02
# 35  서울특별시 강남구 개포동 1195-10     동영빌    25.55     28500  3  2020.0 2020-03-02
# 36  서울특별시 강남구 개포동 1195-10     동영빌    25.55     28500  2  2020.0 2020-03-02
# 37  서울특별시 강남구 개포동 1195-10     동영빌    26.21     28650  4  2020.0 2020-03-02
# 38  서울특별시 강남구 개포동 1195-10     동영빌    26.21     29200  3  2020.0 2020-03-02
# 39  서울특별시 강남구 개포동 1195-10     동영빌    26.21     29200  2  2020.0 2020-03-02
# 40  서울특별시 강남구 개포동 1195-10     동영빌    29.56     32950  2  2020.0 2020-03-02
# 41  서울특별시 강남구 개포동 1195-10     동영빌    29.56     32950  3  2020.0 2020-03-02
# 42  서울특별시 강남구 개포동 1195-10     동영빌    29.60     33000  4  2020.0 2020-03-02
# 43  서울특별시 강남구 개포동 1195-10     동영빌    33.71     36150  5  2020.0 2020-03-02
# 44  서울특별시 강남구 개포동 1195-10     동영빌    38.21     39450  5  2020.0 2020-03-02
# 45  서울특별시 강남구 개포동 1195-10     동영빌    40.15     40000  4  2020.0 2020-03-02
# 46   서울특별시 강남구 개포동 1199-7   개포백년빌    22.29     22950  5  2019.0 2019-12-19
# 47   서울특별시 강남구 개포동 1199-7   개포백년빌    22.75     23000  5  2019.0 2019-12-19
# 48   서울특별시 강남구 개포동 1199-7   개포백년빌    23.05     23600  5  2019.0 2019-12-19
# 49   서울특별시 강남구 개포동 1199-7   개포백년빌    25.57     26750  4  2019.0 2019-12-19
# 50   서울특별시 강남구 개포동 1199-7   개포백년빌    28.02     27650  4  2019.0 2019-12-19
#
#        단가(만원/㎡)  부동산유형       소유자      구_동  평균_전용면적(㎡)  총_전용면적(㎡)  \
# 31  1114.612052  연립다세대  서울주택도시공사  강남구_개포동   28.814667     432.22
# 32  1114.612052  연립다세대  서울주택도시공사  강남구_개포동   28.814667     432.22
# 33  1115.475255  연립다세대  서울주택도시공사  강남구_개포동   28.814667     432.22
# 34  1115.475255  연립다세대  서울주택도시공사  강남구_개포동   28.814667     432.22
# 35  1115.459883  연립다세대  서울주택도시공사  강남구_개포동   28.814667     432.22
# 36  1115.459883  연립다세대  서울주택도시공사  강남구_개포동   28.814667     432.22
# 37  1093.094239  연립다세대  서울주택도시공사  강남구_개포동   28.814667     432.22
# 38  1114.078596  연립다세대  서울주택도시공사  강남구_개포동   28.814667     432.22
# 39  1114.078596  연립다세대  서울주택도시공사  강남구_개포동   28.814667     432.22
# 40  1114.682003  연립다세대  서울주택도시공사  강남구_개포동   28.814667     432.22
# 41  1114.682003  연립다세대  서울주택도시공사  강남구_개포동   28.814667     432.22
# 42  1114.864865  연립다세대  서울주택도시공사  강남구_개포동   28.814667     432.22
# 43  1072.382082  연립다세대  서울주택도시공사  강남구_개포동   28.814667     432.22
# 44  1032.452238  연립다세대  서울주택도시공사  강남구_개포동   28.814667     432.22
# 45   996.264010  연립다세대  서울주택도시공사  강남구_개포동   28.814667     432.22
# 46  1029.609690  연립다세대  한국토지주택공사  강남구_개포동   27.905000     390.67
# 47  1010.989011  연립다세대  한국토지주택공사  강남구_개포동   27.905000     390.67
# 48  1023.861171  연립다세대  한국토지주택공사  강남구_개포동   27.905000     390.67
# 49  1046.147829  연립다세대  한국토지주택공사  강남구_개포동   27.905000     390.67
# 50   986.795146  연립다세대  한국토지주택공사  강남구_개포동   27.905000     390.67
#
#     전용면적_표준편차(㎡)   평균_거래금액(만원)  총_거래금액(만원)  거래금액_표준편차(만원)  최대_층    평균_단가(만원)  \
# 31      4.855684  31463.333333      471950    4139.637090     5  1097.178201
# 32      4.855684  31463.333333      471950    4139.637090     5  1097.178201
# 33      4.855684  31463.333333      471950    4139.637090     5  1097.178201
# 34      4.855684  31463.333333      471950    4139.637090     5  1097.178201
# 35      4.855684  31463.333333      471950    4139.637090     5  1097.178201
# 36      4.855684  31463.333333      471950    4139.637090     5  1097.178201
# 37      4.855684  31463.333333      471950    4139.637090     5  1097.178201
# 38      4.855684  31463.333333      471950    4139.637090     5  1097.178201
# 39      4.855684  31463.333333      471950    4139.637090     5  1097.178201
# 40      4.855684  31463.333333      471950    4139.637090     5  1097.178201
# 41      4.855684  31463.333333      471950    4139.637090     5  1097.178201
# 42      4.855684  31463.333333      471950    4139.637090     5  1097.178201
# 43      4.855684  31463.333333      471950    4139.637090     5  1097.178201
# 44      4.855684  31463.333333      471950    4139.637090     5  1097.178201
# 45      4.855684  31463.333333      471950    4139.637090     5  1097.178201
# 46      3.070186  28857.142857      404000    3536.722578     5  1033.367584
# 47      3.070186  28857.142857      404000    3536.722578     5  1033.367584
# 48      3.070186  28857.142857      404000    3536.722578     5  1033.367584
# 49      3.070186  28857.142857      404000    3536.722578     5  1033.367584
# 50      3.070186  28857.142857      404000    3536.722578     5  1033.367584
#
#     단가_표준편차(만원)  세대_수
# 31    36.299709    15
# 32    36.299709    15
# 33    36.299709    15
# 34    36.299709    15
# 35    36.299709    15
# 36    36.299709    15
# 37    36.299709    15
# 38    36.299709    15
# 39    36.299709    15
# 40    36.299709    15
# 41    36.299709    15
# 42    36.299709    15
# 43    36.299709    15
# 44    36.299709    15
# 45    36.299709    15
# 46    37.609677    14
# 47    37.609677    14
# 48    37.609677    14
# 49    37.609677    14
# 50    37.609677    14

# %%
summary_df = to_print_df.drop(columns=['전용면적(㎡)', '거래금액(만원)', '층', '단가(만원/㎡)', '구_동']).drop_duplicates().reset_index(drop=True)
print(summary_df.shape)
summary_df.head()
# Out:
# (829, 16)
#                     지번주소 건물(단지)명    건축년도       계약날짜  부동산유형       소유자  \
# 0  서울특별시 강남구 개포동 1195-10     동영빌  2020.0 2020-03-02  연립다세대  서울주택도시공사
# 1   서울특별시 강남구 개포동 1199-7   개포백년빌  2019.0 2019-12-19  연립다세대  한국토지주택공사
# 2   서울특별시 강남구 개포동 1216-7     백년빌  2020.0 2020-03-18  연립다세대  서울주택도시공사
# 3   서울특별시 강남구 개포동 1237-7     한별2  2021.0 2021-06-01   오피스텔  서울주택도시공사
# 4   서울특별시 강남구 개포동 1237-7     한별2  2021.0 2021-06-01  연립다세대  서울주택도시공사
#
#    평균_전용면적(㎡)  총_전용면적(㎡)  전용면적_표준편차(㎡)   평균_거래금액(만원)  총_거래금액(만원)  \
# 0   28.814667     432.22      4.855684  31463.333333      471950
# 1   27.905000     390.67      3.070186  28857.142857      404000
# 2   26.686000     400.29      2.367074  30573.333333      458600
# 3   29.665000     118.66      0.390000  33565.250000      134261
# 4   29.946667     449.20      0.037544  38163.333333      572450
#
#    거래금액_표준편차(만원)  최대_층    평균_단가(만원)  단가_표준편차(만원)  세대_수
# 0    4139.637090     5  1097.178201    36.299709    15
# 1    3536.722578     5  1033.367584    37.609677    14
# 2    2134.651750     5  1147.330195    25.484846    15
# 3     437.500000     2  1131.477759     0.128995     4
# 4      44.185755     6  1274.376854     0.358219    15

# %%
summary_df['구_동'] = summary_df['지번주소'].apply(lambda x: x.split(' ')[1]) + '_' + summary_df['지번주소'].apply(lambda x: x.split(' ')[2])

# %%
summary_df.head()
# Out:
#                     지번주소 건물(단지)명    건축년도       계약날짜  부동산유형       소유자  \
# 0  서울특별시 강남구 개포동 1195-10     동영빌  2020.0 2020-03-02  연립다세대  서울주택도시공사
# 1   서울특별시 강남구 개포동 1199-7   개포백년빌  2019.0 2019-12-19  연립다세대  한국토지주택공사
# 2   서울특별시 강남구 개포동 1216-7     백년빌  2020.0 2020-03-18  연립다세대  서울주택도시공사
# 3   서울특별시 강남구 개포동 1237-7     한별2  2021.0 2021-06-01   오피스텔  서울주택도시공사
# 4   서울특별시 강남구 개포동 1237-7     한별2  2021.0 2021-06-01  연립다세대  서울주택도시공사
#
#    평균_전용면적(㎡)  총_전용면적(㎡)  전용면적_표준편차(㎡)   평균_거래금액(만원)  총_거래금액(만원)  \
# 0   28.814667     432.22      4.855684  31463.333333      471950
# 1   27.905000     390.67      3.070186  28857.142857      404000
# 2   26.686000     400.29      2.367074  30573.333333      458600
# 3   29.665000     118.66      0.390000  33565.250000      134261
# 4   29.946667     449.20      0.037544  38163.333333      572450
#
#    거래금액_표준편차(만원)  최대_층    평균_단가(만원)  단가_표준편차(만원)  세대_수      구_동
# 0    4139.637090     5  1097.178201    36.299709    15  강남구_개포동
# 1    3536.722578     5  1033.367584    37.609677    14  강남구_개포동
# 2    2134.651750     5  1147.330195    25.484846    15  강남구_개포동
# 3     437.500000     2  1131.477759     0.128995     4  강남구_개포동
# 4      44.185755     6  1274.376854     0.358219    15  강남구_개포동

# %%
summary_df = summary_df.sort_values(['구_동', '계약날짜'], ascending=[True, False]).reset_index(drop=True)
print(summary_df.shape)
summary_df.head()
# Out:
# (829, 17)
#                     지번주소 건물(단지)명    건축년도       계약날짜  부동산유형       소유자  \
# 0   서울특별시 강남구 개포동 1237-7     한별2  2021.0 2021-06-01   오피스텔  서울주택도시공사
# 1   서울특별시 강남구 개포동 1237-7     한별2  2021.0 2021-06-01  연립다세대  서울주택도시공사
# 2   서울특별시 강남구 개포동 1216-7     백년빌  2020.0 2020-03-18  연립다세대  서울주택도시공사
# 3  서울특별시 강남구 개포동 1195-10     동영빌  2020.0 2020-03-02  연립다세대  서울주택도시공사
# 4   서울특별시 강남구 개포동 1199-7   개포백년빌  2019.0 2019-12-19  연립다세대  한국토지주택공사
#
#    평균_전용면적(㎡)  총_전용면적(㎡)  전용면적_표준편차(㎡)   평균_거래금액(만원)  총_거래금액(만원)  \
# 0   29.665000     118.66      0.390000  33565.250000      134261
# 1   29.946667     449.20      0.037544  38163.333333      572450
# 2   26.686000     400.29      2.367074  30573.333333      458600
# 3   28.814667     432.22      4.855684  31463.333333      471950
# 4   27.905000     390.67      3.070186  28857.142857      404000
#
#    거래금액_표준편차(만원)  최대_층    평균_단가(만원)  단가_표준편차(만원)  세대_수      구_동
# 0     437.500000     2  1131.477759     0.128995     4  강남구_개포동
# 1      44.185755     6  1274.376854     0.358219    15  강남구_개포동
# 2    2134.651750     5  1147.330195    25.484846    15  강남구_개포동
# 3    4139.637090     5  1097.178201    36.299709    15  강남구_개포동
# 4    3536.722578     5  1033.367584    37.609677    14  강남구_개포동

# %%
summary_df = summary_df.drop(columns=['구_동'])

# %%
summary_df['지번주소'] = summary_df['지번주소'].apply(lambda x: x.replace('서울특별시 ', ''))
summary_df['소유자'] = summary_df['소유자'].apply(lambda x: x.replace('서울주택도시공사', 'SH'))
summary_df['소유자'] = summary_df['소유자'].apply(lambda x: x.replace('한국토지주택공사', 'LH'))

# %%
summary_df.to_excel(bulktrade_basedir + '2018년부터/' + '2018년01월01일부터_2021년06월07일까지_SH_LH_거래사례_요약본' + '.xlsx', index=False)

# %%
summary_df['지번주소'] = '서울특별시 ' + summary_df['지번주소']

# %%
print_missing_df = summary_df[summary_df['지번주소'].isin(missing_df['지번주소'].unique())]
print(print_missing_df.shape)
# Out:
# (34, 16)

# %%
print_missing_df['지번주소'] = print_missing_df['지번주소'].apply(lambda x: x.replace('서울특별시 ', ''))

# %%
print_missing_df.head()
# Out:
#               지번주소         건물(단지)명    건축년도       계약날짜  부동산유형 소유자  평균_전용면적(㎡)  \
# 10  강남구 역삼동 778-15  NTRAUM YEOKSAM  2020.0 2020-10-08  연립다세대  LH   29.866897
# 19    강동구 길동 140-0            진영빌라  2020.0 2020-11-18  연립다세대  SH   52.517000
# 22    강동구 길동 139-0             강연빌  2019.0 2020-01-13  연립다세대  SH   32.735882
# 25   강동구 상일동 346-0           청년안테나  2018.0 2018-05-16  연립다세대  SH   33.308000
# 40   강동구 성내동 403-0           주함해븐빌  2018.0 2018-08-09  연립다세대  LH   46.403750
#
#     총_전용면적(㎡)  전용면적_표준편차(㎡)   평균_거래금액(만원)  총_거래금액(만원)  거래금액_표준편차(만원)  최대_층  \
# 10     866.14      1.484001  52689.655172     1528000    1335.195231     6
# 19     525.17      3.372289  38805.000000      388050    2048.366558     5
# 22     556.51      3.196616  25911.764706      440500    1889.984244     5
# 25     333.08      4.349538  21410.000000      214100    2283.248174     5
# 40    3712.30      3.194417  38863.750000     3109100    2043.993593     6
#
#       평균_단가(만원)  단가_표준편차(만원)  세대_수
# 10  1767.152811    75.332183    29
# 19   739.482422    12.662096    10
# 22   793.451708    23.307504    17
# 25   644.635261    30.932276    10
# 40   838.926151    26.128681    80

# %%
print_missing_df.to_excel(bulktrade_basedir + '빠진애들.xlsx', index=False)

# %%
inv_df = concat_df[concat_df['소유자'] == '서울주택도시공사']
print(inv_df.shape)
inv_df.head()

# %%
inv_df = inv_df.sort_values(['단가(만원/㎡)'], ascending=False)
print(inv_df.shape)
inv_df.head()

# %%
land_specs_df = pd.read_csv('./prepped_data/land_specs_baseline.csv')
print(land_specs_df.shape)
land_specs_df.head()

# %%
last_df = land_specs_df.drop_duplicates(subset=['지번주소'], keep='last').drop(columns=['년']).reset_index(drop=True)
print(last_df.shape)
last_df.head()

# %%
merge_df = concat_df.merge(last_df, on=['지번주소'])
print(merge_df.shape)
merge_df.head()

# %%
merge_df['도로접면'].value_counts()

# %%
inv_idx = []
for addr in tqdm(concat_df['지번주소'].unique()):
    addr_df = concat_df[concat_df['지번주소'] == addr]
    
    if addr_df['부동산유형'].nunique() > 1:
        [inv_idx.append(i) for i in addr_df.index]

# %%
len(inv_idx)

# %%
yunrip_officetel_df = concat_df.loc[inv_idx]
print(yunrip_officetel_df.shape)
yunrip_officetel_df.head()

# %%
yunrip_officetel_df['지번주소'].nunique()

# %%
for addr in yunrip_officetel_df['지번주소'].unique():
    addr_df = yunrip_officetel_df[yunrip_officetel_df['지번주소'] == addr]
    
    addr_df = addr_df.drop(columns=['도로명', '계약날짜기준_건물연식', '건물연식', '구', '동', '지수적용단가', '평가날짜', '구_동'])
    
    addr_df.to_excel('./연립다세대_오피스텔_같이사례_주소별/' + addr + '.xlsx', index=False)
    
    print(addr_df.shape)
    display(addr_df)

# %%
1131.413262 / 1274.182789

# %%
889.092576 / 1324.609734

# %%
972.300735 / 1370.087336

# %%
1563.467492 / 1615.878107

# %%
1114.762516 / 1222.272522

# %%
648.957633 / 884.445951

# %%
623.745819 / 689.285714

# %%
yunrip_officetel_df.to_excel('SH_LH_거래사례중_연립다세대_오피스텔_같이_있는_사례들.xlsx')

# %%
count = 0
for addr in tqdm(concat_df['구_동'].unique()):
    addr_df = concat_df[concat_df['구_동'] == addr]
    addr_df = addr_df[['지번주소', '건물(단지)명', '건축년도', '건물연식', '계약날짜기준_건물연식', '층', '전용면적(㎡)',
                       '계약날짜', '단가(만원/㎡)', '평가날짜', '지수적용단가', '소유자', '부동산유형'
                      ]]
    addr_df = addr_df.sort_values(['지번주소', '건축년도', '계약날짜', '층', '전용면적(㎡)'])
    addr_df.to_excel(bulktrade_basedir + '동별/' + addr + '.xlsx', index=False)
    
    
    
    
    count += 1

# %%
concat_df['지번주소'].nunique()

# %%
concat_df.head()

# %%
addr_to_inv = []
for addr in tqdm(concat_df['지번주소'].unique()):
    addr_df = concat_df[concat_df['지번주소'] == addr]
    
    inv_30_df = addr_df[
        (addr_df['전용면적(㎡)'] >= 28)
        &(addr_df['전용면적(㎡)'] <= 32)
    ]
    
    inv_80_df = addr_df[
        (addr_df['전용면적(㎡)'] >= 80)
    ]
    
    if (inv_30_df.shape[0] > 1) & (inv_80_df.shape[0] > 1):
        addr_to_inv.append(addr)

# %%
len(addr_to_inv)

# %%
addr_to_inv = []
for addr in tqdm(concat_df['지번주소'].unique()):
    addr_df = concat_df[concat_df['지번주소'] == addr]

    inv_80_df = addr_df[
        (addr_df['전용면적(㎡)'] >= 80)
    ]
    
    if (inv_80_df.shape[0] > 1):
        addr_to_inv.append(addr)

# %%
len(addr_to_inv)

# %%
addr_to_inv

# %%
inv_df = concat_df[concat_df['지번주소'].isin(addr_to_inv)]
print(inv_df.shape)
inv_df.head()

# %%
inv_df

# %%
concat_df['전용면적(㎡)'] = concat_df['전용면적(㎡)'].apply(round)

# %%
concat_df['평균단가'] = concat_df[['지번주소', '건축년도', '전용면적(㎡)', '단가(만원/㎡)']].groupby(['지번주소', '건축년도', '전용면적(㎡)']).transform('mean')['단가(만원/㎡)']

# %%
concat_df['지수적용평균단가'] = concat_df[['지번주소', '건축년도', '전용면적(㎡)', '지수적용단가']].groupby(['지번주소', '건축년도', '전용면적(㎡)']).transform('mean')['지수적용단가']

# %%
concat_df = concat_df.drop(columns=['도로명', '거래금액(만원)', '층', '단가(만원/㎡)', '지수적용단가']).drop_duplicates().reset_index(drop=True)
print(concat_df.shape)
concat_df.head()

# %%
yunrip_selected_df = yunrip_bulk_df[['지번주소', '건축년도', '건물연식', '계약날짜', '계약날짜기준_건물연식', '전용면적(㎡)', '지번별_전용면적별_평균단가', '부동산유형', '소유자']].drop_duplicates().reset_index(drop=True)
print(yunrip_selected_df.shape)
yunrip_selected_df.head()

# %%
yunrip_selected_df = yunrip_selected_df.sort_values(['지번주소']).reset_index(drop=True)
yunrip_selected_df.to_excel(bulktrade_basedir + '최근_6개월_SH_LH_거래사례.xlsx', index=False)

# %%
yunrip_selected_df['지번별_평균단가'] = yunrip_selected_df[['지번주소', '건축년도', '계약날짜', '지번별_전용면적별_평균단가']].groupby(['지번주소', '건축년도', '계약날짜']).transform('mean')['지번별_전용면적별_평균단가']

# %%
yunrip_selected_df = yunrip_selected_df.drop(columns=['전용면적(㎡)', '지번별_전용면적별_평균단가']).drop_duplicates().reset_index(drop=True)
print(yunrip_selected_df.shape)
yunrip_selected_df.head()

# %%
yunrip_selected_df['구'] = yunrip_selected_df['지번주소'].apply(lambda x: x.split(' ')[1])
yunrip_selected_df['동'] = yunrip_selected_df['지번주소'].apply(lambda x: x.split(' ')[2])
yunrip_selected_df['구동'] = yunrip_selected_df['구'] + '_' + yunrip_selected_df['동']

# %%
basedir = './국토교통부_실거래가_공개시스템/땅값분석/'
yunrip_df = pd.read_csv(basedir + 'yunrip_25.csv')
commerce_df = pd.read_csv(basedir + 'commerce_25.csv')
land_df = pd.read_csv(basedir + 'land.csv')

# %%
common_cols = ['시군구', '번지', '용도지역', '도로조건', '계약날짜', '대지면적(㎡)', '거래금액(만원)', '단가(㎡)', '단가(평)', '부동산유형', '건물연식']
common_df = pd.concat([yunrip_df[common_cols], commerce_df[common_cols], land_df[[col for col in land_df.columns if col not in ['지목', '지분구분', '해제사유발생일']]]])
common_df['계약날짜'] = pd.to_datetime(common_df['계약날짜'], format='%Y-%m-%d')
print(common_df.shape)
common_df.head()

# %%
common_df['구'] = common_df['시군구'].apply(lambda x: x.split(' ')[1])
common_df['동'] = common_df['시군구'].apply(lambda x: x.split(' ')[2])

# %%
yunrip_bulk_df['구동'] = yunrip_bulk_df['구'] + '_' + yunrip_bulk_df['동']

# %%
summary_df = pd.DataFrame({'지역':[], '2종일반중간값':[], '집값중간값':[]})

count = 0
for gudong in tqdm(yunrip_selected_df['구동'].unique()):
    gu = gudong.split('_')[0]
    dong = gudong.split('_')[1]
    
    target_gu = gu
    target_dong = dong
    target_purpose = '2종일반'
    
    target_df = common_df[
        (common_df['구'] == target_gu)
        &(common_df['동'] == target_dong)
        &(common_df['용도지역'].str.contains(target_purpose))
        &(common_df['계약날짜'] >= (date_today - pd.DateOffset(months=target_period)))
        &(common_df['단가(㎡)'] > 250)
    ].sort_values(['번지'])
    
    yunrip_target_df = yunrip_selected_df[
        (yunrip_selected_df['구동'] == gudong)
    ]
    
    summary_df.loc[count, '지역'] = gudong
    summary_df.loc[count, '2종일반중간값'] = target_df['단가(㎡)'].median()
    summary_df.loc[count, '집값중간값'] = yunrip_target_df['지번별_평균단가'].median()
    
    count += 1

# %%
summary_df['차이'] = summary_df['집값중간값'] - summary_df['2종일반중간값']

# %%
summary_df = summary_df.sort_values(['차이'], ascending=False).reset_index(drop=True)
print(summary_df.shape)
summary_df.head()

# %%
summary_df

# %%
summary_df.to_excel('지역별_땅값_일괄매매_중간값.xlsx', index=False)

# %%
summary_df = pd.DataFrame({'지역':[], '2종일반평균':[], '집값평균':[]})

count = 0
for gudong in tqdm(yunrip_bulk_df['구동'].unique()):
    gu = gudong.split('_')[0]
    dong = gudong.split('_')[1]
    
    target_gu = gu
    target_dong = dong
    target_purpose = '2종일반'
    
    target_df = common_df[
        (common_df['구'] == target_gu)
        &(common_df['동'] == target_dong)
        &(common_df['용도지역'].str.contains(target_purpose))
        &(common_df['계약날짜'] >= (date_today - pd.DateOffset(months=target_period)))
        &(common_df['단가(㎡)'] > 250)
    ].sort_values(['번지'])
    
    yunrip_target_df = yunrip_selected_df[
        (yunrip_selected_df['구동'] == gudong)
    ]
    
    summary_df.loc[count, '지역'] = gudong
    summary_df.loc[count, '2종일반평균'] = target_df['단가(㎡)'].mean()
    summary_df.loc[count, '집값평균'] = yunrip_target_df['지번별_평균단가'].mean()
    
    count += 1

# %%
summary_df['차이'] = summary_df['집값평균'] - summary_df['2종일반평균']

# %%
summary_df = summary_df.sort_values(['차이'], ascending=False).reset_index(drop=True)
print(summary_df.shape)
summary_df.head()

# %%
summary_df

# %%
summary_df.to_excel('지역별_땅값_일괄매매_평균.xlsx', index=False)

# %%
yunrip_selected_df.head()

# %%
inv_df = yunrip_selected_df[yunrip_selected_df['구동'] == '성동구_마장동']
print(inv_df.shape)
inv_df.head()

# %%
def mean_prices_per_size(df):
    df = df.copy()
    
    df['크기별_평균단가'] = df[['지번주소', '건축년도', '계약날짜', '전용면적(㎡)', '단가(만원/㎡)']].groupby(['지번주소', '건축년도', '계약날짜', '전용면적(㎡)']).transform('mean')['단가(만원/㎡)']
    df['크기별_평균총액'] = df[['지번주소', '건축년도', '계약날짜', '전용면적(㎡)', '거래금액(만원)']].groupby(['지번주소', '건축년도', '계약날짜', '전용면적(㎡)']).transform('mean')['거래금액(만원)']
    df = df[['지번주소', '건축년도', '건물연식', '계약날짜', '계약날짜기준_건물연식', '전용면적(㎡)', '크기별_평균총액', '크기별_평균단가']]
    df = df.drop_duplicates().reset_index(drop=True)
    
    return df

# %%
yunrip_short_df = mean_prices_per_size(yunrip_selected_df)
print(yunrip_short_df.shape)
yunrip_short_df.head()
