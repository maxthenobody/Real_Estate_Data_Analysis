# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
pd.options.mode.chained_assignment = None  # default='warn'
plt.rcParams['font.family'] = 'Malgun Gothic'
font = {'size': 16}
matplotlib.rc('font', **font)

# %%
def day_modifier(x):
    # x is a number
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x)
        if len(x) == 1:
            return '0' + x
        else:
            return x

# %%
def landnum_modifier(x):
    # x is a string
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x).replace('외', '').replace(' ','')
        splitted = x.split('-')
        if len(splitted) == 1:
            return x + '-0'
        else:
            return x

# %%
def yunrip_data_prep():
    basedir = './국토교통부_실거래가_공개시스템/연립다세대/매매/'
    filenames = [f for f in os.listdir(basedir) if (f.endswith('.csv'))&('(' in f)]
    
    dfs_list = []
    for i, f in tqdm(enumerate(filenames)):
        df = pd.read_csv(basedir + f, encoding='euc-kr', header=15)
        if '해제사유발생일' in df.columns.tolist():
            df = df.drop(columns=['해제사유발생일'])

        dfs_list.append(df)
    
    concat_df = pd.concat(dfs_list).reset_index(drop=True)
    
    concat_df['번지'] = concat_df['번지'].apply(landnum_modifier)
    
    concat_df['계약년월'] = concat_df['계약년월'].apply(str)
    concat_df['계약일'] = concat_df['계약일'].apply(str)
    
    concat_df['건물연식'] = concat_df['계약년월'].apply(lambda x: int(x[:4])) - concat_df['건축년도']
    
    concat_df['계약일'] = concat_df['계약일'].apply(day_modifier)
    
    concat_df['계약날짜'] = concat_df['계약년월'].apply(lambda x: x[:4]) + '-' + concat_df['계약년월'].apply(lambda x: x[-2:])\
    + '-' + concat_df['계약일']
    
    concat_df['계약날짜'] = pd.to_datetime(concat_df['계약날짜'], format='%Y-%m-%d')
    
    concat_df['거래금액(만원)'] = concat_df['거래금액(만원)'].apply(lambda x: int(x.replace(',','')))
    concat_df['전용면적단가(만원/㎡)'] = concat_df['거래금액(만원)'] / concat_df['전용면적(㎡)']
    
    concat_df['지번주소'] = concat_df['시군구'] + ' ' + concat_df['번지']
    
    concat_df['년'] = concat_df['계약날짜'].dt.year
    
    cols_to_drop = ['시군구', '번지', '본번', '부번', '지번주소', '계약년월', '계약일', '도로명']
    
    concat_df = concat_df[concat_df['년'] >= 2015]
    
    return concat_df[['지번주소'] + [col for col in concat_df.columns if col not in cols_to_drop]]

# %%
def officetel_data_prep():
    basedir = './국토교통부_실거래가_공개시스템/오피스텔/매매/'
    filenames = [f for f in os.listdir(basedir) if (f.endswith('.csv'))&('(' in f)]
    
    dfs_list = []
    for i, f in tqdm(enumerate(filenames)):
        df = pd.read_csv(basedir + f, encoding='euc-kr', header=15)
        if '해제사유발생일' in df.columns.tolist():
            df = df.drop(columns=['해제사유발생일'])

        dfs_list.append(df)
    
    concat_df = pd.concat(dfs_list).reset_index(drop=True)
    
    concat_df['번지'] = concat_df['번지'].apply(landnum_modifier)
    
    concat_df['계약년월'] = concat_df['계약년월'].apply(str)
    concat_df['계약일'] = concat_df['계약일'].apply(str)
    
    concat_df['건물연식'] = concat_df['계약년월'].apply(lambda x: int(x[:4])) - concat_df['건축년도']
    
    concat_df['계약일'] = concat_df['계약일'].apply(day_modifier)
    
    concat_df['계약날짜'] = concat_df['계약년월'].apply(lambda x: x[:4]) + '-' + concat_df['계약년월'].apply(lambda x: x[-2:])\
    + '-' + concat_df['계약일']
    
    concat_df['계약날짜'] = pd.to_datetime(concat_df['계약날짜'], format='%Y-%m-%d')
    
    concat_df['거래금액(만원)'] = concat_df['거래금액(만원)'].apply(lambda x: int(x.replace(',','')))
    concat_df['전용면적단가(만원/㎡)'] = concat_df['거래금액(만원)'] / concat_df['전용면적(㎡)']
    
    concat_df['지번주소'] = concat_df['시군구'] + ' ' + concat_df['번지']
    
    concat_df['년'] = concat_df['계약날짜'].dt.year
    
    cols_to_drop = ['시군구', '번지', '본번', '부번', '지번주소', '계약년월', '계약일', '도로명']
    
    concat_df = concat_df[concat_df['년'] >= 2015]
        
    return concat_df[['지번주소'] + [col for col in concat_df.columns if col not in cols_to_drop]]

# %%
yunrip_df = yunrip_data_prep().dropna().reset_index(drop=True)
print(yunrip_df.shape)
yunrip_df.head()
# Out:
# 16it [00:01, 11.04it/s]
# (329064, 11)
#                    지번주소       건물명  전용면적(㎡)  대지권면적(㎡)  거래금액(만원)  층    건축년도  \
# 0  서울특별시 강남구 개포동 1216-4  (1216-4)    33.77     21.67     24800  4  2012.0
# 1  서울특별시 강남구 개포동 1216-4  (1216-4)    35.87     23.02     27200  4  2012.0
# 2  서울특별시 강남구 개포동 1216-4  (1216-4)    29.12     18.68     22200  4  2012.0
# 3  서울특별시 강남구 개포동 1216-4  (1216-4)    29.97     19.23     22500  3  2012.0
# 4  서울특별시 강남구 개포동 170-18  (170-18)    26.60     21.53     21000  1  1988.0
#
#    건물연식       계약날짜  전용면적단가(만원/㎡)     년
# 0   3.0 2015-03-26    734.379627  2015
# 1   3.0 2015-06-23    758.293839  2015
# 2   3.0 2015-07-20    762.362637  2015
# 3   3.0 2015-08-06    750.750751  2015
# 4  27.0 2015-08-21    789.473684  2015

# %%
officetel_df = officetel_data_prep().dropna().reset_index(drop=True)
print(officetel_df.shape)
officetel_df.head()
# Out:
# 16it [00:00, 37.82it/s]
# (76332, 10)
#                  지번주소   단지명  전용면적(㎡)  거래금액(만원)   층    건축년도  건물연식       계약날짜  \
# 0  서울특별시 강남구 개포동 13-3  대청타워    43.24     22000  14  1997.0  18.0 2015-01-08
# 1  서울특별시 강남구 개포동 13-3  대청타워    32.44     15800  21  1997.0  18.0 2015-01-12
# 2  서울특별시 강남구 개포동 13-3  대청타워    32.44     16000  10  1997.0  18.0 2015-01-19
# 3  서울특별시 강남구 개포동 13-3  대청타워    32.44     15400  21  1997.0  18.0 2015-01-26
# 4  서울특별시 강남구 개포동 13-3  대청타워    31.91     16000  26  1997.0  18.0 2015-01-28
#
#    전용면적단가(만원/㎡)     년
# 0    508.788159  2015
# 1    487.053021  2015
# 2    493.218249  2015
# 3    474.722565  2015
# 4    501.410216  2015

# %%
def land_shape2(x):
    # x is a string
    
    if pd.isna(x) == True:
        return x
    else:
        if '사다리' in x:
            return '사다리형'
        elif '장방' in x:
            return '장방형'
        elif '정방' in x:
            return '정방형'
        elif '부정' in x:
            return '부정형'
        elif '않음' in x:
            return '지정되지않음'
        elif '자루' in x:
            return '자루형'
        elif '삼각' in x:
            return '삼각형'
        else:
            return '기타'

# %%
land_specs_df = pd.read_csv('./prepped_data/land_specs_ver_4.csv')
land_specs_df['지형형상2'] = land_specs_df['지형형상'].apply(land_shape2)
print(land_specs_df.shape)
land_specs_df.head()
# Out:
# (8706295, 12)
#                   지번주소     년 지목명   토지면적  용도지역명1  용도지역명2 토지이동상황 지형높이 지형형상 도로접면  \
# 0  서울특별시 강남구 개포동 100-0  2013   전  876.0  자연녹지지역  지정되지않음      전  완경사  부정형   맹지
# 1  서울특별시 강남구 개포동 100-0  2014   전  876.0  자연녹지지역  지정되지않음      전  완경사  부정형   맹지
# 2  서울특별시 강남구 개포동 100-0  2015   전  876.0  자연녹지지역  지정되지않음      전  완경사  부정형   맹지
# 3  서울특별시 강남구 개포동 100-0  2016   전  876.0  자연녹지지역  지정되지않음      전  완경사  부정형   맹지
# 4  서울특별시 강남구 개포동 100-0  2017   전  876.0  자연녹지지역  지정되지않음      전  완경사  부정형   맹지
#
#        공시지가 지형형상2
# 0  325000.0   부정형
# 1  330000.0   부정형
# 2  335000.0   부정형
# 3  345000.0   부정형
# 4  355000.0   부정형

# %%
land_specs_df['지형형상'].value_counts()
# Out:
# 사다리형      2278575
# 세로장방      1636461
# 부정형       1364328
# 지정되지않음    1241904
# 가로장방       866599
# 정방형        845940
# 자루형        301454
# 삼각형        165686
# 역삼각형         5348
# Name: 지형형상, dtype: int64

# %%
last_df = land_specs_df.drop_duplicates(subset=['지번주소'], keep='last').drop(columns=['년', '공시지가']).reset_index(drop=True)
print(last_df.shape)
last_df.head()
# Out:
# (981464, 10)
#                   지번주소 지목명    토지면적  용도지역명1  용도지역명2 토지이동상황 지형높이 지형형상 도로접면 지형형상2
# 0  서울특별시 강남구 개포동 100-0   전   876.0  자연녹지지역  지정되지않음      전  완경사  부정형   맹지   부정형
# 1  서울특별시 강남구 개포동 101-0   전   641.0  자연녹지지역  지정되지않음      전   평지  부정형   맹지   부정형
# 2  서울특별시 강남구 개포동 102-0   전   509.0  자연녹지지역  지정되지않음      전   평지  부정형   맹지   부정형
# 3  서울특별시 강남구 개포동 103-0   전    48.7  자연녹지지역  개발제한구역      전   평지  부정형   맹지   부정형
# 4  서울특별시 강남구 개포동 104-1   전  2995.0  개발제한구역  자연녹지지역      전  완경사  부정형   맹지   부정형

# %%
last_df['도로접면'].value_counts()
# Out:
# 세로한면(가)    291412
# 지정되지않음     151282
# 세로한면(불)    106248
# 세로각지(가)     80726
# 소로한면        68840
# 광대소각        57931
# 소로각지        57412
# 중로각지        51606
# 중로한면        33053
# 광대로한면       31004
# 맹지          20664
# 광대세각        20419
# 세로각지(불)     10852
# Name: 도로접면, dtype: int64

# %%
yunrip_merge_df = yunrip_df.merge(land_specs_df, on=['지번주소', '년'])
print(yunrip_merge_df.shape)
yunrip_merge_df.head()
# Out:
# (326774, 21)
#                    지번주소       건물명  전용면적(㎡)  대지권면적(㎡)  거래금액(만원)  층    건축년도  \
# 0  서울특별시 강남구 개포동 1216-4  (1216-4)    33.77     21.67     24800  4  2012.0
# 1  서울특별시 강남구 개포동 1216-4  (1216-4)    35.87     23.02     27200  4  2012.0
# 2  서울특별시 강남구 개포동 1216-4  (1216-4)    29.12     18.68     22200  4  2012.0
# 3  서울특별시 강남구 개포동 1216-4  (1216-4)    29.97     19.23     22500  3  2012.0
# 4  서울특별시 강남구 개포동 170-18  (170-18)    26.60     21.53     21000  1  1988.0
#
#    건물연식       계약날짜  전용면적단가(만원/㎡)     년 지목명   토지면적     용도지역명1  용도지역명2 토지이동상황  \
# 0   3.0 2015-03-26    734.379627  2015   대  257.0  제2종일반주거지역  지정되지않음    다세대
# 1   3.0 2015-06-23    758.293839  2015   대  257.0  제2종일반주거지역  지정되지않음    다세대
# 2   3.0 2015-07-20    762.362637  2015   대  257.0  제2종일반주거지역  지정되지않음    다세대
# 3   3.0 2015-08-06    750.750751  2015   대  257.0  제2종일반주거지역  지정되지않음    다세대
# 4  27.0 2015-08-21    789.473684  2015   대  130.3  제2종일반주거지역  지정되지않음    다세대
#
#   지형높이  지형형상     도로접면       공시지가 지형형상2
# 0   평지   정방형  세로각지(가)  3470000.0   정방형
# 1   평지   정방형  세로각지(가)  3470000.0   정방형
# 2   평지   정방형  세로각지(가)  3470000.0   정방형
# 3   평지   정방형  세로각지(가)  3470000.0   정방형
# 4   평지  세로장방  세로한면(가)  4370000.0   장방형

# %%
officetel_merge_df = officetel_df.merge(land_specs_df, on=['지번주소', '년'])
print(officetel_merge_df.shape)
officetel_merge_df.head()
# Out:
# (74257, 20)
#                  지번주소   단지명  전용면적(㎡)  거래금액(만원)   층    건축년도  건물연식       계약날짜  \
# 0  서울특별시 강남구 개포동 13-3  대청타워    43.24     22000  14  1997.0  18.0 2015-01-08
# 1  서울특별시 강남구 개포동 13-3  대청타워    32.44     15800  21  1997.0  18.0 2015-01-12
# 2  서울특별시 강남구 개포동 13-3  대청타워    32.44     16000  10  1997.0  18.0 2015-01-19
# 3  서울특별시 강남구 개포동 13-3  대청타워    32.44     15400  21  1997.0  18.0 2015-01-26
# 4  서울특별시 강남구 개포동 13-3  대청타워    31.91     16000  26  1997.0  18.0 2015-01-28
#
#    전용면적단가(만원/㎡)     년 지목명    토지면적  용도지역명1  용도지역명2 토지이동상황 지형높이  지형형상  도로접면  \
# 0    508.788159  2015   대  4188.5  일반상업지역  지정되지않음    업무용   평지  세로장방  광대소각
# 1    487.053021  2015   대  4188.5  일반상업지역  지정되지않음    업무용   평지  세로장방  광대소각
# 2    493.218249  2015   대  4188.5  일반상업지역  지정되지않음    업무용   평지  세로장방  광대소각
# 3    474.722565  2015   대  4188.5  일반상업지역  지정되지않음    업무용   평지  세로장방  광대소각
# 4    501.410216  2015   대  4188.5  일반상업지역  지정되지않음    업무용   평지  세로장방  광대소각
#
#          공시지가 지형형상2
# 0  12670000.0   장방형
# 1  12670000.0   장방형
# 2  12670000.0   장방형
# 3  12670000.0   장방형
# 4  12670000.0   장방형

# %%
reference_df = pd.read_excel('./감정평가사_자료/이승준_총괄표.xlsx', header=[0,1]).dropna(subset=[('소재지','소재지')]).sort_values([('소재지', '지역'),('소재지', '소재지'), ('소재지', '지번')]).reset_index(drop=True)
reference_df.columns = [col[0] + '_' + col[1] for col in reference_df.columns]
print(reference_df.shape)
reference_df.head()
# Out:
# (131, 39)
#   소재지_지역 소재지_소재지   소재지_지번 토지내용_용도지역 토지내용_도로너비  토지내용_토지면적(㎡)   토지내용_토지매매금액  \
# 0    강남구     개포동  1195-10      2종일주       6미터         265.7  2.970000e+09
# 1    강남구     개포동   1199-7      2종일주       4미터         248.0  2.550000e+09
# 2    강남구     개포동   1216-7      2종일주       8미터         258.1  2.931000e+09
# 3    강남구     역삼동    707-9      일반상업       8미터         363.5  9.500000e+09
# 4    강남구     역삼동    751-6      2종일주       6미터         391.8  5.900000e+09
#
#    토지내용_토지매매단가\n(원/㎡)  토지내용_공시지가와격차\n(개공/매매) 건물내용_건물용도  건물내용_공급면적(㎡)  \
# 0          11178020.0                  0.433     다세대주택        519.54
# 1          10282258.0                  0.365     다세대주택        463.84
# 2          11356064.0                  0.472   도시행생활주택        489.46
# 3          26134801.0                  0.580   도시행생활주택       1695.85
# 4          15058703.0                  0.441   도시행생활주택        658.88
#
#    건물내용_전유면적(㎡)  건물내용_전용율  건물내용_용적율\n(%)  건물내용_건폐율\n(%) 건물내용_구분건물호 건물내용_건물동수  \
# 0        432.22     0.832         195.54          59.62       15개호       1개동
# 1        390.67     0.842         187.04          59.61       14개호       1개동
# 2        400.29     0.818         199.62          59.89       15개호       1개동
# 3       1289.62     0.760         199.62          59.89       15개호       1개동
# 4        537.65     0.816         168.17          46.35       20개호       1개동
#
#   건물내용_건물층수 수입/비용_의뢰인  수입/비용_기준시점  수입/비용_전체평가금액  수입/비용_투입비용합계     수입/비용_순이익  \
# 0      지상5층      SH공사  2020.09.23  4.719500e+09  4.167814e+09  5.516858e+08
# 1      지상5층      LH공사  2019.11.29  4.040000e+09  3.593249e+09  4.467511e+08
# 2      지상5층      SH공사  2019.11.29  4.586000e+09  4.054965e+09  5.310348e+08
# 3      지상5층      LH공사  2019.11.29  2.219983e+10  1.398811e+10  8.211721e+09
# 4      지상6층      LH공사  2019.11.29  9.810500e+09  7.604511e+09  2.205989e+09
#
#    수입/비용_순이익율  평가단가(원/전유㎡) _전유면적  평가단가(원/전유㎡) _공급면적  매출원가(원/전유㎡) _전유면적기준  \
# 0       0.117         10919208.0       9.083997e+06         9.642807e+06
# 1       0.111         10341209.0       8.709524e+06         9.197658e+06
# 2       0.116         11456694.0       9.369509e+06         1.013007e+07
# 3       0.370         17214239.0       1.115945e+07         1.084669e+07
# 4       0.225         18247001.0       1.488966e+07         1.414398e+07
#
#    매출원가(원/전유㎡) _공급면적기준 사업진행일자_토지계약일자 사업진행일자_허가일자 사업진행일자_착공일자 사업진행일자_사용승인일  \
# 0            8372395.0    2019.02.26  2019.06.18  2019.06.18   2020.01.13
# 1            8074624.0    2018.08.21  2018.12.31  2019.01.07   2019.06.04
# 2            8312283.0    2019.01.24  2019.06.17  2019.07.23   2020.02.25
# 3           16602582.0    2019.08.14  2019.07.15  2020.01.03   2020.10.07
# 4           12107552.0    2019.01.04  2019.03.05  2019.04.20   2019.11.29
#
#    건축비\n(원/평)_Unnamed: 32_level_1  원가비율_토지원가비율  원가비율_건축원가비율  원가비율_부대비용  \
# 0                       5500000.0       0.7563       0.2139     0.0060
# 1                       5400000.0       0.7520       0.2175     0.0061
# 2                       5400000.0       0.7667       0.2034     0.0057
# 3                       5800000.0       0.7189       0.2568     0.0072
# 4                       5500000.0       0.8249       0.1486     0.0042
#
#    원가비율_금융비용  원가비율_합계 비고_Unnamed: 38_level_1
# 0     0.0239      1.0                    NaN
# 1     0.0244      1.0                    NaN
# 2     0.0242      1.0                    NaN
# 3     0.0170      1.0                    NaN
# 4     0.0223      1.0                    NaN

# %%
reference_df['소재지_지번'] = reference_df['소재지_지번'].apply(landnum_modifier)

# %%
reference_df['지번주소'] = '서울특별시 ' + reference_df['소재지_지역'] + ' ' + reference_df['소재지_소재지']\
+ ' ' + reference_df['소재지_지번']

# %%
def date_modifier(x):
    # x is a string or datetime
    if pd.isna(x) == True:
        return x
    else:
        x = str(x)
        if '-' in x:
            x = x.replace('-', '.')
            
        splitted = x.split('.')
        
        if len(splitted) == 1:
            return np.nan
        else:
            return x

# %%
reference_df['기준시점2'] = reference_df['수입/비용_기준시점'].apply(date_modifier)

# %%
def get_year(x):
    if pd.isna(x) == True:
        return x
    else:
        return int(x.split('.')[0])

# %%
reference_df['년'] = reference_df['기준시점2'].apply(get_year)

# %%
reference_df['년'] = reference_df['년'].fillna(2020)
reference_df['년'].isna().sum()
# Out:
# 0

# %%
def get_bd_type(x):
    # x is a string
    
    if pd.isna(x) == True:
        return x
    else:
        if '오피' in x:
            return '오피스텔'
        else:
            return '다세대'

# %%
reference_df['건물유형'] = reference_df['건물내용_건물용도'].apply(get_bd_type)

# %%
reference_df = reference_df.merge(last_df, on=['지번주소']).reset_index(drop=True)

# %%
reference_df.head()
# Out:
#   소재지_지역 소재지_소재지   소재지_지번 토지내용_용도지역 토지내용_도로너비  토지내용_토지면적(㎡)   토지내용_토지매매금액  \
# 0    강남구     개포동  1195-10      2종일주       6미터         265.7  2.970000e+09
# 1    강남구     개포동   1199-7      2종일주       4미터         248.0  2.550000e+09
# 2    강남구     개포동   1216-7      2종일주       8미터         258.1  2.931000e+09
# 3    강남구     역삼동    707-9      일반상업       8미터         363.5  9.500000e+09
# 4    강남구     역삼동    751-6      2종일주       6미터         391.8  5.900000e+09
#
#    토지내용_토지매매단가\n(원/㎡)  토지내용_공시지가와격차\n(개공/매매) 건물내용_건물용도  건물내용_공급면적(㎡)  \
# 0          11178020.0                  0.433     다세대주택        519.54
# 1          10282258.0                  0.365     다세대주택        463.84
# 2          11356064.0                  0.472   도시행생활주택        489.46
# 3          26134801.0                  0.580   도시행생활주택       1695.85
# 4          15058703.0                  0.441   도시행생활주택        658.88
#
#    건물내용_전유면적(㎡)  건물내용_전용율  건물내용_용적율\n(%)  건물내용_건폐율\n(%) 건물내용_구분건물호 건물내용_건물동수  \
# 0        432.22     0.832         195.54          59.62       15개호       1개동
# 1        390.67     0.842         187.04          59.61       14개호       1개동
# 2        400.29     0.818         199.62          59.89       15개호       1개동
# 3       1289.62     0.760         199.62          59.89       15개호       1개동
# 4        537.65     0.816         168.17          46.35       20개호       1개동
#
#   건물내용_건물층수 수입/비용_의뢰인  수입/비용_기준시점  수입/비용_전체평가금액  수입/비용_투입비용합계     수입/비용_순이익  \
# 0      지상5층      SH공사  2020.09.23  4.719500e+09  4.167814e+09  5.516858e+08
# 1      지상5층      LH공사  2019.11.29  4.040000e+09  3.593249e+09  4.467511e+08
# 2      지상5층      SH공사  2019.11.29  4.586000e+09  4.054965e+09  5.310348e+08
# 3      지상5층      LH공사  2019.11.29  2.219983e+10  1.398811e+10  8.211721e+09
# 4      지상6층      LH공사  2019.11.29  9.810500e+09  7.604511e+09  2.205989e+09
#
#    수입/비용_순이익율  평가단가(원/전유㎡) _전유면적  평가단가(원/전유㎡) _공급면적  매출원가(원/전유㎡) _전유면적기준  \
# 0       0.117         10919208.0       9.083997e+06         9.642807e+06
# 1       0.111         10341209.0       8.709524e+06         9.197658e+06
# 2       0.116         11456694.0       9.369509e+06         1.013007e+07
# 3       0.370         17214239.0       1.115945e+07         1.084669e+07
# 4       0.225         18247001.0       1.488966e+07         1.414398e+07
#
#    매출원가(원/전유㎡) _공급면적기준 사업진행일자_토지계약일자 사업진행일자_허가일자 사업진행일자_착공일자 사업진행일자_사용승인일  \
# 0            8372395.0    2019.02.26  2019.06.18  2019.06.18   2020.01.13
# 1            8074624.0    2018.08.21  2018.12.31  2019.01.07   2019.06.04
# 2            8312283.0    2019.01.24  2019.06.17  2019.07.23   2020.02.25
# 3           16602582.0    2019.08.14  2019.07.15  2020.01.03   2020.10.07
# 4           12107552.0    2019.01.04  2019.03.05  2019.04.20   2019.11.29
#
#    건축비\n(원/평)_Unnamed: 32_level_1  원가비율_토지원가비율  원가비율_건축원가비율  원가비율_부대비용  \
# 0                       5500000.0       0.7563       0.2139     0.0060
# 1                       5400000.0       0.7520       0.2175     0.0061
# 2                       5400000.0       0.7667       0.2034     0.0057
# 3                       5800000.0       0.7189       0.2568     0.0072
# 4                       5500000.0       0.8249       0.1486     0.0042
#
#    원가비율_금융비용  원가비율_합계 비고_Unnamed: 38_level_1                   지번주소  \
# 0     0.0239      1.0                    NaN  서울특별시 강남구 개포동 1195-10
# 1     0.0244      1.0                    NaN   서울특별시 강남구 개포동 1199-7
# 2     0.0242      1.0                    NaN   서울특별시 강남구 개포동 1216-7
# 3     0.0170      1.0                    NaN    서울특별시 강남구 역삼동 707-9
# 4     0.0223      1.0                    NaN    서울특별시 강남구 역삼동 751-6
#
#         기준시점2       년 건물유형 지목명   토지면적     용도지역명1  용도지역명2 토지이동상황 지형높이  지형형상  \
# 0  2020.09.23  2020.0  다세대   대  265.7  제2종일반주거지역  지정되지않음   상업기타   평지  세로장방
# 1  2019.11.29  2019.0  다세대   대  248.0  제2종일반주거지역  지정되지않음    다세대   평지  세로장방
# 2  2019.11.29  2019.0  다세대   대  258.1  제2종일반주거지역  지정되지않음   상업기타   평지   정방형
# 3  2019.11.29  2019.0  다세대   대  363.5     일반상업지역  지정되지않음    업무용   평지   정방형
# 4  2019.11.29  2019.0  다세대   대  391.8  제2종일반주거지역  지정되지않음   상업기타   평지  세로장방
#
#       도로접면 지형형상2
# 0  세로한면(가)   장방형
# 1  세로한면(가)   장방형
# 2     소로한면   정방형
# 3  세로한면(가)   정방형
# 4  세로한면(가)   장방형

# %%
reference_df['최근3년50분위'] = np.nan
reference_df['최근3년50분위_평가단가와의격차'] = np.nan
reference_df['최근3년평균'] = np.nan
reference_df['최근3년평균_평가단가와의격차'] = np.nan
reference_df['최근2년50분위'] = np.nan
reference_df['최근2년50분위_평가단가와의격차'] = np.nan
reference_df['최근2년평균'] = np.nan
reference_df['최근2년평균_평가단가와의격차'] = np.nan
reference_df['당해50분위'] = np.nan
reference_df['당해50분위_평가단가와의격차'] = np.nan
reference_df['당해평균'] = np.nan
reference_df['당해평균_평가단가와의격차'] = np.nan

# %%
count = 0
for i in tqdm(range(reference_df.shape[0])):
    gu = reference_df.loc[i, '소재지_지역'].replace(' ', '')
    dong = reference_df.loc[i, '소재지_소재지'].replace(' ', '')
    
    land_purpose = reference_df.loc[i, '토지내용_용도지역'].replace(' ', '')[:3]
    year = int(reference_df.loc[i, '년'])
    bd_type = reference_df.loc[i, '건물유형']
    doro = reference_df.loc[i, '도로접면']
    land_shape = reference_df.loc[i, '지형형상2']
    
    if bd_type == '오피스텔':
        target_df = officetel_merge_df[(officetel_merge_df['지번주소'].str.contains(gu+' '+dong))&
                                       (officetel_merge_df['용도지역명1'].str.contains(land_purpose))&
                                       (officetel_merge_df['도로접면'] == doro)&
                                       #(officetel_merge_df['지형형상2'] == land_shape)&
                                       (officetel_merge_df['건물연식'] <= 2)
                                      ]
    else:
        target_df = yunrip_merge_df[(yunrip_merge_df['지번주소'].str.contains(gu+' '+dong))&
                                    (yunrip_merge_df['용도지역명1'].str.contains(land_purpose))&
                                    (yunrip_merge_df['도로접면'] == doro)&
                                    #(yunrip_merge_df['지형형상2'] == land_shape)&
                                    (yunrip_merge_df['건물연식'] <= 2)
                                   ]
        
    target_year_minus_two_df = target_df[(target_df['년'] <= year)&(target_df['년'] >= year-2)]
    target_year_minus_two_df['지번별단가평균'] = target_year_minus_two_df[['지번주소', '전용면적단가(만원/㎡)']]\
    .groupby(['지번주소']).transform('mean')['전용면적단가(만원/㎡)']
    target_year_minus_two_df = target_year_minus_two_df[['지번주소', '지번별단가평균']].drop_duplicates()\
    .reset_index(drop=True)
    
    target_year_minus_one_df = target_df[(target_df['년'] <= year)&(target_df['년'] >= year-1)]
    target_year_minus_one_df['지번별단가평균'] = target_year_minus_one_df[['지번주소', '전용면적단가(만원/㎡)']]\
    .groupby(['지번주소']).transform('mean')['전용면적단가(만원/㎡)']
    target_year_minus_one_df = target_year_minus_one_df[['지번주소', '지번별단가평균']].drop_duplicates()\
    .reset_index(drop=True)
    
    target_year_df = target_df[target_df['년'] == year]
    target_year_df['지번별단가평균'] = target_year_df[['지번주소', '전용면적단가(만원/㎡)']]\
    .groupby(['지번주소']).transform('mean')['전용면적단가(만원/㎡)']
    target_year_df = target_year_df[['지번주소', '지번별단가평균']].drop_duplicates()\
    .reset_index(drop=True)
        
    reference_df.loc[i, '최근3년50분위'] = target_year_minus_two_df['지번별단가평균'].median()
    reference_df.loc[i, '최근3년평균'] = target_year_minus_two_df['지번별단가평균'].mean()
    reference_df.loc[i, '최근2년50분위'] = target_year_minus_one_df['지번별단가평균'].median()
    reference_df.loc[i, '최근2년평균'] = target_year_minus_one_df['지번별단가평균'].mean()
    reference_df.loc[i, '당해50분위'] = target_year_df['지번별단가평균'].median()
    reference_df.loc[i, '당해평균'] = target_year_df['지번별단가평균'].mean()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 130/130 [00:24<00:00,  5.24it/s]

# %%
cols = ['지번주소', '기준시점2', '건물내용_건물용도', '건물유형', '토지내용_용도지역', '토지내용_도로너비', '도로접면', '지형형상2',
        '평가단가(원/전유㎡) _전유면적', '최근3년50분위', '최근3년50분위_평가단가와의격차', '최근3년평균',
        '최근3년평균_평가단가와의격차', '최근2년50분위', '최근2년50분위_평가단가와의격차', '최근2년평균',
        '최근2년평균_평가단가와의격차', '당해50분위', '당해50분위_평가단가와의격차', '당해평균', '당해평균_평가단가와의격차'
       ]
selected_df = reference_df[cols]

# %%
selected_df['평가단가(원/전유㎡) _전유면적'] = selected_df['평가단가(원/전유㎡) _전유면적'] / 10000

# %%
selected_cols = ['최근3년50분위', '최근3년평균', '최근2년50분위', '최근2년평균', '당해50분위', '당해평균']
for col in selected_cols:
    selected_df[col+'_평가단가와의격차'] = selected_df[col] / selected_df['평가단가(원/전유㎡) _전유면적']
    selected_df[col+'_오차'] = selected_df[col] - selected_df['평가단가(원/전유㎡) _전유면적']
    selected_df[col+'_오차절대값'] = np.abs(selected_df[col+'_오차'])
    selected_df[col+'_오차율'] = selected_df[col+'_오차'] / selected_df['평가단가(원/전유㎡) _전유면적'] * 100
    selected_df[col+'_절대값오차율'] = selected_df[col+'_오차절대값'] / selected_df['평가단가(원/전유㎡) _전유면적'] * 100

# %%
base_cols = ['지번주소', '기준시점2', '건물내용_건물용도', '건물유형', '토지내용_용도지역', '토지내용_도로너비', '도로접면',
             '지형형상2', '평가단가(원/전유㎡) _전유면적'
            ]
cols_to_show = []
for col in selected_cols:
    cols_to_show.append(col)
    cols_to_show.append(col+'_오차율')

# %%
selected2_df = selected_df[(selected_df['건물내용_건물용도'].str.contains('다세'))|(selected_df['건물내용_건물용도'].str.contains('오피'))].dropna(subset=['기준시점2'])
selected2_df = selected2_df[base_cols + cols_to_show]
selected2_df = selected2_df.reset_index(drop=True)
print(selected2_df.shape)
selected2_df
# Out:
# (51, 21)
#                       지번주소                기준시점2   건물내용_건물용도  건물유형 토지내용_용도지역  \
# 0    서울특별시 강남구 개포동 1195-10           2020.09.23       다세대주택   다세대      2종일주
# 1     서울특별시 강남구 개포동 1199-7           2019.11.29       다세대주택   다세대      2종일주
# 2     서울특별시 강남구 역삼동 778-15           2019.11.29      도생-다세대   다세대      2종일주
# 3      서울특별시 강동구 고덕동 292-5           2019.06.14       다세대주택   다세대    2종일반주거
# 4      서울특별시 강동구 고덕동 292-6           2019.06.14       다세대주택   다세대      2종일주
# 5       서울특별시 강동구 길동 140-0           2019.06.14      단지형다세대   다세대      3종일주
# 6        서울특별시 강동구 길동 96-4           2019.06.14   다세대-도시형주택   다세대      3종일주
# 7      서울특별시 강동구 명일동 350-1           2020.11.11  도생(단지형다세대)   다세대      3종일주
# 8     서울특별시 강동구 암사동 433-69           2020.10.23       다세대주택   다세대      3종일주
# 9     서울특별시 강동구 암사동 454-26           2019.04.01       다세대주택   다세대      2종일주
# 10    서울특별시 강동구 암사동 455-51           2019.04.01       다세대주택   다세대      2종일주
# 11    서울특별시 강동구 암사동 457-30           2019.06.14       다세대주택   다세대      2종일주
# 12      서울특별시 강동구 천호동 36-8           2020.10.23       다세대주택   다세대      2종일주
# 13     서울특별시 강북구 미아동 164-2           2019.11.29      단지형다세대   다세대      2종일주
# 14    서울특별시 강북구 미아동 235-11           2019.12.27       다세대주택   다세대      2종일주
# 15  서울특별시 강북구 미아동 791-2978           2020.10.13       다세대주택   다세대      2종일주
# 16    서울특별시 강북구 수유동 172-47           2020.01.10       다세대주택   다세대      2종일주
# 17    서울특별시 강북구 수유동 280-24           2020.10.06       다세대주택   다세대      2종일주
# 18   서울특별시 강북구 수유동 291-195           2020.07.23   도생-단지형다세대   다세대      2종일주
# 19     서울특별시 강북구 수유동 308-1           2020.06.25         다세대   다세대      2종일주
# 20   서울특별시 강북구 수유동 554-105           2020.05.27       다세대주택   다세대      2종일주
# 21    서울특별시 강북구 우이동 100-31           2020.06.18       다세대주택   다세대      2종일주
# 22    서울특별시 강북구 우이동 147-21           2019.01.28       다세대주택   다세대      2종일주
# 23    서울특별시 강북구 우이동 154-37           2020.06.18       다세대주택   다세대      1종일주
# 24     서울특별시 강북구 우이동 161-1           2019.09.10       다세대주택   다세대      2종일주
# 25     서울특별시 강북구 우이동 23-18           2020.08.27       다세대주택   다세대      2종일주
# 26      서울특별시 강북구 우이동 28-6           2020.08.27       다세대주택   다세대      2종일주
# 27     서울특별시 강북구 우이동 61-23           2019.04.22       다세대주택   다세대      2종일주
# 28    서울특별시 구로구 가리봉동 103-1           2019.01.03       다세대주택   다세대      2종일주
# 29   서울특별시 구로구 가리봉동 134-22           2019.01.18       다세대주택   다세대      2종일주
# 30    서울특별시 구로구 가리봉동 771-3           2019.12.13      도생-다세대   다세대      2종일주
# 31    서울특별시 구로구 가리봉동 87-63           2019.12.18       다세대주택   다세대      2종일주
# 32    서울특별시 구로구 개봉동 109-14           2019.05.14       다세대주택   다세대      2종일주
# 33    서울특별시 구로구 개봉동 109-25  2019.11.22 00:00:00       다세대주택   다세대      2종일주
# 34    서울특별시 구로구 개봉동 109-26  2019.11.22 00:00:00       다세대주택   다세대      2종일주
# 35    서울특별시 구로구 개봉동 141-51  2020.08.13 00:00:00         다세대   다세대      2종일주
# 36     서울특별시 구로구 개봉동 147-3  2020.07.10 00:00:00         다세대   다세대      2종일주
# 37     서울특별시 구로구 개봉동 270-1  2020.06.08 00:00:00         다세대   다세대      2종일주
# 38     서울특별시 구로구 개봉동 326-2  2020.06.18 00:00:00         다세대   다세대      2종일주
# 39     서울특별시 구로구 개봉동 329-3  2020.07.17 00:00:00         다세대   다세대      2종일주
# 40      서울특별시 구로구 개봉동 61-7           2019.05.27         다세대   다세대      2종일주
# 41      서울특별시 구로구 개봉동 7-26           2019.11.22      도생-다세대   다세대      3종일주
# 42     서울특별시 구로구 오류동 239-2  2020.09.21 00:00:00   도생-단지형다세대   다세대      2종일주
# 43    서울특별시 금천구 독산동 332-13  2019.01.28 00:00:00   오피스텔 및 근생  오피스텔       준공업
# 44    서울특별시 금천구 독산동 378-96  2019.06.24 00:00:00         다세대   다세대      2종일주
# 45    서울특별시 금천구 시흥동 169-30  2019.06.24 00:00:00      단지형다세대   다세대      1종일주
# 46     서울특별시 금천구 시흥동 203-4  2018.03.23 00:00:00       다세대주택   다세대      2종일주
# 47    서울특별시 금천구 시흥동 204-11  2019.12.06 00:00:00       다세대주택   다세대      2종일주
# 48    서울특별시 금천구 시흥동 220-53  2019.03.04 00:00:00         다세대   다세대      2종일주
# 49    서울특별시 금천구 시흥동 230-15  2019.12.20 00:00:00         다세대   다세대      2종일주
# 50     서울특별시 서초구 양재동 385-8  2019.04.22 00:00:00      도생-다세대   다세대      2종일주
#
#       토지내용_도로너비     도로접면 지형형상2  평가단가(원/전유㎡) _전유면적     최근3년50분위  최근3년50분위_오차율  \
# 0           6미터  세로한면(가)   장방형          1091.9208  1097.178201      0.481482
# 1           4미터  세로한면(가)   장방형          1034.1209   949.838048     -8.150193
# 2   6미터 및\n 4미터  세로각지(가)   장방형          1656.9493  1244.999451    -24.861947
# 3           4미터  세로한면(가)   정방형           989.5452          NaN           NaN
# 4           4미터  세로한면(가)   정방형           988.1178          NaN           NaN
# 5           6미터  세로한면(가)  사다리형           750.4237          NaN           NaN
# 6           4미터  세로한면(가)   정방형           746.9423          NaN           NaN
# 7           8미터     소로각지   부정형           713.2919   715.074115      0.249858
# 8           4미터  세로각지(가)  사다리형           711.0120          NaN           NaN
# 9           4미터  세로한면(가)  사다리형           609.4015   697.009794     14.376120
# 10          4미터  세로한면(가)   장방형           765.2358   697.009794     -8.915684
# 11          4미터  세로한면(가)  사다리형           644.0624   697.009794      8.220848
# 12        4미터미만  세로한면(가)  사다리형           691.6362   728.420827      5.318494
# 13  6미터 및\n 6미터  세로각지(가)   장방형           691.3012   561.992869    -18.705064
# 14          6미터  세로한면(가)   장방형           648.2654   580.110497    -10.513426
# 15          4미터  세로한면(불)   장방형           526.2514   547.323881      4.004261
# 16          6미터  세로각지(가)   장방형           637.1769   585.620594     -8.091365
# 17          4미터  세로한면(가)   정방형           607.9068   588.363582     -3.214838
# 18          4미터  세로한면(가)   정방형           593.5536   588.363582     -0.874397
# 19          4미터  세로한면(가)   정방형           639.7820   588.363582     -8.036865
# 20          8미터  세로한면(가)  사다리형           590.6258   588.363582     -0.383020
# 21          6미터  세로한면(가)   장방형           548.8026   589.233889      7.367183
# 22          4미터  세로한면(가)   정방형           539.1695   563.793852      4.567089
# 23         15미터     소로각지  사다리형           675.0592   675.461238      0.059556
# 24               세로한면(가)  사다리형           537.8067   563.793852      4.832062
# 25          4미터  세로각지(가)   장방형           589.1063   585.552415     -0.603267
# 26          4미터  세로한면(가)   장방형           588.9797   589.233889      0.043158
# 27          4미터  세로한면(가)  사다리형           545.0481   563.793852      3.439284
# 28               세로한면(가)  사다리형           599.1993   626.087983      4.487436
# 29          4미터  세로한면(가)   부정형           544.4678   626.087983     14.990819
# 30          6미터  세로각지(가)  사다리형           555.8343   677.174113     21.830213
# 31          4미터  세로한면(가)   장방형           639.0066   626.087983     -2.021672
# 32          4미터  세로한면(가)   장방형           517.6010   521.524605      0.758037
# 33          6미터  세로한면(가)   장방형           509.5993   521.524605      2.340134
# 34          6미터  세로한면(가)  사다리형           494.6732   521.524605      5.428110
# 35          6미터  세로한면(가)   장방형           654.3656   603.349250     -7.796307
# 36            0  세로한면(가)   장방형           602.0928   603.349250      0.208681
# 37          8미터  세로각지(가)   장방형           622.9724   616.819794     -0.987621
# 38          6미터  세로한면(가)   정방형           570.5505   603.349250      5.748615
# 39          6미터  세로한면(가)   장방형           613.2075   603.349250     -1.607653
# 40          6미터  세로한면(가)   장방형           516.9589   521.524605      0.883185
# 41          8미터     소로한면   장방형           647.4388   551.638237    -14.796852
# 42         12미터  세로한면(불)   삼각형           621.6501   638.130673      2.651101
# 43         10미터     소로각지   장방형           812.3578   810.799832     -0.191784
# 44          6미터  세로한면(가)   장방형           509.9294   526.488742      3.247379
# 45          6미터  세로각지(가)   장방형           652.5043   566.473988    -13.184635
# 46          6미터  세로한면(가)  사다리형           545.7684   536.328290     -1.729692
# 47          6미터  세로각지(가)  사다리형           581.9892   529.832724     -8.961760
# 48          6미터  세로각지(가)  사다리형           501.3561   529.832724      5.679920
# 49         12미터     중로각지  사다리형           580.3119   580.569224      0.044342
# 50          6미터  세로한면(가)   정방형          1158.2789  1064.461996     -8.099682
#
#          최근3년평균  최근3년평균_오차율     최근2년50분위  최근2년50분위_오차율       최근2년평균  \
# 0   1039.889568   -4.765110  1122.177441      2.770956  1090.256392
# 1    969.236554   -6.274348  1072.297113      3.691659  1000.257160
# 2   1320.050460  -20.332477  1287.127545    -22.319437  1359.707070
# 3           NaN         NaN          NaN           NaN          NaN
# 4           NaN         NaN          NaN           NaN          NaN
# 5           NaN         NaN          NaN           NaN          NaN
# 6           NaN         NaN          NaN           NaN          NaN
# 7    715.074115    0.249858   715.074115      0.249858   715.074115
# 8           NaN         NaN          NaN           NaN          NaN
# 9    735.250341   20.651219   738.792888     21.232535   776.945948
# 10   735.250341   -3.918460   738.792888     -3.455525   776.945948
# 11   735.250341   14.158246   738.792888     14.708278   776.945948
# 12   781.753416   13.029569   733.251573      6.016945   800.522677
# 13   588.130064  -14.924195   615.872306    -10.911148   630.385452
# 14   584.360485   -9.857832   604.357300     -6.773167   595.361185
# 15   545.061959    3.574444   547.323881      4.004261   553.010771
# 16   578.955597   -9.137384   622.139036     -2.360077   604.562102
# 17   571.787401   -5.941601   595.936823     -1.969048   601.067183
# 18   571.787401   -3.667099   595.936823      0.401518   601.067183
# 19   571.787401  -10.627776   595.936823     -6.853143   601.067183
# 20   571.787401   -3.189566   595.936823      0.899220   601.067183
# 21   592.435432    7.950551   589.233889      7.367183   590.487784
# 22   577.953216    7.193233   569.864149      5.692950   578.689822
# 23   675.461238    0.059556   675.461238      0.059556   675.461238
# 24   577.953216    7.464860   569.864149      5.960775   578.689822
# 25   566.279942   -3.874744   599.453043      1.756346   599.453043
# 26   592.435432    0.586732   589.233889      0.043158   590.487784
# 27   577.953216    6.037103   569.864149      4.553002   578.689822
# 28   630.134645    5.162781   612.707474      2.254371   617.994109
# 29   630.134645   15.734052   612.707474     12.533280   617.994109
# 30   716.406087   28.888427   736.022073     32.417534   736.022073
# 31   630.134645   -1.388398   612.707474     -4.115627   617.994109
# 32   539.549830    4.240492   544.210815      5.140990   576.668841
# 33   539.549830    5.877271   544.210815      6.791908   576.668841
# 34   539.549830    9.071975   544.210815     10.014210   576.668841
# 35   624.173465   -4.613955   637.243333     -2.616621   642.782588
# 36   624.173465    3.667319   637.243333      5.838059   642.782588
# 37   655.591959    5.236116   661.641962      6.207267   703.374695
# 38   624.173465    9.398461   637.243333     11.689208   642.782588
# 39   624.173465    1.788296   637.243333      3.919690   642.782588
# 40   539.549830    4.369966   544.210815      5.271583   576.668841
# 41   584.200515   -9.767454          NaN           NaN          NaN
# 42   616.354351   -0.851886   638.130673      2.651101   616.354351
# 43   810.799832   -0.191784   810.799832     -0.191784   810.799832
# 44   554.994053    8.837430   540.214456      5.939068   576.951533
# 45   634.340774   -2.783664   566.473988    -13.184635   634.340774
# 46   527.925684   -3.269283   549.754821      0.730424   548.585301
# 47   540.165147   -7.186397   532.700296     -8.469041   547.125786
# 48   540.165147    7.740815   532.700296      6.251883   547.125786
# 49   580.569224    0.044342   580.569224      0.044342   580.569224
# 50  1062.125499   -8.301403  1086.141240     -6.228004  1103.521388
#
#     최근2년평균_오차율       당해50분위  당해50분위_오차율         당해평균   당해평균_오차율
# 0    -0.152429  1229.894917   12.635909  1203.819410  10.247869
# 1    -3.274640  1078.688631    4.309721  1038.445435   0.418185
# 2   -17.939126  1333.283520  -19.533837  1410.535753 -14.871520
# 3          NaN          NaN         NaN          NaN        NaN
# 4          NaN          NaN         NaN          NaN        NaN
# 5          NaN          NaN         NaN          NaN        NaN
# 6          NaN          NaN         NaN          NaN        NaN
# 7     0.249858   715.074115    0.249858   715.074115   0.249858
# 8          NaN          NaN         NaN          NaN        NaN
# 9    27.493278   704.810481   15.656178   726.680517  19.244951
# 10    1.530267   704.810481   -7.896301   726.680517  -5.038353
# 11   20.632092   704.810481    9.432018   726.680517  12.827657
# 12   15.743317   792.684973   14.610105   837.189541  21.044783
# 13   -8.811752   718.983907    4.004435   719.264491   4.045023
# 14   -8.160888   615.384615   -5.072118   592.432263  -8.612697
# 15    5.084903   546.778147    3.900559   546.778147   3.900559
# 16   -5.118641   615.599104   -3.386469   616.560068  -3.235653
# 17   -1.125110   605.477253   -0.399658   620.570028   2.083087
# 18    1.265864   605.477253    2.008859   620.570028   4.551641
# 19   -6.051251   605.477253   -5.361943   620.570028  -3.002894
# 20    1.767851   605.477253    2.514528   620.570028   5.069915
# 21    7.595661   618.251480   12.654619   618.284502  12.660636
# 22    7.329851   559.433880    3.758443   571.145443   5.930592
# 23    0.059556   675.461238    0.059556   675.461238   0.059556
# 24    7.601825   559.433880    4.021367   571.145443   6.199020
# 25    1.756346   601.568579    2.115455   601.568579   2.115455
# 26    0.256050   618.251480    4.969913   618.284502   4.975520
# 27    6.172248   559.433880    2.639360   571.145443   4.788081
# 28    3.136654   558.352626   -6.816876   539.740764  -9.922998
# 29   13.504253   558.352626    2.550165   539.740764  -0.868194
# 30   32.417534   736.022073   32.417534   736.022073  32.417534
# 31   -3.288306   558.352626  -12.621775   539.740764 -15.534399
# 32   11.411848   548.350151    5.940705   588.413856  13.680974
# 33   13.161231   548.350151    7.604181   588.413856  15.465986
# 34   16.575719   548.350151   10.850992   588.413856  18.950017
# 35   -1.770113   719.063545    9.887125   701.758061   7.242505
# 36    6.758059   719.063545   19.427362   701.758061  16.553140
# 37   12.906237   685.087042    9.970689   729.220063  17.054955
# 38   12.660069   719.063545   26.029781   701.758061  22.996660
# 39    4.823015   719.063545   17.262679   701.758061  14.440554
# 40   11.550230   548.350151    6.072291   588.413856  13.822173
# 41         NaN          NaN         NaN          NaN        NaN
# 42   -0.851886   652.150356    4.906338   656.112416   5.543684
# 43   -0.191784   810.799832   -0.191784   810.799832  -0.191784
# 44   13.143414   560.897436    9.995116   618.393987  21.270511
# 45   -2.783664   566.473988  -13.184635   649.725390  -0.425884
# 46    0.516135   571.271676    4.672912   578.234451   5.948686
# 47   -5.990389   529.832724   -8.961760   545.374229  -6.291349
# 48    9.129177   529.832724    5.679920   545.374229   8.779813
# 49    0.044342   580.569224    0.044342   580.569224   0.044342
# 50   -4.727489  1165.080032    0.587176  1162.012844   0.322370

# %%
for col in selected2_df.columns:
    if '오차율' in col:
        print(col, selected2_df[col].apply(np.abs).mean())
# Out:
# 최근3년50분위_오차율 5.934458459939919
# 최근3년평균_오차율 7.084302834918586
# 최근2년50분위_오차율 6.367786045496198
# 최근2년평균_오차율 7.478096721729216
# 당해50분위_오차율 7.930385474871837
# 당해평균_오차율 8.95426703244608
