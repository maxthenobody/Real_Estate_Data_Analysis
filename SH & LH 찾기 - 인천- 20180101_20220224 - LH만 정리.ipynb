# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
pd.options.mode.chained_assignment = None  # default='warn'
plt.rcParams['font.family'] = 'Malgun Gothic'
import datetime
import time
tqdm.tqdm.pandas()

# %%
new_df = pd.read_excel('./공공주택찾기/인천/LH_거래사례_20180101_20220224.xlsx')
new_df = new_df.drop(columns=[
    '일괄계약', '도로명', '시군구', '본번', '부번', '건물연식'
])
print(new_df.shape)
new_df.head()
# Out:
# (2397, 10)
#                       지번주소    건물(단지)명  전용면적(㎡)  거래금액(만원)  층  건축년도       계약날짜  \
# 0  인천광역시 강화군 강화읍 관청리 555-4  송학하얀집1동2동    67.94     14140  4  2018 2018-12-31
# 1  인천광역시 강화군 강화읍 관청리 555-4  송학하얀집1동2동    67.94     14140  3  2018 2018-12-31
# 2  인천광역시 강화군 강화읍 관청리 555-4  송학하얀집1동2동    67.94     14140  2  2018 2018-12-31
# 3  인천광역시 강화군 강화읍 관청리 555-4  송학하얀집1동2동    68.59     14275  5  2018 2018-12-31
# 4  인천광역시 강화군 강화읍 관청리 555-4  송학하얀집1동2동    69.09     14379  4  2018 2018-12-31
#
#      단가(만원/㎡)  부동산유형 소유자
# 0  208.124816  연립다세대  LH
# 1  208.124816  연립다세대  LH
# 2  208.124816  연립다세대  LH
# 3  208.120717  연립다세대  LH
# 4  208.119844  연립다세대  LH

# %%
concat_df = new_df.copy().sort_values(['지번주소', '건축년도', '부동산유형', '계약날짜', '전용면적(㎡)', '층']).reset_index(drop=True)
print(concat_df.shape)
concat_df.head()
# Out:
# (2397, 10)
#                       지번주소    건물(단지)명  전용면적(㎡)  거래금액(만원)  층  건축년도       계약날짜  \
# 0  인천광역시 강화군 강화읍 관청리 555-4  송학하얀집1동2동    67.94     14140  2  2018 2018-12-31
# 1  인천광역시 강화군 강화읍 관청리 555-4  송학하얀집1동2동    67.94     14140  3  2018 2018-12-31
# 2  인천광역시 강화군 강화읍 관청리 555-4  송학하얀집1동2동    67.94     14140  4  2018 2018-12-31
# 3  인천광역시 강화군 강화읍 관청리 555-4  송학하얀집1동2동    68.59     14275  5  2018 2018-12-31
# 4  인천광역시 강화군 강화읍 관청리 555-4  송학하얀집1동2동    69.09     14379  2  2018 2018-12-31
#
#      단가(만원/㎡)  부동산유형 소유자
# 0  208.124816  연립다세대  LH
# 1  208.124816  연립다세대  LH
# 2  208.124816  연립다세대  LH
# 3  208.120717  연립다세대  LH
# 4  208.119844  연립다세대  LH

# %%
concat_df['계약날짜'] = pd.to_datetime(concat_df['계약날짜'])

# %%
from_2019_df = concat_df.copy()

# %%
from_2019_df['전용면적(㎡)_최소'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '전용면적(㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('min')['전용면적(㎡)']
from_2019_df['전용면적(㎡)_평균'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '전용면적(㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('mean')['전용면적(㎡)']
from_2019_df['전용면적(㎡)_최대'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '전용면적(㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('max')['전용면적(㎡)']
from_2019_df['전용면적(㎡)_합'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '전용면적(㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('sum')['전용면적(㎡)']

# %%
from_2019_df['거래금액(만원)_최소'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '거래금액(만원)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('min')['거래금액(만원)']
from_2019_df['거래금액(만원)_평균'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '거래금액(만원)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('mean')['거래금액(만원)']
from_2019_df['거래금액(만원)_최대'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '거래금액(만원)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('max')['거래금액(만원)']
from_2019_df['거래금액(만원)_합'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '거래금액(만원)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('sum')['거래금액(만원)']

# %%
from_2019_df['층_최대'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '층']].groupby(['지번주소', '건축년도', '부동산유형']).transform('max')['층']

# %%
from_2019_df['단가(만원/㎡)_최소'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '단가(만원/㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('min')['단가(만원/㎡)']
from_2019_df['단가(만원/㎡)_평균'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '단가(만원/㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('mean')['단가(만원/㎡)']
from_2019_df['단가(만원/㎡)_최대'] = from_2019_df[['지번주소', '건축년도', '부동산유형', '단가(만원/㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('max')['단가(만원/㎡)']

# %%
from_2019_df.head()
# Out:
#                       지번주소    건물(단지)명  전용면적(㎡)  거래금액(만원)  층  건축년도       계약날짜  \
# 0  인천광역시 강화군 강화읍 관청리 555-4  송학하얀집1동2동    67.94     14140  2  2018 2018-12-31
# 1  인천광역시 강화군 강화읍 관청리 555-4  송학하얀집1동2동    67.94     14140  3  2018 2018-12-31
# 2  인천광역시 강화군 강화읍 관청리 555-4  송학하얀집1동2동    67.94     14140  4  2018 2018-12-31
# 3  인천광역시 강화군 강화읍 관청리 555-4  송학하얀집1동2동    68.59     14275  5  2018 2018-12-31
# 4  인천광역시 강화군 강화읍 관청리 555-4  송학하얀집1동2동    69.09     14379  2  2018 2018-12-31
#
#      단가(만원/㎡)  부동산유형 소유자  전용면적(㎡)_최소  전용면적(㎡)_평균  전용면적(㎡)_최대  전용면적(㎡)_합  \
# 0  208.124816  연립다세대  LH       67.94    68.88375       69.74    1102.14
# 1  208.124816  연립다세대  LH       67.94    68.88375       69.74    1102.14
# 2  208.124816  연립다세대  LH       67.94    68.88375       69.74    1102.14
# 3  208.120717  연립다세대  LH       67.94    68.88375       69.74    1102.14
# 4  208.119844  연립다세대  LH       67.94    68.88375       69.74    1102.14
#
#    거래금액(만원)_최소  거래금액(만원)_평균  거래금액(만원)_최대  거래금액(만원)_합  층_최대  단가(만원/㎡)_최소  \
# 0        14140    14336.125        14514      229378     5   208.115859
# 1        14140    14336.125        14514      229378     5   208.115859
# 2        14140    14336.125        14514      229378     5   208.115859
# 3        14140    14336.125        14514      229378     5   208.115859
# 4        14140    14336.125        14514      229378     5   208.115859
#
#    단가(만원/㎡)_평균  단가(만원/㎡)_최대
# 0   208.120582   208.124816
# 1   208.120582   208.124816
# 2   208.120582   208.124816
# 3   208.120582   208.124816
# 4   208.120582   208.124816

# %%
summary_df = from_2019_df.drop(columns=['전용면적(㎡)', '거래금액(만원)', '층', '단가(만원/㎡)']).drop_duplicates()
summary_df['구'] = summary_df['지번주소'].apply(lambda x: x.split(' ')[1])
summary_df['동'] = summary_df['지번주소'].apply(lambda x: x.split(' ')[2])
summary_df = summary_df.sort_values(['구', '동', '계약날짜', '지번주소', '부동산유형']).reset_index(drop=True)
summary_df = summary_df.drop(columns=['구', '동'])
print(summary_df.shape)
summary_df.head()
# Out:
# (142, 18)
#                       지번주소       건물(단지)명  건축년도       계약날짜  부동산유형 소유자  \
# 0  인천광역시 강화군 강화읍 관청리 555-4     송학하얀집1동2동  2018 2018-12-31  연립다세대  LH
# 1  인천광역시 강화군 강화읍 관청리 755-0         송악하얀집  2019 2019-11-25  연립다세대  LH
# 2      인천광역시 계양구 임학동 60-15         명성다온채  2020 2020-06-25  연립다세대  LH
# 3      인천광역시 계양구 임학동 63-40  명성다온채(63-40)  2020 2020-12-29  연립다세대  LH
# 4     인천광역시 계양구 효성동 495-16         월드사랑채  2017 2018-01-23  연립다세대  LH
#
#    전용면적(㎡)_최소  전용면적(㎡)_평균  전용면적(㎡)_최대  전용면적(㎡)_합  거래금액(만원)_최소   거래금액(만원)_평균  \
# 0       67.94   68.883750       69.74    1102.14        14140  14336.125000
# 1       59.71   67.496250       78.23    1619.91        14321  15558.625000
# 2       48.75   65.350625       84.06    1045.61        17688  22196.437500
# 3       50.99   64.331875       71.57    1029.31        18345  22686.562500
# 4       68.69   74.767368       81.83    1420.58        16959  18459.105263
#
#    거래금액(만원)_최대  거래금액(만원)_합  층_최대  단가(만원/㎡)_최소  단가(만원/㎡)_평균  단가(만원/㎡)_최대
# 0        14514      229378     5   208.115859   208.120582   208.124816
# 1        17356      373407     5   221.858622   230.842863   239.842572
# 2        26143      355143     5   311.004045   342.320245   362.830769
# 3        25121      362985     5   350.999022   352.975876   359.776427
# 4        21068      350723     5   243.070087   246.839317   257.460589

# %%
concat_df['지번주소'].nunique()
# Out:
# 136

# %%
# %%time
summary_df.to_excel('./공공주택찾기/인천/LH_거래사례_요약_동별계약날짜순정렬_20180101_20220224.xlsx', index=False)
# Out:
# Wall time: 86 ms
