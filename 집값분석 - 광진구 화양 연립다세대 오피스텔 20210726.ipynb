# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
pd.options.mode.chained_assignment = None  # default='warn'
plt.rcParams['font.family'] = 'Malgun Gothic'
import datetime

# %%
target_gu = '광진구'
target_dong = '화양'
#target_purpose = '준주거'
target_building_age = 3
target_period = 36 # in months

# %%
date_today = pd.to_datetime(datetime.datetime.now().strftime('%Y-%m-%d'), format='%Y-%m-%d')

# %%
date_today_record = str(date_today).split(' ')[0].replace('-', '')
date_today_record
# Out:
# '20210726'

# %%
def day_modifier(x):
    # x is a number
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x)
        if len(x) == 1:
            return '0' + x
        else:
            return x

# %%
def landnum_modifier(x):
    # x is a string
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x).replace('외', '').replace(' ','')
        splitted = x.split('-')
        if len(splitted) == 1:
            return x + '-0'
        else:
            return x

# %%
def data_prep(bdtype, tradetype):
    # bdtype is a string: one of 아파트, 연립다세대 or 오피스텔
    # tradetype is a string: one of 매매 or 전월세
    
    basedir = './국토교통부_실거래가_공개시스템/{}/{}/'.format(bdtype, tradetype)
    filenames = [f for f in os.listdir(basedir) if (f.endswith('.csv'))&('(' in f)]
    
    dfs_list = []
    for i, f in tqdm(enumerate(filenames)):
        df = pd.read_csv(basedir + f, encoding='euc-kr', header=15)
        if '해제사유발생일' in df.columns.tolist():
            df = df[df['해제사유발생일'].isna()]
            df = df.drop(columns=['해제사유발생일'])

        dfs_list.append(df)
    
    concat_df = pd.concat(dfs_list).reset_index(drop=True)
        
    concat_df['번지'] = concat_df['번지'].apply(landnum_modifier)
    
    concat_df['계약년월'] = concat_df['계약년월'].apply(str)
    concat_df['계약일'] = concat_df['계약일'].apply(str)
    
    concat_df['계약날짜기준_건물연식'] = concat_df['계약년월'].apply(lambda x: int(x[:4])) - concat_df['건축년도']
    
    concat_df['계약일'] = concat_df['계약일'].apply(day_modifier)
    
    concat_df['계약날짜'] = concat_df['계약년월'].apply(lambda x: x[:4]) + '-' + concat_df['계약년월'].apply(lambda x: x[-2:])\
    + '-' + concat_df['계약일']
    
    concat_df['계약날짜'] = pd.to_datetime(concat_df['계약날짜'], format='%Y-%m-%d')
    
    concat_df['거래금액(만원)'] = concat_df['거래금액(만원)'].apply(lambda x: int(x.replace(',','')))
    concat_df['단가(만원/㎡)'] = concat_df['거래금액(만원)'] / concat_df['전용면적(㎡)']
    
    concat_df['지번주소'] = concat_df['시군구'] + ' ' + concat_df['번지']
        
    cols_to_drop = ['시군구', '번지', '본번', '부번', '지번주소', '계약년월', '계약일', '도로명']
        
    concat_df = concat_df[['지번주소', '도로명'] + [col for col in concat_df.columns if col not in cols_to_drop]]
    
    date_today = pd.to_datetime(datetime.datetime.now().strftime('%Y-%m-%d'), format='%Y-%m-%d')
    concat_df['건물연식'] = date_today.year - concat_df['건축년도']
    
    concat_df = concat_df.dropna(subset=['지번주소'])
    
    if '건물명' in concat_df.columns:
        concat_df.rename(columns={'건물명':'건물(단지)명'}, inplace=True)
    elif '단지명' in concat_df.columns:
        concat_df.rename(columns={'단지명':'건물(단지)명'}, inplace=True)
    
    concat_df = concat_df[concat_df['층'] >= 0].reset_index(drop=True)
    
    return concat_df

# %%
yunrip_df = data_prep('연립다세대', '매매')
yunrip_df['부동산유형'] = '연립다세대'
print(yunrip_df.shape)
yunrip_df.head()
# Out:
# 16it [00:01, 10.66it/s]
# (644920, 13)
#                    지번주소         도로명   건물(단지)명  전용면적(㎡)  대지권면적(㎡)  거래금액(만원)  층  \
# 0  서울특별시 강남구 개포동 171-13   선릉로14길 11  (171-13)    68.08     56.10     56500  2
# 1  서울특별시 강남구 개포동 1239-7   개포로15길 25   강남빌라 가동    52.59     45.00     40500  2
# 2  서울특별시 강남구 개포동 1239-7   개포로15길 25   강남빌라 가동    52.59     45.00     42000  1
# 3  서울특별시 강남구 개포동 1239-6   개포로15길 27   강남빌라 나동    52.75     44.68     22000  2
# 4  서울특별시 강남구 개포동 1175-2  논현로6길 36-8      강남파크    49.43     23.70     17000  4
#
#      건축년도  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형
# 0  1988.0         18.0 2006-12-20  829.905993  33.0  연립다세대
# 1  1988.0         18.0 2006-12-09  770.108386  33.0  연립다세대
# 2  1988.0         18.0 2006-12-19  798.630918  33.0  연립다세대
# 3  1988.0         18.0 2006-11-02  417.061611  33.0  연립다세대
# 4  1993.0         13.0 2006-07-19  343.920696  28.0  연립다세대

# %%
officetel_df = data_prep('오피스텔', '매매')
officetel_df['부동산유형'] = '오피스텔'
print(officetel_df.shape)
officetel_df.head()
# Out:
# 16it [00:00, 42.75it/s]
# (183378, 12)
#                  지번주소      도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)   층    건축년도  \
# 0  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44      6400   8  1997.0
# 1  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44      7100   7  1997.0
# 2  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44      7300  11  1997.0
# 3  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    31.91      7500  10  1997.0
# 4  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44      7400  15  1997.0
#
#    계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식 부동산유형
# 0          9.0 2006-01-10  197.287300  24.0  오피스텔
# 1          9.0 2006-01-10  218.865598  24.0  오피스텔
# 2          9.0 2006-01-11  225.030826  24.0  오피스텔
# 3          9.0 2006-01-18  235.036039  24.0  오피스텔
# 4          9.0 2006-01-19  228.113440  24.0  오피스텔

# %%
yunrip_df = yunrip_df.drop(columns=['대지권면적(㎡)'])
house_df = pd.concat([yunrip_df, officetel_df]).sort_values(['지번주소', '건축년도', '전용면적(㎡)', '계약날짜']).reset_index(drop=True)
print(house_df.shape)
house_df.head()
# Out:
# (828298, 12)
#                     지번주소       도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 0   서울특별시 강남구 개포동 1164-0   논현로2길 6    골드캐슬    58.05     57500  2  2017.0
# 1   서울특별시 강남구 개포동 1164-0   논현로2길 6    골드캐슬    58.05     57000  1  2017.0
# 2   서울특별시 강남구 개포동 1164-0   논현로2길 6    골드캐슬    58.05     63000  2  2017.0
# 3  서울특별시 강남구 개포동 1164-26  논현로2길 64   슈베르트빌    34.47     31000  4  2015.0
# 4  서울특별시 강남구 개포동 1164-26  논현로2길 64   슈베르트빌    34.47     30000  3  2015.0
#
#    계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형
# 0          1.0 2018-01-20   990.525409   4.0  연립다세대
# 1          1.0 2018-06-01   981.912145   4.0  연립다세대
# 2          2.0 2019-01-19  1085.271318   4.0  연립다세대
# 3          1.0 2016-03-01   899.332753   6.0  연립다세대
# 4          1.0 2016-03-20   870.322019   6.0  연립다세대

# %%
'''land_specs_df = pd.read_csv('./prepped_data/land_specs_ver_4.csv')
print(land_specs_df.shape)
land_specs_df.head()'''
# Out:
# "land_specs_df = pd.read_csv('./prepped_data/land_specs_ver_4.csv')\nprint(land_specs_df.shape)\nland_specs_df.head()"

# %%
'''last_df = land_specs_df.drop_duplicates(subset=['지번주소'], keep='last').drop(columns=['년', '공시지가']).reset_index(drop=True)
print(last_df.shape)
last_df.head()'''
# Out:
# "last_df = land_specs_df.drop_duplicates(subset=['지번주소'], keep='last').drop(columns=['년', '공시지가']).reset_index(drop=True)\nprint(last_df.shape)\nlast_df.head()"

# %%
'''house_merge_df = house_df.merge(last_df, on=['지번주소']).reset_index(drop=True)
print(house_merge_df.shape)'''
# Out:
# "house_merge_df = house_df.merge(last_df, on=['지번주소']).reset_index(drop=True)\nprint(house_merge_df.shape)"

# %%
house_df['구'] = house_df['지번주소'].apply(lambda x: x.split(' ')[1])
house_df['동'] = house_df['지번주소'].apply(lambda x: x.split(' ')[2])
#house_merge_df['구'] = house_merge_df['지번주소'].apply(lambda x: x.split(' ')[1])
#house_merge_df['동'] = house_merge_df['지번주소'].apply(lambda x: x.split(' ')[2])

# %%
target_df = house_df[
    (house_df['지번주소'].str.contains(target_gu + ' ' + target_dong))
    #&(house_df['동'] == target_dong)
    &(house_df['계약날짜'] >= (date_today - pd.DateOffset(months=target_period)))
    &(house_df['건물연식'] <= target_building_age)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_df.shape)
target_df.head()
# Out:
# (45, 14)
#                          지번주소         도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층  \
# 248286  서울특별시 광진구 화양동 111-102    광나루로 382    아스하임    17.15     20000  5
# 248436    서울특별시 광진구 화양동 17-68  광나루로16길 19  세종에버그린    33.71     29250  3
# 248437    서울특별시 광진구 화양동 17-92  광나루로16길 21  세종에버그린    33.53     27000  6
# 248438    서울특별시 광진구 화양동 17-92  광나루로16길 21  세종에버그린    33.53     32900  6
# 248439    서울특별시 광진구 화양동 17-92  광나루로16길 21  세종에버그린    33.71     30500  5
#
#           건축년도  계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식 부동산유형    구    동
# 248286  2018.0          2.0 2020-07-20  1166.180758   3.0  오피스텔  광진구  화양동
# 248436  2018.0          3.0 2021-07-06   867.695046   3.0  오피스텔  광진구  화양동
# 248437  2018.0          1.0 2019-04-29   805.249031   3.0  오피스텔  광진구  화양동
# 248438  2018.0          2.0 2020-12-14   981.210856   3.0  오피스텔  광진구  화양동
# 248439  2018.0          3.0 2021-06-04   904.776031   3.0  오피스텔  광진구  화양동

# %%
sales_idx_basedir = './한국부동산원/실거래가격지수/'
filenames = [f for f in os.listdir(sales_idx_basedir) if '연립다세대' in f]

sales_idx_df = pd.read_excel(sales_idx_basedir + filenames[0], header=[10, 11])

sales_idx_cols_list = []
for i in range(sales_idx_df.shape[1]):
    if i == 0:
        sales_idx_cols_list.append(sales_idx_df.columns[i][0])
    else:
        sales_idx_cols_list.append(sales_idx_df.columns[i][0] + '_' + sales_idx_df.columns[i][1])

sales_idx_df.columns = sales_idx_cols_list

# %%
def get_sales_idx(x):
    # x is a pandas timestamp
    
    df = sales_idx_df.copy()
    
    if pd.isna(x) == True:
        return x
    else:
        year = str(x.year)
        month = str(x.month)
        if len(month) == 1:
            month = '0'+month
        
        idx = df[year+'년 '+month+'월_지수'].iloc[0]
        
        return idx

# %%
def get_index_applied_prices(df):
    df = df.copy()
    
    last_idx = sales_idx_df.iloc[0,-2]
    
    last_date = sales_idx_df.columns[-1].split('_')[0]
    
    last_date = last_date.split(' ')[0].replace('년','') + '-' + last_date.split(' ')[1].replace('월','') + '-01'
    
    target_upper_limit_df = df[df['계약날짜'] < pd.to_datetime(last_date)]
    target_upper_limit_df['계약날짜_실거래지수'] = target_upper_limit_df['계약날짜'].apply(get_sales_idx)
    target_upper_limit_df['지수적용단가'] = target_upper_limit_df['단가(만원/㎡)'] / target_upper_limit_df['계약날짜_실거래지수'] * last_idx
    df['지수적용단가'] = df['단가(만원/㎡)']
    df.loc[target_upper_limit_df.index, '지수적용단가'] = target_upper_limit_df['지수적용단가']
    df['평가날짜'] = df['계약날짜']
    df.loc[target_upper_limit_df.index, '평가날짜'] = pd.to_datetime(last_date[:-2] + '01')
    
    return df

# %%
target_df = get_index_applied_prices(target_df)
print(target_df.shape)
target_df.head()
# Out:
# (45, 16)
#                          지번주소         도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층  \
# 248286  서울특별시 광진구 화양동 111-102    광나루로 382    아스하임    17.15     20000  5
# 248436    서울특별시 광진구 화양동 17-68  광나루로16길 19  세종에버그린    33.71     29250  3
# 248437    서울특별시 광진구 화양동 17-92  광나루로16길 21  세종에버그린    33.53     27000  6
# 248438    서울특별시 광진구 화양동 17-92  광나루로16길 21  세종에버그린    33.53     32900  6
# 248439    서울특별시 광진구 화양동 17-92  광나루로16길 21  세종에버그린    33.71     30500  5
#
#           건축년도  계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식 부동산유형    구    동  \
# 248286  2018.0          2.0 2020-07-20  1166.180758   3.0  오피스텔  광진구  화양동
# 248436  2018.0          3.0 2021-07-06   867.695046   3.0  오피스텔  광진구  화양동
# 248437  2018.0          1.0 2019-04-29   805.249031   3.0  오피스텔  광진구  화양동
# 248438  2018.0          2.0 2020-12-14   981.210856   3.0  오피스텔  광진구  화양동
# 248439  2018.0          3.0 2021-06-04   904.776031   3.0  오피스텔  광진구  화양동
#
#              지수적용단가       평가날짜
# 248286  1289.880108 2021-05-01
# 248436   867.695046 2021-07-06
# 248437   981.406310 2021-05-01
# 248438  1035.551401 2021-05-01
# 248439   904.776031 2021-06-04

# %%
target_df = target_df.sort_values(['지번주소', '건축년도', '계약날짜']).reset_index(drop=True)
target_df1 = target_df[['지번주소', '건물(단지)명', '건물연식', '층', '전용면적(㎡)', '계약날짜', '거래금액(만원)', '단가(만원/㎡)', '평가날짜', '지수적용단가', '부동산유형']]
target_df1.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/실거래가.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
target_df1.head()
# Out:
#                     지번주소 건물(단지)명  건물연식  층  전용면적(㎡)       계약날짜  거래금액(만원)  \
# 0  서울특별시 광진구 화양동 111-102    아스하임   3.0  5    17.15 2020-07-20     20000
# 1    서울특별시 광진구 화양동 17-68  세종에버그린   3.0  3    33.71 2021-07-06     29250
# 2    서울특별시 광진구 화양동 17-92  세종에버그린   3.0  6    33.53 2019-04-29     27000
# 3    서울특별시 광진구 화양동 17-92  세종에버그린   3.0  6    33.53 2020-12-14     32900
# 4    서울특별시 광진구 화양동 17-92  세종에버그린   3.0  5    33.71 2021-06-04     30500
#
#       단가(만원/㎡)       평가날짜       지수적용단가 부동산유형
# 0  1166.180758 2021-05-01  1289.880108  오피스텔
# 1   867.695046 2021-07-06   867.695046  오피스텔
# 2   805.249031 2021-05-01   981.406310  오피스텔
# 3   981.210856 2021-05-01  1035.551401  오피스텔
# 4   904.776031 2021-06-04   904.776031  오피스텔

# %%
target_df1_30 = target_df1[
    (target_df1['전용면적(㎡)'] >= 28)
    &(target_df1['전용면적(㎡)'] <= 32)
]

# %%
target_df1_30.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/실거래가_30.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('최근 {}개월 {} {} 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 {}건의 전용면적 단가'.format(target_period, target_gu, target_dong, target_building_age, target_df.shape[0]))
plt.grid(True)
ax.xaxis.update_units(target_df['계약날짜'])
sns.regplot(x=ax.xaxis.convert_units(target_df['계약날짜']), y=target_df['단가(만원/㎡)'])
plt.savefig('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/산포도.png'.format(target_gu, target_dong, date_today_record))

# %%
target_last_df = target_df.drop_duplicates(subset=['지번주소', '건축년도'], keep='last').reset_index(drop=True)

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('최근 {}개월 {} {} 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 {}건의 전용면적 단가'.format(target_period, target_gu, target_dong, target_building_age, target_last_df.shape[0]))
plt.grid(True)
ax.xaxis.update_units(target_last_df['계약날짜'])
sns.regplot(x=ax.xaxis.convert_units(target_last_df['계약날짜']), y=target_last_df['단가(만원/㎡)'])
plt.savefig('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/마지막_산포도.png'.format(target_gu, target_dong, date_today_record))

# %%
target_last_df.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/마지막_실거래가.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
target_df2 = house_df[
    (house_df['지번주소'].str.contains(target_gu + ' ' + target_dong))
    #&(house_df['동'] == target_dong)
    #&(house_merge_df['계약날짜'] >= (date_today - pd.DateOffset(months=target_period)))
    &(house_df['계약날짜기준_건물연식'] <= target_building_age)
    #&(house_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_df2.shape)
target_df2.head()
# Out:
# (455, 14)
#                        지번주소         도로명  건물(단지)명  전용면적(㎡)  거래금액(만원)  층  \
# 248129  서울특별시 광진구 화양동 101-2  능동로17길 7-2  (101-2)    14.31     11783  5
# 248130  서울특별시 광진구 화양동 101-2  능동로17길 7-2  (101-2)    14.31     11783  3
# 248131  서울특별시 광진구 화양동 101-2  능동로17길 7-2  (101-2)    14.35     11783  5
# 248132  서울특별시 광진구 화양동 101-2  능동로17길 7-2  (101-2)    14.35     11783  3
# 248133  서울특별시 광진구 화양동 101-2  능동로17길 7-2  (101-2)    15.47     12807  3
#
#           건축년도  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형    구    동
# 248129  2015.0          2.0 2017-06-27  823.410203   6.0  연립다세대  광진구  화양동
# 248130  2015.0          2.0 2017-06-27  823.410203   6.0  연립다세대  광진구  화양동
# 248131  2015.0          2.0 2017-06-27  821.114983   6.0  연립다세대  광진구  화양동
# 248132  2015.0          2.0 2017-06-27  821.114983   6.0  연립다세대  광진구  화양동
# 248133  2015.0          2.0 2017-06-27  827.860375   6.0  연립다세대  광진구  화양동

# %%
target_df2 = get_index_applied_prices(target_df2)

# %%
font = {'size': 12}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(12,6))
plt.title('{} {} 계약날짜기준 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 {}건의 전용면적 단가'.format(target_gu, target_dong, target_building_age, target_df2.shape[0]))
plt.grid(True)
sns.histplot(target_df2['단가(만원/㎡)'], kde=True)
# Out:
# <AxesSubplot:title={'center':'광진구 화양 계약날짜기준 건물연식 3년이하 연립다세대 및 오피스텔 매매 실거래 455건의 전용면적 단가'}, xlabel='단가(만원/㎡)', ylabel='Count'>

# %%
target_df3 = target_df2[['지번주소', '건물(단지)명', '건축년도', '층', '전용면적(㎡)', '계약날짜', '단가(만원/㎡)', '평가날짜', '지수적용단가', '부동산유형']]
target_df3 = target_df3.sort_values(['지번주소', '건축년도', '계약날짜']).reset_index(drop=True)
target_df3.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/지수적용_실거래가.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
target_df3_30 = target_df3[
    (target_df3['전용면적(㎡)'] >= 28)
    &(target_df3['전용면적(㎡)'] <= 32)
]

# %%
target_df3_30.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/지수적용_실거래가_30.xlsx'.format(target_gu, target_dong, date_today_record), index=False)

# %%
concat_df = pd.concat([target_df2])

# %%
concat_df = concat_df.sort_values(['지번주소', '건축년도', '전용면적(㎡)', '계약날짜']).reset_index(drop=True)
concat_df = concat_df.drop_duplicates(['지번주소', '건축년도', '전용면적(㎡)'], keep='last').reset_index(drop=True)

# %%
concat_df['단가평균'] = concat_df[['지번주소', '건축년도', '단가(만원/㎡)']].groupby(['지번주소', '건축년도']).transform('mean')['단가(만원/㎡)']
concat_df['지수적용단가평균'] = concat_df[['지번주소', '건축년도', '지수적용단가']].groupby(['지번주소', '건축년도']).transform('mean')['지수적용단가']

# %%
concat_df = concat_df.sort_values(['지번주소', '건축년도', '평가날짜']).reset_index(drop=True)
print(concat_df.shape)
concat_df.head()
# Out:
# (108, 18)
#                   지번주소         도로명  건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 0  서울특별시 광진구 화양동 101-2  능동로17길 7-2  (101-2)    14.31     11783  3  2015.0
# 1  서울특별시 광진구 화양동 101-2  능동로17길 7-2  (101-2)    14.35     11783  3  2015.0
# 2  서울특별시 광진구 화양동 101-2  능동로17길 7-2  (101-2)    15.47     12807  5  2015.0
# 3  서울특별시 광진구 화양동 101-2  능동로17길 7-2  (101-2)    15.78     13149  5  2015.0
# 4  서울특별시 광진구 화양동 109-4    군자로6길 27    예그리나Ⅰ    12.00     12000  3  2013.0
#
#    계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형    구    동       지수적용단가  \
# 0          2.0 2017-06-27   823.410203   6.0  연립다세대  광진구  화양동  1071.564530
# 1          2.0 2017-06-27   821.114983   6.0  연립다세대  광진구  화양동  1068.577590
# 2          2.0 2017-06-27   827.860375   6.0  연립다세대  광진구  화양동  1077.355867
# 3          2.0 2017-06-27   833.269962   6.0  연립다세대  광진구  화양동  1084.395763
# 4          2.0 2015-10-06  1000.000000   8.0  연립다세대  광진구  화양동  1408.125314
#
#         평가날짜        단가평균     지수적용단가평균
# 0 2021-05-01  826.413881  1075.473437
# 1 2021-05-01  826.413881  1075.473437
# 2 2021-05-01  826.413881  1075.473437
# 3 2021-05-01  826.413881  1075.473437
# 4 2021-05-01  606.717135   854.333756

# %%
concat_last_df = concat_df.drop_duplicates(subset=['지번주소', '건축년도'], keep='last')
print(concat_last_df.shape)
concat_last_df
# Out:
# (35, 18)
#                       지번주소           도로명      건물(단지)명  전용면적(㎡)  거래금액(만원)   층  \
# 3      서울특별시 광진구 화양동 101-2    능동로17길 7-2      (101-2)    15.78     13149   5
# 13     서울특별시 광진구 화양동 109-4      군자로6길 27        예그리나Ⅰ    20.74      4300   6
# 21     서울특별시 광진구 화양동 109-7      군자로6길 28        예그리나Ⅱ    25.22      5250   6
# 22   서울특별시 광진구 화양동 111-102      광나루로 382         아스하임    17.15     20000   5
# 24    서울특별시 광진구 화양동 111-22   능동로19길 7-10       정익제이타워    14.68     19400   7
# 25    서울특별시 광진구 화양동 112-14                   (112-14)    15.86     13865   6
# 29     서울특별시 광진구 화양동 113-1     능동로19길 35       광진 코지웰    23.31     14964  13
# 33     서울특별시 광진구 화양동 17-16        군자로 43         아스하임    20.91     22900   3
# 39     서울특별시 광진구 화양동 17-21   광나루로16길 9-7         smp樂    35.73     12000   7
# 42     서울특별시 광진구 화양동 17-43    군자로7길 2-13        화양아트빌    65.28     16855   5
# 43     서울특별시 광진구 화양동 17-68    광나루로16길 19       세종에버그린    33.71     29250   3
# 46     서울특별시 광진구 화양동 17-92    광나루로16길 21       세종에버그린    33.71     30500   5
# 49      서울특별시 광진구 화양동 18-9      광나루로 358      화양 디펠리체    20.45     22000  18
# 50     서울특별시 광진구 화양동 19-39    광나루로14길 15       YN웰하우스    12.00      9400   2
# 53     서울특별시 광진구 화양동 19-52  광나루로14길 21-1  sheel tower    14.85      8865   4
# 54     서울특별시 광진구 화양동 19-53    광나루로16길 18        KY동부빌    55.86     30000   3
# 55     서울특별시 광진구 화양동 19-57    광나루로16길 14  \t(19-57)\t    78.05     29500   5
# 57      서울특별시 광진구 화양동 19-9    광나루로16길 12       로제트화양빌    29.66     15700   4
# 60     서울특별시 광진구 화양동 193-0      광나루로 386      하이뷰오피스텔    18.57     18630   4
# 65      서울특별시 광진구 화양동 2-22     능동로 153-1        비다펠리즈    15.20     27300   9
# 68     서울특별시 광진구 화양동 20-10    광나루로14길 24        더하우스인    37.22     27500   6
# 69     서울특별시 광진구 화양동 20-11    광나루로14길 30      (20-11)    59.40     19400   5
# 74      서울특별시 광진구 화양동 21-2      광나루로 346     브라운스톤 화양    64.86     20900   4
# 77     서울특별시 광진구 화양동 21-20                    광진캠퍼스시티    24.38     19400   4
# 78     서울특별시 광진구 화양동 21-22     동일로30길 23  케이타워 오피스텔 B    18.85     15000  10
# 80     서울특별시 광진구 화양동 21-23     광나루로14길 8  케이타워 오피스텔 A    19.93     13400   3
# 83      서울특별시 광진구 화양동 3-93  아차산로33길 84-4        그린시티빌    35.16     35000   8
# 86     서울특별시 광진구 화양동 32-27     동일로28길 38      (32-27)    36.82     17250   5
# 91     서울특별시 광진구 화양동 35-46  아차산로27길 57-3      (35-46)    44.40     14250   5
# 95      서울특별시 광진구 화양동 42-7       동일로 122        삼원제우스    29.98     28000   6
# 97     서울특별시 광진구 화양동 46-20  아차산로25길 32-5         대은빌라    69.70     18800   3
# 98      서울특별시 광진구 화양동 56-0      군자로4길 22          에버빌    51.72     27500   3
# 103      서울특별시 광진구 화양동 7-3      아차산로 229         한림타워    33.10     18000  18
# 104     서울특별시 광진구 화양동 77-0    군자로6길 50-5       (77-0)    41.54     37000   3
# 107     서울특별시 광진구 화양동 93-3      능동로16길 9         캠퍼니안    42.42     12200   7
#
#        건축년도  계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형    구    동  \
# 3    2015.0          2.0 2017-06-27   833.269962   6.0  연립다세대  광진구  화양동
# 13   2013.0          2.0 2015-10-06   207.328833   8.0   오피스텔  광진구  화양동
# 21   2013.0          2.0 2015-09-18   208.168121   8.0   오피스텔  광진구  화양동
# 22   2018.0          2.0 2020-07-20  1166.180758   3.0   오피스텔  광진구  화양동
# 24   2016.0          2.0 2018-09-14  1321.525886   5.0  연립다세대  광진구  화양동
# 25   2015.0          2.0 2017-01-10   874.211854   6.0   오피스텔  광진구  화양동
# 29   2014.0          0.0 2014-12-15   641.956242   7.0   오피스텔  광진구  화양동
# 33   2016.0          0.0 2016-06-11  1095.169775   5.0   오피스텔  광진구  화양동
# 39   2012.0          1.0 2013-04-27   335.852225   9.0  연립다세대  광진구  화양동
# 42   2004.0          2.0 2006-01-24   258.195466  17.0  연립다세대  광진구  화양동
# 43   2018.0          3.0 2021-07-06   867.695046   3.0   오피스텔  광진구  화양동
# 46   2018.0          3.0 2021-06-04   904.776031   3.0   오피스텔  광진구  화양동
# 49   2019.0          2.0 2021-01-18  1075.794621   2.0   오피스텔  광진구  화양동
# 50   2012.0          1.0 2013-11-21   783.333333   9.0  연립다세대  광진구  화양동
# 53   2012.0          2.0 2014-11-05   596.969697   9.0  연립다세대  광진구  화양동
# 54   2013.0          1.0 2014-12-22   537.056928   8.0  연립다세대  광진구  화양동
# 55   2012.0          3.0 2015-11-13   377.962844   9.0   오피스텔  광진구  화양동
# 57   2014.0          1.0 2015-12-26   529.332434   7.0  연립다세대  광진구  화양동
# 60   2020.0          1.0 2021-04-07  1003.231018   1.0   오피스텔  광진구  화양동
# 65   2021.0          0.0 2021-07-01  1796.052632   0.0  연립다세대  광진구  화양동
# 68   2018.0          1.0 2019-03-09   738.850081   3.0   오피스텔  광진구  화양동
# 69   2014.0          0.0 2014-03-29   326.599327   7.0  연립다세대  광진구  화양동
# 74   2006.0          2.0 2008-08-18   322.232501  15.0   오피스텔  광진구  화양동
# 77   2017.0          1.0 2018-11-26   795.734208   4.0   오피스텔  광진구  화양동
# 78   2013.0          3.0 2016-12-24   795.755968   8.0   오피스텔  광진구  화양동
# 80   2013.0          3.0 2016-11-18   672.353236   8.0   오피스텔  광진구  화양동
# 83   2014.0          0.0 2014-07-30   995.449374   7.0  연립다세대  광진구  화양동
# 86   2008.0          1.0 2009-09-16   468.495383  13.0  연립다세대  광진구  화양동
# 91   2011.0          3.0 2014-05-17   320.945946  10.0  연립다세대  광진구  화양동
# 95   2016.0          2.0 2018-12-26   933.955971   5.0  연립다세대  광진구  화양동
# 97   2004.0          2.0 2006-09-01   269.727403  17.0  연립다세대  광진구  화양동
# 98   2008.0          1.0 2009-07-14   531.709203  13.0  연립다세대  광진구  화양동
# 103  2006.0          3.0 2009-12-03   543.806647  15.0   오피스텔  광진구  화양동
# 104  2008.0          3.0 2011-07-20   890.707752  13.0  연립다세대  광진구  화양동
# 107  2004.0          3.0 2007-11-22   287.600189  17.0   오피스텔  광진구  화양동
#
#           지수적용단가       평가날짜         단가평균     지수적용단가평균
# 3    1084.395763 2021-05-01   826.413881  1075.473437
# 13    291.944978 2021-05-01   606.717135   854.333756
# 21    295.264950 2021-05-01   566.086211   802.934746
# 22   1289.880108 2021-05-01  1166.180758  1289.880108
# 24   1599.448892 2021-05-01  1302.233123  1650.365950
# 25   1175.281388 2021-05-01   874.211854  1175.281388
# 29    965.687512 2021-05-01   772.418020  1053.718240
# 33   1517.829233 2021-05-01  1082.412808  1431.641988
# 39    504.117084 2021-05-01   559.100961   839.215361
# 42    661.999042 2021-05-01   258.225928   662.077146
# 43    867.695046 2021-07-06   867.695046   867.695046
# 46    904.776031 2021-06-04   870.785625   948.926498
# 49   1121.271588 2021-05-01  1041.636069  1168.441413
# 50   1181.659733 2021-05-01   783.333333  1181.659733
# 53    900.150111 2021-05-01   598.125738   901.893266
# 54    807.888660 2021-05-01   537.056928   807.888660
# 55    536.254833 2021-05-01   377.962844   536.254833
# 57    757.682533 2021-05-01   536.050621   729.187469
# 60   1019.554600 2021-05-01  1019.328483  1035.913987
# 65   1796.052632 2021-07-01  1621.127832  1629.880953
# 68    904.730449 2021-05-01   973.233913  1175.087696
# 69    489.440833 2021-05-01   326.599327   489.440833
# 74    434.672326 2021-05-01   314.731044   435.292589
# 77    978.303550 2021-05-01   887.679304  1028.469941
# 78   1072.954869 2021-05-01   795.755968  1072.954869
# 80    905.256696 2021-05-01   677.430410   941.096503
# 83   1505.925434 2021-05-01   868.675522  1236.463134
# 86    626.093679 2021-05-01   540.369731   722.146013
# 91    484.982976 2021-05-01   650.121577   982.906931
# 95   1149.940547 2021-05-01   942.166653  1168.710830
# 97    585.897694 2021-05-01   167.797328   361.059505
# 98    737.007240 2021-05-01   531.709203   737.007240
# 103   739.186108 2021-05-01   535.076596   742.488646
# 104  1250.602919 2021-05-01   890.707752  1250.602919
# 107   455.064127 2021-05-01   274.780872   491.562305

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('{} {} 계약날짜기준 건물연식 {}년이하 연립다세대 및 오피스텔 매매 실거래 지번별 {}곳의 전용면적 실거래가격지수 적용후 단가평균'.format(target_gu, target_dong, target_building_age, concat_last_df.shape[0]))
plt.grid(True)
sns.histplot(concat_last_df['지수적용단가'], kde=True)
plt.savefig('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/지번별_분포도.png'.format(target_gu, target_dong, date_today_record))

# %%
concat_last_df = concat_last_df.sort_values(['지번주소']).reset_index(drop=True)

# %%
concat_last_df = concat_last_df[['지번주소', '건물(단지)명', '건축년도', '전용면적(㎡)', '층', '계약날짜', '단가(만원/㎡)', '평가날짜', '지수적용단가', '부동산유형']]
concat_last_df.rename(columns={'계약날짜':'마지막_계약날짜'}, inplace=True)
concat_last_df.head()
# Out:
#                     지번주소  건물(단지)명    건축년도  전용면적(㎡)  층   마지막_계약날짜     단가(만원/㎡)  \
# 0    서울특별시 광진구 화양동 101-2  (101-2)  2015.0    15.78  5 2017-06-27   833.269962
# 1    서울특별시 광진구 화양동 109-4    예그리나Ⅰ  2013.0    20.74  6 2015-10-06   207.328833
# 2    서울특별시 광진구 화양동 109-7    예그리나Ⅱ  2013.0    25.22  6 2015-09-18   208.168121
# 3  서울특별시 광진구 화양동 111-102     아스하임  2018.0    17.15  5 2020-07-20  1166.180758
# 4   서울특별시 광진구 화양동 111-22   정익제이타워  2016.0    14.68  7 2018-09-14  1321.525886
#
#         평가날짜       지수적용단가  부동산유형
# 0 2021-05-01  1084.395763  연립다세대
# 1 2021-05-01   291.944978   오피스텔
# 2 2021-05-01   295.264950   오피스텔
# 3 2021-05-01  1289.880108   오피스텔
# 4 2021-05-01  1599.448892  연립다세대

# %%
concat_last_df.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대_오피스텔_{}/지수적용_마지막_실거래가.xlsx'.format(target_gu, target_dong, date_today_record), index=False)
