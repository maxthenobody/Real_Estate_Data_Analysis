# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
pd.options.mode.chained_assignment = None  # default='warn'
plt.rcParams['font.family'] = 'Malgun Gothic'
import datetime

# %%
date_today = pd.to_datetime(datetime.datetime.now().strftime('%Y-%m-%d'), format='%Y-%m-%d')

# %%
def day_modifier(x):
    # x is a number
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x)
        if len(x) == 1:
            return '0' + x
        else:
            return x

# %%
def landnum_modifier(x):
    # x is a string
    
    if pd.isna(x) == True:
        return x
    else:
        x = str(x).replace('외', '').replace(' ','')
        splitted = x.split('-')
        if len(splitted) == 1:
            return x + '-0'
        else:
            return x

# %%
def data_prep(bdtype, tradetype):
    # bdtype is a string: one of 아파트, 연립다세대 or 오피스텔
    # tradetype is a string: one of 매매 or 전월세
    
    basedir = './국토교통부_실거래가_공개시스템/{}/{}/'.format(bdtype, tradetype)
    filenames = [f for f in os.listdir(basedir) if (f.endswith('.csv'))&('(' in f)]
    
    dfs_list = []
    for i, f in tqdm(enumerate(filenames)):
        df = pd.read_csv(basedir + f, encoding='euc-kr', header=15)
        if '해제사유발생일' in df.columns.tolist():
            df = df[df['해제사유발생일'].isna()]
            df = df.drop(columns=['해제사유발생일'])

        dfs_list.append(df)
    
    concat_df = pd.concat(dfs_list).reset_index(drop=True)
        
    concat_df['번지'] = concat_df['번지'].apply(landnum_modifier)
    
    concat_df['계약년월'] = concat_df['계약년월'].apply(str)
    concat_df['계약일'] = concat_df['계약일'].apply(str)
    
    concat_df['계약날짜기준_건물연식'] = concat_df['계약년월'].apply(lambda x: int(x[:4])) - concat_df['건축년도']
    
    concat_df['계약일'] = concat_df['계약일'].apply(day_modifier)
    
    concat_df['계약날짜'] = concat_df['계약년월'].apply(lambda x: x[:4]) + '-' + concat_df['계약년월'].apply(lambda x: x[-2:])\
    + '-' + concat_df['계약일']
    
    concat_df['계약날짜'] = pd.to_datetime(concat_df['계약날짜'], format='%Y-%m-%d')
    
    concat_df['거래금액(만원)'] = concat_df['거래금액(만원)'].apply(lambda x: int(x.replace(',','')))
    concat_df['단가(만원/㎡)'] = concat_df['거래금액(만원)'] / concat_df['전용면적(㎡)']
    
    concat_df['지번주소'] = concat_df['시군구'] + ' ' + concat_df['번지']
        
    cols_to_drop = ['시군구', '번지', '본번', '부번', '지번주소', '계약년월', '계약일', '도로명']
        
    concat_df = concat_df[['지번주소', '도로명'] + [col for col in concat_df.columns if col not in cols_to_drop]]
    
    date_today = pd.to_datetime(datetime.datetime.now().strftime('%Y-%m-%d'), format='%Y-%m-%d')
    concat_df['건물연식'] = date_today.year - concat_df['건축년도']
    
    concat_df = concat_df.dropna(subset=['지번주소'])
    
    if '건물명' in concat_df.columns:
        concat_df.rename(columns={'건물명':'건물(단지)명'}, inplace=True)
    elif '단지명' in concat_df.columns:
        concat_df.rename(columns={'단지명':'건물(단지)명'}, inplace=True)
    
    concat_df = concat_df.reset_index(drop=True)
    
    return concat_df

# %%
yunrip_df = data_prep('연립다세대', '매매')
yunrip_df['부동산유형'] = '연립다세대'
print(yunrip_df.shape)
yunrip_df.head()
# Out:
# 16it [00:02,  7.18it/s]
# (688876, 13)
#                    지번주소          도로명   건물(단지)명  전용면적(㎡)  대지권면적(㎡)  거래금액(만원)  \
# 0  서울특별시 강남구 개포동 1264-3  개포로31길 23-7  (1264-3)    53.28     29.23     11500
# 1  서울특별시 강남구 개포동 171-13    선릉로14길 11  (171-13)    68.08     56.10     56500
# 2  서울특별시 강남구 개포동 1239-7    개포로15길 25   강남빌라 가동    52.59     45.00     40500
# 3  서울특별시 강남구 개포동 1239-7    개포로15길 25   강남빌라 가동    52.59     45.00     42000
# 4  서울특별시 강남구 개포동 1239-6    개포로15길 27   강남빌라 나동    52.75     44.68     22000
#
#    층    건축년도  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형
# 0 -1  1992.0         14.0 2006-08-29  215.840841  29.0  연립다세대
# 1  2  1988.0         18.0 2006-12-20  829.905993  33.0  연립다세대
# 2  2  1988.0         18.0 2006-12-09  770.108386  33.0  연립다세대
# 3  1  1988.0         18.0 2006-12-19  798.630918  33.0  연립다세대
# 4  2  1988.0         18.0 2006-11-02  417.061611  33.0  연립다세대

# %%
officetel_df = data_prep('오피스텔', '매매')
officetel_df['부동산유형'] = '오피스텔'
print(officetel_df.shape)
officetel_df.head()
# Out:
# 16it [00:00, 31.24it/s]
# (178516, 12)
#                  지번주소      도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)   층    건축년도  \
# 0  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44      6400   8  1997.0
# 1  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44      7100   7  1997.0
# 2  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44      7300  11  1997.0
# 3  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    31.91      7500  10  1997.0
# 4  서울특별시 강남구 개포동 13-3  개포로 623    대청타워    32.44      7400  15  1997.0
#
#    계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식 부동산유형
# 0          9.0 2006-01-10  197.287300  24.0  오피스텔
# 1          9.0 2006-01-10  218.865598  24.0  오피스텔
# 2          9.0 2006-01-11  225.030826  24.0  오피스텔
# 3          9.0 2006-01-18  235.036039  24.0  오피스텔
# 4          9.0 2006-01-19  228.113440  24.0  오피스텔

# %%
land_specs_df = pd.read_csv('./prepped_data/land_specs_ver_4.csv')
#land_specs_df['지형형상2'] = land_specs_df['지형형상'].apply(land_shape2)
print(land_specs_df.shape)
land_specs_df.head()
# Out:
# (8706295, 11)
#                   지번주소     년 지목명   토지면적  용도지역명1  용도지역명2 토지이동상황 지형높이 지형형상 도로접면  \
# 0  서울특별시 강남구 개포동 100-0  2013   전  876.0  자연녹지지역  지정되지않음      전  완경사  부정형   맹지
# 1  서울특별시 강남구 개포동 100-0  2014   전  876.0  자연녹지지역  지정되지않음      전  완경사  부정형   맹지
# 2  서울특별시 강남구 개포동 100-0  2015   전  876.0  자연녹지지역  지정되지않음      전  완경사  부정형   맹지
# 3  서울특별시 강남구 개포동 100-0  2016   전  876.0  자연녹지지역  지정되지않음      전  완경사  부정형   맹지
# 4  서울특별시 강남구 개포동 100-0  2017   전  876.0  자연녹지지역  지정되지않음      전  완경사  부정형   맹지
#
#        공시지가
# 0  325000.0
# 1  330000.0
# 2  335000.0
# 3  345000.0
# 4  355000.0

# %%
last_df = land_specs_df.drop_duplicates(subset=['지번주소'], keep='last').drop(columns=['년', '공시지가']).reset_index(drop=True)
print(last_df.shape)
last_df.head()
# Out:
# (981464, 9)
#                   지번주소 지목명    토지면적  용도지역명1  용도지역명2 토지이동상황 지형높이 지형형상 도로접면
# 0  서울특별시 강남구 개포동 100-0   전   876.0  자연녹지지역  지정되지않음      전  완경사  부정형   맹지
# 1  서울특별시 강남구 개포동 101-0   전   641.0  자연녹지지역  지정되지않음      전   평지  부정형   맹지
# 2  서울특별시 강남구 개포동 102-0   전   509.0  자연녹지지역  지정되지않음      전   평지  부정형   맹지
# 3  서울특별시 강남구 개포동 103-0   전    48.7  자연녹지지역  개발제한구역      전   평지  부정형   맹지
# 4  서울특별시 강남구 개포동 104-1   전  2995.0  개발제한구역  자연녹지지역      전  완경사  부정형   맹지

# %%
yunrip_merge_df = yunrip_df.merge(last_df, on=['지번주소']).reset_index(drop=True)
officetel_merge_df = officetel_df.merge(last_df, on=['지번주소']).reset_index(drop=True)

# %%
yunrip_df['구'] = yunrip_df['지번주소'].apply(lambda x: x.split(' ')[1])
yunrip_df['동'] = yunrip_df['지번주소'].apply(lambda x: x.split(' ')[2])
yunrip_merge_df['구'] = yunrip_merge_df['지번주소'].apply(lambda x: x.split(' ')[1])
yunrip_merge_df['동'] = yunrip_merge_df['지번주소'].apply(lambda x: x.split(' ')[2])
officetel_df['구'] = officetel_df['지번주소'].apply(lambda x: x.split(' ')[1])
officetel_df['동'] = officetel_df['지번주소'].apply(lambda x: x.split(' ')[2])
officetel_merge_df['구'] = officetel_merge_df['지번주소'].apply(lambda x: x.split(' ')[1])
officetel_merge_df['동'] = officetel_merge_df['지번주소'].apply(lambda x: x.split(' ')[2])

# %%
target_gu = '동대문구'
target_dong = '전농동'
target_purpose = '2종일반'

# %%
target_df = yunrip_merge_df[
    (yunrip_merge_df['구'] == target_gu)
    &(yunrip_merge_df['동'] == target_dong)
    &(yunrip_merge_df['계약날짜'] >= (date_today - pd.DateOffset(months=18)))
    &(yunrip_merge_df['건물연식'] <= 4)
    #&(yunrip_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_df.shape)
target_df.head()
# Out:
# (50, 23)
#                          지번주소           도로명   건물(단지)명  전용면적(㎡)  대지권면적(㎡)  \
# 638537  서울특별시 동대문구 전농동 213-18   답십리로23길 110    213-18    29.08     20.50
# 638538  서울특별시 동대문구 전농동 213-18   답십리로23길 110    213-18    28.35     20.50
# 654150  서울특별시 동대문구 전농동 213-12  서울시립대로16길 26  (213-12)    29.83     18.50
# 654163  서울특별시 동대문구 전농동 127-25  서울시립대로25길 22  City 팰리스    58.73     36.35
# 654164  서울특별시 동대문구 전농동 127-25  서울시립대로25길 22  City 팰리스    58.73     36.35
#
#         거래금액(만원)  층    건축년도  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식  부동산유형  \
# 638537     26900  5  2017.0          3.0 2020-12-02  925.034388   4.0  연립다세대
# 638538     24000  3  2017.0          3.0 2020-12-24  846.560847   4.0  연립다세대
# 654150     26500  3  2017.0          3.0 2020-06-15  888.367415   4.0  연립다세대
# 654163     58000  2  2017.0          2.0 2019-11-16  987.570237   4.0  연립다세대
# 654164     42000  4  2017.0          3.0 2020-01-13  715.137068   4.0  연립다세대
#
#        지목명   토지면적     용도지역명1  용도지역명2 토지이동상황 지형높이  지형형상     도로접면     구    동
# 638537   대  394.0  제2종일반주거지역  지정되지않음   주상기타   평지  사다리형     소로각지  동대문구  전농동
# 638538   대  394.0  제2종일반주거지역  지정되지않음   주상기타   평지  사다리형     소로각지  동대문구  전농동
# 654150   대  261.0  제2종일반주거지역  지정되지않음    다세대   평지  사다리형  세로한면(가)  동대문구  전농동
# 654163   대  238.0  제3종일반주거지역  지정되지않음    다세대   평지  사다리형  세로한면(가)  동대문구  전농동
# 654164   대  238.0  제3종일반주거지역  지정되지않음    다세대   평지  사다리형  세로한면(가)  동대문구  전농동

# %%
target_df2 = officetel_merge_df[
    (officetel_merge_df['구'] == target_gu)
    &(officetel_merge_df['동'] == target_dong)
    &(officetel_merge_df['계약날짜'] >= (date_today - pd.DateOffset(months=18)))
    &(officetel_merge_df['건물연식'] <= 4)
    #&(officetel_merge_df['용도지역명1'].str.contains(target_purpose))
]
print(target_df2.shape)
target_df2.head()
# Out:
# (7, 22)
#                         지번주소      도로명    건물(단지)명  전용면적(㎡)  거래금액(만원)   층  \
# 166415  서울특별시 동대문구 전농동 601-2           에스앤제이프리미안    16.58     13900   4
# 166416  서울특별시 동대문구 전농동 601-2           에스앤제이프리미안    16.58     11700  11
# 166417  서울특별시 동대문구 전농동 601-2           에스앤제이프리미안    16.58     11200   5
# 171507  서울특별시 동대문구 전농동 100-1  왕산로 294      다스하우스    14.70     12300  10
# 171508  서울특별시 동대문구 전농동 100-1  왕산로 294      다스하우스    14.70     12000  12
#
#           건축년도  계약날짜기준_건물연식       계약날짜    단가(만원/㎡)  건물연식 부동산유형 지목명   토지면적  \
# 166415  2017.0          3.0 2020-12-29  838.359469   4.0  오피스텔   대  144.1
# 166416  2017.0          4.0 2021-01-20  705.669481   4.0  오피스텔   대  144.1
# 166417  2017.0          4.0 2021-03-01  675.512666   4.0  오피스텔   대  144.1
# 171507  2018.0          1.0 2019-11-30  836.734694   3.0  오피스텔   대  248.0
# 171508  2018.0          1.0 2019-12-26  816.326531   3.0  오피스텔   대  248.0
#
#         용도지역명1     용도지역명2 토지이동상황 지형높이  지형형상   도로접면     구    동
# 166415  일반상업지역  제2종일반주거지역    업무용   평지  사다리형  광대로한면  동대문구  전농동
# 166416  일반상업지역  제2종일반주거지역    업무용   평지  사다리형  광대로한면  동대문구  전농동
# 166417  일반상업지역  제2종일반주거지역    업무용   평지  사다리형  광대로한면  동대문구  전농동
# 171507  일반상업지역  제2종일반주거지역   상업기타   평지  사다리형  광대로한면  동대문구  전농동
# 171508  일반상업지역  제2종일반주거지역   상업기타   평지  사다리형  광대로한면  동대문구  전농동

# %%
font = {'size': 16}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(20,10))
plt.title('최근 18개월 {} {} 건물연식 4년이하 연립다세대 매매 실거래 {}건의 전용면적 단가'.format(target_gu, target_dong, target_df.shape[0]))
plt.grid(True)
ax.xaxis.update_units(target_df['계약날짜'])
sns.regplot(x=ax.xaxis.convert_units(target_df['계약날짜']), y=target_df['단가(만원/㎡)'])
#plt.savefig('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대/연립다세대_산포도.png'.format(target_gu, target_dong))
# Out:
# <AxesSubplot:title={'center':'최근 18개월 동대문구 전농동 건물연식 4년이하 연립다세대 매매 실거래 50건의 전용면적 단가'}, ylabel='단가(만원/㎡)'>

# %%
concat_df = pd.concat([target_df])

# %%
concat_df['단가평균'] = concat_df[['지번주소', '건축년도', '단가(만원/㎡)']].groupby(['지번주소', '건축년도']).transform('mean')['단가(만원/㎡)']

# %%
selected_df = concat_df[['지번주소', '건물(단지)명', '부동산유형', '건축년도', '단가평균', '용도지역명1']].drop_duplicates()
selected_df = selected_df.sort_values(['지번주소']).reset_index(drop=True)
print(selected_df.shape)
selected_df.head()
# Out:
# (26, 6)
#                      지번주소    건물(단지)명  부동산유형    건축년도         단가평균     용도지역명1
# 0  서울특별시 동대문구 전농동 103-116      그린빌리지  연립다세대  2019.0  2231.821170  제2종일반주거지역
# 1  서울특별시 동대문구 전농동 103-228      하이프라자  연립다세대  2019.0  1466.225378  제2종일반주거지역
# 2   서울특별시 동대문구 전농동 103-30       포에버빌  연립다세대  2018.0   828.631876  제2종일반주거지역
# 3  서울특별시 동대문구 전농동 103-377  (103-377)  연립다세대  2019.0  1307.328796  제2종일반주거지역
# 4   서울특별시 동대문구 전농동 103-49        명가뷰  연립다세대  2018.0   835.618227  제2종일반주거지역

# %%
selected_df
# Out:
#                       지번주소         건물(단지)명  부동산유형    건축년도         단가평균  \
# 0   서울특별시 동대문구 전농동 103-116           그린빌리지  연립다세대  2019.0  2231.821170
# 1   서울특별시 동대문구 전농동 103-228           하이프라자  연립다세대  2019.0  1466.225378
# 2    서울특별시 동대문구 전농동 103-30            포에버빌  연립다세대  2018.0   828.631876
# 3   서울특별시 동대문구 전농동 103-377       (103-377)  연립다세대  2019.0  1307.328796
# 4    서울특별시 동대문구 전농동 103-49             명가뷰  연립다세대  2018.0   835.618227
# 5    서울특별시 동대문구 전농동 103-93             포시즌  연립다세대  2018.0  1033.388982
# 6    서울특별시 동대문구 전농동 126-27         더가온102동  연립다세대  2019.0  1448.290688
# 7    서울특별시 동대문구 전농동 126-28         더가온101동  연립다세대  2019.0  1438.103991
# 8    서울특별시 동대문구 전농동 126-72        (126-72)  연립다세대  2019.0  1139.031793
# 9   서울특별시 동대문구 전농동 127-102            예원캐슬  연립다세대  2019.0  1404.286770
# 10  서울특별시 동대문구 전농동 127-134  태성골드빌(127-134)  연립다세대  2019.0  1218.026797
# 11  서울특별시 동대문구 전농동 127-156           센트럴21  연립다세대  2019.0  1529.051988
# 12   서울특별시 동대문구 전농동 127-25        City 팰리스  연립다세대  2017.0  1141.291767
# 13   서울특별시 동대문구 전농동 127-34            오크밸리  연립다세대  2018.0  1666.666667
# 14   서울특별시 동대문구 전농동 127-38    현대캐슬(127-38)  연립다세대  2018.0  1594.154395
# 15   서울특별시 동대문구 전농동 127-46       로얄펠리스103동  연립다세대  2020.0   933.333333
# 16   서울특별시 동대문구 전농동 127-57             타워빌  연립다세대  2019.0   754.178557
# 17   서울특별시 동대문구 전농동 127-60             진성빌  연립다세대  2019.0   990.990991
# 18   서울특별시 동대문구 전농동 130-21            그린캐슬  연립다세대  2019.0  1180.916391
# 19   서울특별시 동대문구 전농동 212-19             모두가  연립다세대  2017.0   977.931359
# 20   서울특별시 동대문구 전농동 213-12        (213-12)  연립다세대  2017.0   888.367415
# 21   서울특별시 동대문구 전농동 213-18          213-18  연립다세대  2017.0   885.797617
# 22    서울특별시 동대문구 전농동 213-5         (213-5)  연립다세대  2020.0  1116.967774
# 23    서울특별시 동대문구 전농동 46-21          드림캐슬2차  연립다세대  2017.0   885.966803
# 24     서울특별시 동대문구 전농동 55-3    인성하이츠24차 에이동  연립다세대  2018.0   719.895288
# 25   서울특별시 동대문구 전농동 648-64           로얄팰리스  연립다세대  2018.0  1124.905944
#
#        용도지역명1
# 0   제2종일반주거지역
# 1   제2종일반주거지역
# 2   제2종일반주거지역
# 3   제2종일반주거지역
# 4   제2종일반주거지역
# 5   제3종일반주거지역
# 6   제2종일반주거지역
# 7   제2종일반주거지역
# 8   제2종일반주거지역
# 9   제3종일반주거지역
# 10  제3종일반주거지역
# 11  제3종일반주거지역
# 12  제3종일반주거지역
# 13  제3종일반주거지역
# 14  제3종일반주거지역
# 15  제3종일반주거지역
# 16  제3종일반주거지역
# 17  제3종일반주거지역
# 18  제2종일반주거지역
# 19  제2종일반주거지역
# 20  제2종일반주거지역
# 21  제2종일반주거지역
# 22  제2종일반주거지역
# 23  제2종일반주거지역
# 24  제2종일반주거지역
# 25  제2종일반주거지역

# %%
font = {'size': 13}
matplotlib.rc('font', **font)
f, ax = plt.subplots(figsize=(12,6))
plt.grid(True)
plt.ylabel('수')
plt.title('최근 18개월 {} {} 건물연식 3년이하 연립다세대 매매 실거래 {}곳의 전용면적 단가 평균'.format(target_gu, target_dong, selected_df.shape[0]))
sns.histplot(selected_df['단가평균'], kde=True)
#plt.savefig('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대/연립다세대_분포도.png'.format(target_gu, target_dong))
plt.show()
plt.clf()

# %%
selected_df = selected_df.sort_values(['지번주소']).reset_index(drop=True)

# %%
selected_df.to_excel('./국토교통부_실거래가_공개시스템/집값분석/{}_{}_연립다세대/연립다세대_실거래가.xlsx'.format(target_gu, target_dong), index=False)
