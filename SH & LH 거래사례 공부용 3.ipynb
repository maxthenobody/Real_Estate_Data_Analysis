# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
pd.options.mode.chained_assignment = None  # default='warn'
plt.rcParams['font.family'] = 'Malgun Gothic'
import datetime
import time
import math

# %%
def get_gu_dong(df):
    df = df.copy()
    
    df['구'] = df['지번주소'].apply(lambda x: x.split(' ')[1])
    df['동'] = df['지번주소'].apply(lambda x: x.split(' ')[2])
    
    return df

# %%
bulktrade_basedir = './국토교통부_실거래가_공개시스템/집값분석/일괄구매/10호이상/'

# %%
date_today = pd.to_datetime(datetime.datetime.now())
target_period = 6 # in months

# %%
concat_df = pd.read_csv(bulktrade_basedir+'2018년01월01일부터_2021년06월07일까지_SH_LH_아파트_연립다세대_오피스텔_거래사례.csv')
missing_df = pd.read_csv(bulktrade_basedir+'2018부터_아파트_연립다세대_오피스텔_일괄구매_전체_소유자_포함_기존자료_제외.csv')

# %%
concat_df = concat_df.drop(columns=['Unnamed: 0'])

# %%
print(concat_df.shape)
concat_df.head()
# Out:
# (14793, 13)
#                     지번주소         도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 0  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.39     28300  3  2020.0
# 1  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.39     28300  2  2020.0
# 2  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.46     28400  3  2020.0
# 3  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.46     28400  2  2020.0
# 4  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.55     28500  3  2020.0
#
#    계약날짜기준_건물연식        계약날짜     단가(만원/㎡)  건물연식  부동산유형 소유자
# 0          0.0  2020-03-02  1114.612052   1.0  연립다세대  SH
# 1          0.0  2020-03-02  1114.612052   1.0  연립다세대  SH
# 2          0.0  2020-03-02  1115.475255   1.0  연립다세대  SH
# 3          0.0  2020-03-02  1115.475255   1.0  연립다세대  SH
# 4          0.0  2020-03-02  1115.459883   1.0  연립다세대  SH

# %%
print(missing_df.shape)
missing_df.head()
# Out:
# (11112, 13)
#                    지번주소       도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 0  서울특별시 강남구 개포동 1166-9  논현로2길 37     동영빌    21.50     25850  4  2021.0
# 1  서울특별시 강남구 개포동 1166-9  논현로2길 37     동영빌    21.92     25950  3  2021.0
# 2  서울특별시 강남구 개포동 1166-9  논현로2길 37     동영빌    21.92     26050  2  2021.0
# 3  서울특별시 강남구 개포동 1166-9  논현로2길 37     동영빌    24.42     28150  5  2021.0
# 4  서울특별시 강남구 개포동 1166-9  논현로2길 37     동영빌    25.01     29450  3  2021.0
#
#    계약날짜기준_건물연식        계약날짜     단가(만원/㎡)  건물연식  부동산유형      소유자
# 0          0.0  2021-06-22  1202.325581   0.0  연립다세대  장**외 1명
# 1          0.0  2021-06-22  1183.850365   0.0  연립다세대  장**외 1명
# 2          0.0  2021-06-22  1188.412409   0.0  연립다세대  장**외 1명
# 3          0.0  2021-06-22  1152.743653   0.0  연립다세대  장**외 1명
# 4          0.0  2021-06-22  1177.528988   0.0  연립다세대  장**외 1명

# %%
missing_df['소유자'].isna().sum()
# Out:
# 394

# %%
concat_df = pd.concat([concat_df, missing_df])

concat_df['계약날짜'] = pd.to_datetime(concat_df['계약날짜'])
#yunrip_bulk_df = yunrip_bulk_df[yunrip_bulk_df['계약날짜']  >= (date_today - pd.DateOffset(months=target_period))]
concat_df = concat_df[
    (concat_df['소유자'] == '서***~')
    |(concat_df['소유자'] == '한***~')
    |(concat_df['소유자'] == 'SH')
    |(concat_df['소유자'] == 'LH')
].reset_index(drop=True)
concat_df = get_gu_dong(concat_df)
print(concat_df.shape)
concat_df.head()
# Out:
# (15782, 15)
#                     지번주소         도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 0  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.39     28300  3  2020.0
# 1  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.39     28300  2  2020.0
# 2  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.46     28400  3  2020.0
# 3  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.46     28400  2  2020.0
# 4  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.55     28500  3  2020.0
#
#    계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형 소유자    구    동
# 0          0.0 2020-03-02  1114.612052   1.0  연립다세대  SH  강남구  개포동
# 1          0.0 2020-03-02  1114.612052   1.0  연립다세대  SH  강남구  개포동
# 2          0.0 2020-03-02  1115.475255   1.0  연립다세대  SH  강남구  개포동
# 3          0.0 2020-03-02  1115.475255   1.0  연립다세대  SH  강남구  개포동
# 4          0.0 2020-03-02  1115.459883   1.0  연립다세대  SH  강남구  개포동

# %%
sales_idx_basedir = './한국부동산원/실거래가격지수/'
filenames = [f for f in os.listdir(sales_idx_basedir) if '연립다세대' in f]

sales_idx_df = pd.read_excel(sales_idx_basedir + filenames[0], header=[10, 11])

sales_idx_cols_list = []
for i in range(sales_idx_df.shape[1]):
    if i == 0:
        sales_idx_cols_list.append(sales_idx_df.columns[i][0])
    else:
        sales_idx_cols_list.append(sales_idx_df.columns[i][0] + '_' + sales_idx_df.columns[i][1])

sales_idx_df.columns = sales_idx_cols_list

# %%
def get_sales_idx(x):
    # x is a pandas timestamp
    
    df = sales_idx_df.copy()
    
    if pd.isna(x) == True:
        return x
    else:
        year = str(x.year)
        month = str(x.month)
        if len(month) == 1:
            month = '0'+month
        
        idx = df[year+'년 '+month+'월_지수'].iloc[0]
        
        return idx

# %%
def get_index_applied_prices(df):
    df = df.copy()
    
    last_idx = sales_idx_df.iloc[0,-2]
    
    last_date = sales_idx_df.columns[-1].split('_')[0]
    
    last_date = last_date.split(' ')[0].replace('년','') + '-' + last_date.split(' ')[1].replace('월','') + '-01'
    
    target_upper_limit_df = df[df['계약날짜'] < pd.to_datetime(last_date)]
    target_upper_limit_df['계약날짜_실거래지수'] = target_upper_limit_df['계약날짜'].apply(get_sales_idx)
    target_upper_limit_df['지수적용단가'] = target_upper_limit_df['단가(만원/㎡)'] / target_upper_limit_df['계약날짜_실거래지수'] * last_idx
    df['지수적용단가'] = df['단가(만원/㎡)']
    df.loc[target_upper_limit_df.index, '지수적용단가'] = target_upper_limit_df['지수적용단가']
    df['평가날짜'] = df['계약날짜']
    df.loc[target_upper_limit_df.index, '평가날짜'] = pd.to_datetime(last_date[:-2] + '01')
    
    return df

# %%
concat_df = get_index_applied_prices(concat_df)
print(concat_df.shape)
concat_df.head()
# Out:
# (15782, 17)
#                     지번주소         도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 0  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.39     28300  3  2020.0
# 1  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.39     28300  2  2020.0
# 2  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.46     28400  3  2020.0
# 3  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.46     28400  2  2020.0
# 4  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.55     28500  3  2020.0
#
#    계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형 소유자    구    동  \
# 0          0.0 2020-03-02  1114.612052   1.0  연립다세대  SH  강남구  개포동
# 1          0.0 2020-03-02  1114.612052   1.0  연립다세대  SH  강남구  개포동
# 2          0.0 2020-03-02  1115.475255   1.0  연립다세대  SH  강남구  개포동
# 3          0.0 2020-03-02  1115.475255   1.0  연립다세대  SH  강남구  개포동
# 4          0.0 2020-03-02  1115.459883   1.0  연립다세대  SH  강남구  개포동
#
#         지수적용단가       평가날짜
# 0  1275.958091 2021-04-01
# 1  1275.958091 2021-04-01
# 2  1276.946247 2021-04-01
# 3  1276.946247 2021-04-01
# 4  1276.928649 2021-04-01

# %%
concat_df['구_동'] = concat_df['구'] + '_' + concat_df['동']

# %%
def change_name(x):
    # x is a string
    
    if pd.isna(x) == True:
        return x
    else:
        if x == '한***~':
            return '한국토지주택공사'
        elif x == '서***~':
            return '서울주택도시공사'
        else:
            return x

# %%
concat_df['소유자'] = concat_df['소유자'].apply(change_name)

# %%
concat_df['지번주소'].unique()
# Out:
# array(['서울특별시 강남구 개포동 1195-10', '서울특별시 강남구 개포동 1199-7',
#        '서울특별시 강남구 개포동 1216-7', '서울특별시 강남구 개포동 1237-7',
#        '서울특별시 강남구 개포동 1244-12', '서울특별시 강남구 역삼동 707-9',
#        '서울특별시 강남구 역삼동 751-6', '서울특별시 강남구 역삼동 777-11',
#        '서울특별시 강남구 역삼동 778-15', '서울특별시 강남구 역삼동 778-19',
#        '서울특별시 강남구 역삼동 778-3', '서울특별시 강남구 역삼동 782-26',
#        '서울특별시 강동구 고덕동 194-3', '서울특별시 강동구 고덕동 292-5',
#        '서울특별시 강동구 고덕동 292-6', '서울특별시 강동구 길동 127-8', '서울특별시 강동구 길동 139-0',
#        '서울특별시 강동구 길동 140-0', '서울특별시 강동구 길동 349-9', '서울특별시 강동구 길동 359-16',
#        '서울특별시 강동구 길동 369-4', '서울특별시 강동구 길동 369-5', '서울특별시 강동구 길동 96-4',
#        '서울특별시 강동구 명일동 350-1', '서울특별시 강동구 상일동 346-0',
#        '서울특별시 강동구 성내동 127-13', '서울특별시 강동구 성내동 226-6',
#        '서울특별시 강동구 성내동 275-3', '서울특별시 강동구 성내동 288-45',
#        '서울특별시 강동구 성내동 403-0', '서울특별시 강동구 성내동 404-13',
#        '서울특별시 강동구 성내동 420-3', '서울특별시 강동구 성내동 434-40',
#        '서울특별시 강동구 성내동 440-26', '서울특별시 강동구 성내동 440-5',
#        '서울특별시 강동구 성내동 461-20', '서울특별시 강동구 성내동 461-24',
#        '서울특별시 강동구 성내동 461-3', '서울특별시 강동구 성내동 529-2',
#        '서울특별시 강동구 암사동 430-14', '서울특별시 강동구 암사동 454-26',
#        '서울특별시 강동구 암사동 455-51', '서울특별시 강동구 암사동 456-70',
#        '서울특별시 강동구 암사동 457-30', '서울특별시 강동구 암사동 473-20',
#        '서울특별시 강동구 암사동 475-56', '서울특별시 강동구 암사동 477-33',
#        '서울특별시 강동구 암사동 478-13', '서울특별시 강동구 암사동 486-59',
#        '서울특별시 강동구 암사동 489-22', '서울특별시 강동구 암사동 489-29',
#        '서울특별시 강동구 암사동 489-36', '서울특별시 강동구 천호동 130-2',
#        '서울특별시 강동구 천호동 131-3', '서울특별시 강동구 천호동 133-21',
#        '서울특별시 강동구 천호동 142-25', '서울특별시 강동구 천호동 167-145',
#        '서울특별시 강동구 천호동 17-4', '서울특별시 강동구 천호동 18-163',
#        '서울특별시 강동구 천호동 18-65', '서울특별시 강동구 천호동 185-1',
#        '서울특별시 강동구 천호동 196-1', '서울특별시 강동구 천호동 21-219',
#        '서울특별시 강동구 천호동 210-3', '서울특별시 강동구 천호동 211-10',
#        '서울특별시 강동구 천호동 214-54', '서울특별시 강동구 천호동 224-2',
#        '서울특별시 강동구 천호동 228-1', '서울특별시 강동구 천호동 233-133',
#        '서울특별시 강동구 천호동 233-2', '서울특별시 강동구 천호동 237-27',
#        '서울특별시 강동구 천호동 243-165', '서울특별시 강동구 천호동 289-28',
#        '서울특별시 강동구 천호동 299-10', '서울특별시 강동구 천호동 322-11',
#        '서울특별시 강동구 천호동 330-10', '서울특별시 강동구 천호동 337-64',
#        '서울특별시 강동구 천호동 339-18', '서울특별시 강동구 천호동 36-8',
#        '서울특별시 강동구 천호동 363-26', '서울특별시 강동구 천호동 363-8',
#        '서울특별시 강동구 천호동 386-13', '서울특별시 강동구 천호동 387-50',
#        '서울특별시 강동구 천호동 388-27', '서울특별시 강동구 천호동 391-1',
#        '서울특별시 강동구 천호동 391-19', '서울특별시 강동구 천호동 391-22',
#        '서울특별시 강동구 천호동 391-3', '서울특별시 강동구 천호동 391-5',
#        '서울특별시 강동구 천호동 391-7', '서울특별시 강동구 천호동 392-9',
#        '서울특별시 강동구 천호동 576-0', '서울특별시 강동구 천호동 83-24',
#        '서울특별시 강동구 천호동 84-15', '서울특별시 강동구 천호동 84-19', '서울특별시 강동구 천호동 84-6',
#        '서울특별시 강동구 천호동 87-3', '서울특별시 강동구 천호동 90-4', '서울특별시 강동구 천호동 98-4',
#        '서울특별시 강북구 미아동 164-2', '서울특별시 강북구 미아동 235-11',
#        '서울특별시 강북구 미아동 734-243', '서울특별시 강북구 미아동 734-276',
#        '서울특별시 강북구 미아동 734-278', '서울특별시 강북구 미아동 834-8',
#        '서울특별시 강북구 번동 148-8', '서울특별시 강북구 번동 427-30', '서울특별시 강북구 수유동 130-9',
#        '서울특별시 강북구 수유동 172-47', '서울특별시 강북구 수유동 245-7',
#        '서울특별시 강북구 수유동 269-5', '서울특별시 강북구 수유동 270-163',
#        '서울특별시 강북구 수유동 279-108', '서울특별시 강북구 수유동 291-181',
#        '서울특별시 강북구 수유동 291-193', '서울특별시 강북구 수유동 291-195',
#        '서울특별시 강북구 수유동 308-1', '서울특별시 강북구 수유동 32-5', '서울특별시 강북구 수유동 335-8',
#        '서울특별시 강북구 수유동 359-38', '서울특별시 강북구 수유동 391-387',
#        '서울특별시 강북구 수유동 410-266', '서울특별시 강북구 수유동 412-83',
#        '서울특별시 강북구 수유동 439-5', '서울특별시 강북구 수유동 440-50',
#        '서울특별시 강북구 수유동 50-31', '서울특별시 강북구 수유동 508-10',
#        '서울특별시 강북구 수유동 508-50', '서울특별시 강북구 수유동 508-92',
#        '서울특별시 강북구 수유동 516-2', '서울특별시 강북구 수유동 52-25',
#        '서울특별시 강북구 수유동 554-105', '서울특별시 강북구 수유동 557-19',
#        '서울특별시 강북구 수유동 560-3', '서울특별시 강북구 수유동 573-5',
#        '서울특별시 강북구 수유동 708-7', '서울특별시 강북구 수유동 708-8',
#        '서울특별시 강북구 수유동 709-16', '서울특별시 강북구 수유동 711-8',
#        '서울특별시 강북구 우이동 100-31', '서울특별시 강북구 우이동 147-21',
#        '서울특별시 강북구 우이동 154-37', '서울특별시 강북구 우이동 161-1',
#        '서울특별시 강북구 우이동 28-6', '서울특별시 강북구 우이동 30-17', '서울특별시 강북구 우이동 47-10',
#        '서울특별시 강북구 우이동 61-23', '서울특별시 강서구 공항동 34-53', '서울특별시 강서구 공항동 40-9',
#        '서울특별시 강서구 방화동 180-3', '서울특별시 강서구 방화동 593-2',
#        '서울특별시 강서구 화곡동 1040-4', '서울특별시 강서구 화곡동 1051-24',
#        '서울특별시 강서구 화곡동 379-43', '서울특별시 강서구 화곡동 410-128',
#        '서울특별시 강서구 화곡동 55-82', '서울특별시 강서구 화곡동 56-112',
#        '서울특별시 강서구 화곡동 56-26', '서울특별시 강서구 화곡동 808-3',
#        '서울특별시 강서구 화곡동 817-4', '서울특별시 강서구 화곡동 829-8',
#        '서울특별시 관악구 신림동 103-231', '서울특별시 관악구 신림동 598-159',
#        '서울특별시 관악구 신림동 598-160', '서울특별시 관악구 신림동 610-144',
#        '서울특별시 관악구 신림동 610-207', '서울특별시 관악구 신림동 631-35',
#        '서울특별시 관악구 신림동 650-19', '서울특별시 관악구 신림동 652-154',
#        '서울특별시 광진구 구의동 227-31', '서울특별시 광진구 구의동 64-4',
#        '서울특별시 광진구 구의동 68-17', '서울특별시 광진구 능동 253-6', '서울특별시 광진구 자양동 218-9',
#        '서울특별시 광진구 자양동 219-24', '서울특별시 광진구 자양동 219-8',
#        '서울특별시 광진구 자양동 227-276', '서울특별시 광진구 자양동 800-5',
#        '서울특별시 광진구 중곡동 150-236', '서울특별시 광진구 중곡동 160-4',
#        '서울특별시 광진구 중곡동 189-46', '서울특별시 광진구 중곡동 190-5',
#        '서울특별시 광진구 중곡동 197-11', '서울특별시 광진구 중곡동 210-23',
#        '서울특별시 광진구 중곡동 235-22', '서울특별시 광진구 중곡동 242-28',
#        '서울특별시 광진구 중곡동 245-2', '서울특별시 광진구 중곡동 247-51',
#        '서울특별시 광진구 중곡동 255-9', '서울특별시 광진구 중곡동 554-2',
#        '서울특별시 광진구 중곡동 56-22', '서울특별시 광진구 중곡동 56-4', '서울특별시 광진구 중곡동 574-2',
#        '서울특별시 광진구 중곡동 686-13', '서울특별시 광진구 중곡동 696-1',
#        '서울특별시 광진구 중곡동 73-83', '서울특별시 광진구 중곡동 74-22',
#        '서울특별시 광진구 중곡동 90-31', '서울특별시 구로구 가리봉동 103-1',
#        '서울특별시 구로구 가리봉동 134-22', '서울특별시 구로구 가리봉동 771-4',
#        '서울특별시 구로구 가리봉동 87-63', '서울특별시 구로구 개봉동 108-22',
#        '서울특별시 구로구 개봉동 109-14', '서울특별시 구로구 개봉동 111-15',
#        '서울특별시 구로구 개봉동 111-8', '서울특별시 구로구 개봉동 124-4',
#        '서울특별시 구로구 개봉동 131-5', '서울특별시 구로구 개봉동 137-2',
#        '서울특별시 구로구 개봉동 139-1', '서울특별시 구로구 개봉동 139-67',
#        '서울특별시 구로구 개봉동 139-9', '서울특별시 구로구 개봉동 141-51',
#        '서울특별시 구로구 개봉동 147-3', '서울특별시 구로구 개봉동 270-1',
#        '서울특별시 구로구 개봉동 280-21', '서울특별시 구로구 개봉동 280-6',
#        '서울특별시 구로구 개봉동 305-21', '서울특별시 구로구 개봉동 326-12',
#        '서울특별시 구로구 개봉동 326-2', '서울특별시 구로구 개봉동 329-3',
#        '서울특별시 구로구 개봉동 33-60', '서울특별시 구로구 개봉동 33-69',
#        '서울특별시 구로구 개봉동 335-19', '서울특별시 구로구 개봉동 57-14',
#        '서울특별시 구로구 개봉동 61-3', '서울특별시 구로구 개봉동 7-26', '서울특별시 구로구 고척동 133-14',
#        '서울특별시 구로구 고척동 133-16', '서울특별시 구로구 고척동 145-145',
#        '서울특별시 구로구 고척동 171-1', '서울특별시 구로구 고척동 171-13',
#        '서울특별시 구로구 고척동 241-84', '서울특별시 구로구 고척동 241-88',
#        '서울특별시 구로구 고척동 249-37', '서울특별시 구로구 고척동 249-47',
#        '서울특별시 구로구 고척동 249-94', '서울특별시 구로구 고척동 251-47',
#        '서울특별시 구로구 고척동 268-6', '서울특별시 구로구 고척동 271-193',
#        '서울특별시 구로구 고척동 271-28', '서울특별시 구로구 고척동 62-118',
#        '서울특별시 구로구 궁동 170-0', '서울특별시 구로구 궁동 170-13', '서울특별시 구로구 궁동 187-1',
#        '서울특별시 구로구 궁동 187-23', '서울특별시 구로구 궁동 187-4',
#        '서울특별시 구로구 궁동 190-164', '서울특별시 구로구 궁동 190-165',
#        '서울특별시 구로구 궁동 190-51', '서울특별시 구로구 궁동 190-55',
#        '서울특별시 구로구 궁동 207-27', '서울특별시 구로구 궁동 237-11',
#        '서울특별시 구로구 궁동 280-14', '서울특별시 구로구 궁동 281-7', '서울특별시 구로구 궁동 83-3',
#        '서울특별시 구로구 궁동 89-2', '서울특별시 구로구 궁동 89-8', '서울특별시 구로구 오류동 13-135',
#        '서울특별시 구로구 오류동 135-71', '서울특별시 구로구 오류동 14-360',
#        '서울특별시 구로구 오류동 239-2', '서울특별시 구로구 오류동 240-7',
#        '서울특별시 구로구 오류동 27-20', '서울특별시 구로구 오류동 9-73',
#        '서울특별시 금천구 가산동 148-29', '서울특별시 금천구 가산동 148-53',
#        '서울특별시 금천구 가산동 148-54', '서울특별시 금천구 가산동 148-55',
#        '서울특별시 금천구 가산동 148-56', '서울특별시 금천구 가산동 148-57',
#        '서울특별시 금천구 가산동 153-6', '서울특별시 금천구 독산동 1005-3',
#        '서울특별시 금천구 독산동 1039-25', '서울특별시 금천구 독산동 1057-37',
#        '서울특별시 금천구 독산동 1068-16', '서울특별시 금천구 독산동 1074-14',
#        '서울특별시 금천구 독산동 1075-42', '서울특별시 금천구 독산동 1157-0',
#        '서울특별시 금천구 독산동 234-13', '서울특별시 금천구 독산동 234-25',
#        '서울특별시 금천구 독산동 331-69', '서울특별시 금천구 독산동 332-13',
#        '서울특별시 금천구 독산동 335-3', '서울특별시 금천구 독산동 378-226',
#        '서울특별시 금천구 독산동 378-297', '서울특별시 금천구 독산동 378-332',
#        '서울특별시 금천구 독산동 893-9', '서울특별시 금천구 독산동 913-0',
#        '서울특별시 금천구 독산동 927-8', '서울특별시 금천구 독산동 939-8',
#        '서울특별시 금천구 독산동 941-7', '서울특별시 금천구 독산동 972-0',
#        '서울특별시 금천구 독산동 999-10', '서울특별시 금천구 시흥동 169-30',
#        '서울특별시 금천구 시흥동 203-4', '서울특별시 금천구 시흥동 204-11',
#        '서울특별시 금천구 시흥동 212-6', '서울특별시 금천구 시흥동 220-1',
#        '서울특별시 금천구 시흥동 220-10', '서울특별시 금천구 시흥동 220-161',
#        '서울특별시 금천구 시흥동 220-49', '서울특별시 금천구 시흥동 220-53',
#        '서울특별시 금천구 시흥동 220-79', '서울특별시 금천구 시흥동 230-121',
#        '서울특별시 금천구 시흥동 230-15', '서울특별시 금천구 시흥동 230-50',
#        '서울특별시 금천구 시흥동 230-84', '서울특별시 금천구 시흥동 237-45',
#        '서울특별시 금천구 시흥동 237-6', '서울특별시 금천구 시흥동 239-12',
#        '서울특별시 금천구 시흥동 239-23', '서울특별시 금천구 시흥동 239-25',
#        '서울특별시 금천구 시흥동 790-19', '서울특별시 금천구 시흥동 790-21',
#        '서울특별시 금천구 시흥동 790-8', '서울특별시 금천구 시흥동 799-21',
#        '서울특별시 금천구 시흥동 804-18', '서울특별시 금천구 시흥동 811-7',
#        '서울특별시 금천구 시흥동 813-33', '서울특별시 금천구 시흥동 813-43',
#        '서울특별시 금천구 시흥동 815-9', '서울특별시 금천구 시흥동 819-18',
#        '서울특별시 금천구 시흥동 820-10', '서울특별시 금천구 시흥동 823-55',
#        '서울특별시 금천구 시흥동 825-19', '서울특별시 금천구 시흥동 825-24',
#        '서울특별시 금천구 시흥동 827-15', '서울특별시 금천구 시흥동 827-17',
#        '서울특별시 금천구 시흥동 827-18', '서울특별시 금천구 시흥동 827-29',
#        '서울특별시 금천구 시흥동 833-13', '서울특별시 금천구 시흥동 848-26',
#        '서울특별시 금천구 시흥동 849-32', '서울특별시 금천구 시흥동 849-33',
#        '서울특별시 금천구 시흥동 857-12', '서울특별시 금천구 시흥동 861-58',
#        '서울특별시 금천구 시흥동 863-16', '서울특별시 금천구 시흥동 864-23',
#        '서울특별시 금천구 시흥동 865-30', '서울특별시 금천구 시흥동 865-6',
#        '서울특별시 금천구 시흥동 897-2', '서울특별시 금천구 시흥동 897-22',
#        '서울특별시 금천구 시흥동 919-78', '서울특별시 금천구 시흥동 919-88',
#        '서울특별시 금천구 시흥동 921-4', '서울특별시 금천구 시흥동 922-21',
#        '서울특별시 금천구 시흥동 923-14', '서울특별시 금천구 시흥동 923-29',
#        '서울특별시 금천구 시흥동 924-18', '서울특별시 금천구 시흥동 925-18',
#        '서울특별시 금천구 시흥동 925-7', '서울특별시 금천구 시흥동 927-21',
#        '서울특별시 금천구 시흥동 934-34', '서울특별시 금천구 시흥동 935-83',
#        '서울특별시 금천구 시흥동 940-28', '서울특별시 금천구 시흥동 946-17',
#        '서울특별시 금천구 시흥동 960-10', '서울특별시 금천구 시흥동 989-20',
#        '서울특별시 금천구 시흥동 989-6', '서울특별시 노원구 공릉동 107-136',
#        '서울특별시 노원구 공릉동 270-10', '서울특별시 노원구 공릉동 270-79',
#        '서울특별시 노원구 공릉동 270-80', '서울특별시 노원구 공릉동 370-2',
#        '서울특별시 노원구 공릉동 499-45', '서울특별시 노원구 공릉동 513-22',
#        '서울특별시 노원구 공릉동 517-51', '서울특별시 노원구 공릉동 561-3',
#        '서울특별시 노원구 공릉동 561-4', '서울특별시 노원구 상계동 1017-1',
#        '서울특별시 노원구 상계동 1048-17', '서울특별시 노원구 상계동 1048-18',
#        '서울특별시 노원구 상계동 1048-20', '서울특별시 노원구 상계동 1048-22',
#        '서울특별시 노원구 상계동 1048-29', '서울특별시 노원구 상계동 1048-3',
#        '서울특별시 노원구 상계동 1048-31', '서울특별시 노원구 상계동 1048-38',
#        '서울특별시 노원구 상계동 1048-41', '서울특별시 노원구 상계동 1051-6',
#        '서울특별시 노원구 상계동 1051-8', '서울특별시 노원구 상계동 1052-11',
#        '서울특별시 노원구 상계동 1052-4', '서울특별시 노원구 상계동 1090-21',
#        '서울특별시 노원구 상계동 133-0', '서울특별시 노원구 상계동 134-55',
#        '서울특별시 노원구 상계동 140-237', '서울특별시 노원구 상계동 140-243',
#        '서울특별시 노원구 상계동 142-6', '서울특별시 노원구 상계동 389-229',
#        '서울특별시 노원구 상계동 456-86', '서울특별시 노원구 월계동 534-125',
#        '서울특별시 노원구 월계동 534-186', '서울특별시 노원구 월계동 534-192',
#        '서울특별시 노원구 월계동 534-39', '서울특별시 노원구 하계동 65-4', '서울특별시 노원구 하계동 65-7',
#        '서울특별시 도봉구 도봉동 569-29', '서울특별시 도봉구 도봉동 608-0',
#        '서울특별시 도봉구 도봉동 608-1', '서울특별시 도봉구 도봉동 625-35',
#        '서울특별시 도봉구 방학동 411-1', '서울특별시 도봉구 방학동 623-26',
#        '서울특별시 도봉구 방학동 623-29', '서울특별시 도봉구 방학동 624-30',
#        '서울특별시 도봉구 방학동 632-34', '서울특별시 도봉구 방학동 640-26',
#        '서울특별시 도봉구 방학동 665-29', '서울특별시 도봉구 방학동 675-18',
#        '서울특별시 도봉구 방학동 695-3', '서울특별시 도봉구 쌍문동 137-134',
#        '서울특별시 도봉구 쌍문동 137-200', '서울특별시 도봉구 쌍문동 137-203',
#        '서울특별시 도봉구 쌍문동 137-3', '서울특별시 도봉구 쌍문동 137-30',
#        '서울특별시 도봉구 쌍문동 137-32', '서울특별시 도봉구 쌍문동 137-34',
#        '서울특별시 도봉구 쌍문동 137-40', '서울특별시 도봉구 쌍문동 315-117',
#        '서울특별시 도봉구 쌍문동 498-102', '서울특별시 도봉구 쌍문동 498-70',
#        '서울특별시 도봉구 쌍문동 522-15', '서울특별시 도봉구 쌍문동 522-7',
#        '서울특별시 도봉구 쌍문동 75-14', '서울특별시 도봉구 쌍문동 75-25',
#        '서울특별시 도봉구 쌍문동 94-25', '서울특별시 도봉구 창동 527-21',
#        '서울특별시 도봉구 창동 578-10', '서울특별시 도봉구 창동 603-16',
#        '서울특별시 도봉구 창동 607-32', '서울특별시 도봉구 창동 628-17',
#        '서울특별시 도봉구 창동 628-28', '서울특별시 도봉구 창동 629-8', '서울특별시 도봉구 창동 657-11',
#        '서울특별시 동대문구 답십리동 27-7', '서울특별시 동대문구 답십리동 4-41',
#        '서울특별시 동대문구 답십리동 482-56', '서울특별시 동대문구 답십리동 482-65',
#        '서울특별시 동대문구 용두동 39-455', '서울특별시 동대문구 이문동 210-1',
#        '서울특별시 동대문구 이문동 341-15', '서울특별시 동대문구 장안동 123-21',
#        '서울특별시 동대문구 장안동 130-5', '서울특별시 동대문구 장안동 134-3',
#        '서울특별시 동대문구 장안동 135-6', '서울특별시 동대문구 장안동 138-40',
#        '서울특별시 동대문구 장안동 138-61', '서울특별시 동대문구 장안동 138-62',
#        '서울특별시 동대문구 장안동 138-63', '서울특별시 동대문구 장안동 152-30',
#        '서울특별시 동대문구 장안동 291-18', '서울특별시 동대문구 장안동 291-8',
#        '서울특별시 동대문구 장안동 293-3', '서울특별시 동대문구 장안동 315-17',
#        '서울특별시 동대문구 장안동 326-4', '서울특별시 동대문구 장안동 327-6',
#        '서울특별시 동대문구 장안동 333-4', '서울특별시 동대문구 장안동 339-2',
#        '서울특별시 동대문구 장안동 341-19', '서울특별시 동대문구 장안동 349-25',
#        '서울특별시 동대문구 장안동 349-6', '서울특별시 동대문구 장안동 389-2',
#        '서울특별시 동대문구 장안동 391-10', '서울특별시 동대문구 장안동 392-7',
#        '서울특별시 동대문구 장안동 392-9', '서울특별시 동대문구 장안동 397-2',
#        '서울특별시 동대문구 장안동 401-2', '서울특별시 동대문구 장안동 426-8',
#        '서울특별시 동대문구 장안동 439-9', '서울특별시 동대문구 장안동 453-8',
#        '서울특별시 동대문구 장안동 92-38', '서울특별시 동대문구 장안동 93-33',
#        '서울특별시 동대문구 제기동 135-7', '서울특별시 동대문구 제기동 135-90',
#        '서울특별시 동대문구 청량리동 2-6', '서울특별시 동대문구 회기동 77-7',
#        '서울특별시 동대문구 휘경동 77-8', '서울특별시 동작구 대방동 391-216',
#        '서울특별시 동작구 사당동 175-13', '서울특별시 동작구 사당동 183-14',
#        '서울특별시 동작구 사당동 183-2', '서울특별시 동작구 사당동 183-24',
#        '서울특별시 동작구 사당동 190-152', '서울특별시 동작구 사당동 269-20',
#        '서울특별시 동작구 사당동 314-10', '서울특별시 동작구 사당동 314-12',
#        '서울특별시 동작구 상도1동 483-19', '서울특별시 동작구 상도동 214-61',
#        '서울특별시 동작구 상도동 244-297', '서울특별시 동작구 상도동 279-228',
#        '서울특별시 동작구 상도동 279-417', '서울특별시 동작구 상도동 378-2',
#        '서울특별시 동작구 상도동 7-45', '서울특별시 동작구 신대방동 344-69',
#        '서울특별시 동작구 신대방동 685-2', '서울특별시 마포구 성산동 200-115',
#        '서울특별시 마포구 성산동 636-1', '서울특별시 마포구 연남동 478-6',
#        '서울특별시 마포구 합정동 390-6', '서울특별시 서대문구 남가좌동 331-16',
#        '서울특별시 서대문구 남가좌동 336-18', '서울특별시 서대문구 남가좌동 395-0',
#        '서울특별시 서대문구 대현동 90-26', '서울특별시 서대문구 북가좌동 286-16',
#        '서울특별시 서대문구 북가좌동 3-130', '서울특별시 서대문구 연희동 100-1',
#        '서울특별시 서대문구 연희동 106-14', '서울특별시 서대문구 홍은동 295-5',
#        '서울특별시 서대문구 홍은동 396-6', '서울특별시 서대문구 홍은동 405-18',
#        '서울특별시 서대문구 홍은동 407-10', '서울특별시 서대문구 홍은동 407-11',
#        '서울특별시 서대문구 홍은동 407-3', '서울특별시 서대문구 홍은동 410-23',
#        '서울특별시 서대문구 홍은동 411-12', '서울특별시 서대문구 홍은동 413-6',
#        '서울특별시 서대문구 홍제동 285-14', '서울특별시 서대문구 홍제동 356-15',
#        '서울특별시 서대문구 홍제동 356-18', '서울특별시 서대문구 홍제동 360-62',
#        '서울특별시 서대문구 홍제동 472-0', '서울특별시 서초구 반포동 726-40',
#        '서울특별시 서초구 방배동 467-7', '서울특별시 서초구 방배동 593-2',
#        '서울특별시 서초구 방배동 792-17', '서울특별시 서초구 방배동 882-16',
#        '서울특별시 서초구 방배동 890-28', '서울특별시 서초구 서초동 1428-4',
#        '서울특별시 서초구 서초동 1469-7', '서울특별시 서초구 서초동 1478-16',
#        '서울특별시 서초구 서초동 1478-9', '서울특별시 서초구 서초동 1479-14',
#        '서울특별시 서초구 서초동 1480-11', '서울특별시 서초구 서초동 1481-14',
#        '서울특별시 서초구 양재동 264-2', '서울특별시 서초구 양재동 265-17',
#        '서울특별시 서초구 양재동 337-9', '서울특별시 서초구 양재동 348-8',
#        '서울특별시 서초구 양재동 360-1', '서울특별시 서초구 양재동 361-7',
#        '서울특별시 서초구 양재동 375-3', '서울특별시 서초구 양재동 385-8',
#        '서울특별시 서초구 양재동 388-4', '서울특별시 서초구 양재동 391-15',
#        '서울특별시 서초구 양재동 392-20', '서울특별시 서초구 양재동 395-10',
#        '서울특별시 서초구 양재동 400-6', '서울특별시 서초구 양재동 400-7', '서울특별시 서초구 양재동 6-8',
#        '서울특별시 서초구 우면동 3-1', '서울특별시 서초구 잠원동 34-7', '서울특별시 성동구 마장동 790-19',
#        '서울특별시 성동구 송정동 72-136', '서울특별시 성북구 돈암동 30-53',
#        '서울특별시 성북구 동선동4가 278-1', '서울특별시 성북구 보문동6가 160-0',
#        '서울특별시 성북구 삼선동5가 100-2', '서울특별시 성북구 삼선동5가 28-8',
#        '서울특별시 성북구 상월곡동 85-3', '서울특별시 성북구 석관동 110-7',
#        '서울특별시 성북구 석관동 120-10', '서울특별시 성북구 석관동 120-5',
#        '서울특별시 성북구 석관동 180-12', '서울특별시 성북구 석관동 261-211',
#        '서울특별시 성북구 석관동 261-28', '서울특별시 성북구 석관동 338-39',
#        '서울특별시 성북구 안암동1가 317-14', '서울특별시 성북구 안암동3가 133-51',
#        '서울특별시 성북구 장위동 219-118', '서울특별시 성북구 장위동 219-217',
#        '서울특별시 성북구 장위동 223-53', '서울특별시 성북구 장위동 223-73',
#        '서울특별시 성북구 장위동 224-1', '서울특별시 성북구 장위동 225-63',
#        '서울특별시 성북구 장위동 231-233', '서울특별시 성북구 장위동 232-13',
#        '서울특별시 성북구 장위동 232-76', '서울특별시 성북구 장위동 234-60',
#        '서울특별시 성북구 장위동 234-97', '서울특별시 성북구 장위동 238-127',
#        '서울특별시 성북구 장위동 238-2', '서울특별시 성북구 장위동 238-37',
#        '서울특별시 성북구 장위동 246-66', '서울특별시 성북구 장위동 65-166',
#        '서울특별시 성북구 장위동 65-57', '서울특별시 성북구 장위동 66-204',
#        '서울특별시 성북구 장위동 66-270', '서울특별시 성북구 장위동 68-1044',
#        '서울특별시 성북구 장위동 75-303', '서울특별시 성북구 장위동 75-367',
#        '서울특별시 성북구 장위동 77-50', '서울특별시 성북구 정릉동 206-136',
#        '서울특별시 성북구 정릉동 206-139', '서울특별시 성북구 정릉동 227-84',
#        '서울특별시 성북구 정릉동 266-71', '서울특별시 성북구 정릉동 329-1',
#        '서울특별시 성북구 정릉동 392-33', '서울특별시 성북구 정릉동 410-23',
#        '서울특별시 성북구 정릉동 716-50', '서울특별시 성북구 종암동 10-76',
#        '서울특별시 성북구 종암동 102-119', '서울특별시 성북구 종암동 28-61',
#        '서울특별시 성북구 종암동 98-34', '서울특별시 성북구 종암동 98-4', '서울특별시 성북구 하월곡동 5-16',
#        '서울특별시 성북구 하월곡동 90-1117', '서울특별시 성북구 하월곡동 90-1453',
#        '서울특별시 성북구 하월곡동 90-293', '서울특별시 성북구 하월곡동 90-646',
#        '서울특별시 송파구 가락동 107-2', '서울특별시 송파구 가락동 109-5',
#        '서울특별시 송파구 가락동 11-18', '서울특별시 송파구 가락동 13-0', '서울특별시 송파구 가락동 182-0',
#        '서울특별시 송파구 가락동 182-1', '서울특별시 송파구 가락동 198-5',
#        '서울특별시 송파구 가락동 74-14', '서울특별시 송파구 거여동 251-22',
#        '서울특별시 송파구 마천동 14-4', '서울특별시 송파구 문정동 35-11', '서울특별시 송파구 문정동 35-13',
#        '서울특별시 송파구 방이동 100-16', '서울특별시 송파구 방이동 111-3',
#        '서울특별시 송파구 방이동 118-13', '서울특별시 송파구 방이동 151-23',
#        '서울특별시 송파구 방이동 161-17', '서울특별시 송파구 방이동 211-11',
#        '서울특별시 송파구 방이동 99-5', '서울특별시 송파구 삼전동 170-14',
#        '서울특별시 송파구 삼전동 171-19', '서울특별시 송파구 삼전동 171-20',
#        '서울특별시 송파구 삼전동 171-21', '서울특별시 송파구 삼전동 171-6',
#        '서울특별시 송파구 삼전동 61-7', '서울특별시 송파구 삼전동 64-6', '서울특별시 송파구 석촌동 164-8',
#        '서울특별시 송파구 석촌동 165-8', '서울특별시 송파구 석촌동 245-19',
#        '서울특별시 송파구 석촌동 252-5', '서울특별시 송파구 석촌동 54-19',
#        '서울특별시 송파구 송파동 101-20', '서울특별시 송파구 송파동 102-16',
#        '서울특별시 송파구 송파동 102-26', '서울특별시 송파구 송파동 108-5',
#        '서울특별시 송파구 송파동 11-4', '서울특별시 송파구 송파동 117-31',
#        '서울특별시 송파구 송파동 118-13', '서울특별시 송파구 송파동 139-12',
#        '서울특별시 송파구 송파동 139-21', '서울특별시 송파구 송파동 145-5',
#        '서울특별시 송파구 송파동 174-12', '서울특별시 송파구 송파동 180-3',
#        '서울특별시 송파구 송파동 29-5', '서울특별시 송파구 송파동 90-4', '서울특별시 송파구 오금동 115-1',
#        '서울특별시 송파구 오금동 119-7', '서울특별시 송파구 오금동 133-1',
#        '서울특별시 송파구 오금동 137-0', '서울특별시 송파구 오금동 143-16',
#        '서울특별시 송파구 오금동 143-6', '서울특별시 송파구 오금동 52-21',
#        '서울특별시 송파구 오금동 53-16', '서울특별시 송파구 오금동 53-6', '서울특별시 송파구 오금동 55-0',
#        '서울특별시 송파구 오금동 56-2', '서울특별시 송파구 오금동 69-7', '서울특별시 송파구 오금동 73-2',
#        '서울특별시 송파구 오금동 76-2', '서울특별시 송파구 오금동 79-4', '서울특별시 송파구 오금동 80-1',
#        '서울특별시 송파구 오금동 94-8', '서울특별시 송파구 잠실동 204-3',
#        '서울특별시 송파구 잠실동 239-15', '서울특별시 송파구 잠실동 247-4',
#        '서울특별시 송파구 잠실동 247-7', '서울특별시 송파구 잠실동 295-3',
#        '서울특별시 송파구 잠실동 318-0', '서울특별시 송파구 잠실동 339-0',
#        '서울특별시 양천구 목동 230-15', '서울특별시 양천구 목동 231-106',
#        '서울특별시 양천구 목동 231-119', '서울특별시 양천구 목동 231-120',
#        '서울특별시 양천구 목동 231-33', '서울특별시 양천구 목동 231-97',
#        '서울특별시 양천구 목동 318-44', '서울특별시 양천구 목동 318-66',
#        '서울특별시 양천구 목동 324-85', '서울특별시 양천구 목동 42-7', '서울특별시 양천구 목동 538-18',
#        '서울특별시 양천구 목동 538-29', '서울특별시 양천구 목동 555-12',
#        '서울특별시 양천구 목동 624-10', '서울특별시 양천구 목동 716-2', '서울특별시 양천구 목동 718-1',
#        '서울특별시 양천구 목동 741-16', '서울특별시 양천구 목동 744-9', '서울특별시 양천구 목동 764-2',
#        '서울특별시 양천구 목동 779-2', '서울특별시 양천구 목동 779-22',
#        '서울특별시 양천구 신월동 126-36', '서울특별시 양천구 신월동 492-6',
#        '서울특별시 양천구 신월동 539-10', '서울특별시 양천구 신월동 80-2',
#        '서울특별시 양천구 신월동 80-23', '서울특별시 양천구 신월동 80-24',
#        '서울특별시 양천구 신정동 1286-2', '서울특별시 양천구 신정동 1286-6',
#        '서울특별시 양천구 신정동 917-11', '서울특별시 양천구 신정동 919-2',
#        '서울특별시 양천구 신정동 927-17', '서울특별시 양천구 신정동 967-13',
#        '서울특별시 양천구 신정동 998-2', '서울특별시 영등포구 당산동 121-163',
#        '서울특별시 영등포구 당산동1가 388-1', '서울특별시 영등포구 대림동 663-13',
#        '서울특별시 영등포구 대림동 722-1', '서울특별시 영등포구 대림동 723-9',
#        '서울특별시 영등포구 대림동 779-4', '서울특별시 영등포구 도림동 140-3',
#        '서울특별시 영등포구 도림동 232-9', '서울특별시 영등포구 신길동 453-2',
#        '서울특별시 영등포구 신길동 89-31', '서울특별시 영등포구 양평동6가 65-0',
#        '서울특별시 영등포구 양평동6가 65-1', '서울특별시 영등포구 영등포동2가 196-0',
#        '서울특별시 영등포구 영등포동2가 299-0', '서울특별시 영등포구 영등포동6가 129-0',
#        '서울특별시 은평구 갈현동 228-25', '서울특별시 은평구 갈현동 327-71',
#        '서울특별시 은평구 갈현동 327-95', '서울특별시 은평구 갈현동 479-3',
#        '서울특별시 은평구 갈현동 491-17', '서울특별시 은평구 갈현동 502-37',
#        '서울특별시 은평구 구산동 177-149', '서울특별시 은평구 구산동 178-22',
#        '서울특별시 은평구 구산동 210-14', '서울특별시 은평구 구산동 24-13',
#        '서울특별시 은평구 구산동 24-22', '서울특별시 은평구 구산동 373-3',
#        '서울특별시 은평구 구산동 373-8', '서울특별시 은평구 녹번동 137-21',
#        '서울특별시 은평구 녹번동 144-48', '서울특별시 은평구 녹번동 148-1',
#        '서울특별시 은평구 녹번동 148-25', '서울특별시 은평구 녹번동 156-17',
#        '서울특별시 은평구 녹번동 169-30', '서울특별시 은평구 녹번동 62-1',
#        '서울특별시 은평구 녹번동 95-12', '서울특별시 은평구 대조동 179-21',
#        '서울특별시 은평구 대조동 59-5', '서울특별시 은평구 불광동 484-144',
#        '서울특별시 은평구 불광동 512-0', '서울특별시 은평구 불광동 514-0',
#        '서울특별시 은평구 신사동 15-24', '서울특별시 은평구 신사동 184-16',
#        '서울특별시 은평구 신사동 237-372', '서울특별시 은평구 신사동 270-6',
#        '서울특별시 은평구 신사동 280-1', '서울특별시 은평구 신사동 350-30',
#        '서울특별시 은평구 신사동 6-42', '서울특별시 은평구 역촌동 10-56', '서울특별시 은평구 역촌동 13-15',
#        '서울특별시 은평구 역촌동 2-61', '서울특별시 은평구 역촌동 24-12', '서울특별시 은평구 역촌동 24-13',
#        '서울특별시 은평구 역촌동 43-68', '서울특별시 은평구 역촌동 44-2', '서울특별시 은평구 역촌동 59-11',
#        '서울특별시 은평구 역촌동 77-26', '서울특별시 은평구 응암동 105-22',
#        '서울특별시 은평구 응암동 349-2', '서울특별시 은평구 응암동 42-49',
#        '서울특별시 은평구 응암동 697-9', '서울특별시 은평구 응암동 730-20',
#        '서울특별시 종로구 연지동 231-0', '서울특별시 중구 신당동 340-38', '서울특별시 중구 오장동 90-8',
#        '서울특별시 중랑구 망우동 435-16', '서울특별시 중랑구 망우동 522-12',
#        '서울특별시 중랑구 망우동 522-14', '서울특별시 중랑구 면목동 143-6',
#        '서울특별시 중랑구 면목동 143-72', '서울특별시 중랑구 면목동 155-6',
#        '서울특별시 중랑구 면목동 160-20', '서울특별시 중랑구 면목동 637-2',
#        '서울특별시 중랑구 면목동 661-56', '서울특별시 중랑구 면목동 87-35',
#        '서울특별시 중랑구 묵동 159-14', '서울특별시 중랑구 묵동 187-7', '서울특별시 중랑구 묵동 240-55',
#        '서울특별시 중랑구 묵동 244-43', '서울특별시 중랑구 상봉동 119-30',
#        '서울특별시 중랑구 상봉동 205-4', '서울특별시 중랑구 상봉동 205-46',
#        '서울특별시 중랑구 상봉동 205-8', '서울특별시 중랑구 상봉동 210-26',
#        '서울특별시 중랑구 상봉동 308-1', '서울특별시 중랑구 상봉동 308-20',
#        '서울특별시 중랑구 상봉동 308-21', '서울특별시 중랑구 상봉동 308-22',
#        '서울특별시 중랑구 상봉동 308-23', '서울특별시 중랑구 상봉동 87-21',
#        '서울특별시 중랑구 중화동 10-0', '서울특별시 중랑구 중화동 299-117',
#        '서울특별시 중랑구 중화동 319-3', '서울특별시 중랑구 중화동 323-10',
#        '서울특별시 중랑구 중화동 323-18', '서울특별시 중랑구 중화동 324-34',
#        '서울특별시 중랑구 중화동 330-15', '서울특별시 중랑구 중화동 332-78',
#        '서울특별시 강동구 고덕동 197-1', '서울특별시 강동구 성내동 436-2',
#        '서울특별시 강동구 천호동 206-6', '서울특별시 강동구 천호동 233-46',
#        '서울특별시 강동구 천호동 339-29', '서울특별시 강북구 수유동 130-17',
#        '서울특별시 관악구 신림동 626-11', '서울특별시 구로구 개봉동 115-9',
#        '서울특별시 구로구 구로동 429-154', '서울특별시 금천구 독산동 1159-0',
#        '서울특별시 노원구 공릉동 661-20', '서울특별시 동대문구 장안동 337-2',
#        '서울특별시 동대문구 장안동 341-32', '서울특별시 동대문구 장안동 346-21',
#        '서울특별시 동대문구 장안동 382-14', '서울특별시 동작구 대방동 516-0',
#        '서울특별시 동작구 상도동 279-63', '서울특별시 마포구 공덕동 108-57',
#        '서울특별시 마포구 성산동 200-182', '서울특별시 서초구 양재동 361-5',
#        '서울특별시 서초구 양재동 365-11', '서울특별시 성북구 동소문동4가 75-2',
#        '서울특별시 성북구 상월곡동 54-1', '서울특별시 송파구 가락동 47-10',
#        '서울특별시 송파구 삼전동 117-15', '서울특별시 송파구 신천동 17-0',
#        '서울특별시 송파구 오금동 118-5', '서울특별시 송파구 오금동 46-4', '서울특별시 송파구 오금동 85-5',
#        '서울특별시 송파구 잠실동 226-3', '서울특별시 양천구 신정동 980-9',
#        '서울특별시 은평구 갈현동 456-20', '서울특별시 은평구 역촌동 2-100',
#        '서울특별시 은평구 진관동 100-5', '서울특별시 중랑구 망우동 133-14',
#        '서울특별시 중랑구 면목동 113-13', '서울특별시 중랑구 상봉동 84-11'], dtype=object)

# %%
concat_df['소유자'].value_counts()
# Out:
# SH          8474
# LH          6319
# 서울주택도시공사     496
# 한국토지주택공사     493
# Name: 소유자, dtype: int64

# %%
concat_df.head()
# Out:
#                     지번주소         도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 0  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.39     28300  3  2020.0
# 1  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.39     28300  2  2020.0
# 2  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.46     28400  3  2020.0
# 3  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.46     28400  2  2020.0
# 4  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.55     28500  3  2020.0
#
#    계약날짜기준_건물연식       계약날짜     단가(만원/㎡)  건물연식  부동산유형 소유자    구    동  \
# 0          0.0 2020-03-02  1114.612052   1.0  연립다세대  SH  강남구  개포동
# 1          0.0 2020-03-02  1114.612052   1.0  연립다세대  SH  강남구  개포동
# 2          0.0 2020-03-02  1115.475255   1.0  연립다세대  SH  강남구  개포동
# 3          0.0 2020-03-02  1115.475255   1.0  연립다세대  SH  강남구  개포동
# 4          0.0 2020-03-02  1115.459883   1.0  연립다세대  SH  강남구  개포동
#
#         지수적용단가       평가날짜      구_동
# 0  1275.958091 2021-04-01  강남구_개포동
# 1  1275.958091 2021-04-01  강남구_개포동
# 2  1276.946247 2021-04-01  강남구_개포동
# 3  1276.946247 2021-04-01  강남구_개포동
# 4  1276.928649 2021-04-01  강남구_개포동

# %%
to_print_df = concat_df.drop(columns=['도로명', '계약날짜기준_건물연식', '건물연식', '구', '동', '지수적용단가', '평가날짜'])
print(to_print_df.shape)
to_print_df.head()
# Out:
# (15782, 11)
#                     지번주소 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도       계약날짜  \
# 0  서울특별시 강남구 개포동 1195-10     동영빌    25.39     28300  3  2020.0 2020-03-02
# 1  서울특별시 강남구 개포동 1195-10     동영빌    25.39     28300  2  2020.0 2020-03-02
# 2  서울특별시 강남구 개포동 1195-10     동영빌    25.46     28400  3  2020.0 2020-03-02
# 3  서울특별시 강남구 개포동 1195-10     동영빌    25.46     28400  2  2020.0 2020-03-02
# 4  서울특별시 강남구 개포동 1195-10     동영빌    25.55     28500  3  2020.0 2020-03-02
#
#       단가(만원/㎡)  부동산유형 소유자      구_동
# 0  1114.612052  연립다세대  SH  강남구_개포동
# 1  1114.612052  연립다세대  SH  강남구_개포동
# 2  1115.475255  연립다세대  SH  강남구_개포동
# 3  1115.475255  연립다세대  SH  강남구_개포동
# 4  1115.459883  연립다세대  SH  강남구_개포동

# %%
to_print_df['구_동'].nunique()
# Out:
# 121

# %%
to_print_df = to_print_df[to_print_df['계약날짜'] >= pd.to_datetime('2018-01-01')]
print(to_print_df.shape)
to_print_df.head()
# Out:
# (15782, 11)
#                     지번주소 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도       계약날짜  \
# 0  서울특별시 강남구 개포동 1195-10     동영빌    25.39     28300  3  2020.0 2020-03-02
# 1  서울특별시 강남구 개포동 1195-10     동영빌    25.39     28300  2  2020.0 2020-03-02
# 2  서울특별시 강남구 개포동 1195-10     동영빌    25.46     28400  3  2020.0 2020-03-02
# 3  서울특별시 강남구 개포동 1195-10     동영빌    25.46     28400  2  2020.0 2020-03-02
# 4  서울특별시 강남구 개포동 1195-10     동영빌    25.55     28500  3  2020.0 2020-03-02
#
#       단가(만원/㎡)  부동산유형 소유자      구_동
# 0  1114.612052  연립다세대  SH  강남구_개포동
# 1  1114.612052  연립다세대  SH  강남구_개포동
# 2  1115.475255  연립다세대  SH  강남구_개포동
# 3  1115.475255  연립다세대  SH  강남구_개포동
# 4  1115.459883  연립다세대  SH  강남구_개포동

# %%
to_print_df['구_동'].nunique()
# Out:
# 121

# %%
to_print_df['계약날짜'].describe()
# Out:
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
# count                   15782
# unique                    450
# top       2020-01-16 00:00:00
# freq                      270
# first     2018-01-02 00:00:00
# last      2021-06-22 00:00:00
# Name: 계약날짜, dtype: object

# %%
for gudong in tqdm(to_print_df['구_동'].unique()):
    gudong_df = to_print_df[to_print_df['구_동'] == gudong].drop(columns=['구_동'])
    gudong_df.to_excel(bulktrade_basedir + '2018년부터/' + gudong + '.xlsx', index=False)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 121/121 [00:05<00:00, 24.10it/s]

# %%
to_print_df.head()
# Out:
#                     지번주소 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도       계약날짜  \
# 0  서울특별시 강남구 개포동 1195-10     동영빌    25.39     28300  3  2020.0 2020-03-02
# 1  서울특별시 강남구 개포동 1195-10     동영빌    25.39     28300  2  2020.0 2020-03-02
# 2  서울특별시 강남구 개포동 1195-10     동영빌    25.46     28400  3  2020.0 2020-03-02
# 3  서울특별시 강남구 개포동 1195-10     동영빌    25.46     28400  2  2020.0 2020-03-02
# 4  서울특별시 강남구 개포동 1195-10     동영빌    25.55     28500  3  2020.0 2020-03-02
#
#       단가(만원/㎡)  부동산유형 소유자      구_동
# 0  1114.612052  연립다세대  SH  강남구_개포동
# 1  1114.612052  연립다세대  SH  강남구_개포동
# 2  1115.475255  연립다세대  SH  강남구_개포동
# 3  1115.475255  연립다세대  SH  강남구_개포동
# 4  1115.459883  연립다세대  SH  강남구_개포동

# %%
to_print_df['소유자'] = to_print_df['소유자'].apply(lambda x: x.replace('서울주택도시공사', 'SH'))
to_print_df['소유자'] = to_print_df['소유자'].apply(lambda x: x.replace('한국토지주택공사', 'LH'))

# %%
to_print_df['소유자'].value_counts()
# Out:
# SH    8970
# LH    6812
# Name: 소유자, dtype: int64

# %%
to_print_df['평균_전용면적(㎡)'] = to_print_df[['지번주소', '건축년도', '부동산유형', '전용면적(㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('mean')['전용면적(㎡)']

# %%
to_print_df['총_전용면적(㎡)'] = to_print_df[['지번주소', '건축년도', '부동산유형', '전용면적(㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('sum')['전용면적(㎡)']

# %%
to_print_df['전용면적_표준편차(㎡)'] = to_print_df[['지번주소', '건축년도', '부동산유형', '전용면적(㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('std')['전용면적(㎡)']

# %%
to_print_df['평균_거래금액(만원)'] = to_print_df[['지번주소', '건축년도', '부동산유형', '거래금액(만원)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('mean')['거래금액(만원)']

# %%
to_print_df['총_거래금액(만원)'] = to_print_df[['지번주소', '건축년도', '부동산유형', '거래금액(만원)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('sum')['거래금액(만원)']

# %%
to_print_df['거래금액_표준편차(만원)'] = to_print_df[['지번주소', '건축년도', '부동산유형', '거래금액(만원)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('std')['거래금액(만원)']

# %%
to_print_df['최대_층'] = to_print_df[['지번주소', '건축년도', '부동산유형', '층']].groupby(['지번주소', '건축년도', '부동산유형']).transform('max')['층']

# %%
to_print_df['평균_단가(만원)'] = to_print_df[['지번주소', '건축년도', '부동산유형', '단가(만원/㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('mean')['단가(만원/㎡)']

# %%
to_print_df['단가_표준편차(만원)'] = to_print_df[['지번주소', '건축년도', '부동산유형', '단가(만원/㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('std')['단가(만원/㎡)']

# %%
to_print_df['세대_수'] = to_print_df[['지번주소', '건축년도', '부동산유형', '단가(만원/㎡)']].groupby(['지번주소', '건축년도', '부동산유형']).transform('count')['단가(만원/㎡)']

# %%
to_print_df.head()
# Out:
#                     지번주소 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도       계약날짜  \
# 0  서울특별시 강남구 개포동 1195-10     동영빌    25.39     28300  3  2020.0 2020-03-02
# 1  서울특별시 강남구 개포동 1195-10     동영빌    25.39     28300  2  2020.0 2020-03-02
# 2  서울특별시 강남구 개포동 1195-10     동영빌    25.46     28400  3  2020.0 2020-03-02
# 3  서울특별시 강남구 개포동 1195-10     동영빌    25.46     28400  2  2020.0 2020-03-02
# 4  서울특별시 강남구 개포동 1195-10     동영빌    25.55     28500  3  2020.0 2020-03-02
#
#       단가(만원/㎡)  부동산유형 소유자      구_동  평균_전용면적(㎡)  총_전용면적(㎡)  전용면적_표준편차(㎡)  \
# 0  1114.612052  연립다세대  SH  강남구_개포동   28.814667     432.22      4.855684
# 1  1114.612052  연립다세대  SH  강남구_개포동   28.814667     432.22      4.855684
# 2  1115.475255  연립다세대  SH  강남구_개포동   28.814667     432.22      4.855684
# 3  1115.475255  연립다세대  SH  강남구_개포동   28.814667     432.22      4.855684
# 4  1115.459883  연립다세대  SH  강남구_개포동   28.814667     432.22      4.855684
#
#     평균_거래금액(만원)  총_거래금액(만원)  거래금액_표준편차(만원)  최대_층    평균_단가(만원)  단가_표준편차(만원)  \
# 0  31463.333333      471950     4139.63709     5  1097.178201    36.299709
# 1  31463.333333      471950     4139.63709     5  1097.178201    36.299709
# 2  31463.333333      471950     4139.63709     5  1097.178201    36.299709
# 3  31463.333333      471950     4139.63709     5  1097.178201    36.299709
# 4  31463.333333      471950     4139.63709     5  1097.178201    36.299709
#
#    세대_수
# 0    15
# 1    15
# 2    15
# 3    15
# 4    15

# %%
to_print_df['계약날짜'].describe()
# Out:
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
# count                   15782
# unique                    450
# top       2020-01-16 00:00:00
# freq                      270
# first     2018-01-02 00:00:00
# last      2021-06-22 00:00:00
# Name: 계약날짜, dtype: object

# %%
to_print_df['계약날짜'].max()
# Out:
# Timestamp('2021-06-22 00:00:00')

# %%
to_print_df['계약날짜'].nunique()
# Out:
# 450

# %%
idx_to_drop = []
for addr in tqdm(to_print_df['지번주소'].unique()):
    addr_df = to_print_df[to_print_df['지번주소'] == addr]
    
    if to_print_df['계약날짜'].nunique() > 1:
        not_max_df = addr_df[addr_df['계약날짜'] != addr_df['계약날짜'].max()]
        [idx_to_drop.append(i) for i in not_max_df.index]
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 848/848 [00:01<00:00, 685.38it/s]

# %%
len(idx_to_drop)
# Out:
# 91

# %%
to_print_df = to_print_df.drop(idx_to_drop).reset_index(drop=True)

# %%
summary_df = to_print_df.drop(columns=['전용면적(㎡)', '거래금액(만원)', '층', '단가(만원/㎡)', '구_동']).drop_duplicates().reset_index(drop=True)
print(summary_df.shape)
summary_df.head()
# Out:
# (864, 16)
#                     지번주소 건물(단지)명    건축년도       계약날짜  부동산유형 소유자  평균_전용면적(㎡)  \
# 0  서울특별시 강남구 개포동 1195-10     동영빌  2020.0 2020-03-02  연립다세대  SH   28.814667
# 1   서울특별시 강남구 개포동 1199-7   개포백년빌  2019.0 2019-12-19  연립다세대  LH   27.905000
# 2   서울특별시 강남구 개포동 1216-7     백년빌  2020.0 2020-03-18  연립다세대  SH   26.686000
# 3   서울특별시 강남구 개포동 1237-7     한별2  2021.0 2021-06-01   오피스텔  SH   29.665000
# 4   서울특별시 강남구 개포동 1237-7     한별2  2021.0 2021-06-01  연립다세대  SH   29.946667
#
#    총_전용면적(㎡)  전용면적_표준편차(㎡)   평균_거래금액(만원)  총_거래금액(만원)  거래금액_표준편차(만원)  최대_층  \
# 0     432.22      4.855684  31463.333333      471950    4139.637090     5
# 1     390.67      3.070186  28857.142857      404000    3536.722578     5
# 2     400.29      2.367074  30573.333333      458600    2134.651750     5
# 3     118.66      0.390000  33565.250000      134261     437.500000     2
# 4     449.20      0.037544  38163.333333      572450      44.185755     6
#
#      평균_단가(만원)  단가_표준편차(만원)  세대_수
# 0  1097.178201    36.299709    15
# 1  1033.367584    37.609677    14
# 2  1147.330195    25.484846    15
# 3  1131.477759     0.128995     4
# 4  1274.376854     0.358219    15

# %%
summary_df['구_동'] = summary_df['지번주소'].apply(lambda x: x.split(' ')[1]) + '_' + summary_df['지번주소'].apply(lambda x: x.split(' ')[2])

# %%
summary_df = summary_df.sort_values(['구_동', '계약날짜'], ascending=[True, False]).reset_index(drop=True)
print(summary_df.shape)
summary_df.head()
# Out:
# (864, 17)
#                     지번주소 건물(단지)명    건축년도       계약날짜  부동산유형 소유자  평균_전용면적(㎡)  \
# 0   서울특별시 강남구 개포동 1237-7     한별2  2021.0 2021-06-01   오피스텔  SH   29.665000
# 1   서울특별시 강남구 개포동 1237-7     한별2  2021.0 2021-06-01  연립다세대  SH   29.946667
# 2   서울특별시 강남구 개포동 1216-7     백년빌  2020.0 2020-03-18  연립다세대  SH   26.686000
# 3  서울특별시 강남구 개포동 1195-10     동영빌  2020.0 2020-03-02  연립다세대  SH   28.814667
# 4   서울특별시 강남구 개포동 1199-7   개포백년빌  2019.0 2019-12-19  연립다세대  LH   27.905000
#
#    총_전용면적(㎡)  전용면적_표준편차(㎡)   평균_거래금액(만원)  총_거래금액(만원)  거래금액_표준편차(만원)  최대_층  \
# 0     118.66      0.390000  33565.250000      134261     437.500000     2
# 1     449.20      0.037544  38163.333333      572450      44.185755     6
# 2     400.29      2.367074  30573.333333      458600    2134.651750     5
# 3     432.22      4.855684  31463.333333      471950    4139.637090     5
# 4     390.67      3.070186  28857.142857      404000    3536.722578     5
#
#      평균_단가(만원)  단가_표준편차(만원)  세대_수      구_동
# 0  1131.477759     0.128995     4  강남구_개포동
# 1  1274.376854     0.358219    15  강남구_개포동
# 2  1147.330195    25.484846    15  강남구_개포동
# 3  1097.178201    36.299709    15  강남구_개포동
# 4  1033.367584    37.609677    14  강남구_개포동

# %%
summary_df = summary_df.drop(columns=['구_동'])

# %%
summary_df['지번주소'] = summary_df['지번주소'].apply(lambda x: x.replace('서울특별시 ', ''))
summary_df['소유자'] = summary_df['소유자'].apply(lambda x: x.replace('서울주택도시공사', 'SH'))
summary_df['소유자'] = summary_df['소유자'].apply(lambda x: x.replace('한국토지주택공사', 'LH'))

# %%
summary_df['계약날짜'].describe()
# Out:
# c:\users\max6296\ml\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
# count                     864
# unique                    446
# top       2020-12-28 00:00:00
# freq                       11
# first     2018-01-02 00:00:00
# last      2021-06-22 00:00:00
# Name: 계약날짜, dtype: object

# %%
summary_df.to_excel(bulktrade_basedir + '2018년부터/' + '2018년01월01일부터_2021년06월22일까지_SH_LH_아파트_연립다세대_오피스텔_거래사례_요약본' + '.xlsx', index=False)

# %%
summary_df['지번주소'] = '서울특별시 ' + summary_df['지번주소']

# %%
print_missing_df = summary_df[summary_df['지번주소'].isin(missing_df['지번주소'].unique())]
print(print_missing_df.shape)
# Out:
# (34, 16)

# %%
print_missing_df['지번주소'] = print_missing_df['지번주소'].apply(lambda x: x.replace('서울특별시 ', ''))

# %%
print_missing_df.head()
# Out:
#               지번주소         건물(단지)명    건축년도       계약날짜  부동산유형 소유자  평균_전용면적(㎡)  \
# 10  강남구 역삼동 778-15  NTRAUM YEOKSAM  2020.0 2020-10-08  연립다세대  LH   29.866897
# 19    강동구 길동 140-0            진영빌라  2020.0 2020-11-18  연립다세대  SH   52.517000
# 22    강동구 길동 139-0             강연빌  2019.0 2020-01-13  연립다세대  SH   32.735882
# 25   강동구 상일동 346-0           청년안테나  2018.0 2018-05-16  연립다세대  SH   33.308000
# 40   강동구 성내동 403-0           주함해븐빌  2018.0 2018-08-09  연립다세대  LH   46.403750
#
#     총_전용면적(㎡)  전용면적_표준편차(㎡)   평균_거래금액(만원)  총_거래금액(만원)  거래금액_표준편차(만원)  최대_층  \
# 10     866.14      1.484001  52689.655172     1528000    1335.195231     6
# 19     525.17      3.372289  38805.000000      388050    2048.366558     5
# 22     556.51      3.196616  25911.764706      440500    1889.984244     5
# 25     333.08      4.349538  21410.000000      214100    2283.248174     5
# 40    3712.30      3.194417  38863.750000     3109100    2043.993593     6
#
#       평균_단가(만원)  단가_표준편차(만원)  세대_수
# 10  1767.152811    75.332183    29
# 19   739.482422    12.662096    10
# 22   793.451708    23.307504    17
# 25   644.635261    30.932276    10
# 40   838.926151    26.128681    80

# %%
print_missing_df.to_excel(bulktrade_basedir + '빠진애들.xlsx', index=False)

# %%
inv_df = concat_df[concat_df['소유자'] == '서울주택도시공사']
print(inv_df.shape)
inv_df.head()

# %%
inv_df = inv_df.sort_values(['단가(만원/㎡)'], ascending=False)
print(inv_df.shape)
inv_df.head()

# %%
land_specs_df = pd.read_csv('./prepped_data/land_specs_baseline.csv')
print(land_specs_df.shape)
land_specs_df.head()

# %%
last_df = land_specs_df.drop_duplicates(subset=['지번주소'], keep='last').drop(columns=['년']).reset_index(drop=True)
print(last_df.shape)
last_df.head()

# %%
merge_df = concat_df.merge(last_df, on=['지번주소'])
print(merge_df.shape)
merge_df.head()

# %%
merge_df['도로접면'].value_counts()

# %%
inv_idx = []
for addr in tqdm(concat_df['지번주소'].unique()):
    addr_df = concat_df[concat_df['지번주소'] == addr]
    
    if addr_df['부동산유형'].nunique() > 1:
        [inv_idx.append(i) for i in addr_df.index]

# %%
len(inv_idx)

# %%
yunrip_officetel_df = concat_df.loc[inv_idx]
print(yunrip_officetel_df.shape)
yunrip_officetel_df.head()

# %%
yunrip_officetel_df['지번주소'].nunique()

# %%
for addr in yunrip_officetel_df['지번주소'].unique():
    addr_df = yunrip_officetel_df[yunrip_officetel_df['지번주소'] == addr]
    
    addr_df = addr_df.drop(columns=['도로명', '계약날짜기준_건물연식', '건물연식', '구', '동', '지수적용단가', '평가날짜', '구_동'])
    
    addr_df.to_excel('./연립다세대_오피스텔_같이사례_주소별/' + addr + '.xlsx', index=False)
    
    print(addr_df.shape)
    display(addr_df)

# %%
1131.413262 / 1274.182789

# %%
889.092576 / 1324.609734

# %%
972.300735 / 1370.087336

# %%
1563.467492 / 1615.878107

# %%
1114.762516 / 1222.272522

# %%
648.957633 / 884.445951

# %%
623.745819 / 689.285714

# %%
yunrip_officetel_df.to_excel('SH_LH_거래사례중_연립다세대_오피스텔_같이_있는_사례들.xlsx')

# %%
count = 0
for addr in tqdm(concat_df['구_동'].unique()):
    addr_df = concat_df[concat_df['구_동'] == addr]
    addr_df = addr_df[['지번주소', '건물(단지)명', '건축년도', '건물연식', '계약날짜기준_건물연식', '층', '전용면적(㎡)',
                       '계약날짜', '단가(만원/㎡)', '평가날짜', '지수적용단가', '소유자', '부동산유형'
                      ]]
    addr_df = addr_df.sort_values(['지번주소', '건축년도', '계약날짜', '층', '전용면적(㎡)'])
    addr_df.to_excel(bulktrade_basedir + '동별/' + addr + '.xlsx', index=False)
    
    
    
    
    count += 1

# %%
concat_df['지번주소'].nunique()

# %%
concat_df.head()

# %%
addr_to_inv = []
for addr in tqdm(concat_df['지번주소'].unique()):
    addr_df = concat_df[concat_df['지번주소'] == addr]
    
    inv_30_df = addr_df[
        (addr_df['전용면적(㎡)'] >= 28)
        &(addr_df['전용면적(㎡)'] <= 32)
    ]
    
    inv_80_df = addr_df[
        (addr_df['전용면적(㎡)'] >= 80)
    ]
    
    if (inv_30_df.shape[0] > 1) & (inv_80_df.shape[0] > 1):
        addr_to_inv.append(addr)

# %%
len(addr_to_inv)

# %%
addr_to_inv = []
for addr in tqdm(concat_df['지번주소'].unique()):
    addr_df = concat_df[concat_df['지번주소'] == addr]

    inv_80_df = addr_df[
        (addr_df['전용면적(㎡)'] >= 80)
    ]
    
    if (inv_80_df.shape[0] > 1):
        addr_to_inv.append(addr)

# %%
len(addr_to_inv)

# %%
addr_to_inv

# %%
inv_df = concat_df[concat_df['지번주소'].isin(addr_to_inv)]
print(inv_df.shape)
inv_df.head()

# %%
inv_df

# %%
concat_df['전용면적(㎡)'] = concat_df['전용면적(㎡)'].apply(round)

# %%
concat_df['평균단가'] = concat_df[['지번주소', '건축년도', '전용면적(㎡)', '단가(만원/㎡)']].groupby(['지번주소', '건축년도', '전용면적(㎡)']).transform('mean')['단가(만원/㎡)']

# %%
concat_df['지수적용평균단가'] = concat_df[['지번주소', '건축년도', '전용면적(㎡)', '지수적용단가']].groupby(['지번주소', '건축년도', '전용면적(㎡)']).transform('mean')['지수적용단가']

# %%
concat_df = concat_df.drop(columns=['도로명', '거래금액(만원)', '층', '단가(만원/㎡)', '지수적용단가']).drop_duplicates().reset_index(drop=True)
print(concat_df.shape)
concat_df.head()

# %%
yunrip_selected_df = yunrip_bulk_df[['지번주소', '건축년도', '건물연식', '계약날짜', '계약날짜기준_건물연식', '전용면적(㎡)', '지번별_전용면적별_평균단가', '부동산유형', '소유자']].drop_duplicates().reset_index(drop=True)
print(yunrip_selected_df.shape)
yunrip_selected_df.head()

# %%
yunrip_selected_df = yunrip_selected_df.sort_values(['지번주소']).reset_index(drop=True)
yunrip_selected_df.to_excel(bulktrade_basedir + '최근_6개월_SH_LH_거래사례.xlsx', index=False)

# %%
yunrip_selected_df['지번별_평균단가'] = yunrip_selected_df[['지번주소', '건축년도', '계약날짜', '지번별_전용면적별_평균단가']].groupby(['지번주소', '건축년도', '계약날짜']).transform('mean')['지번별_전용면적별_평균단가']

# %%
yunrip_selected_df = yunrip_selected_df.drop(columns=['전용면적(㎡)', '지번별_전용면적별_평균단가']).drop_duplicates().reset_index(drop=True)
print(yunrip_selected_df.shape)
yunrip_selected_df.head()

# %%
yunrip_selected_df['구'] = yunrip_selected_df['지번주소'].apply(lambda x: x.split(' ')[1])
yunrip_selected_df['동'] = yunrip_selected_df['지번주소'].apply(lambda x: x.split(' ')[2])
yunrip_selected_df['구동'] = yunrip_selected_df['구'] + '_' + yunrip_selected_df['동']

# %%
basedir = './국토교통부_실거래가_공개시스템/땅값분석/'
yunrip_df = pd.read_csv(basedir + 'yunrip_25.csv')
commerce_df = pd.read_csv(basedir + 'commerce_25.csv')
land_df = pd.read_csv(basedir + 'land.csv')

# %%
common_cols = ['시군구', '번지', '용도지역', '도로조건', '계약날짜', '대지면적(㎡)', '거래금액(만원)', '단가(㎡)', '단가(평)', '부동산유형', '건물연식']
common_df = pd.concat([yunrip_df[common_cols], commerce_df[common_cols], land_df[[col for col in land_df.columns if col not in ['지목', '지분구분', '해제사유발생일']]]])
common_df['계약날짜'] = pd.to_datetime(common_df['계약날짜'], format='%Y-%m-%d')
print(common_df.shape)
common_df.head()

# %%
common_df['구'] = common_df['시군구'].apply(lambda x: x.split(' ')[1])
common_df['동'] = common_df['시군구'].apply(lambda x: x.split(' ')[2])

# %%
yunrip_bulk_df['구동'] = yunrip_bulk_df['구'] + '_' + yunrip_bulk_df['동']

# %%
summary_df = pd.DataFrame({'지역':[], '2종일반중간값':[], '집값중간값':[]})

count = 0
for gudong in tqdm(yunrip_selected_df['구동'].unique()):
    gu = gudong.split('_')[0]
    dong = gudong.split('_')[1]
    
    target_gu = gu
    target_dong = dong
    target_purpose = '2종일반'
    
    target_df = common_df[
        (common_df['구'] == target_gu)
        &(common_df['동'] == target_dong)
        &(common_df['용도지역'].str.contains(target_purpose))
        &(common_df['계약날짜'] >= (date_today - pd.DateOffset(months=target_period)))
        &(common_df['단가(㎡)'] > 250)
    ].sort_values(['번지'])
    
    yunrip_target_df = yunrip_selected_df[
        (yunrip_selected_df['구동'] == gudong)
    ]
    
    summary_df.loc[count, '지역'] = gudong
    summary_df.loc[count, '2종일반중간값'] = target_df['단가(㎡)'].median()
    summary_df.loc[count, '집값중간값'] = yunrip_target_df['지번별_평균단가'].median()
    
    count += 1

# %%
summary_df['차이'] = summary_df['집값중간값'] - summary_df['2종일반중간값']

# %%
summary_df = summary_df.sort_values(['차이'], ascending=False).reset_index(drop=True)
print(summary_df.shape)
summary_df.head()

# %%
summary_df

# %%
summary_df.to_excel('지역별_땅값_일괄매매_중간값.xlsx', index=False)

# %%
summary_df = pd.DataFrame({'지역':[], '2종일반평균':[], '집값평균':[]})

count = 0
for gudong in tqdm(yunrip_bulk_df['구동'].unique()):
    gu = gudong.split('_')[0]
    dong = gudong.split('_')[1]
    
    target_gu = gu
    target_dong = dong
    target_purpose = '2종일반'
    
    target_df = common_df[
        (common_df['구'] == target_gu)
        &(common_df['동'] == target_dong)
        &(common_df['용도지역'].str.contains(target_purpose))
        &(common_df['계약날짜'] >= (date_today - pd.DateOffset(months=target_period)))
        &(common_df['단가(㎡)'] > 250)
    ].sort_values(['번지'])
    
    yunrip_target_df = yunrip_selected_df[
        (yunrip_selected_df['구동'] == gudong)
    ]
    
    summary_df.loc[count, '지역'] = gudong
    summary_df.loc[count, '2종일반평균'] = target_df['단가(㎡)'].mean()
    summary_df.loc[count, '집값평균'] = yunrip_target_df['지번별_평균단가'].mean()
    
    count += 1

# %%
summary_df['차이'] = summary_df['집값평균'] - summary_df['2종일반평균']

# %%
summary_df = summary_df.sort_values(['차이'], ascending=False).reset_index(drop=True)
print(summary_df.shape)
summary_df.head()

# %%
summary_df

# %%
summary_df.to_excel('지역별_땅값_일괄매매_평균.xlsx', index=False)

# %%
yunrip_selected_df.head()

# %%
inv_df = yunrip_selected_df[yunrip_selected_df['구동'] == '성동구_마장동']
print(inv_df.shape)
inv_df.head()

# %%
def mean_prices_per_size(df):
    df = df.copy()
    
    df['크기별_평균단가'] = df[['지번주소', '건축년도', '계약날짜', '전용면적(㎡)', '단가(만원/㎡)']].groupby(['지번주소', '건축년도', '계약날짜', '전용면적(㎡)']).transform('mean')['단가(만원/㎡)']
    df['크기별_평균총액'] = df[['지번주소', '건축년도', '계약날짜', '전용면적(㎡)', '거래금액(만원)']].groupby(['지번주소', '건축년도', '계약날짜', '전용면적(㎡)']).transform('mean')['거래금액(만원)']
    df = df[['지번주소', '건축년도', '건물연식', '계약날짜', '계약날짜기준_건물연식', '전용면적(㎡)', '크기별_평균총액', '크기별_평균단가']]
    df = df.drop_duplicates().reset_index(drop=True)
    
    return df

# %%
yunrip_short_df = mean_prices_per_size(yunrip_selected_df)
print(yunrip_short_df.shape)
yunrip_short_df.head()
