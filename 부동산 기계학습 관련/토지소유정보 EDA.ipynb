# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
pd.options.mode.chained_assignment = None  # default='warn'
plt.rcParams['font.family'] = 'Malgun Gothic'
font = {'size': 16}
matplotlib.rc('font', **font)
tqdm.tqdm.pandas()

# %%
# %%time
land_data_df = pd.read_csv('./토지소유정보/AL_11_D161_20210929.csv', encoding='euc-kr')
print(land_data_df.shape)
land_data_df.head()
# Out:
# <string>:2: DtypeWarning: Columns (7,8,9,10,17,23) have mixed types.Specify dtype option on import or set low_memory=False.
# (7347747, 28)
# Wall time: 23.8 s
#                   고유번호       법정동코드           법정동명  대장구분코드 대장구분명 지번  집합건물일련번호  \
# 0  1111010100100010000  1111010100  서울특별시 종로구 청운동       1  토지대장  1         1
# 1  1111010100100010000  1111010100  서울특별시 종로구 청운동       1  토지대장  1         1
# 2  1111010100100010000  1111010100  서울특별시 종로구 청운동       1  토지대장  1         1
# 3  1111010100100010000  1111010100  서울특별시 종로구 청운동       1  토지대장  1         1
# 4  1111010100100010000  1111010100  서울특별시 종로구 청운동       1  토지대장  1         1
#
#   건물동명 건물층명 건물호명 건물실명  공유인일련번호     기준연월  지목코드 지목    토지면적     공시지가 소유구분코드 소유구분  \
# 0    1    1  111    0        8  2021-06     8  대  122.05  4357000     01   개인
# 1    1    1  111    0        9  2021-06     8  대  122.05  4357000     01   개인
# 2    1    1  112    0        5  2021-06     8  대  122.05  4357000     01   개인
# 3    1    2  121    0        5  2021-06     8  대  122.05  4357000     01   개인
# 4    1    2  121    0        6  2021-06     8  대  122.05  4357000     01   개인
#
#   거주지구분코드 거주지구분 국가기관구분코드 국가기관구분 소유권변동원인코드 소유권변동원인     소유권변동일자  공유인수  \
# 0      02   시도내       ZZ   구분없음        03   소유권이전  2015-12-15     0
# 1      02   시도내       ZZ   구분없음        03   소유권이전  2015-12-15     0
# 2      03  읍면동내       ZZ   구분없음        04    주소변경  2017-03-16     0
# 3      03  읍면동내       ZZ   구분없음        03   소유권이전  2012-11-22     0
# 4      03  읍면동내       ZZ   구분없음        03   소유권이전  2012-11-22     0
#
#       데이터기준일자
# 0  2021-09-17
# 1  2021-09-17
# 2  2021-09-17
# 3  2021-09-17
# 4  2021-09-17
