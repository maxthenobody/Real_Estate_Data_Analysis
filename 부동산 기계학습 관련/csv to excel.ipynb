# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
pd.options.mode.chained_assignment = None  # default='warn'
plt.rcParams['font.family'] = 'Malgun Gothic'
font = {'size': 16}
matplotlib.rc('font', **font)
tqdm.tqdm.pandas()

# %%
os.listdir('../../')
# Out:
# ['2018년01월01일부터_2021년06월07일까지_SH_LH_아파트_연립다세대_오피스텔_거래사례.csv',
#  '2018년01월01일부터_2021년06월22일까지_SH_LH_아파트_연립다세대_오피스텔_거래사례_요약본.xlsx',
#  '2019년귀속업종분류코드책자.pdf',
#  '3080_공공재개발_관련',
#  'Data Analysis',
#  'LH',
#  'myidcard.jpg',
#  'myidcard_masked.jpg',
#  'myphoto.jpg',
#  'Presentation',
#  'Projects',
#  'SH',
#  '국토교통부',
#  '기타',
#  '김상범_대표님_프로필_사진.jpg',
#  '등기부등본',
#  '매입대금상한선.xlsx',
#  '매입의향서',
#  '명함.png',
#  '사업수지(실행)-방이동.xlsx',
#  '서울시',
#  '세금',
#  '수익분석',
#  '수협은행_대출상품.jpg',
#  '심의도서',
#  '윤본부장님_사진.jpg',
#  '이스트그룹_대표_조민주_서울시_역세권사업_비교정리표.pdf',
#  '자율주택정비사업 관련 자료',
#  '자율주택정비사업 관련 자료.zip',
#  '주간업무보고',
#  '지구단위계획',
#  '지음_건축사_대표_김영삼_사진.png',
#  '지주공동사업계획서',
#  '청년주택사업.zip',
#  '카드사용내역서',
#  '캐드관련',
#  '특약사항.docx',
#  '한국부동산원',
#  '한별_사업자등록증.jpg',
#  '한회장님_사진.jpg',
#  '할일']

# %%
data_df = pd.read_csv('../../2018년01월01일부터_2021년06월07일까지_SH_LH_아파트_연립다세대_오피스텔_거래사례.csv')
print(data_df.shape)
data_df.head()
# Out:
# (14793, 14)
#    Unnamed: 0                   지번주소         도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  \
# 0          62  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.39     28300
# 1          63  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.39     28300
# 2          64  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.46     28400
# 3          65  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.46     28400
# 4          66  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.55     28500
#
#    층    건축년도  계약날짜기준_건물연식        계약날짜     단가(만원/㎡)  건물연식  부동산유형 소유자
# 0  3  2020.0          0.0  2020-03-02  1114.612052   1.0  연립다세대  SH
# 1  2  2020.0          0.0  2020-03-02  1114.612052   1.0  연립다세대  SH
# 2  3  2020.0          0.0  2020-03-02  1115.475255   1.0  연립다세대  SH
# 3  2  2020.0          0.0  2020-03-02  1115.475255   1.0  연립다세대  SH
# 4  3  2020.0          0.0  2020-03-02  1115.459883   1.0  연립다세대  SH

# %%
data_df = data_df.drop(columns=['Unnamed: 0'])
print(data_df.shape)
data_df.head()
# Out:
# (14793, 13)
#                     지번주소         도로명 건물(단지)명  전용면적(㎡)  거래금액(만원)  층    건축년도  \
# 0  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.39     28300  3  2020.0
# 1  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.39     28300  2  2020.0
# 2  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.46     28400  3  2020.0
# 3  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.46     28400  2  2020.0
# 4  서울특별시 강남구 개포동 1195-10  논현로12길 3-1     동영빌    25.55     28500  3  2020.0
#
#    계약날짜기준_건물연식        계약날짜     단가(만원/㎡)  건물연식  부동산유형 소유자
# 0          0.0  2020-03-02  1114.612052   1.0  연립다세대  SH
# 1          0.0  2020-03-02  1114.612052   1.0  연립다세대  SH
# 2          0.0  2020-03-02  1115.475255   1.0  연립다세대  SH
# 3          0.0  2020-03-02  1115.475255   1.0  연립다세대  SH
# 4          0.0  2020-03-02  1115.459883   1.0  연립다세대  SH

# %%
# %%time
data_df.to_excel('../../2018년01월01일부터_2021년06월07일까지_SH_LH_아파트_연립다세대_오피스텔_거래사례.xlsx', index=False)
# Out:
# Wall time: 3.54 s
