# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import math
from tqdm import tqdm
import requests
from urllib.parse import urlparse
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
import datetime
from sklearn.preprocessing import quantile_transform
pd.options.mode.chained_assignment = None  # default='warn'
import gc
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
font_path = './NanumFontSetup_TTF_BARUNGOTHIC/NanumBarunGothic.ttf'
import matplotlib.font_manager as fm
fontprop = fm.FontProperties(fname=font_path, size=18)
import shap
import seaborn as sns

# %%
shap_summary_df = pd.read_csv('./Training/training_data_ver_16/shap_summary.csv', index_col=[0])

# %%
print(shap_summary_df.shape)
shap_summary_df.head()
# Out:
# (399, 6)
#            model_0_shap_summary  model_1_shap_summary  model_2_shap_summary  \
# 전용면적                  39.238704             37.367223             40.471796
# 층                      4.472709              4.795792              5.369097
# 건축년도                  47.382718             49.343322             49.110734
# 전용면적_mean              3.089907              2.201902              2.586846
# 전용면적_min               3.705040              2.832465              3.060137
#
#            model_3_shap_summary  model_4_shap_summary  shap_summary_mean
# 전용면적                  38.169571             39.531332          38.955725
# 층                      4.725520              4.664758           4.805575
# 건축년도                  48.584290             47.759808          48.436175
# 전용면적_mean              2.889645              2.403864           2.634433
# 전용면적_min               3.657026              3.089195           3.268773

# %%
vif_df = pd.read_csv('./Production_Prep/vif.csv', index_col=[0])

# %%
print(vif_df.shape)
vif_df.head()
# Out:
# (399, 399)
#                 전용면적         층      건축년도  전용면적_mean   전용면적_min   전용면적_max  \
# 전용면적             inf  2.409987  5.170410  23.687030  12.158034  10.557539
# 층           2.409987       inf  2.508320   2.532646   2.201143   2.697265
# 건축년도        5.170410  2.508320       inf   6.352439   5.533573   4.915367
# 전용면적_mean  23.687030  2.532646  6.352439        inf  24.036943  18.304363
# 전용면적_min   12.158034  2.201143  5.533573  24.036943        inf   7.118979
#
#                건물나이  year_linear  month_sin  month_cos     xnorm     ynorm  \
# 전용면적       2.087508     3.307804   1.000495   1.000029  1.002237  1.078596
# 층          1.768481     2.170612   1.000227   1.000004  1.003013  1.053358
# 건축년도       3.483416     8.197806   1.000861   1.000007  1.000777  1.087516
# 전용면적_mean  2.197115     3.661590   1.000565   1.000024  1.002364  1.082129
# 전용면적_min   2.044251     3.347569   1.000607   1.000030  1.001188  1.074863
#
# ...

# %%
cols_to_drop = []
cols_already_tested = []
for col in tqdm(vif_df.columns):
    col_series = vif_df[col]
    
    over_10 = [idx for idx in col_series.index if (col_series[idx] > 5)&(idx not in cols_already_tested)&(idx not in cols_to_drop)]
    
    if over_10 != []:
        shap_over_10_series = shap_summary_df['shap_summary_mean'].loc[over_10]

        max_series = shap_over_10_series[shap_over_10_series != shap_over_10_series.max()]
        
        for idx2 in max_series.index:
            cols_to_drop.append(idx2)
    
    cols_already_tested.append(col)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 399/399 [00:01<00:00, 352.81it/s]

# %%
len(cols_to_drop)
# Out:
# 25

# %%
cols_to_drop = list(set(cols_to_drop))

# %%
len(cols_to_drop)
# Out:
# 25

# %%
cols_to_drop
# Out:
# ['전용면적_max',
#  '체육공원',
#  '총주차수',
#  '4대문안',
#  '전용면적_min',
#  '총용적률연면적',
#  '전용면적',
#  '층median',
#  '중요시설물보호지구(공항)',
#  '총건축면적',
#  '철근콘크리트구조_fraction',
#  '건축년도',
#  '상대보호구역',
#  '지구단위계획구역',
#  '총연면적',
#  '호수대비연면적',
#  '상대정화구역',
#  '전용면적_mean',
#  '토지이동상황',
#  '주_용도_공동주택_fraction',
#  '공원자연환경지구',
#  '토지면적',
#  '층max',
#  '총호수',
#  '광로2류(폭_50M~70M)']

# %%
vif_result_df = pd.DataFrame()
vif_result_df['cols_to_drop'] = cols_to_drop

# %%
vif_result_df
# Out:
#           cols_to_drop
# 0             전용면적_max
# 1                 체육공원
# 2                 총주차수
# 3                 4대문안
# 4             전용면적_min
# 5              총용적률연면적
# 6                 전용면적
# 7              층median
# 8        중요시설물보호지구(공항)
# 9                총건축면적
# 10   철근콘크리트구조_fraction
# 11                건축년도
# 12              상대보호구역
# 13            지구단위계획구역
# 14                총연면적
# 15             호수대비연면적
# 16              상대정화구역
# 17           전용면적_mean
# 18              토지이동상황
# 19  주_용도_공동주택_fraction
# 20            공원자연환경지구
# 21                토지면적
# 22                층max
# 23                 총호수
# 24     광로2류(폭_50M~70M)

# %%
vif_result_df.to_csv('./Production_Prep/vif5.csv', index=False)
